# %% [markdown]
# # LDAの動作確認 part 3 (回答文)

# %% [markdown]
# 続いて、回答文に対するLDAの動作確認を行いました。

# %% [markdown]
# ### 日本語のテストデータを抽出

# %%
import os
import pandas

def replace_newline(val):
    return val.replace('\r', '').replace('\n', '')

n_samples = 100

csvDir = "../learning/tests/engine/fixtures/"
csvFile = "test_daikin_conversation.csv"
csvPath = os.path.join(csvDir, csvFile)

csvTemp = pandas.read_csv(csvPath, encoding='Shift_JIS')
csvData = csvTemp.drop_duplicates(subset=['answer_id'])

testData = csvData.ix[0:n_samples-1, ['question', 'answer_body']]
testData
# Out:
#                                              question  \
# 0      Outlook2010にてメールを送信する際、自分宛のメールをBCCで運用したいのですが？
# 1                  Outlook2010にて、メールの署名の作り方が教えてください。
# 2     Thunderbirdのテンプレートメールと同等の機能はOutlook2010にありますか？
# 3   Thunderbirdの場合、「宛先」に姓を入れるとアドレス帳の候補者が出ましたが、Outl...
# 4   Outlookにて、メールアドレス検索の時にアドレス一覧をいちいち選択するのがわずらわしいで...
# 5                       Outlook2010にて、メールの再編集は可能ですか？
# 6                      Outlook2010にて、未読メールを探すのが大変です。
# 7          ThunderbirdとOutlook2010では送信済トレイの違いはありますか？
# 8            Outlook2010にて、メールに添付するファイルに容量の制限はありますか？
# 9   Outlook2010にて、長期休暇など長期でメールの返事ができない際、メールの自動応答をさ...
# 10      Thunderbirdと同様に返信メールにインデントを付けたいのですが、可能でしょうか。
# 11       Outlookにて、メールサーバとローカルフォルダのメールを一括で検索可能でしょうか。
# 12             Outlook2010にて、メールの署名のvCardは使用可能でしょうか。
# 13  Outlookにて、他のユーザーが作成した個人アドレス帳を別のOutlookでインポート/エ...
# 14             Outlook2010にて、個人アドレス帳に写真を入れることができますか。
# 15             Thunderbirdと同様にメールの受信を通知させる事は可能でしょうか。
# 16           Outlookにてメール本文の１行に表示される文字数を変更する事は可能ですか。
# 17  Thunderbirdからアドレス帳をエクスポートして、Outlook2010にインポートを...
# 18  Outlookにて、『Drafts(下書き)』、『Deleted Items(削除済みアイテ...
# 19  Outlook2010にて、アドレス帳から宛先を探す際に、姓名で検索しても正しく結果が表示さ...
# 20  Outlook2010にて、利用を初めた時から、Office2000を使用して終了した時に必...
# 21  Outlook2010にて、メーリングリストを差出人に設定しメールを送信すると、送信エラーの...
# 22  Outlookにて、『名前の確認（簡易検索）』を行ったのですが、存在するはずのユーザが検索結...
# 23  Outlook2010をインストールしてから、フォルダの検索画面を表示しようとすると見慣れな...
# 24  Thunderbirdより移行したローカルメールを再利用（返信）してメールを送信するとエラー...
# 25  Outlook2010にて、必要なメールが迷惑メールフォルダ(Junk Email)に振り分...
# 26  Outlook2010をインストール後、以前IMEに登録していた辞書の内容が消えてしまいました。
# 27  Thunderbirdから手順書に沿ってローカルメールの移行を行っているが、途中でエラーが発...
# 28  Outlook2010にて、画像付(HTML形式)のメールを受信したのですが、プレビュー画面...
# 29  Outlook2010にて、画像付(HTML形式)のメールを印刷したのですが、画像が印刷され...
# ..                                                ...
# 69  Outlook2010にてメールを検索したが検索結果の上に”インデックスを作成中…”メッセー...
# 70        Outlook2010にて、明らかにメールが表示されているのに検索結果が表示されない。
# 71        端末をリプレイスしているが、Outlookの仕分けルールは移行されるのか教えて欲しい。
# 72                       Outlook2010に届く迷惑メールを受信拒否したい。
# 73    Outlook2010にて、正常なメールがスパムフォルダに届く、受信トレイに届くようにしたい。
# 74      Outlook2010にて、部門用の連絡先グループを作成したので、他メンバーと共有したい。
# 75        Outlook2010にて、メールをプレビューする画面が消えた。戻し方を教えて欲しい。
# 76  Outlook2010にて、連絡先にThunderbirdから移行した個人アドレス帳が表示さ...
# 77  Ouｔlook2010の受信トレイに表示される”件名”フィールドを操作を誤って削除してしまっ...
# 78          Outlook2010にて、メールを送信したが、送信トレイに保存され送信できない。
# 79         Outlook2010にて、ローカルフォルダを作成したいが、対応方法を教えてほしい。
# 80  端末にOffice365のメールアカウントを作成しているが、”暗号化に失敗しました。”のメッ...
# 81  Outlook2010にて、アドレス帳のアドレス一覧に表示されている中に不要なアドレス帳が表...
# 82                          Outlook2010のインストール媒体が欲しい。
# 83        イントラHPから「Webメール」-「OWA」をクリックしても、最初画面が表示されない。
# 84          端末が新しくなったため、Outlook2010を設定したいが手順書を教えて欲しい。
# 85                           出張先に自分の端末が無いが、メールを利用したい。
# 87         Outlook2010にて、同期の失敗メールが受信されるが、対応方法を教えて欲しい。
# 88  Outlook2010のメールアカウント設定完了したが、Outlookを起動すると「構成の進...
# 89  Outlook2010のグローバルアドレス一覧にて、”名前”かつ”場所”や”拠点”にて検索す...
# 90          Outlook2010の受信トレイに未読メールが存在するが、メールが表示されない。
# 91  社外から添付ファイル付きメールを送信して頂くことになったが、メール受信できる容量制限を教えて...
# 92      Outlook2010にて、メール本文にURLを記載し送信すると本文のURLが改行される。
# 93  Outlook2010を起動すると、ライセンス認証されていないとメッセージが表示される。ライ...
# 94  Outlook2010のアドレス帳に”（モバイル）”と付くアドレス帳が多数表示される。表示さ...
# 95  携帯のメールアドレスにてメーリングリストを作成し、携帯からメール送信したい。対応可能か教えて...
# 96        Outlook2010の英語版を利用しているが、ダイキン設定は存在するか教えて欲しい。
# 97  Ouｔlook2010にて、 アカウントを設定したが、Ouｔlookを起動すると前の方のメー...
# 98  Outlook2010起動時、McAfeeのアドインメッセージが表示された、「はい」と「いい...
# 99  Outlook2010にて、メール本文作成時に数字を入力後、文章を入力しEnterを実行する...
#
#                                           answer_body
# 0   Thunderbirdではメールを作成した際、自動的にBCCに自分のメールアドレスが設定され...
# 1   署名の作り方については『【Outlook2010操作マニュアル 応用編】 署名の作成』を参照...
# 2   Outlook2010にはThunderbirdのテンプレートと同様の機能はありません。\r...
# 3   Outlook2010では、過去に入力したアドレスを記憶するオートコンプリート機能がついてい...
# 4   可能です。\r方法については『【Outlook2010操作マニュアル 応用編】 アドレス検索...
# 5   方法については『【Outlook2010操作マニュアル 基本編】 送信済メールの再利用（メー...
# 6   方法については『【Outlook2010操作マニュアル 応用編】 検索フォルダ―(未読のメー...
# 7   Outlook2010とThunderbirdでは送信済トレイのフォルダ名が異なります。\r...
# 8          添付ファイルの容量の制限は10MBです。\r（メーリングリストも同様になります。）
# 9   Outlook2010には自動応答機能は存在しますが、原則利用しないでください。\r\r自動...
# 10  可能です。 設定方法については『【Outlook2010操作マニュアル 応用編】 返信メール...
# 11  可能です。 検索方法については『【Outlook2010操作マニュアル 応用編】 メールの検...
# 12            海外とのやり取りで文字化けが発生する可能性があるため使用は禁止しております。
# 13  可能です。 方法については『【Outlook2010操作マニュアル 応用編】 ユーザー間で個...
# 14  自分の顔写真は入れることができます。\r自分の顔写真以外は絶対に使用しないで下さい。\r※自...
# 15  可能です。\r設定方法は下記をご参照ください。\r【Outlook2010操作マニュアル 応...
# 16  下記手順にて設定が可能です。\r※この設定はテキスト形式で作成・送信したメッセージが、送信先...
# 17  Thuderbirdのアドレス帳にFAXが登録されている場合、FAXも1件と扱われ、2件のデ...
# 18  Outlook2010の初期設定では『Drafts(下書き)』、『(削除済みアイテム)』、『...
# 19   アドレス検索にて、『その他のフィールド』が選択されているか確認してください。『名前のみ』が...
# 20  下記のエラーが発生した場合は、『OK』を押下し、終了してください。\rデータの破損などの実害...
# 21  新メールシステムでは差出人にメーリングアドレスを設定することはできません。\r業務上必要な場...
# 22  検索対象の宛先に『Daikin Directory』を追加してください。\r設定方法について...
# 23  Outlook2010の設定を実施した際に、WindowsSearchをインストールを行った...
# 24  Thunderbirdから移行したメールを再利用（返信）する場合は、既に入力されている差出人...
# 25  以下の設定を行うことにより、迷惑メールに届いていたメールを受信フォルダ(inbox)に移動し...
# 26  登録単語が正常に引継できていないことが原因だと考えられます。\r以下の手順で『手動での登録単...
# 27  Thunderbirdのローカルメールの容量が50GB以上の場合、一括でローカルメールを移行...
# 28  ダイキン設定では受信したメールをテキスト形式にて表示しております。\r画像付（HTML形式)...
# 29  画像付(HTML形式)のメールを印刷する場合、一度、HTML形式でメールを表示させてから印刷...
# ..                                                ...
# 69  ”インデックスを作成中…”メッセージは、Outlookの検索機能にて利用されます。\rメール...
# 70  Outlookのインデックスが壊れてるため、検索できない状態になっています。\r\r以下UR...
# 71  Outlookの仕分けルールを確認し仕分けルールの名前にクライアントルールと記載があれば、端...
# 72  迷惑メールの受信拒否はメールサーバ上を対応しています。\rOutlookに届く迷惑メールを拒...
# 73  Outlookのスパムフォルダに届く、正常メールを受信トレイに届くように設定する場合は以下手...
# 74  Outlookにて、作成された連絡先グループを共有化される場合は、以下手順を実施ください。\...
# 75  以下手順を実施ください。\r\r(手順)\r１．Outlookを起動ください。\r２．「表示...
# 76  Outlookへ個人アドレス帳を移行されている場合は、以下手順を実施ください。\r\r（手順...
# 77  以下手順を実施ください。\r\r（手順）\r１．Outlookを起動ください。\r２．受信ト...
# 78  以下手順を実施しOutlookにてメールサーバに接続されているか確認ください。\r\r（手順...
# 79  以下手順を実施ください。\r\r（手順）\r１．Outlookを起動ください。\r２．Out...
# 80  メールのパスワードを更新されていない場合は、以下3点を確認ください。\r\r（手順）\r１．...
# 81  Outlookのアドレス帳から個人アドレス帳の表示を削除される場合は、以下l手順を実施くださ...
# 82  Outlook2010のインストール媒体は、関係各所のIT担当者へ恒久版のDVDをお渡しして...
# 83  以下手順を実施ください。\r\r（手順）\r１．IE11を起動してください。\r２．IE11...
# 84  手順書はダイキンイントラHPに３種類ありますので、以下URLから手順を確認ください。\rht...
# 85  ご自分の端末が無い場合は、OWAからメールを利用ください。\r以下手順を実施ください。\r\...
# 87  同期の失敗メールは、メールサーバと同期を取る際、あるタイミングで失敗したためのメールです。\...
# 88  office2010に問題があるので、officeの修復を以下手順を実施ください。\r\r（...
# 89  グローバルアドレス一覧では、拠点や場所の情報がないため、検索できません。\rDaikin D...
# 90  以下手順を実施ください。\r\r（手順）\r１．Outlookを起動ください。\r２．Out...
# 91  ダイキン社内間であれば、メール送受信の容量制限は10MBになります。\rメール本文も含めた容...
# 92              URLのパスを””、<>で囲っていただくことで、改善されるか確認ください。
# 93  office2010のインストラ媒体からOutlookをインストールされている場合は、DVD...
# 94  アドレス帳に表示される（モバイル）は、個人アドレス帳を作成した際に、同時に作成されるため、削...
# 95  メーリングリストはダイキンのメールアドレス以外は原則禁止されています。\r必要な場合は理由を...
# 96  ダイキン設定は日本語、英語関係ありません。\rOutlook2010のインストールDVDに入...
# 97  前の方のメールプロファイルが残っているため、発生しております。\rメールプロファイルを削除す...
# 98  McAfeeのアドインは、利用する必要があるので「いいえ」を選択ください。\r誤って、「はい...
# 99  以下手順を実施ください。\r\r（手順）\r１．Outlookを起動ください。\r２．Out...
#
# [99 rows x 2 columns]

# %% [markdown]
# ### MeCab を準備

# %%
import MeCab
meCab = MeCab.Tagger('-Owakati -d /usr/local/lib/mecab/dic/ipadic')

# %% [markdown]
# ### コーパスを作成

# %%
corpus = []
origin_text = []

for i in range(0, n_samples):
    try:
        answer_body = testData.ix[i, 'answer_body']
    except:
        continue
    answer_body = replace_newline(answer_body)
    parsed_text = meCab.parse(answer_body)
    corpus.append(replace_newline(parsed_text))
    origin_text.append(replace_newline(answer_body))

# %%
n_samples = len(corpus)
print('Parsed answer (count=%d):' % n_samples)

# 最初の１０件を表示
for i in range(0, 10):
    #for debug
    print('#%d=[%s]' % (i, corpus[i]))
# Out:
# Parsed answer (count=99):
# #0=[Thunderbird で は メール を 作成 し た 際 、 自動的 に BCC に 自分 の メールアドレス が 設定 さ れ て い まし た が 、 Outlook 2010 より BCC に 自動的 に 自分 の メールアドレス が 設定 さ れ なく なり まし た 。 自分 自身 が 送信 し た メール に つき まし て は 、 『 送信 済み トレイ ( Sent Items )』 に 格納 さ れ て おり ます ので 、 そちら で ご 確認 ください 。 また 、 Outlook 2010 で の BCC の 設定 方法 に つき まし て は こちら を ご 確認 ください 。 【 手順 】 １ ． メール 作成 画面 の リボン から 『 オプション 』 を 選択 し ます 。 ２ ． 『 BCC 』 を クリック し ます 。 ３ ． 『 BCC 』 の 項目 が 、 『 CC 』 の 下 に 表示 さ れ ます 。 　 　 補足 一 度 、 設定 する と 本 設定 は 常に 有効 に なり ます 。 その 都度 設定 する 必要 は あり ませ ん 。 ]
# #1=[署名 の 作り方 について は 『 【 Outlook 2010 操作 マニュアル 応用 編 】 署名 の 作成 』 を 参照 し て ください 。 http :// www . intra . daikin . co . jp / office 365 / ol 2010 / Applied . html ? cid = C 008 【 手順 】 １ ． リボン から 『 ファイル 』 を 選択 し 、 『 オプション 』 を 押下 し ます 。 ２ ． 『 メール 』 を 押下 し ます ３ ． 『 署名 』 ボタン を 押下 し ます 。 ４ ． 『 新規 作成 』 ボタン を 押下 し ます 。 ５ ． 署名 の 名前 を 入力 し ます 。 （ 分かり やすい 名前 を つけ て ください 。 ） ６ ． 『 OK 』 ボタン を 押下 し ます 。 ７ ． 作成 し た 署名 を 選択 し ます 。 （ 既に 作成 さ れ て いる 場合 は 、 編集 し たい 署名 を 選択 ) ８ ． 署名 の 内容 を 入力 し ます 。 ９ ． 新しい メッセージ を 作成 する 際 に 挿入 さ れる 署名 を 選択 し ます 。 １ ０ ． 返信 / 転送 を 行う 際 に 挿入 さ れる 署名 を 選択 し ます 。 １ １ ． 『 OK 』 ボタン を 押下 し ます 。 ]
# #2=[Outlook 2010 に は Thunderbird の テンプレート と 同様 の 機能 は あり ませ ん 。 類似 機能 の 『 【 Outlook 2010 操作 マニュアル 基本 編 】 送信 済 メール の 再 利用 （ メール の 再送 ） 』 を ご 利用 ください 。 http :// www . intra . daikin . co . jp / office 365 / ol 2010 / Basic . html ? cid = B 007 【 手順 】 １ ． 再 利用 し たい メール を ダブル クリック し ます 。 ２ ． 『 メッセージ 』 リボン から 『 アクション 』 の ▼ を 押下 し 、 『 この メッセージ を 再送 』 を 押下 し ます 。 メール 編集 画面 が 表示 さ れ ます ので 、 以降 の 操作 は 『 メール の 送信 』 を 参照 し メール を 送信 し て ください 。 ※ 古い メール を 再 利用 （ 再送 ） する と 、 送信 エラー が 発生 する こと が あり ます ので 、 　 その 場合 は 、 再 利用 （ 再送 ） で は なく 新規 作成 を し て 下さい 。 ]
# #3=[Outlook 2010 で は 、 過去 に 入力 し た アドレス を 記憶 する オートコンプリート 機能 が つい て い ます 。 この 為 、 アドレス を 途中 まで 入力 する と アドレス 候補 が 自動的 に 表示 さ れ ます 。 ※ オートコンプリート 機能 に つき まし て は 、 よく 利用 し て いる メールアドレス が 表示 さ れ ます が 、 意図 的 に 記憶 さ せる こと は でき ませ ん 。 あくまで 補助 機能 として お 使い ください 。 また 、 名前 検索 を 利用 する こと により 、 アドレス 帳 から 相手 の メールアドレス を 簡易 検索 する こと が でき ます 。 名前 検索 に つき まし て は 『 【 Outlook 2010 操作 マニュアル 基本 編 】 宛先 の 簡易 検索 ( 名前 の 確認 )』 を 参照 し て ください 。 http :// www . intra . daikin . co . jp / office 365 / ol 2010 / Basic . html ? cid = B 006 ]
# #4=[可能 です 。 方法 について は 『 【 Outlook 2010 操作 マニュアル 応用 編 】 アドレス 検索 ( デフォルト の 検索 先 に 指定 し たい アドレス 帳 を 指定 )』 を 参照 し て ください 。 http :// www . intra . daikin . co . jp / office 365 / ol 2010 / Applied . html ? cid = C 003 【 手順 】 １ ． リボン から 『 ホーム 』 を 選択 し ます 。 ２ ． 『 アドレス 帳 』 を 押下 し ます 。 ３ ．[ メニュー ]→[ ツール ]→[ オプション ] を 押下 し ます 。 ４ ． 『 デフォルト の 検索 先 に 指定 し たい アドレス 帳 』 を 選択 し ます 。 ５ ． 『 OK 』 ボタン を 押下 し ます 。 ]
# #5=[方法 について は 『 【 Outlook 2010 操作 マニュアル 基本 編 】 送信 済 メール の 再 利用 （ メール の 再送 ） 』 を 参照 し て ください 。 http :// www . intra . daikin . co . jp / office 365 / ol 2010 / Basic . html ? cid = B 007 【 手順 】 １ ． 再 利用 し たい メール を ダブル クリック し ます 。 ２ ． 『 メッセージ 』 リボン から 『 アクション 』 の ▼ を 押下 し 、 『 この メッセージ を 再送 』 を 押下 し ます 。 ３ ． メール 編集 画面 が 表示 さ れ ます ので 、 以降 の 操作 は 『 メール の 送信 』 を 参照 し メール を 送信 し て ください 。 ※ 古い メール を 再 利用 （ 再送 ） する と 、 送信 エラー が 発生 する こと が あり ます ので 、 　 その 場合 は 、 再 利用 （ 再送 ） で は なく 新規 作成 を し て 下さい 。 ]
# #6=[方法 について は 『 【 Outlook 2010 操作 マニュアル 応用 編 】 検索 フォルダ ―( 未読 の メール の フォルダ を 作成 する )』 を 参照 し て ください 。 http :// www . intra . daikin . co . jp / office 365 / ol 2010 / Applied . html ? cid = C 007 【 手順 】 １ ． 検索 フォルダ ― を 右 クリック し 、 『 新しい 検索 フォルダ ― 』 を 押下 し ます 。 ２ ． 『 未読 の メール 』 を 選択 し ます 。 ３ ． 『 OK 』 ボタン を 押下 し ます 。 ４ ． 『 未読 の メール 』 検索 フォルダー が 作成 さ れ て いる こと を 確認 し ます 。 ※ 検索 フォルダ ― で は 未読 の メール 以外 に も 、 フラグ の 設定 さ れ た メール など 様々 な 条件 の メール を 検索 条件 と する こと が でき ます 。 ※ 検索 フォルダ ― に 表示 さ れ て いる メール は 検索 結果 と なり ます ので 、 メール は 元 の フォルダ から 移動 は し て おり ませ ん 。 ]
# #7=[Outlook 2010 と Thunderbird で は 送信 済 トレイ の フォルダ 名 が 異なり ます 。 Thunderbird の 送信 済 メール について は 『 Sent 』 フォルダ に 保存 さ れ て おり ます 。 Outlook 2010 で は 『 Sent Items ( 送信 済み アイテム )』 に 保存 さ れ ます 。 ]
# #8=[添付 ファイル の 容量 の 制限 は 10 MB です 。 （ メーリングリスト も 同様 に なり ます 。 ） ]
# #9=[Outlook 2010 に は 自動 応答 機能 は 存在 し ます が 、 原則 利用 し ない で ください 。 自動 応答 の 設定 を 行っ た 場合 、 ユーザ 宛 に 送信 さ れ て き た [ SPAM メール ] に対して も 自動 で メール を 送信 し て しまい 、 セキュリティ 上 問題 が あり ます 。 ただし 、 業務 上 やむを得ない 場合 、 別途 こちら まで ご 相談 ください 。 http :// www . intra . daikin . co . jp / office 365 / inquiry / install - prb . html ]

# %% [markdown]
# ### TFベクターを作成

# %%
from time import time
from sklearn.feature_extraction.text import CountVectorizer

n_features = 1000
print("Extracting tf features for LDA...")
tf_vectorizer = CountVectorizer(max_df=0.66,
                                min_df=1,
                                max_features=n_features # 特徴語の上限
                                )
t0 = time()
tf = tf_vectorizer.fit_transform(corpus)
print("done in %0.3fs." % (time() - t0))
# Out:
# Extracting tf features for LDA...
# done in 0.007s.

# %% [markdown]
# ### 特徴語を確認

# %%
tf_feature_names = tf_vectorizer.get_feature_names()
len(tf_feature_names)
# Out:
# 768

# %%
tf_feature_names
# Out:
# ['002',
#  '003',
#  '006',
#  '007',
#  '008',
#  '009',
#  '01',
#  '012',
#  '013',
#  '014',
#  '08',
#  '10',
#  '102817357',
#  '11',
#  '132',
#  '15',
#  '20',
#  '2000',
#  '2010',
#  '2014',
#  '205',
#  '27',
#  '28',
#  '365',
#  '400',
#  '413',
#  '413３',
#  '50',
#  'and',
#  'application',
#  'applied',
#  'aspx',
#  'basic',
#  'bat',
#  'bcc',
#  'big',
#  'cannotconnect',
#  'cc',
#  'cid',
#  'co',
#  'com',
#  'csv',
#  'daikin',
#  'data',
#  'deleted',
#  'dic',
#  'directory',
#  'dki',
#  'doc',
#  'docthunderbird',
#  'documents',
#  'drafts',
#  'dvd',
#  'editprofile',
#  'email',
#  'en',
#  'excel',
#  'excenge',
#  'exchange',
#  'exe',
#  'faq',
#  'fax',
#  'files',
#  'folders',
#  'for',
#  'gb',
#  'grp',
#  'ha',
#  'help',
#  'hp',
#  'html',
#  'http',
#  'id',
#  'ie',
#  'imap',
#  'ime',
#  'imjp',
#  'inbox',
#  'index',
#  'inquiry',
#  'install',
#  'intra',
#  'it',
#  'item',
#  'items',
#  'ja',
#  'jp',
#  'js',
#  'junk',
#  'lan',
#  'ldap',
#  'ldapmanual',
#  'light',
#  'local',
#  'loginservlet',
#  'mail',
#  'mailstore',
#  'manual',
#  'mb',
#  'mcafee',
#  'mdb',
#  'microsoft',
#  'mozilla',
#  'msi',
#  'net',
#  'numlock',
#  'off',
#  'office',
#  'ok',
#  'ol',
#  'on',
#  'ost',
#  'outlook',
#  'ouｔlook',
#  'owa',
#  'pac',
#  'pack',
#  'pc',
#  'pdf',
#  'portal',
#  'prb',
#  'program',
#  'proxy',
#  'pst',
#  'purchase',
#  'pwchg',
#  'pｓｔ',
#  'rfc',
#  'sakaguchi',
#  'sakaguchiyo',
#  'securepremium',
#  'sent',
#  'sentitems',
#  'service',
#  'settings',
#  'sp',
#  'spam',
#  'startupmanual',
#  'storelocalmailshiftmanual',
#  'tab',
#  'taro',
#  'thuderbird',
#  'thunderbird',
#  'unyo',
#  'url',
#  'users',
#  'vbs',
#  'vpn',
#  'web',
#  'webmtn',
#  'windows',
#  'windowssearch',
#  'www',
#  'xx',
#  'xxxx',
#  'xxxxx',
#  'yoshihiko',
#  'zip',
#  'あい',
#  'あくまで',
#  'あらかじめ',
#  'あり',
#  'ある',
#  'あれ',
#  'いいえ',
#  'いき',
#  'いただく',
#  'いただけ',
#  'いただける',
#  'いる',
#  'おこなっ',
#  'おり',
#  'お待ち',
#  'お手数',
#  'お願い',
#  'から',
#  'くだ',
#  'くだい',
#  'くる',
#  'ここ',
#  'こちら',
#  'こと',
#  'この',
#  'これ',
#  'ごと',
#  'さえ',
#  'しまい',
#  'しまう',
#  'すべて',
#  'する',
#  'せる',
#  'そちら',
#  'その',
#  'そのまま',
#  'その他',
#  'それ',
#  'たい',
#  'ただし',
#  'ため',
#  'たら',
#  'だけ',
#  'つい',
#  'つき',
#  'つけ',
#  'てる',
#  'でき',
#  'できる',
#  'でしょ',
#  'です',
#  'でも',
#  'という',
#  'とき',
#  'として',
#  'とも',
#  'どうしても',
#  'ない',
#  'なかっ',
#  'なく',
#  'なけれ',
#  'なっ',
#  'など',
#  'なり',
#  'なる',
#  'なれ',
#  'について',
#  'にて',
#  'によって',
#  'により',
#  'に対して',
#  'に従い',
#  'ので',
#  'のみ',
#  'はい',
#  'はずし',
#  'ほど',
#  'まし',
#  'ませ',
#  'また',
#  'または',
#  'まで',
#  'もどる',
#  'もの',
#  'やすい',
#  'やむを得ない',
#  'やり取り',
#  'よう',
#  'よく',
#  'より',
#  'られ',
#  'れる',
#  'わから',
#  'アイコ',
#  'アイテム',
#  'アカウント',
#  'アクション',
#  'アド',
#  'アドレス',
#  'イン',
#  'インストラ',
#  'インストール',
#  'インターネット',
#  'インデックス',
#  'インデント',
#  'イントラ',
#  'インフラ',
#  'インポート',
#  'インライン',
#  'ウィンドウ',
#  'エクスポート',
#  'エラー',
#  'エラーメッセージ',
#  'オフライン',
#  'オプション',
#  'オート',
#  'オートコンプリート',
#  'オートフォマット',
#  'カタカナ',
#  'カナ',
#  'カンマ',
#  'キャッシュ',
#  'キャンセル',
#  'キー',
#  'クイック',
#  'クライアントルール',
#  'クリック',
#  'グループ',
#  'グローバル',
#  'ケーブル',
#  'コピー',
#  'コレクト',
#  'コントロール',
#  'コンプライアンス',
#  'サイズ',
#  'サインアウト',
#  'サインイン',
#  'サーバ',
#  'システム',
#  'スタート',
#  'スタートメニュ',
#  'スパムフォルダ',
#  'スペル',
#  'セキュリティ',
#  'セット',
#  'センター',
#  'タイトル',
#  'タイミング',
#  'タブ',
#  'タロウ',
#  'ダイキン',
#  'ダイキンイントラ',
#  'ダイキンメール',
#  'ダブル',
#  'チェック',
#  'ツール',
#  'テキスト',
#  'テキストファイル',
#  'テスト',
#  'テンプレート',
#  'ディスク',
#  'デスク',
#  'デフォルト',
#  'データ',
#  'データファイル',
#  'トップ',
#  'トレイ',
#  'ドット',
#  'ドメイン',
#  'ドライブ',
#  'ドレス',
#  'ドロップダウンリスト',
#  'ナビゲーションウィンドウ',
#  'ネットワーク',
#  'バージョン',
#  'パス',
#  'パスワード',
#  'パネル',
#  'ビュー',
#  'ファイル',
#  'フィールド',
#  'フォルダ',
#  'フォルダー',
#  'フォーム',
#  'フラグ',
#  'プレビュー',
#  'プログラム',
#  'プロパティ',
#  'プロファイル',
#  'ヘルプ',
#  'ページ',
#  'ペースト',
#  'ホーム',
#  'ボタン',
#  'ボックス',
#  'ポート',
#  'マニュアル',
#  'メッセージ',
#  'メニュー',
#  'メーリングアドレス',
#  'メーリングリスト',
#  'メール',
#  'メールアドレス',
#  'メールプロファイル',
#  'メールボックス',
#  'モバイル',
#  'モード',
#  'ユーザ',
#  'ユーザー',
#  'ライセンス',
#  'リスト',
#  'リプレイス',
#  'リプレース',
#  'リボン',
#  'リンク',
#  'ルール',
#  'ログ',
#  'ログイン',
#  'ログオン',
#  'ローカル',
#  'ローカルフォルダ',
#  'ローマ字',
#  '一度',
#  '一括',
#  '一時',
#  '一致',
#  '一覧',
#  '一部',
#  '上記',
#  '下さい',
#  '下図',
#  '下書き',
#  '下記',
#  '不便',
#  '不明',
#  '不要',
#  '不調',
#  '並び',
#  '中部',
#  '了承',
#  '今後',
#  '仕分け',
#  '仕様',
#  '仕訳',
#  '付い',
#  '付ける',
#  '以上',
#  '以下',
#  '以前',
#  '以外',
#  '以降',
#  '件名',
#  '件数',
#  '任意',
#  '伴い',
#  '但し',
#  '作り方',
#  '作成',
#  '作業',
#  '使い',
#  '使う',
#  '使用',
#  '例外',
#  '依存',
#  '依頼',
#  '侵害',
#  '保存',
#  '信頼',
#  '修復',
#  '個人',
#  '候補',
#  '優先',
#  '先頭',
#  '入っ',
#  '入ら',
#  '入れ',
#  '入れる',
#  '入力',
#  '全角',
#  '共有',
#  '内容',
#  '再度',
#  '再送',
#  '写真',
#  '処理',
#  '分かり',
#  '分割',
#  '切替',
#  '初めて',
#  '初期',
#  '別途',
#  '利用',
#  '制限',
#  '削除',
#  '動作',
#  '化け',
#  '区切り',
#  '半角',
#  '単語',
#  '印刷',
#  '危険',
#  '原則',
#  '原因',
#  '参照',
#  '反し',
#  '反映',
#  '取っ',
#  '取る',
#  '取込み',
#  '受信',
#  '古い',
#  '可能',
#  '右側',
#  '各所',
#  '合計',
#  '同じ',
#  '同封',
#  '同時に',
#  '同期',
#  '同様',
#  '名前',
#  '含ま',
#  '含め',
#  '問い合わせ',
#  '問合せ',
#  '問題',
#  '囲っ',
#  '圧縮',
#  '基本',
#  '場合',
#  '場所',
#  '壊れ',
#  '変わり',
#  '変換',
#  '変更',
#  '外し',
#  '外部',
#  '大文字',
#  '大金',
#  '太郎',
#  '失敗',
#  '始まり',
#  '媒体',
#  '存在',
#  '完了',
#  '完璧',
#  '宛先',
#  '宜しく',
#  '実害',
#  '実施',
#  '実行',
#  '容量',
#  '対処',
#  '対応',
#  '対象',
#  '小文字',
#  '届い',
#  '届か',
#  '届く',
#  '履歴',
#  '左上',
#  '左下',
#  '差出人',
#  '常に',
#  '引き継げ',
#  '引継',
#  '強化',
#  '形式',
#  '後尾',
#  '復元',
#  '必ず',
#  '必要',
#  '応用',
#  '応答',
#  '思い',
#  '恒久',
#  '情報',
#  '意図',
#  '成功',
#  '戻り',
#  '戻る',
#  '手動',
#  '手段',
#  '手順',
#  '扱わ',
#  '折り返す',
#  '押さ',
#  '押す',
#  '押下',
#  '担当',
#  '拒否',
#  '拠点',
#  '拡張',
#  '指し',
#  '指定',
#  '挿入',
#  '掛かる',
#  '掛け',
#  '探し',
#  '接続',
#  '控え',
#  '掲載',
#  '提供',
#  '換わっ',
#  '操作',
#  '改善',
#  '放置',
#  '数字',
#  '整理',
#  '文字',
#  '文字数',
#  '文書',
#  '文章',
#  '新しい',
#  '新旧',
#  '新規',
#  '方法',
#  '既に',
#  '日付',
#  '日時',
#  '日本語',
#  '時間',
#  '暗号',
#  '更新',
#  '書き',
#  '替え',
#  '替わっ',
#  '最大',
#  '最小',
#  '最新',
#  '有効',
#  '有線',
#  '期日',
#  '期間',
#  '未満',
#  '未読',
#  '末尾',
#  '本文',
#  '条件',
#  '校正',
#  '格納',
#  '案内',
#  '検索',
#  '業務',
#  '構成',
#  '様々',
#  '標準',
#  '機能',
#  '正しい',
#  '正しく',
#  '正常',
#  '残さ',
#  '残す',
#  '残っ',
#  '残り',
#  '段落',
#  '毎回',
#  '気づか',
#  '求め',
#  '沿っ',
#  '法務',
#  '注意',
#  '注記',
#  '海外',
#  '消え',
#  '添付',
#  '済み',
#  '渡し',
#  '漢字',
#  '無い',
#  '無効',
#  '無線',
#  '特に',
#  '特定',
#  '状態',
#  '状況',
#  '現象',
#  '理由',
#  '理解',
#  '環境',
#  '用途',
#  '画像',
#  '画面',
#  '番号',
#  '異なり',
#  '発生',
#  '登録',
#  '直し',
#  '直前',
#  '相手',
#  '相談',
#  '破損',
#  '確認',
#  '社内',
#  '社外',
#  '禁止',
#  '移動',
#  '移行',
#  '種類',
#  '空ける',
#  '端末',
#  '箇所',
#  '箇条',
#  '管理',
#  '簡易',
#  '終了',
#  '経由',
#  '経過',
#  '結果',
#  '絶対',
#  '続行',
#  '編集',
#  '署名',
#  '翌日',
#  '考え',
#  '肖像',
#  '自分',
#  '自動',
#  '自動的',
#  '自身',
#  '致し',
#  '英語',
#  '著作',
#  '行い',
#  '行う',
#  '行える',
#  '行っ',
#  '行わ',
#  '行頭',
#  '表示',
#  '補助',
#  '補足',
#  '複数',
#  '要求',
#  '見え',
#  '見つかり',
#  '見る',
#  '見れ',
#  '見解',
#  '規定',
#  '解消',
#  '解除',
#  '記号',
#  '記憶',
#  '記載',
#  '設定',
#  '試し',
#  '該当',
#  '詳細',
#  '認証',
#  '誤っ',
#  '誤り',
#  '説明',
#  '読み込み',
#  '調べる',
#  '調達',
#  '警告',
#  '貼る',
#  '購買',
#  '起動',
#  '転送',
#  '辞書',
#  '込む',
#  '込ん',
#  '返っ',
#  '返信',
#  '迷惑',
#  '追加',
#  '送り主',
#  '送付',
#  '送信',
#  '送受信',
#  '途中',
#  '通り',
#  '通常',
#  '通知',
#  '連絡',
#  '連続',
#  '進ん',
#  '過去',
#  '適用',
#  '選択',
#  '部分',
#  '部門',
#  '都度',
#  '閉じる',
#  '開い',
#  '開き',
#  '開く',
#  '開始',
#  '間違っ',
#  '関わら',
#  '関係',
#  '閲覧',
#  '限定',
#  '集中',
#  '難しい',
#  '電子',
#  '電話',
#  '頂き',
#  '頂く',
#  '項目',
#  '順序',
#  '順次',
#  '願い',
#  '類似',
#  '１つ',
#  'ｄｉｒｅctory',
#  'ｏｋ',
#  'ｐｓｔ']

# %% [markdown]
# ### 学習実行

# %%
from sklearn.decomposition import LatentDirichletAllocation

print("Fitting LDA models with tf features, "
      "n_samples=%d and n_features=%d..."
      % (n_samples, n_features))
lda = LatentDirichletAllocation(n_topics=15, # トピック分類件数
                                max_iter=30, # 繰り返し実行
                                learning_method='online', # 学習実行-->即結果を出力
                                learning_offset=25.,
                                random_state=1)
t0 = time()
answers = lda.fit_transform(tf)
print("done in %0.3fs." % (time() - t0))
# Out:
# Fitting LDA models with tf features, n_samples=99 and n_features=1000...
# done in 0.612s.

# %% [markdown]
# ### トピックに含まれる上位の特徴語

# %%
def get_top_words_in_topic(lda, tf_feature_names, n_top_words):
    top_words = []

    for topic_idx, topic in enumerate(lda.components_):
        # 特徴語のインデックスを、単語出現確率の高いもの順に取得
        top_words_idx_list = topic.argsort()
        reverse_idx = -n_top_words - 1
        top_words_idx = top_words_idx_list[:reverse_idx:-1]

        # 特徴語をリストに取得
        top_words_list = [tf_feature_names[i] for i in top_words_idx]
        top_words.append(top_words_list)

    # 上位の特徴語リストを戻す
    return top_words

# %%
n_top_words = 15

def print_top_words_in_topic(lda, tf_feature_names, n_top_words):
    top_words_list = get_top_words_in_topic(lda, tf_feature_names, n_top_words)
    for topic_idx, top_words in enumerate(top_words_list):
        print("Topic #%d:" % topic_idx)
        print(",".join(top_words))

print_top_words_in_topic(lda, tf_feature_names, n_top_words)
# Out:
# Topic #0:
# いただく,パス,囲っ,れる,こと,url,改善,同期,メール,まし,確認,失敗,という,クリック,ツール
# Topic #1:
# メール,利用,送信,再送,新規,手順,あり,場合,365,ので,端末,集中,購買,用途,office
# Topic #2:
# 署名,押下,選択,オプション,ok,作成,から,です,www,いただく,deleted,ボタン,応用,最大,手順
# Topic #3:
# メール,フォルダ,する,outlook,送信,場合,いる,ない,ファイル,手順,選択,から,表示,設定,あり
# Topic #4:
# する,から,設定,office,クリック,メール,手順,差出人,起動,返信,選択,インデント,端末,いる,テキスト
# Topic #5:
# 変更,en,ja,太郎,大金,アドレス,taro,お願い,fax,ポート,daikin,イン,仕様,致し,削除
# Topic #6:
# アドレス,押下,outlook,選択,ボタン,ファイル,表示,する,使用,手順,メール,個人,開き,削除,カナ
# Topic #7:
# 場合,社外,メール,容量,確認,ない,電話,制限,なり,あり,形式,アド,サーバ,正しい,画像
# Topic #8:
# www,メール,自動,daikin,場合,行っ,office,接続,intra,web,ha,co,html,必要,id
# Topic #9:
# ユーザ,daikin,co,jp,id,確認,場合,いる,あり,パスワード,ログイン,入力,メールアドレス,仕分け,ルール
# Topic #10:
# 押下,outlook,ボタン,選択,設定,クリック,から,する,検索,メール,アドレス,表示,手順,作成,2010
# Topic #11:
# 手順,確認,以下,メール,outlook,場合,から,ない,クリック,office,表示,削除,いる,起動,実施
# Topic #12:
# 検索,アドレス,する,名前,こと,押下,でき,入力,2010,オートコンプリート,宛先,簡易,daikin,ませ,outlook
# Topic #13:
# microsoft,最新,light,ie,対応,について,owa,替わっ,ha,いき,com,102817357,致し,ja,１つ
# Topic #14:
# 設定,メール,ローカル,以下,差出人,co,場合,jp,daikin,office,する,ダイキン,移行,2010,365

# %% [markdown]
# ### 分類結果の検証
#
# それぞれの質問文が、どのトピックに分類されたかを検証してみます。

# %%
def get_hit_topic_idx(probs):
    topic_idx = 0
    max_prob = 0.0
    for i in range(0, len(probs)):
        if max_prob < probs[i]:
            topic_idx = i
            max_prob = probs[i]

    return topic_idx

# %%
# トピックの上位特徴語を表示
print_top_words_in_topic(lda, tf_feature_names, n_top_words)

# 最初の１０件の質問文について検証してみます
for data_idx in range(0, 10): 
    topic_idx = get_hit_topic_idx(answers[data_idx])
    topic_prob_rate = answers[data_idx][topic_idx] * 100
    
    print("==========")
    print("Sample Text #%d ---> Topic #%d (%0.1f%%):" % (data_idx, topic_idx, topic_prob_rate))
    print(origin_text[data_idx])
# Out:
# Topic #0:
# いただく,パス,囲っ,れる,こと,url,改善,同期,メール,まし,確認,失敗,という,クリック,ツール
# Topic #1:
# メール,利用,送信,再送,新規,手順,あり,場合,365,ので,端末,集中,購買,用途,office
# Topic #2:
# 署名,押下,選択,オプション,ok,作成,から,です,www,いただく,deleted,ボタン,応用,最大,手順
# Topic #3:
# メール,フォルダ,する,outlook,送信,場合,いる,ない,ファイル,手順,選択,から,表示,設定,あり
# Topic #4:
# する,から,設定,office,クリック,メール,手順,差出人,起動,返信,選択,インデント,端末,いる,テキスト
# Topic #5:
# 変更,en,ja,太郎,大金,アドレス,taro,お願い,fax,ポート,daikin,イン,仕様,致し,削除
# Topic #6:
# アドレス,押下,outlook,選択,ボタン,ファイル,表示,する,使用,手順,メール,個人,開き,削除,カナ
# Topic #7:
# 場合,社外,メール,容量,確認,ない,電話,制限,なり,あり,形式,アド,サーバ,正しい,画像
# Topic #8:
# www,メール,自動,daikin,場合,行っ,office,接続,intra,web,ha,co,html,必要,id
# Topic #9:
# ユーザ,daikin,co,jp,id,確認,場合,いる,あり,パスワード,ログイン,入力,メールアドレス,仕分け,ルール
# Topic #10:
# 押下,outlook,ボタン,選択,設定,クリック,から,する,検索,メール,アドレス,表示,手順,作成,2010
# Topic #11:
# 手順,確認,以下,メール,outlook,場合,から,ない,クリック,office,表示,削除,いる,起動,実施
# Topic #12:
# 検索,アドレス,する,名前,こと,押下,でき,入力,2010,オートコンプリート,宛先,簡易,daikin,ませ,outlook
# Topic #13:
# microsoft,最新,light,ie,対応,について,owa,替わっ,ha,いき,com,102817357,致し,ja,１つ
# Topic #14:
# 設定,メール,ローカル,以下,差出人,co,場合,jp,daikin,office,する,ダイキン,移行,2010,365
# ==========
# Sample Text #0 ---> Topic #10 (71.4%):
# Thunderbirdではメールを作成した際、自動的にBCCに自分のメールアドレスが設定されていましたが、 Outlook2010よりBCCに自動的に自分のメールアドレスが設定されなくなりました。自分自身が送信したメールにつきましては、『送信済みトレイ(Sent Items)』に格納されておりますので、そちらでご確認ください。 また、Outlook2010でのBCCの設定方法につきましてはこちらをご確認ください。 【手順】１．メール作成画面のリボンから『オプション』を選択します。 ２．『BCC』をクリックします。３．『BCC』の項目が、『CC』の下に表示されます。　　補足一度、設定すると本設定は常に有効になります。その都度設定する必要はありません。
# ==========
# Sample Text #1 ---> Topic #10 (98.9%):
# 署名の作り方については『【Outlook2010操作マニュアル 応用編】 署名の作成』を参照してください。 http://www.intra.daikin.co.jp/office365/ol2010/Applied.html?cid=C008【手順】１．リボンから『ファイル』を選択し、『オプション』を押下します。２．『メール』を押下します３．『署名』ボタンを押下します。４．『新規作成』ボタンを押下します。５．署名の名前を入力します。（分かりやすい名前をつけてください。） ６．『OK』ボタンを押下します。７．作成した署名を選択します。（既に作成されている場合は、編集したい署名を選択) ８．署名の内容を入力します。 ９．新しいメッセージを作成する際に挿入される署名を選択します。 １０．返信/転送を行う際に挿入される署名を選択します。 １１．『OK』ボタンを押下します。
# ==========
# Sample Text #2 ---> Topic #1 (75.2%):
# Outlook2010にはThunderbirdのテンプレートと同様の機能はありません。類似機能の『【Outlook2010操作マニュアル 基本編】 送信済メールの再利用（メールの再送）』をご利用ください。http://www.intra.daikin.co.jp/office365/ol2010/Basic.html?cid=B007【手順】１．再利用したいメールをダブルクリックします。２．『メッセージ』リボンから『アクション』の▼を押下し、『このメッセージを再送』を押下します。 メール編集画面が表示されますので、以降の操作は『メールの送信』を参照しメールを送信してください。 ※古いメールを再利用（再送）すると、送信エラーが発生することがありますので、　その場合は、再利用（再送）ではなく新規作成をして下さい。
# ==========
# Sample Text #3 ---> Topic #10 (98.9%):
# Outlook2010では、過去に入力したアドレスを記憶するオートコンプリート機能がついています。この為、アドレスを途中まで入力するとアドレス候補が自動的に表示されます。※オートコンプリート機能につきましては、よく利用しているメールアドレスが表示されますが、意図的に記憶させることはできません。あくまで補助機能としてお使いください。また、名前検索を利用することにより、アドレス帳から相手のメールアドレスを簡易検索することができます。名前検索につきましては『【Outlook2010操作マニュアル 基本編】 宛先の簡易検索(名前の確認)』を参照してください。 http://www.intra.daikin.co.jp/office365/ol2010/Basic.html?cid=B006
# ==========
# Sample Text #4 ---> Topic #10 (98.2%):
# 可能です。方法については『【Outlook2010操作マニュアル 応用編】 アドレス検索(デフォルトの検索先に指定したいアドレス帳を指定)』を参照してください。 http://www.intra.daikin.co.jp/office365/ol2010/Applied.html?cid=C003【手順】１．リボンから『ホーム』を選択します。 ２．『アドレス帳』を押下します。３．[メニュー]→[ツール]→[オプション]を押下します。４．『デフォルトの検索先に指定したいアドレス帳』を選択します。 ５．『OK』ボタンを押下します。
# ==========
# Sample Text #5 ---> Topic #1 (69.4%):
# 方法については『【Outlook2010操作マニュアル 基本編】 送信済メールの再利用（メールの再送）』を参照してください。 http://www.intra.daikin.co.jp/office365/ol2010/Basic.html?cid=B007【手順】１．再利用したいメールをダブルクリックします。 ２．『メッセージ』リボンから『アクション』の▼を押下し、『このメッセージを再送』を押下します。 ３．メール編集画面が表示されますので、以降の操作は『メールの送信』を参照しメールを送信してください。 ※古いメールを再利用（再送）すると、送信エラーが発生することがありますので、　その場合は、再利用（再送）ではなく新規作成をして下さい。
# ==========
# Sample Text #6 ---> Topic #10 (67.7%):
# 方法については『【Outlook2010操作マニュアル 応用編】 検索フォルダ―(未読のメールのフォルダを作成する)』を参照してください。 http://www.intra.daikin.co.jp/office365/ol2010/Applied.html?cid=C007【手順】１．検索フォルダ―を右クリックし、『新しい検索フォルダ―』を押下します。２．『未読のメール』を選択します。 ３．『OK』ボタンを押下します。４．『未読のメール』検索フォルダーが作成されていることを確認します。※検索フォルダ―では未読のメール以外にも、フラグの設定されたメールなど様々な条件のメールを検索条件とすることができます。※検索フォルダ―に表示されているメールは検索結果となりますので、メールは元のフォルダから移動はしておりません。
# ==========
# Sample Text #7 ---> Topic #3 (96.1%):
# Outlook2010とThunderbirdでは送信済トレイのフォルダ名が異なります。Thunderbirdの送信済メールについては『Sent』フォルダに保存されております。Outlook2010では『Sent Items(送信済みアイテム)』に保存されます。
# ==========
# Sample Text #8 ---> Topic #3 (91.5%):
# 添付ファイルの容量の制限は10MBです。（メーリングリストも同様になります。）
# ==========
# Sample Text #9 ---> Topic #1 (98.0%):
# Outlook2010には自動応答機能は存在しますが、原則利用しないでください。自動応答の設定を行った場合、ユーザ宛に送信されてきた[SPAMメール]に対しても自動でメールを送信してしまい、セキュリティ上問題があります。ただし、業務上やむを得ない場合、別途こちらまでご相談ください。 http://www.intra.daikin.co.jp/office365/inquiry/install-prb.html
