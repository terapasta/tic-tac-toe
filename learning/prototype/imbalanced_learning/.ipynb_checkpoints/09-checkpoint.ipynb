# %% [markdown]
# # IsolationForest の動作確認
#
# scikit-learn の <b>IsolationForest</b> を使用し、動作確認を行いました。

# %% [markdown]
# ## (0) IsolationForest について
#
# こちらを参照しました。
#
# http://scikit-learn.org/stable/modules/generated/sklearn.ensemble.IsolationForest.html
#
# 仕組みとしては、
#
#
# - feature をランダムに選択し、その feature について最大〜最小の間の値をランダムに分割することで、サンプルを分割（Isolation）する
#
#
# - ランダムに分割されたサブサンプルから、ランダムフォレスト（複数の決定木群）を構成する
#
#
# - ランダムフォレストの木の深さを平均したものを、正常性の尺度とする
#
#
# - ランダムフォレストのなかで、パスが異常に短い（＝中間ノードが極端に少ない）サンプルを、アノマリーと判定する
#
#
# ・・・といったことのようです。

# %% [markdown]
# ## (1) テストデータ／環境準備
#
# マイオペで使用しているテストデータ（learning/tests/engine/fixtures/ 配下のCSVファイル）をベースに動作確認を行います。
#
# 動作確認にあたっては、MySQLdb に接続できないため、ローカル環境テスト用の Bot クラスを使用しています。

# %%
'''
    テスト環境を準備するためのモジュールを使用します。
'''
import sys
import os
learning_dir = os.path.abspath("../../") #<--- donusagi-bot/learning
os.chdir(learning_dir)

if learning_dir not in sys.path:
    sys.path.append(learning_dir)

from prototype.modules import TestTool

# %%
'''
    データファイルは、既存の訓練データを別場所にコピーしてから使用します
    テストデータは、csv_file_name で指定したものを使用します。
'''
csv_file_name = 'test_benefitone_conversation.csv'
copied_csv_file_path = TestTool.copy_testdata_csv(learning_dir, csv_file_name)
# Out:
# CSV file for test=[/Users/makmorit/GitHub/donusagi-bot/learning/prototype/resources/test_benefitone_conversation.csv]

# %% [markdown]
# ## (2) TF-IDFベクターの準備
#
# Bot クラス内に組み込まれている __build_training_set_from_csv 関数をバラして実行しています。

# %%
'''
    初期設定
    データファイル、エンコードを指定
    内容は、learn.py を参考にしました。    
'''
from learning.core.learn.learning_parameter import LearningParameter
attr = {
    'include_failed_data': False,
    'include_tag_vector': False,
    'classify_threshold': None,
    # 'algorithm': LearningParameter.ALGORITHM_NAIVE_BAYES
    'algorithm': LearningParameter.ALGORITHM_LOGISTIC_REGRESSION,
    # 'params_for_algorithm': { 'C': 200 }
    'params_for_algorithm': {}
}
learning_parameter = LearningParameter(attr)

bot_id = 7777
csv_file_path = copied_csv_file_path
csv_file_encoding = 'utf-8'

# %%
'''
    訓練データの生成（内部で TF-IDF 処理を実行）
'''
from learning.core.training_set.training_message_from_csv import TrainingMessageFromCsv
training_set = TrainingMessageFromCsv(bot_id, csv_file_path, learning_parameter, encoding=csv_file_encoding)
build_training_set_from_csv = training_set.build()
# Out:
# 2017/03/17 PM 08:36:36 TrainingMessageFromCsv#__build_learning_training_messages count of learning data: 4114
# 2017/03/17 PM 08:36:36 TextArray#__init__ start
# 2017/03/17 PM 08:36:37 TextArray#to_vec start
# 2017/03/17 PM 08:36:37 TextArray#to_vec end

# %%
'''
    ラベルごとのサンプル数を調査します。
'''
X = build_training_set_from_csv.x
y = build_training_set_from_csv.y
count = TestTool.count_sample_by_label(y)
count
# Out:
# [[4677, 14],
#  [4678, 2584],
#  [4679, 14],
#  [4680, 14],
#  [4683, 14],
#  [4686, 14],
#  [4687, 8],
#  [4690, 8],
#  [4691, 14],
#  [4692, 44],
#  [4693, 30],
#  [4700, 12],
#  [4707, 18],
#  [4708, 14],
#  [4709, 14],
#  [4710, 14],
#  [4711, 14],
#  [4712, 16],
#  [4713, 14],
#  [4718, 20],
#  [4719, 8],
#  [4720, 20],
#  [4721, 8],
#  [4724, 8],
#  [4727, 14],
#  [4728, 62],
#  [4729, 26],
#  [4730, 20],
#  [4731, 14],
#  [4732, 22],
#  [4733, 14],
#  [4734, 34],
#  [4735, 12],
#  [4738, 14],
#  [4739, 14],
#  [4740, 14],
#  [4741, 8],
#  [4742, 20],
#  [4743, 14],
#  [4744, 14],
#  [4745, 20],
#  [4750, 22],
#  [4751, 20],
#  [4752, 14],
#  [4753, 8],
#  [4754, 8],
#  [4755, 14],
#  [4756, 20],
#  [4757, 8],
#  [4758, 28],
#  [4759, 14],
#  [4760, 8],
#  [4761, 20],
#  [4762, 8],
#  [4766, 14],
#  [4767, 14],
#  [4772, 60],
#  [4776, 8],
#  [4781, 14],
#  [4782, 14],
#  [4783, 20],
#  [4786, 8],
#  [4792, 20],
#  [4793, 8],
#  [4794, 8],
#  [4795, 14],
#  [4797, 42],
#  [4798, 36],
#  [4800, 14],
#  [4802, 14],
#  [4804, 14],
#  [4807, 8],
#  [4808, 106],
#  [4817, 26],
#  [4821, 24],
#  [4824, 16],
#  [4827, 8],
#  [4830, 22],
#  [4831, 14],
#  [4833, 14],
#  [4834, 14],
#  [4835, 36],
#  [4836, 30],
#  [4837, 8]]

# %% [markdown]
# ## (3) IsolationForestで学習

# %%
'''
    IsolationForest with default
'''
from sklearn.ensemble import IsolationForest
clf = IsolationForest() # デフォルトでは、外れ判定される件数の見積もりを全体の1割と想定
clf.fit(X)
# Out:
# IsolationForest(bootstrap=False, contamination=0.1, max_features=1.0,
#         max_samples='auto', n_estimators=100, n_jobs=1, random_state=None,
#         verbose=0)

# %% [markdown]
# ## (4) 外れデータを使って予測

# %% [markdown]
# <b><a href="01.ipynb">こちらで以前確認した</a></b>外れと思しきデータ＋α を使用して予測します。

# %%
'''
    マイオペのプロダクション・コードと同じように、
    訓練データ作成時と同じベクトライザーを使用します。
'''
from learning.core.training_set.text_array import TextArray

test_X = [
    '人生相談をしたいのですが？', # 以前全く違う回答を誘導させた質問文です
    '何か習い事をしたほうがいいですか？', # 複数のfeatureが得られるような質問文を追加
    '会社を辞めたいのですが誰に相談すればいいですか？',
    '有給休暇を取って世界旅行に行きたいと思っています。',
]
vectorizer = training_set.body_array.vectorizer
text_array = TextArray(test_X, vectorizer=vectorizer)

'''
    外れデータのTF-IDFベクターを取得
'''
X_error = text_array.to_vec()
# Out:
# 2017/03/17 PM 08:36:38 TextArray#__init__ start
# 2017/03/17 PM 08:36:38 TextArray#to_vec start
# 2017/03/17 PM 08:36:38 TextArray#to_vec end

# %%
'''
    外れデータを使用して、外れ判定を実行してみます
'''
y_pred_error = clf.predict(X_error)

# %% [markdown]
# #### 残念ながら、外れとは判定されませんでした・・・

# %%
y_pred_error
# Out:
# array([1, 1, 1, 1])

# %% [markdown]
# #### ちなみに、このサンプルの feature は以下の通りでした。
#
# （ボキャブラリーの中身は<b><a href="08.ipynb#ご参考：ボキャブラリーの中身">こちらをご参照</a></b>）

# %%
'''
    feature をダンプするためのツール
'''
def get_item_from_vocabulary(vocabulary, index):
    for k, v in vocabulary.items():
        if v == index:
            return k

    return None

def dump_features(arr, vocabulary):
    features_str = ''

    for i, v in enumerate(arr):
        if v == 0.0:
            continue

        if features_str != '':
            features_str += ' '
        
        item = get_item_from_vocabulary(vocabulary, i)
        features_str += '%s=%0.3f' % (item, v)

    return '[' + features_str + ']'

# %%
vocabulary = text_array._vectorizer.vocabulary_

for i, label in enumerate(X_error):
    arr = X_error[i].toarray()[0]
    dump_str = dump_features(arr, vocabulary)
    print('index=%d%s' % (i, dump_str))
# Out:
# index=0[する=1.000]
# index=1[いい=0.577 する=0.577 何=0.577]
# index=2[いい=0.500 する=0.500 会社=0.500 誰=0.500]
# index=3[取る=0.577 思う=0.577 行く=0.577]

# %% [markdown]
# ## (5) ご参考：訓練データを使って予測

# %% [markdown]
# 訓練データを使って外れ判定をしても、1割ほどのデータが外れ判定されてしまいます。
#
# （デフォルトにおける、contamination=0.1 の指定通りの結果）

# %%
'''
    訓練データを使用して、外れ判定を実行してみます
'''
y_pred_train = clf.predict(X)

# %% [markdown]
# #### 長いですが、ご参考のため、全量を表示します。
#
# --->error detected と表示されているのが、外れ判定されたサンプルになります。
#
# 訓練データのインデックスと、あらかじめ与えられたラベル、featureの値を出力させています。
#
# One-clsss SVM とは違い、傾向としては下記例のように、少々の乖離では外れと判定されにくくなっています。
#
# ~~~~
# One-class SVM での例：（外れ判定１件あり）
# index=3928, label=4678 [会社=0.577 概要=0.577 欲しい=0.577]
# index=3929, label=4678 [会社=0.577 概要=0.577 無い=0.577]--->error detected
# index=3930, label=4678 [会社=0.577 案内=0.577 欲しい=0.577]
# index=3931, label=4678 [会社=0.577 案内=0.577 無い=0.577]
#
# IsolationForest での例：（外れ判定なし）
# index=3928, label=4678 [会社=0.577 概要=0.577 欲しい=0.577]
# index=3929, label=4678 [会社=0.577 概要=0.577 無い=0.577]
# index=3930, label=4678 [会社=0.577 案内=0.577 欲しい=0.577]
# index=3931, label=4678 [会社=0.577 案内=0.577 無い=0.577]
# ~~~~

# %%
'''
    外れ判定のエラー率を計算します --->0.1と算出されました
'''
error_count = 0.0
for i, label in enumerate(y):
    arr = X[i].toarray()[0]
    dump_str = dump_features(arr, vocabulary)
    if y_pred_train[i] == -1: # 外れと判定された場合
        print('index=%d, label=%d %s--->error detected' % (i, label, dump_str))
        error_count += 1.0
    if y_pred_train[i] == 1: # 外れと判定されなかった場合
        print('index=%d, label=%d %s' % (i, label, dump_str))

print('')
print('error rate=%0.1f' % (error_count/len(y)))
# Out:
# index=0, label=4677 [捺印=0.500 方法=0.500 申請=0.500 知る=0.500]--->error detected
# index=1, label=4679 [する=0.447 印鑑=0.447 捺印=0.447 知る=0.447 種類=0.447]
# index=2, label=4680 [ほしい=0.500 印紙=0.500 収入=0.500 教える=0.500]
# index=3, label=4683 [契約=0.577 書=0.577 見る=0.577]
# index=4, label=4686 [出張=0.577 方法=0.577 申請=0.577]
# index=5, label=4687 [bt=0.447 hi=0.447 per=0.447 できる=0.447 ログイン=0.447]
# index=6, label=4690 [bt=0.447 hi=0.447 per=0.447 する=0.447 登録=0.447]
# index=7, label=4691 [bt=0.378 hi=0.378 per=0.378 する=0.378 変更=0.378 承認=0.378 権限=0.378]
# index=8, label=4692 [小口=0.577 方法=0.577 申請=0.577]
# index=9, label=4692 [suica=0.577 する=0.577 登録=0.577]
# index=10, label=4692 [する=0.577 パスモ=0.577 登録=0.577]
# index=11, label=4692 [icoca=0.577 する=0.577 登録=0.577]
# index=12, label=4693 [プリンター=0.707 動く=0.707]
# index=13, label=4693 [する=0.577 プリンター=0.577 故障=0.577]
# index=14, label=4700 [プリンター=0.707 欲しい=0.707]
# index=15, label=4707 [プリンター=0.707 換える=0.707]
# index=16, label=4708 [動く=0.577 機=0.577 複合=0.577]
# index=17, label=4709 [する=0.500 故障=0.500 機=0.500 複合=0.500]
# index=18, label=4710 [する=0.577 カラー=0.577 コピー=0.577]
# index=19, label=4711 [できる=0.577 カラー=0.577 コピー=0.577]
# index=20, label=4712 [コピー=0.447 ホチキス=0.447 機=0.447 無くなる=0.447 針=0.447]
# index=21, label=4712 [する=0.408 コピー=0.408 ホチキス=0.408 機=0.408 補充=0.408 針=0.408]
# index=22, label=4713 [られる=0.577 イントラ=0.577 見る=0.577]
# index=23, label=4718 [する=0.577 変更=0.577 座席=0.577]
# index=24, label=4719 [する=0.577 変更=0.577 座席=0.577]
# index=25, label=4720 [する=0.500 予定=0.500 変更=0.500 座席=0.500]
# index=26, label=4721 [スローガン=1.000]
# index=27, label=4724 [カード=0.577 キー=0.577 忘れる=0.577]
# index=28, label=4727 [カード=0.577 キー=0.577 無い=0.577]
# index=29, label=4728 [カード=0.500 キー=0.500 入れ物=0.500 壊れる=0.500]
# index=30, label=4728 [カード=0.500 キー=0.500 入れ物=0.500 欲しい=0.500]
# index=31, label=4728 [カード=0.577 ケース=0.577 壊れる=0.577]
# index=32, label=4728 [カード=0.577 ケース=0.577 取り替える=0.577]
# index=33, label=4729 [する=0.500 予約=0.500 会議=0.500 室=0.500]--->error detected
# index=34, label=4730 [する=0.500 ルーム=0.500 ワーク=0.500 予約=0.500]
# index=35, label=4731 [する=0.500 予約=0.500 室=0.500 顧問=0.500]
# index=36, label=4732 [暑い=0.707 部屋=0.707]
# index=37, label=4732 [寒い=0.707 部屋=0.707]
# index=38, label=4678 [会議=0.577 使う=0.577 室=0.577]
# index=39, label=4678 [会議=0.577 借りる=0.577 室=0.577]
# index=40, label=4678 [壊れる=0.500 機=0.500 給=0.500 茶=0.500]
# index=41, label=4678 [出る=0.447 機=0.447 水=0.447 給=0.447 茶=0.447]
# index=42, label=4678 [お湯=0.447 出る=0.447 機=0.447 給=0.447 茶=0.447]
# index=43, label=4678 [機=0.447 無い=0.447 粉=0.447 給=0.447 茶=0.447]
# index=44, label=4733 [コーヒー=0.707 無い=0.707]
# index=45, label=4678 [コーヒー=0.577 フィルター=0.577 無い=0.577]
# index=46, label=4678 [コーヒー=0.577 無い=0.577 豆=0.577]
# index=47, label=4678 [ない=0.577 コーヒー=0.577 ミルク=0.577]
# index=48, label=4678 [コーヒー=0.577 スプーン=0.577 無い=0.577]
# index=49, label=4678 [コップ=0.577 無い=0.577 紙=0.577]
# index=50, label=4678 [グラス=0.707 無い=0.707]
# index=51, label=4678 [湯呑み=0.707 無い=0.707]
# index=52, label=4678 [受け=0.577 無い=0.577 茶=0.577]
# index=53, label=4678 [コード=0.577 借りる=0.577 延長=0.577]
# index=54, label=4678 [コード=0.577 使う=0.577 延長=0.577]
# index=55, label=4678 [テプラ=0.707 使う=0.707]
# index=56, label=4678 [テプラ=0.707 借りる=0.707]
# index=57, label=4678 [ic=0.577 レコーダー=0.577 使う=0.577]
# index=58, label=4678 [ic=0.577 レコーダー=0.577 借りる=0.577]
# index=59, label=4734 [ビデオカメラ=0.707 使う=0.707]
# index=60, label=4678 [ビデオカメラ=0.707 借りる=0.707]
# index=61, label=4735 [sd=0.577 カード=0.577 無い=0.577]
# index=62, label=4738 [デジカメ=0.707 使う=0.707]
# index=63, label=4739 [デジカメ=0.707 借りる=0.707]
# index=64, label=4740 [三脚=0.707 使う=0.707]
# index=65, label=4741 [三脚=0.707 借りる=0.707]
# index=66, label=4742 [aed=0.707 借りる=0.707]
# index=67, label=4743 [ポインター=0.577 レーザー=0.577 使う=0.577]
# index=68, label=4744 [ポインター=0.577 レーザー=0.577 借りる=0.577]
# index=69, label=4678 [システム=0.500 会議=0.500 使う=0.500 電話=0.500]
# index=70, label=4678 [システム=0.500 会議=0.500 借りる=0.500 電話=0.500]
# index=71, label=4678 [プロジェクター=0.707 壊れる=0.707]
# index=72, label=4678 [プロジェクター=0.707 壊す=0.707]
# index=73, label=4678 [プロジェクター=0.707 無い=0.707]
# index=74, label=4678 [プロジェクター=0.707 使う=0.707]
# index=75, label=4678 [する=0.577 プロジェクター=0.577 予約=0.577]
# index=76, label=4678 [プロジェクター=0.707 借りる=0.707]
# index=77, label=4745 [ipad=0.707 使う=0.707]
# index=78, label=4678 [ipad=0.707 借りる=0.707]
# index=79, label=4750 [コート=0.577 ハンガー=0.577 使う=0.577]
# index=80, label=4750 [コート=0.577 使う=0.577 掛け=0.577]
# index=81, label=4751 [壊れる=0.707 携帯=0.707]
# index=82, label=4752 [動く=0.707 携帯=0.707]
# index=83, label=4753 [換える=0.707 携帯=0.707]
# index=84, label=4754 [する=0.408 交換=0.408 携帯=0.408 早い=0.408 減る=0.408 電池=0.408]
# index=85, label=4755 [iphone=0.577 メッセージ=0.577 壊れる=0.577]
# index=86, label=4756 [iphone=0.577 メッセージ=0.577 送れる=0.577]
# index=87, label=4757 [iphone=0.577 メッセージ=0.577 届く=0.577]
# index=88, label=4758 [iphone=0.577 メッセージ=0.577 重い=0.577]
# index=89, label=4759 [iphone=0.577 メッセージ=0.577 動く=0.577]
# index=90, label=4758 [iphone=0.500 メッセージ=0.500 動き=0.500 遅い=0.500]
# index=91, label=4760 [iphone=0.408 する=0.408 交換=0.408 早い=0.408 減る=0.408 電池=0.408]
# index=92, label=4678 [カバー=0.447 スマ=0.447 ホ=0.447 携帯=0.447 欲しい=0.447]
# index=93, label=4678 [する=0.378 ほしい=0.378 カバー=0.378 スマ=0.378 ホ=0.378 交換=0.378 携帯=0.378]
# index=94, label=4678 [スマ=0.447 フィルム=0.447 ホ=0.447 携帯=0.447 欲しい=0.447]
# index=95, label=4678 [する=0.378 ほしい=0.378 スマ=0.378 フィルム=0.378 ホ=0.378 交換=0.378 携帯=0.378]
# index=96, label=4678 [お守り=0.577 ステッカー=0.577 欲しい=0.577]
# index=97, label=4761 [イヤ=0.577 ホン=0.577 壊れる=0.577]
# index=98, label=4678 [イヤ=0.500 ホン=0.500 新しい=0.500 欲しい=0.500]
# index=99, label=4678 [する=0.447 ほしい=0.447 イヤ=0.447 ホン=0.447 交換=0.447]
# index=100, label=4762 [コード=0.577 充電=0.577 切れる=0.577]
# index=101, label=4766 [コード=0.577 充電=0.577 壊れる=0.577]
# index=102, label=4767 [コード=0.500 充電=0.500 新しい=0.500 欲しい=0.500]
# index=103, label=4678 [する=0.447 ほしい=0.447 コード=0.447 交換=0.447 充電=0.447]
# index=104, label=4678 [する=0.577 変更=0.577 機種=0.577]
# index=105, label=4678 [iphone=0.707 する=0.707]
# index=106, label=4678 [する=0.707 ガラケー=0.707]
# index=107, label=4678 [する=0.500 帳=0.500 更新=0.500 電話=0.500]
# index=108, label=4678 [する=0.447 スマホ=0.447 帳=0.447 更新=0.447 電話=0.447]--->error detected
# index=109, label=4678 [する=0.447 スマホ=0.447 先=0.447 更新=0.447 連絡=0.447]--->error detected
# index=110, label=4678 [する=0.447 帳=0.447 携帯=0.447 更新=0.447 電話=0.447]
# index=111, label=4678 [する=0.447 先=0.447 携帯=0.447 更新=0.447 連絡=0.447]--->error detected
# index=112, label=4772 [メールアドレス=0.707 無い=0.707]
# index=113, label=4772 [メールアドレス=0.707 作る=0.707]
# index=114, label=4772 [メールアドレス=0.707 欲しい=0.707]
# index=115, label=4772 [もらう=0.707 メールアドレス=0.707]
# index=116, label=4678 [取れる=0.577 決裁=0.577 知る=0.577]
# index=117, label=4776 [どこ=0.447 今=0.447 回る=0.447 決裁=0.447 知る=0.447]
# index=118, label=4781 [決裁=0.577 見る=0.577 過去=0.577]
# index=119, label=4782 [捺印=0.577 知る=0.577 終わる=0.577]
# index=120, label=4678 [どこ=0.447 今=0.447 回る=0.447 捺印=0.447 知る=0.447]
# index=121, label=4678 [ex=0.577 カード=0.577 借りる=0.577]
# index=122, label=4678 [する=0.707 出張=0.707]
# index=123, label=4678 [コピー=0.577 欲しい=0.577 用紙=0.577]
# index=124, label=4678 [コピー=0.577 無い=0.577 用紙=0.577]
# index=125, label=4678 [封筒=0.707 欲しい=0.707]
# index=126, label=4678 [封筒=0.707 買う=0.707]
# index=127, label=4678 [封筒=0.707 無い=0.707]
# index=128, label=4678 [会社=0.577 概要=0.577 欲しい=0.577]
# index=129, label=4678 [会社=0.577 概要=0.577 無い=0.577]
# index=130, label=4678 [会社=0.577 案内=0.577 欲しい=0.577]
# index=131, label=4678 [会社=0.577 案内=0.577 無い=0.577]
# index=132, label=4678 [欲しい=0.707 紙袋=0.707]
# index=133, label=4678 [無い=0.707 紙袋=0.707]
# index=134, label=4678 [ラミネートフィルム=0.707 使う=0.707]
# index=135, label=4678 [ラミネートフィルム=0.707 借りる=0.707]
# index=136, label=4678 [ひも=0.707 欲しい=0.707]
# index=137, label=4678 [ひも=0.707 無くなる=0.707]
# index=138, label=4678 [コップ=0.577 欲しい=0.577 紙=0.577]
# index=139, label=4678 [ゴミ=0.707 捨てる=0.707]
# index=140, label=4678 [いっぱい=0.577 なる=0.577 ゴミ=0.577]
# index=141, label=4678 [捨てる=0.707 段ボール=0.707]
# index=142, label=4678 [捨てる=0.707 電池=0.707]
# index=143, label=4678 [割れ物=0.707 捨てる=0.707]
# index=144, label=4678 [来社=0.500 欲しい=0.500 票=0.500 記録=0.500]
# index=145, label=4678 [来社=0.500 無い=0.500 票=0.500 記録=0.500]
# index=146, label=4678 [受付=0.447 来社=0.447 票=0.447 置く=0.447 記録=0.447]
# index=147, label=4678 [どこ=0.408 わかる=0.408 来社=0.408 票=0.408 置く=0.408 記録=0.408]--->error detected
# index=148, label=4678 [届く=0.707 落とし物=0.707]
# index=149, label=4678 [落とし物=0.707 見つける=0.707]
# index=150, label=4678 [ポスター=0.707 貼る=0.707]
# index=151, label=4678 [掃除=0.577 欲しい=0.577 道具=0.577]
# index=152, label=4678 [借りる=0.577 掃除=0.577 道具=0.577]
# index=153, label=4678 [欲しい=0.707 雑巾=0.707]
# index=154, label=4678 [借りる=0.707 雑巾=0.707]
# index=155, label=4678 [買う=0.707 雑巾=0.707]
# index=156, label=4678 [ふきん=0.707 無くなる=0.707]
# index=157, label=4678 [ふきん=0.707 欲しい=0.707]
# index=158, label=4678 [ふきん=0.707 買う=0.707]
# index=159, label=4678 [洗剤=0.707 無くなる=0.707]
# index=160, label=4678 [欲しい=0.707 洗剤=0.707]
# index=161, label=4678 [洗剤=0.707 買う=0.707]
# index=162, label=4678 [スポンジ=0.707 無くなる=0.707]
# index=163, label=4678 [スポンジ=0.707 欲しい=0.707]
# index=164, label=4678 [スポンジ=0.707 買う=0.707]
# index=165, label=4678 [する=0.577 スポンジ=0.577 交換=0.577]
# index=166, label=4678 [枯れる=0.577 植物=0.577 観葉=0.577]
# index=167, label=4678 [捨てる=0.577 植物=0.577 観葉=0.577]
# index=168, label=4678 [する=0.447 せる=0.447 植物=0.447 移動=0.447 観葉=0.447]
# index=169, label=4783 [ほしい=0.577 券=0.577 定期=0.577]
# index=170, label=4678 [ヘルメット=0.707 欲しい=0.707]
# index=171, label=4678 [ヘルメット=0.707 無い=0.707]
# index=172, label=4678 [欲しい=0.707 軍手=0.707]
# index=173, label=4678 [無い=0.707 軍手=0.707]
# index=174, label=4678 [ハンガー=0.577 マグネット=0.577 欲しい=0.577]
# index=175, label=4678 [ハンガー=0.577 マグネット=0.577 無い=0.577]
# index=176, label=4678 [伝票=0.500 宅配=0.500 欲しい=0.500 見る=0.500]
# index=177, label=4678 [何=0.500 便=0.500 時=0.500 社内=0.500]
# index=178, label=4678 [何=0.500 便=0.500 宅配=0.500 時=0.500]
# index=179, label=4678 [ヤマト=0.500 何=0.500 便=0.500 時=0.500]
# index=180, label=4678 [佐川急便=0.577 何=0.577 時=0.577]
# index=181, label=4678 [ゆう=0.500 パック=0.500 何=0.500 時=0.500]
# index=182, label=4678 [グループ=0.447 パソナ=0.447 便=0.447 社内=0.447 送れる=0.447]--->error detected
# index=183, label=4678 [ソリューションズ=0.500 便=0.500 社内=0.500 送れる=0.500]
# index=184, label=4678 [ヘルスケア=0.500 便=0.500 社内=0.500 送れる=0.500]
# index=185, label=4678 [ペイロール=0.500 便=0.500 社内=0.500 送れる=0.500]
# index=186, label=4678 [便=0.408 封筒=0.408 欲しい=0.408 無い=0.408 無くなる=0.408 社内=0.408]
# index=187, label=4678 [出す=0.707 郵便=0.707]
# index=188, label=4678 [ハスラー=0.577 使い方=0.577 分かる=0.577]
# index=189, label=4678 [ハスラー=0.707 動く=0.707]
# index=190, label=4678 [ハスラー=0.577 押す=0.577 間違える=0.577]
# index=191, label=4678 [シール=0.707 無い=0.707]
# index=192, label=4678 [インク=0.577 ハスラー=0.577 切れる=0.577]
# index=193, label=4678 [なる=0.500 ハスラー=0.500 不足=0.500 残高=0.500]--->error detected
# index=194, label=4678 [なる=0.500 ハスラー=0.500 不足=0.500 料金=0.500]--->error detected
# index=195, label=4786 [する=0.354 利用=0.354 発送=0.354 確認=0.354 者=0.707]
# index=196, label=4678 [壊れる=0.707 椅子=0.707]
# index=197, label=4678 [する=0.500 ほしい=0.500 交換=0.500 椅子=0.500]
# index=198, label=4678 [壊れる=0.707 机=0.707]
# index=199, label=4678 [する=0.500 ほしい=0.500 交換=0.500 机=0.500]
# index=200, label=4678 [椅子=0.707 欲しい=0.707]
# index=201, label=4678 [机=0.707 欲しい=0.707]
# index=202, label=4678 [ない=0.577 固定=0.577 電話機=0.577]--->error detected
# index=203, label=4678 [固定=0.577 欲しい=0.577 電話機=0.577]
# index=204, label=4678 [作る=0.707 合鍵=0.707]
# index=205, label=4678 [机=0.577 無い=0.577 鍵=0.577]
# index=206, label=4678 [キャビネット=0.577 無い=0.577 鍵=0.577]
# index=207, label=4678 [トナー=0.577 プリンター=0.577 欲しい=0.577]
# index=208, label=4678 [トナー=0.577 プリンター=0.577 無くなる=0.577]
# index=209, label=4678 [する=0.500 トナー=0.500 プリンター=0.500 交換=0.500]
# index=210, label=4678 [ずれる=0.577 時刻=0.577 時計=0.577]
# index=211, label=4678 [時計=0.577 止まる=0.577 針=0.577]
# index=212, label=4678 [ずれる=0.500 ほしい=0.500 チャイム=0.500 直す=0.500]
# index=213, label=4678 [パンチ=0.500 借りる=0.500 穴=0.500 開ける=0.500]
# index=214, label=4678 [ホチキス=0.577 厚い=0.577 止める=0.577]--->error detected
# index=215, label=4678 [クリア=0.577 ファイル=0.577 無い=0.577]
# index=216, label=4678 [クリア=0.577 ファイル=0.577 欲しい=0.577]
# index=217, label=4678 [いる=0.500 なる=0.500 クリア=0.500 ファイル=0.500]
# index=218, label=4734 [借りる=0.707 台車=0.707]
# index=219, label=4792 [使う=0.707 台車=0.707]
# index=220, label=4793 [借りる=0.707 脚立=0.707]
# index=221, label=4794 [使う=0.707 脚立=0.707]
# index=222, label=4678 [ドライバー=0.707 借りる=0.707]
# index=223, label=4678 [切れる=0.707 電気=0.707]
# index=224, label=4678 [切れる=0.577 灯=0.577 蛍光=0.577]
# index=225, label=4678 [こぼす=0.707 ジュース=0.707]
# index=226, label=4678 [こぼす=0.707 コーヒー=0.707]
# index=227, label=4678 [お茶=0.707 こぼす=0.707]
# index=228, label=4678 [床=0.707 汚す=0.707]
# index=229, label=4678 [ブラインド=0.707 壊れる=0.707]
# index=230, label=4678 [ブラインド=0.707 動く=0.707]
# index=231, label=4678 [テプラ=0.577 テープ=0.577 無くなる=0.577]--->error detected
# index=232, label=4678 [テプラ=0.577 テープ=0.577 欲しい=0.577]
# index=233, label=4678 [文具=0.707 欲しい=0.707]
# index=234, label=4678 [テープ=0.577 欲しい=0.577 製本=0.577]
# index=235, label=4678 [テープ=0.577 使う=0.577 製本=0.577]
# index=236, label=4678 [欲しい=0.707 電池=0.707]
# index=237, label=4678 [無くなる=0.707 電池=0.707]
# index=238, label=4678 [付箋=0.707 欲しい=0.707]
# index=239, label=4678 [付箋=0.707 無くなる=0.707]
# index=240, label=4678 [ほしい=0.707 ホワイトボードマーカー=0.707]
# index=241, label=4678 [ホワイトボードマーカー=0.707 無くなる=0.707]
# index=242, label=4678 [ガム=0.577 テープ=0.577 欲しい=0.577]
# index=243, label=4678 [ガム=0.577 テープ=0.577 無くなる=0.577]
# index=244, label=4678 [セロテープ=0.707 欲しい=0.707]
# index=245, label=4678 [セロテープ=0.707 無くなる=0.707]
# index=246, label=4678 [欲しい=0.707 消しゴム=0.707]
# index=247, label=4678 [消しゴム=0.707 無くなる=0.707]
# index=248, label=4678 [シャー=0.500 ペン=0.500 欲しい=0.500 芯=0.500]
# index=249, label=4678 [シャー=0.500 ペン=0.500 無くなる=0.500 芯=0.500]
# index=250, label=4678 [ホチキス=0.577 欲しい=0.577 針=0.577]
# index=251, label=4678 [ホチキス=0.577 無くなる=0.577 針=0.577]
# index=252, label=4678 [クリップ=0.707 欲しい=0.707]
# index=253, label=4678 [クリップ=0.707 無い=0.707]
# index=254, label=4678 [欲しい=0.707 輪ゴム=0.707]
# index=255, label=4678 [無い=0.707 輪ゴム=0.707]
# index=256, label=4678 [のり=0.707 欲しい=0.707]
# index=257, label=4678 [のり=0.707 無い=0.707]
# index=258, label=4678 [デート=0.577 印=0.577 壊れる=0.577]
# index=259, label=4678 [名刺=0.707 無くなる=0.707]
# index=260, label=4678 [作る=0.707 名刺=0.707]
# index=261, label=4678 [する=0.500 内容=0.500 名刺=0.500 変更=0.500]
# index=262, label=4678 [内容=0.577 名刺=0.577 変える=0.577]
# index=263, label=4678 [氷=0.707 無い=0.707]
# index=264, label=4678 [できる=0.707 氷=0.707]
# index=265, label=4678 [いっぱい=0.577 入る=0.577 冷蔵庫=0.577]
# index=266, label=4678 [する=0.500 ほしい=0.500 冷蔵庫=0.500 整理=0.500]
# index=267, label=4678 [入る=0.707 変=0.707]
# index=268, label=4678 [ニッポン=0.408 レンタカー=0.816 使う=0.408]
# index=269, label=4678 [する=0.378 ニッポン=0.378 レンタカー=0.756 申請=0.378]
# index=270, label=4678 [レンタカー=0.707 使う=0.707]
# index=271, label=4678 [する=0.577 レンタカー=0.577 申請=0.577]--->error detected
# index=272, label=4678 [カー=0.577 シェア=0.577 使う=0.577]
# index=273, label=4678 [レンタカー=0.577 使う=0.577 初めて=0.577]
# index=274, label=4678 [受ける=0.577 安全=0.577 講習=0.577]--->error detected
# index=275, label=4678 [受ける=0.577 安全=0.577 講習=0.577]--->error detected
# index=276, label=4678 [レンタカー=0.447 使う=0.447 受ける=0.447 安全=0.447 講習=0.447]--->error detected
# index=277, label=4678 [etc=0.577 カード=0.577 借りる=0.577]
# index=278, label=4795 [pc=0.577 ノート=0.577 借りる=0.577]
# index=279, label=4798 [pc=0.500 利用=0.500 外=0.500 時間=0.500]
# index=280, label=4800 [pc=0.577 つく=0.577 電源=0.577]
# index=281, label=4802 [pc=0.577 する=0.577 故障=0.577]
# index=282, label=4804 [iphone=0.707 テザリング=0.707]
# index=283, label=4807 [する=0.500 れる=0.500 アカウント=0.500 ロック=0.500]
# index=284, label=4817 [ク=0.577 ネットワ=0.577 繋がる=0.577]
# index=285, label=4821 [word=1.000]
# index=286, label=4821 [excel=1.000]
# index=287, label=4821 [powerpoint=1.000]
# index=288, label=4824 [する=0.500 ほしい=0.500 データ=0.500 復旧=0.500]
# index=289, label=4824 [する=0.500 ほしい=0.500 ファイル=0.500 復旧=0.500]
# index=290, label=4827 [できる=0.447 サーバ=0.447 データ=0.447 ファイル=0.447 保存=0.447]
# index=291, label=4830 [サーバ=0.447 ファイル=0.447 会議=0.447 室=0.447 見る=0.447]
# index=292, label=4830 [会議=0.500 室=0.500 環境=0.500 社内=0.500]
# index=293, label=4831 [する=0.447 ネット=0.447 会議=0.447 室=0.447 接続=0.447]
# index=294, label=4798 [usb=0.577 メモリ=0.577 借りる=0.577]
# index=295, label=4798 [wifi=0.577 ルータ=0.577 借りる=0.577]
# index=296, label=4808 [lan=0.577 ケーブル=0.577 借りる=0.577]
# index=297, label=4808 [コード=0.500 借りる=0.500 延長=0.500 電源=0.500]
# index=298, label=4808 [dvd=0.577 する=0.577 再生=0.577]
# index=299, label=4808 [する=0.577 再生=0.577 動画=0.577]
# index=300, label=4808 [する=0.577 動画=0.577 編集=0.577]
# index=301, label=4833 [dat=0.500 winmail=0.500 する=0.500 解凍=0.500]
# index=302, label=4834 [pdf=0.707 見れる=0.707]
# index=303, label=4808 [できる=0.577 ファイル=0.577 解凍=0.577]
# index=304, label=4808 [できる=0.577 ファイル=0.577 圧縮=0.577]
# index=305, label=4808 [する=0.447 パスワード=0.447 ファイル=0.447 付き=0.447 圧縮=0.447]
# index=306, label=4835 [する=0.447 メール=0.447 応答=0.447 自動=0.447 設定=0.447]
# index=307, label=4835 [する=0.500 メール=0.500 検索=0.500 過去=0.500]
# index=308, label=4797 [する=0.577 メーリングリスト=0.577 作成=0.577]
# index=309, label=4797 [する=0.577 メーリングリスト=0.577 変更=0.577]
# index=310, label=4797 [ほしい=0.577 メーリングリスト=0.577 外す=0.577]
# index=311, label=4836 [くる=0.577 メール=0.577 怪しい=0.577]
# index=312, label=4836 [くる=0.707 スパムメール=0.707]
# index=313, label=4837 [ソフト=0.707 使う=0.707]
# index=314, label=4693 [プリンターー=0.707 動く=0.707]
# index=315, label=4693 [プリンタ=0.707 動く=0.707]
# index=316, label=4693 [する=0.577 プリンターー=0.577 故障=0.577]
# index=317, label=4693 [する=0.577 プリンタ=0.577 故障=0.577]
# index=318, label=4700 [プリンターー=0.707 欲しい=0.707]
# index=319, label=4700 [プリンタ=0.707 欲しい=0.707]
# index=320, label=4707 [プリンターー=0.707 換える=0.707]
# index=321, label=4707 [プリンタ=0.707 換える=0.707]
# index=322, label=4772 [e=0.577 メールアドレス=0.577 無い=0.577]
# index=323, label=4772 [email=0.577 アドレス=0.577 無い=0.577]
# index=324, label=4772 [e=0.577 メールアドレス=0.577 作る=0.577]
# index=325, label=4772 [email=0.577 アドレス=0.577 作る=0.577]
# index=326, label=4772 [e=0.577 メールアドレス=0.577 欲しい=0.577]
# index=327, label=4772 [email=0.577 アドレス=0.577 欲しい=0.577]
# index=328, label=4772 [e=0.577 もらう=0.577 メールアドレス=0.577]
# index=329, label=4772 [email=0.577 もらう=0.577 アドレス=0.577]
# index=330, label=4678 [なる=0.500 ハスラー=0.500 不足=0.500 費用=0.500]--->error detected
# index=331, label=4678 [トナー=0.577 プリンターー=0.577 欲しい=0.577]
# index=332, label=4678 [トナー=0.577 プリンタ=0.577 欲しい=0.577]
# index=333, label=4678 [トナー=0.577 プリンターー=0.577 無くなる=0.577]
# index=334, label=4678 [トナー=0.577 プリンタ=0.577 無くなる=0.577]
# index=335, label=4678 [する=0.500 トナー=0.500 プリンターー=0.500 交換=0.500]
# index=336, label=4678 [する=0.500 トナー=0.500 プリンタ=0.500 交換=0.500]
# index=337, label=4835 [e=0.408 する=0.408 メール=0.408 応答=0.408 自動=0.408 設定=0.408]
# index=338, label=4835 [email=0.447 する=0.447 応答=0.447 自動=0.447 設定=0.447]
# index=339, label=4835 [e=0.447 する=0.447 メール=0.447 検索=0.447 過去=0.447]
# index=340, label=4835 [email=0.500 する=0.500 検索=0.500 過去=0.500]
# index=341, label=4836 [e=0.500 くる=0.500 メール=0.500 怪しい=0.500]
# index=342, label=4836 [email=0.577 くる=0.577 怪しい=0.577]
# index=343, label=4836 [e=0.500 くる=0.500 スパム=0.500 メール=0.500]
# index=344, label=4836 [email=0.577 くる=0.577 スパム=0.577]
# index=345, label=4693 [プリンターー=0.707 動く=0.707]
# index=346, label=4693 [プリンタ=0.707 動く=0.707]
# index=347, label=4693 [する=0.577 プリンターー=0.577 故障=0.577]
# index=348, label=4693 [する=0.577 プリンタ=0.577 故障=0.577]
# index=349, label=4700 [プリンターー=0.707 欲しい=0.707]
# index=350, label=4700 [プリンタ=0.707 欲しい=0.707]
# index=351, label=4707 [プリンターー=0.707 換える=0.707]
# index=352, label=4707 [プリンタ=0.707 換える=0.707]
# index=353, label=4772 [e=0.577 メールアドレス=0.577 無い=0.577]
# index=354, label=4772 [email=0.577 アドレス=0.577 無い=0.577]
# index=355, label=4772 [e=0.577 メールアドレス=0.577 作る=0.577]
# index=356, label=4772 [email=0.577 アドレス=0.577 作る=0.577]
# index=357, label=4772 [e=0.577 メールアドレス=0.577 欲しい=0.577]
# index=358, label=4772 [email=0.577 アドレス=0.577 欲しい=0.577]
# index=359, label=4772 [e=0.577 もらう=0.577 メールアドレス=0.577]
# index=360, label=4772 [email=0.577 もらう=0.577 アドレス=0.577]
# index=361, label=4678 [なる=0.500 ハスラー=0.500 不足=0.500 費用=0.500]--->error detected
# index=362, label=4678 [トナー=0.577 プリンターー=0.577 欲しい=0.577]
# index=363, label=4678 [トナー=0.577 プリンタ=0.577 欲しい=0.577]
# index=364, label=4678 [トナー=0.577 プリンターー=0.577 無くなる=0.577]
# index=365, label=4678 [トナー=0.577 プリンタ=0.577 無くなる=0.577]
# index=366, label=4678 [する=0.500 トナー=0.500 プリンターー=0.500 交換=0.500]
# index=367, label=4678 [する=0.500 トナー=0.500 プリンタ=0.500 交換=0.500]
# index=368, label=4835 [e=0.408 する=0.408 メール=0.408 応答=0.408 自動=0.408 設定=0.408]
# index=369, label=4835 [email=0.447 する=0.447 応答=0.447 自動=0.447 設定=0.447]
# index=370, label=4835 [e=0.447 する=0.447 メール=0.447 検索=0.447 過去=0.447]
# index=371, label=4835 [email=0.500 する=0.500 検索=0.500 過去=0.500]
# index=372, label=4836 [e=0.500 くる=0.500 メール=0.500 怪しい=0.500]
# index=373, label=4836 [email=0.577 くる=0.577 怪しい=0.577]
# index=374, label=4836 [e=0.500 くる=0.500 スパム=0.500 メール=0.500]
# index=375, label=4836 [email=0.577 くる=0.577 スパム=0.577]
# index=376, label=4677 [する=0.577 捺印=0.577 申請=0.577]--->error detected
# index=377, label=4677 [やり方=0.577 捺印=0.577 申請=0.577]
# index=378, label=4677 [手順=0.577 捺印=0.577 申請=0.577]
# index=379, label=4677 [捺印=0.500 教える=0.500 方法=0.500 申請=0.500]--->error detected
# index=380, label=4677 [やり方=0.500 捺印=0.500 申請=0.500 知る=0.500]--->error detected
# index=381, label=4677 [いただける=0.447 捺印=0.447 教える=0.447 方法=0.447 申請=0.447]--->error detected
# index=382, label=4679 [する=0.577 印鑑=0.577 捺印=0.577]
# index=383, label=4679 [する=0.577 印鑑=0.577 捺印=0.577]
# index=384, label=4679 [印鑑=0.500 必要=0.500 捺印=0.500 種類=0.500]
# index=385, label=4679 [する=0.447 印鑑=0.447 捺印=0.447 教える=0.447 種類=0.447]
# index=386, label=4679 [する=0.408 どれ=0.408 使う=0.408 印鑑=0.408 捺印=0.408 種類=0.408]
# index=387, label=4679 [する=0.577 印鑑=0.577 捺印=0.577]
# index=388, label=4680 [する=0.447 印紙=0.447 収入=0.447 欲しい=0.447 説明=0.447]
# index=389, label=4680 [印紙=0.577 収入=0.577 知る=0.577]
# index=390, label=4680 [事項=0.408 印紙=0.408 収入=0.408 教える=0.408 注意=0.408 貼る=0.408]
# index=391, label=4680 [いただける=0.500 印紙=0.500 収入=0.500 教える=0.500]
# index=392, label=4680 [印紙=0.577 収入=0.577 教える=0.577]
# index=393, label=4680 [印紙=0.577 収入=0.577 教える=0.577]
# index=394, label=4683 [契約=0.577 書=0.577 見せる=0.577]
# index=395, label=4683 [する=0.500 契約=0.500 書=0.500 確認=0.500]
# index=396, label=4683 [可能=0.500 契約=0.500 書=0.500 閲覧=0.500]
# index=397, label=4683 [契約=0.577 書=0.577 見れる=0.577]
# index=398, label=4683 [できる=0.500 契約=0.500 拝見=0.500 書=0.500]
# index=399, label=4683 [できる=0.500 契約=0.500 書=0.500 確認=0.500]
# index=400, label=4686 [出張=0.500 方法=0.500 申請=0.500 知る=0.500]
# index=401, label=4686 [出張=0.447 教える=0.447 方法=0.447 欲しい=0.447 申請=0.447]
# index=402, label=4686 [出張=0.500 方法=0.500 申請=0.500 知る=0.500]
# index=403, label=4686 [やり方=0.577 出張=0.577 申請=0.577]
# index=404, label=4686 [使い方=0.577 出張=0.577 申請=0.577]
# index=405, label=4686 [出張=0.577 方法=0.577 申請=0.577]
# index=406, label=4687 [bt=0.447 hi=0.447 per=0.447 できる=0.447 ログイン=0.447]
# index=407, label=4687 [bt=0.447 hi=0.447 per=0.447 できる=0.447 ログイン=0.447]
# index=408, label=4687 [bt=0.408 hi=0.408 per=0.408 いる=0.408 できる=0.408 ログイン=0.408]
# index=409, label=4690 [bt=0.447 hi=0.447 per=0.447 できる=0.447 登録=0.447]
# index=410, label=4690 [bt=0.447 hi=0.447 per=0.447 可能=0.447 登録=0.447]
# index=411, label=4690 [bt=0.447 hi=0.447 per=0.447 希望=0.447 登録=0.447]
# index=412, label=4691 [bt=0.408 hi=0.408 per=0.408 変える=0.408 承認=0.408 権限=0.408]--->error detected
# index=413, label=4691 [bt=0.289 hi=0.289 per=0.289 いい=0.289 する=0.577 どう=0.289 変更=0.289 承認=0.289 権限=0.289]--->error detected
# index=414, label=4691 [bt=0.333 hi=0.333 per=0.333 変更=0.333 承認=0.333 教える=0.333 方法=0.333 権限=0.333 欲しい=0.333]--->error detected
# index=415, label=4691 [bt=0.378 hi=0.378 per=0.378 できる=0.378 変更=0.378 承認=0.378 権限=0.378]--->error detected
# index=416, label=4691 [bt=0.378 hi=0.378 per=0.378 変更=0.378 希望=0.378 承認=0.378 権限=0.378]--->error detected
# index=417, label=4691 [bt=0.354 hi=0.354 per=0.354 できる=0.354 れる=0.354 変える=0.354 承認=0.354 権限=0.354]--->error detected
# index=418, label=4692 [する=0.500 小口=0.500 方法=0.500 申請=0.500]
# index=419, label=4692 [する=0.500 やり方=0.500 小口=0.500 申請=0.500]
# index=420, label=4692 [小口=0.577 方法=0.577 申請=0.577]
# index=421, label=4692 [suica=0.577 できる=0.577 登録=0.577]
# index=422, label=4692 [suica=0.500 お願い=0.500 する=0.500 登録=0.500]
# index=423, label=4692 [suica=0.500 する=0.500 希望=0.500 登録=0.500]
# index=424, label=4692 [pasmo=0.577 する=0.577 登録=0.577]
# index=425, label=4692 [pasmo=0.577 する=0.577 登録=0.577]
# index=426, label=4692 [pasmo=0.707 入れる=0.707]
# index=427, label=4692 [できる=0.577 パスモ=0.577 登録=0.577]
# index=428, label=4692 [できる=0.500 パスモ=0.500 利用=0.500 登録=0.500]
# index=429, label=4692 [パスモ=0.577 希望=0.577 登録=0.577]
# index=430, label=4692 [icoca=0.354 いい=0.354 する=0.707 どう=0.354 登録=0.354]
# index=431, label=4692 [icoca=0.500 教える=0.500 方法=0.500 登録=0.500]
# index=432, label=4692 [icoca=0.447 する=0.447 やり方=0.447 教える=0.447 登録=0.447]
# index=433, label=4692 [icoca=0.577 できる=0.577 登録=0.577]
# index=434, label=4692 [icoca=0.500 する=0.500 希望=0.500 登録=0.500]
# index=435, label=4692 [icoca=0.577 可能=0.577 登録=0.577]
# index=436, label=4693 [プリンター=0.707 動く=0.707]
# index=437, label=4693 [する=0.577 プリンター=0.577 作動=0.577]
# index=438, label=4693 [プリンター=0.707 使える=0.707]
# index=439, label=4693 [プリンター=0.707 動く=0.707]
# index=440, label=4693 [できる=0.577 プリンター=0.577 使用=0.577]
# index=441, label=4693 [プリンター=0.707 使える=0.707]
# index=442, label=4693 [する=0.577 プリンター=0.577 故障=0.577]
# index=443, label=4693 [する=0.577 プリンター=0.577 故障=0.577]
# index=444, label=4693 [プリンター=0.707 使える=0.707]
# index=445, label=4700 [ga=0.707 プリンター=0.707]
# index=446, label=4700 [する=0.577 プリンター=0.577 用意=0.577]
# index=447, label=4700 [プリンター=0.577 使える=0.577 思う=0.577]
# index=448, label=4707 [する=0.577 プリンター=0.577 交換=0.577]
# index=449, label=4707 [する=0.577 プリンター=0.577 他=0.577]
# index=450, label=4707 [プリンター=0.577 他=0.577 換える=0.577]
# index=451, label=4707 [できる=0.577 プリンター=0.577 交換=0.577]
# index=452, label=4707 [できる=0.577 プリンター=0.577 違う=0.577]
# index=453, label=4707 [する=0.577 プリンター=0.577 違う=0.577]
# index=454, label=4708 [悪い=0.500 機=0.500 複合=0.500 調子=0.500]
# index=455, label=4708 [する=0.500 作動=0.500 機=0.500 複合=0.500]
# index=456, label=4708 [しあい=0.500 機=0.500 複合=0.500 起動=0.500]
# index=457, label=4708 [動く=0.577 機=0.577 複合=0.577]
# index=458, label=4708 [使える=0.577 機=0.577 複合=0.577]--->error detected
# index=459, label=4708 [できる=0.500 使用=0.500 機=0.500 複合=0.500]
# index=460, label=4709 [する=0.500 故障=0.500 機=0.500 複合=0.500]
# index=461, label=4709 [使える=0.577 機=0.577 複合=0.577]--->error detected
# index=462, label=4709 [する=0.500 故障=0.500 機=0.500 複合=0.500]
# index=463, label=4709 [プリンタ=0.500 壊れる=0.500 機=0.500 複合=0.500]
# index=464, label=4709 [処置=0.500 動く=0.500 機=0.500 複合=0.500]
# index=465, label=4709 [する=0.577 プリンタ=0.577 動作=0.577]
# index=466, label=4710 [する=0.577 カラー=0.577 コピー=0.577]
# index=467, label=4710 [カラー=0.577 コピー=0.577 出す=0.577]
# index=468, label=4710 [カラー=0.577 コピー=0.577 使う=0.577]
# index=469, label=4710 [する=0.577 カラー=0.577 コピー=0.577]
# index=470, label=4710 [する=0.577 カラー=0.577 コピー=0.577]
# index=471, label=4710 [する=0.577 コピー=0.577 白黒=0.577]
# index=472, label=4711 [する=0.500 カラー=0.500 コピー=0.500 機能=0.500]
# index=473, label=4711 [カラー=0.577 コピー=0.577 使える=0.577]--->error detected
# index=474, label=4711 [カラー=0.577 コピー=0.577 動く=0.577]
# index=475, label=4711 [できる=0.577 カラー=0.577 コピー=0.577]
# index=476, label=4711 [する=0.577 カラー=0.577 コピー=0.577]
# index=477, label=4711 [できる=0.577 カラー=0.577 コピー=0.577]
# index=478, label=4712 [コピー=0.447 ホチキス=0.447 機=0.447 無くなる=0.447 針=0.447]
# index=479, label=4712 [する=0.408 コピー=0.408 ホチキス=0.408 機=0.408 補充=0.408 針=0.408]
# index=480, label=4712 [コピー=0.500 ホチキス=0.500 機=0.500 針=0.500]
# index=481, label=4712 [できる=0.408 コピー=0.408 ホチキス=0.408 機=0.408 補充=0.408 針=0.408]
# index=482, label=4712 [コピー=0.408 ホチキス=0.408 可能=0.408 機=0.408 補充=0.408 針=0.408]
# index=483, label=4712 [する=0.378 コピー=0.378 ホチキス=0.378 希望=0.378 機=0.378 補充=0.378 針=0.378]--->error detected
# index=484, label=4713 [イントラ=0.577 出来る=0.577 見る=0.577]
# index=485, label=4713 [イントラ=0.707 入れる=0.707]
# index=486, label=4713 [いい=0.408 する=0.408 どう=0.408 られる=0.408 イントラ=0.408 見る=0.408]
# index=487, label=4713 [イントラ=0.707 見れる=0.707]
# index=488, label=4713 [イントラ=0.707 見れる=0.707]
# index=489, label=4713 [イントラ=0.707 見る=0.707]
# index=490, label=4718 [変える=0.707 座席=0.707]
# index=491, label=4718 [なる=0.577 変更=0.577 座席=0.577]
# index=492, label=4718 [変わる=0.707 席=0.707]
# index=493, label=4718 [なる=0.577 変更=0.577 座席=0.577]
# index=494, label=4718 [変わる=0.707 座席=0.707]
# index=495, label=4718 [入れ替える=0.707 座席=0.707]
# index=496, label=4718 [できる=0.577 変更=0.577 座席=0.577]
# index=497, label=4718 [する=0.577 変更=0.577 座席=0.577]
# index=498, label=4718 [れる=0.577 変える=0.577 座席=0.577]
# index=499, label=4719 [できる=0.577 変更=0.577 座席=0.577]
# index=500, label=4719 [可能=0.577 変更=0.577 座席=0.577]
# index=501, label=4719 [いただける=0.577 変える=0.577 座席=0.577]
# index=502, label=4720 [予定=0.577 変える=0.577 座席=0.577]
# index=503, label=4720 [する=0.500 なる=0.500 変更=0.500 座席=0.500]
# index=504, label=4720 [予定=0.577 変更=0.577 座席=0.577]
# index=505, label=4720 [予定=0.577 変える=0.577 座席=0.577]
# index=506, label=4720 [する=0.577 変更=0.577 座席=0.577]
# index=507, label=4720 [れる=0.577 変える=0.577 座席=0.577]
# index=508, label=4720 [する=0.447 予定=0.447 依頼=0.447 変更=0.447 座席=0.447]
# index=509, label=4720 [変更=0.577 希望=0.577 座席=0.577]
# index=510, label=4720 [する=0.577 シート=0.577 変更=0.577]
# index=511, label=4721 [標語=1.000]
# index=512, label=4721 [ときの声=1.000]
# index=513, label=4721 [理念=1.000]
# index=514, label=4724 [カード=0.577 キー=0.577 忘れる=0.577]
# index=515, label=4724 [カード=0.500 キー=0.500 忘れる=0.500 持つ=0.500]
# index=516, label=4724 [カード=0.577 キー=0.577 持つ=0.577]
# index=517, label=4727 [なくす=0.577 カード=0.577 キー=0.577]
# index=518, label=4727 [する=0.500 カード=0.500 キー=0.500 紛失=0.500]
# index=519, label=4727 [カード=0.577 キー=0.577 落とす=0.577]
# index=520, label=4727 [カード=0.577 キー=0.577 欲しい=0.577]
# index=521, label=4727 [くださる=0.577 カード=0.577 キー=0.577]
# index=522, label=4727 [もらえる=0.577 カード=0.577 キー=0.577]
# index=523, label=4728 [する=0.447 カード=0.447 キー=0.447 ケース=0.447 破損=0.447]
# index=524, label=4728 [カードキーケース=0.707 壊れる=0.707]
# index=525, label=4728 [なる=0.447 カード=0.447 キー=0.447 ダメ=0.447 入れ物=0.447]--->error detected
# index=526, label=4728 [カード=0.500 キー=0.500 ケース=0.500 壊れる=0.500]
# index=527, label=4728 [カード=0.577 キー=0.577 入れ物=0.577]
# index=528, label=4728 [する=0.447 カード=0.447 キー=0.447 入れ物=0.447 故障=0.447]
# index=529, label=4728 [カード=0.500 キー=0.500 入れ物=0.500 壊れる=0.500]
# index=530, label=4728 [カード=0.500 キー=0.500 入れ物=0.500 壊れる=0.500]
# index=531, label=4728 [する=0.447 カード=0.447 キー=0.447 入れ物=0.447 破損=0.447]
# index=532, label=4728 [カード=0.500 キー=0.500 ケース=0.500 欲しい=0.500]
# index=533, label=4728 [カード=0.447 キー=0.447 ケース=0.447 入れる=0.447 欲しい=0.447]
# index=534, label=4728 [カードキーケース=0.707 下さる=0.707]
# index=535, label=4728 [いただける=0.500 カード=0.500 キー=0.500 入れ物=0.500]
# index=536, label=4728 [する=0.447 カード=0.447 キー=0.447 入れ物=0.447 用意=0.447]
# index=537, label=4728 [お願い=0.408 する=0.408 カード=0.408 キー=0.408 入れ物=0.408 準備=0.408]
# index=538, label=4728 [する=0.500 カード=0.500 入れ物=0.500 故障=0.500]
# index=539, label=4728 [なる=0.500 カード=0.500 ケース=0.500 悪い=0.500]
# index=540, label=4728 [なる=0.500 カード=0.500 ケース=0.500 ダメ=0.500]
# index=541, label=4728 [カード=0.577 ケース=0.577 壊れる=0.577]
# index=542, label=4728 [カード=0.577 ケース=0.577 壊れる=0.577]
# index=543, label=4728 [カード=0.577 ケース=0.577 破ける=0.577]
# index=544, label=4728 [する=0.500 カード=0.500 ケース=0.500 新しい=0.500]
# index=545, label=4728 [する=0.500 カード=0.500 ケース=0.500 別=0.500]
# index=546, label=4728 [する=0.500 カード=0.500 ケース=0.500 他=0.500]
# index=547, label=4728 [カード=0.500 ケース=0.500 変える=0.500 新しもの=0.500]
# index=548, label=4728 [できる=0.500 カード=0.500 ケース=0.500 取り換える=0.500]
# index=549, label=4728 [する=0.500 カード=0.500 ケース=0.500 新しい=0.500]
# index=550, label=4729 [する=0.408 どう=0.408 予約=0.408 会議=0.408 出来る=0.408 室=0.408]--->error detected
# index=551, label=4729 [いい=0.333 する=0.667 どう=0.333 予約=0.333 会議=0.333 室=0.333]--->error detected
# index=552, label=4729 [する=0.378 予約=0.378 会議=0.378 室=0.378 教える=0.378 方法=0.378 欲しい=0.378]--->error detected
# index=553, label=4729 [予約=0.500 会議=0.500 取る=0.500 室=0.500]
# index=554, label=4729 [する=0.500 リザーブ=0.500 会議=0.500 室=0.500]
# index=555, label=4729 [会議=0.577 使う=0.577 室=0.577]
# index=556, label=4729 [予約=0.500 会議=0.500 室=0.500 行う=0.500]
# index=557, label=4729 [会議=0.577 使う=0.577 室=0.577]
# index=558, label=4729 [会議=0.577 室=0.577 押さえる=0.577]
# index=559, label=4729 [できる=0.500 予約=0.500 会議=0.500 室=0.500]--->error detected
# index=560, label=4729 [お願い=0.447 する=0.447 予約=0.447 会議=0.447 室=0.447]--->error detected
# index=561, label=4729 [できる=0.500 予約=0.500 会議=0.500 室=0.500]--->error detected
# index=562, label=4730 [ルーム=0.408 ワーク=0.408 予約=0.408 教える=0.408 方法=0.408 欲しい=0.408]--->error detected
# index=563, label=4730 [いい=0.333 する=0.667 どう=0.333 ルーム=0.333 ワーク=0.333 予約=0.333]
# index=564, label=4730 [ルーム=0.577 ワーク=0.577 押さえる=0.577]
# index=565, label=4730 [ルーム=0.577 ワーク=0.577 借りる=0.577]
# index=566, label=4730 [ルーム=0.577 ワーク=0.577 取る=0.577]
# index=567, label=4730 [する=0.500 リザーブ=0.500 ルーム=0.500 ワーク=0.500]
# index=568, label=4730 [できる=0.500 ルーム=0.500 ワーク=0.500 予約=0.500]--->error detected
# index=569, label=4730 [ルーム=0.500 ワーク=0.500 予約=0.500 希望=0.500]--->error detected
# index=570, label=4730 [できる=0.500 ルーム=0.500 ワーク=0.500 予約=0.500]--->error detected
# index=571, label=4731 [する=0.500 予約=0.500 室=0.500 顧問=0.500]
# index=572, label=4731 [室=0.577 押さえる=0.577 顧問=0.577]
# index=573, label=4731 [借りる=0.577 室=0.577 顧問=0.577]
# index=574, label=4731 [できる=0.500 予約=0.500 室=0.500 顧問=0.500]--->error detected
# index=575, label=4731 [する=0.447 できる=0.447 使用=0.447 室=0.447 顧問=0.447]
# index=576, label=4731 [できる=0.500 使用=0.500 室=0.500 顧問=0.500]
# index=577, label=4732 [温度=0.577 部屋=0.577 高い=0.577]
# index=578, label=4732 [涼しい=0.707 部屋=0.707]
# index=579, label=4732 [下げる=0.500 暑い=0.500 温度=0.500 部屋=0.500]
# index=580, label=4732 [下げる=0.577 温度=0.577 部屋=0.577]
# index=581, label=4732 [暑い=0.707 部屋=0.707]
# index=582, label=4732 [温度=0.577 部屋=0.577 高い=0.577]
# index=583, label=4732 [冷える=0.707 部屋=0.707]
# index=584, label=4732 [とっても=0.577 寒い=0.577 部屋=0.577]
# index=585, label=4732 [寒い=0.707 部屋=0.707]
# index=586, label=4678 [会議=0.577 使える=0.577 室=0.577]
# index=587, label=4678 [できる=0.500 会議=0.500 利用=0.500 室=0.500]
# index=588, label=4678 [できる=0.500 会議=0.500 使用=0.500 室=0.500]
# index=589, label=4678 [する=0.500 会議=0.500 利用=0.500 室=0.500]
# index=590, label=4678 [する=0.500 会議=0.500 借りる=0.500 室=0.500]
# index=591, label=4678 [する=0.500 レンタル=0.500 会議=0.500 室=0.500]
# index=592, label=4678 [れる=0.500 会議=0.500 借りる=0.500 室=0.500]
# index=593, label=4678 [会議=0.577 使う=0.577 室=0.577]
# index=594, label=4678 [会議=0.577 使える=0.577 室=0.577]
# index=595, label=4678 [会議=0.500 利用=0.500 室=0.500 方法=0.500]
# index=596, label=4678 [会議=0.577 借りる=0.577 室=0.577]
# index=597, label=4678 [予約=0.447 会議=0.447 借りる=0.447 場合=0.447 室=0.447]--->error detected
# index=598, label=4678 [なる=0.447 動く=0.447 機=0.447 給=0.447 茶=0.447]
# index=599, label=4678 [する=0.447 故障=0.447 機=0.447 給=0.447 茶=0.447]
# index=600, label=4678 [お願い=0.378 する=0.378 修理=0.378 壊れる=0.378 機=0.378 給=0.378 茶=0.378]
# index=601, label=4678 [する=0.447 故障=0.447 機=0.447 給=0.447 茶=0.447]
# index=602, label=4678 [する=0.447 故障=0.447 機=0.447 給=0.447 茶=0.447]
# index=603, label=4678 [壊れる=0.500 機=0.500 給=0.500 茶=0.500]
# index=604, label=4678 [出る=0.447 機=0.447 水=0.447 給=0.447 茶=0.447]
# index=605, label=4678 [出る=0.447 機=0.447 水=0.447 給=0.447 茶=0.447]
# index=606, label=4678 [使える=0.447 機=0.447 水=0.447 給=0.447 茶=0.447]
# index=607, label=4678 [お湯=0.447 出る=0.447 機=0.447 給=0.447 茶=0.447]
# index=608, label=4678 [お湯=0.447 でる=0.447 機=0.447 給=0.447 茶=0.447]
# index=609, label=4678 [お湯=0.408 でる=0.408 機=0.408 直す=0.408 給=0.408 茶=0.408]
# index=610, label=4678 [機=0.500 粉=0.500 給=0.500 茶=0.500]
# index=611, label=4678 [ストック=0.378 切れる=0.378 機=0.378 用=0.378 粉=0.378 給=0.378 茶=0.378]
# index=612, label=4678 [切れ=0.408 在庫=0.408 機=0.408 粉=0.408 給=0.408 茶=0.408]
# index=613, label=4678 [機=0.500 粉=0.500 給=0.500 茶=0.500]
# index=614, label=4678 [ストック=0.408 切れる=0.408 機=0.408 粉=0.408 給=0.408 茶=0.408]
# index=615, label=4678 [ない=0.408 在庫=0.408 機=0.408 粉=0.408 給=0.408 茶=0.408]
# index=616, label=4678 [機=0.447 欲しい=0.447 粉=0.447 給=0.447 茶=0.447]
# index=617, label=4678 [機=0.500 粉=0.500 給=0.500 茶=0.500]
# index=618, label=4678 [くださる=0.447 機=0.447 粉=0.447 給=0.447 茶=0.447]
# index=619, label=4733 [コーヒー=0.707 ストック=0.707]
# index=620, label=4733 [コーヒー=0.707 切れる=0.707]
# index=621, label=4733 [コーヒー=0.577 切れ=0.577 在庫=0.577]
# index=622, label=4733 [コーヒー=1.000]
# index=623, label=4733 [コーヒー=0.707 欲しい=0.707]
# index=624, label=4733 [くださる=0.707 コーヒー=0.707]
# index=625, label=4678 [コーヒー=0.707 フィルター=0.707]
# index=626, label=4678 [ない=0.500 コーヒー=0.500 ストック=0.500 フィルター=0.500]--->error detected
# index=627, label=4678 [コーヒー=0.500 フィルター=0.500 切れる=0.500 在庫=0.500]
# index=628, label=4678 [コーヒー=0.707 フィルター=0.707]
# index=629, label=4678 [コーヒー=0.577 フィルター=0.577 見当たる=0.577]
# index=630, label=4678 [ない=0.577 コーヒー=0.577 フィルター=0.577]--->error detected
# index=631, label=4678 [コーヒー=0.500 ストック=0.500 切れる=0.500 豆=0.500]
# index=632, label=4678 [コーヒー=0.577 切らす=0.577 豆=0.577]
# index=633, label=4678 [ない=0.500 コーヒー=0.500 残り=0.500 豆=0.500]
# index=634, label=4678 [コーヒー=0.707 豆=0.707]
# index=635, label=4678 [もらえる=0.577 コーヒー=0.577 豆=0.577]
# index=636, label=4678 [くださる=0.577 コーヒー=0.577 豆=0.577]
# index=637, label=4678 [ない=0.500 コーヒー=0.500 在庫=0.500 豆=0.500]
# index=638, label=4678 [コーヒー=0.577 切らす=0.577 豆=0.577]
# index=639, label=4678 [コーヒー=0.577 無くなる=0.577 豆=0.577]
# index=640, label=4678 [ない=0.500 コーヒー=0.500 ミルク=0.500 使う=0.500]
# index=641, label=4678 [ない=0.500 コーヒー=0.500 ミルク=0.500 入れる=0.500]
# index=642, label=4678 [コーヒー=0.408 ミルク=0.816 入れる=0.408]
# index=643, label=4678 [コーヒー=0.707 スプーン=0.707]
# index=644, label=4678 [コーヒー=0.577 スプーン=0.577 用意=0.577]
# index=645, label=4678 [コーヒー=0.577 スプーン=0.577 見当たる=0.577]
# index=646, label=4678 [コップ=0.707 紙=0.707]
# index=647, label=4678 [ない=0.500 コップ=0.500 在庫=0.500 紙=0.500]--->error detected
# index=648, label=4678 [コップ=0.500 ストック=0.500 切れる=0.500 紙=0.500]
# index=649, label=4678 [コップ=0.577 必要=0.577 紙=0.577]
# index=650, label=4678 [コップ=0.707 紙=0.707]
# index=651, label=4678 [する=0.447 ない=0.447 コップ=0.447 用意=0.447 紙=0.447]
# index=652, label=4678 [ない=0.500 ひとつ=0.500 コップ=0.500 紙=0.500]
# index=653, label=4678 [どこ=0.577 コップ=0.577 紙=0.577]
# index=654, label=4678 [どこ=0.500 コップ=0.500 無い=0.500 紙=0.500]
# index=655, label=4678 [グラス=1.000]
# index=656, label=4678 [グラス=0.707 足る=0.707]
# index=657, label=4678 [する=0.577 グラス=0.577 不足=0.577]
# index=658, label=4678 [グラス=1.000]
# index=659, label=4678 [する=0.500 ない=0.500 グラス=0.500 用意=0.500]--->error detected
# index=660, label=4678 [お願い=0.447 する=0.447 ない=0.447 グラス=0.447 準備=0.447]--->error detected
# index=661, label=4678 [湯呑み=1.000]
# index=662, label=4678 [湯呑み=0.707 足りる=0.707]
# index=663, label=4678 [する=0.500 不足=0.500 数=0.500 湯呑み=0.500]
# index=664, label=4678 [湯呑み=1.000]
# index=665, label=4678 [湯呑み=0.707 見当たる=0.707]
# index=666, label=4678 [湯呑み=0.707 見つかる=0.707]
# index=667, label=4678 [受け=0.707 茶=0.707]
# index=668, label=4678 [切れる=0.500 受け=0.500 在庫=0.500 茶=0.500]
# index=669, label=4678 [ストック=0.577 受け=0.577 茶=0.577]
# index=670, label=4678 [ない=0.707 茶菓子=0.707]
# index=671, label=4678 [ない=0.707 デザート=0.707]
# index=672, label=4678 [つまめる=0.707 ない=0.707]
# index=673, label=4678 [お茶=0.577 受け=0.577 無い=0.577]
# index=674, label=4678 [お茶=0.707 受け=0.707]
# index=675, label=4678 [お茶=0.577 受け=0.577 欲しい=0.577]
# index=676, label=4678 [コード=0.577 延長=0.577 貸す=0.577]
# index=677, label=4678 [いい=0.500 コード=0.500 借りる=0.500 延長=0.500]
# index=678, label=4678 [コード=0.447 使う=0.447 可能=0.447 延長=0.447 貸出=0.447]
# index=679, label=4678 [られる=0.500 コード=0.500 借りる=0.500 延長=0.500]
# index=680, label=4678 [コード=0.577 延長=0.577 貸す=0.577]
# index=681, label=4678 [コード=0.577 延長=0.577 貸与=0.577]
# index=682, label=4678 [コード=0.500 延長=0.500 欲しい=0.500 貸す=0.500]
# index=683, label=4678 [コード=0.577 延長=0.577 貸す=0.577]
# index=684, label=4678 [コード=0.500 可能=0.500 延長=0.500 貸し出し=0.500]
# index=685, label=4678 [れる=0.500 コード=0.500 借りる=0.500 延長=0.500]
# index=686, label=4678 [コード=0.500 借りる=0.500 延長=0.500 知る=0.500]
# index=687, label=4678 [できる=0.500 コード=0.500 借りる=0.500 延長=0.500]
# index=688, label=4678 [する=0.500 コード=0.500 使用=0.500 延長=0.500]
# index=689, label=4678 [コード=0.500 延長=0.500 欲しい=0.500 貸す=0.500]
# index=690, label=4678 [られる=0.500 コード=0.500 借りる=0.500 延長=0.500]
# index=691, label=4678 [できる=0.500 コード=0.500 使用=0.500 延長=0.500]
# index=692, label=4678 [する=0.500 コード=0.500 利用=0.500 延長=0.500]
# index=693, label=4678 [コード=0.577 使える=0.577 延長=0.577]
# index=694, label=4678 [できる=0.577 テプラ=0.577 利用=0.577]
# index=695, label=4678 [する=0.577 テプラ=0.577 使用=0.577]
# index=696, label=4678 [テプラ=0.577 使用=0.577 希望=0.577]
# index=697, label=4678 [テプラ=0.707 使える=0.707]
# index=698, label=4678 [お願い=0.500 する=0.500 テプラ=0.500 用意=0.500]--->error detected
# index=699, label=4678 [できる=0.577 テプラ=0.577 利用=0.577]
# index=700, label=4678 [ic=0.577 レコーダー=0.577 使える=0.577]
# index=701, label=4678 [ic=0.500 できる=0.500 レコーダー=0.500 使用=0.500]
# index=702, label=4678 [ic=0.500 レコーダー=0.500 使える=0.500 思う=0.500]--->error detected
# index=703, label=4678 [ic=0.500 れる=0.500 レコーダー=0.500 借りる=0.500]
# index=704, label=4678 [ic=0.577 レコーダー=0.577 貸す=0.577]
# index=705, label=4678 [ic=0.500 レコーダー=0.500 可能=0.500 貸し出し=0.500]--->error detected
# index=706, label=4678 [ic=0.577 レコーダー=0.577 使える=0.577]
# index=707, label=4678 [ic=0.500 できる=0.500 レコーダー=0.500 利用=0.500]
# index=708, label=4678 [ic=0.500 れる=0.500 レコーダー=0.500 借りる=0.500]
# index=709, label=4734 [する=0.577 ビデオカメラ=0.577 使用=0.577]
# index=710, label=4734 [する=0.500 ビデオカメラ=0.500 使用=0.500 希望=0.500]
# index=711, label=4734 [いい=0.577 ビデオカメラ=0.577 使う=0.577]
# index=712, label=4734 [ビデオカメラ=0.707 使える=0.707]
# index=713, label=4734 [できる=0.577 ビデオカメラ=0.577 利用=0.577]
# index=714, label=4734 [する=0.500 ビデオカメラ=0.500 使用=0.500 希望=0.500]
# index=715, label=4678 [ビデオカメラ=0.707 貸す=0.707]
# index=716, label=4678 [ビデオカメラ=0.577 可能=0.577 貸し出し=0.577]
# index=717, label=4678 [いい=0.577 ビデオカメラ=0.577 借りる=0.577]
# index=718, label=4678 [れる=0.577 ビデオカメラ=0.577 借りる=0.577]
# index=719, label=4678 [ビデオカメラ=0.707 借りる=0.707]
# index=720, label=4678 [ビデオカメラ=0.577 借りる=0.577 可能=0.577]
# index=721, label=4735 [sd=0.707 カード=0.707]
# index=722, label=4735 [カード=0.577 見当たる=0.577 ｓｄ=0.577]
# index=723, label=4735 [sd=0.707 カード=0.707]
# index=724, label=4735 [sd=0.577 ない=0.577 カード=0.577]--->error detected
# index=725, label=4735 [sd=0.577 どこ=0.577 カード=0.577]
# index=726, label=4738 [する=0.577 デジカメ=0.577 使用=0.577]
# index=727, label=4738 [デジカメ=0.577 使用=0.577 可能=0.577]
# index=728, label=4738 [いい=0.577 デジカメ=0.577 使う=0.577]
# index=729, label=4738 [デジカメ=0.707 使える=0.707]
# index=730, label=4738 [できる=0.577 デジカメ=0.577 利用=0.577]
# index=731, label=4738 [できる=0.577 デジカメ=0.577 使用=0.577]
# index=732, label=4739 [デジカメ=0.577 欲しい=0.577 貸す=0.577]
# index=733, label=4739 [れる=0.577 デジカメ=0.577 借りる=0.577]
# index=734, label=4739 [せる=0.577 デジカメ=0.577 使う=0.577]
# index=735, label=4739 [カメラ=0.577 デジタル=0.577 借りる=0.577]
# index=736, label=4739 [カメラ=0.577 デジタル=0.577 使える=0.577]
# index=737, label=4739 [れる=0.447 カメラ=0.447 デジタル=0.447 借りる=0.447 教える=0.447]
# index=738, label=4740 [する=0.577 三脚=0.577 使用=0.577]
# index=739, label=4740 [いい=0.577 三脚=0.577 使う=0.577]
# index=740, label=4740 [られる=0.500 三脚=0.500 使用=0.500 認める=0.500]
# index=741, label=4740 [つかえる=0.707 三脚=0.707]
# index=742, label=4740 [いい=0.577 三脚=0.577 使う=0.577]
# index=743, label=4740 [三脚=0.500 使用=0.500 可能=0.500 知る=0.500]
# index=744, label=4741 [れる=0.577 三脚=0.577 借りる=0.577]
# index=745, label=4741 [三脚=0.707 使える=0.707]
# index=746, label=4741 [する=0.500 三脚=0.500 使用=0.500 希望=0.500]
# index=747, label=4742 [aed=0.577 欲しい=0.577 貸す=0.577]
# index=748, label=4742 [aed=0.707 貸す=0.707]
# index=749, label=4742 [aed=0.577 可能=0.577 貸し出し=0.577]--->error detected
# index=750, label=4742 [aed=0.707 貸す=0.707]
# index=751, label=4742 [aed=0.577 られる=0.577 借りる=0.577]
# index=752, label=4742 [aed=0.707 レンタル=0.707]
# index=753, label=4742 [aed=0.707 借りる=0.707]
# index=754, label=4742 [aed=0.577 れる=0.577 借りる=0.577]
# index=755, label=4742 [aed=0.577 できる=0.577 借りる=0.577]
# index=756, label=4743 [ポインター=0.500 レーザー=0.500 欲しい=0.500 貸す=0.500]
# index=757, label=4743 [する=0.500 ポインター=0.500 レーザー=0.500 使用=0.500]
# index=758, label=4743 [する=0.447 ポインター=0.447 レーザー=0.447 使用=0.447 貸す=0.447]
# index=759, label=4743 [ポインター=0.577 レーザー=0.577 使える=0.577]
# index=760, label=4743 [する=0.447 ポインター=0.447 レーザー=0.447 使用=0.447 希望=0.447]
# index=761, label=4743 [できる=0.500 ポインター=0.500 レーザー=0.500 利用=0.500]
# index=762, label=4744 [ポインター=0.500 レーザー=0.500 欲しい=0.500 貸す=0.500]
# index=763, label=4744 [ポインター=0.500 レーザー=0.500 可能=0.500 貸し出し=0.500]
# index=764, label=4744 [いい=0.500 ポインター=0.500 レーザー=0.500 借りる=0.500]
# index=765, label=4744 [ポインター=0.577 レーザー=0.577 使える=0.577]
# index=766, label=4744 [ポインター=0.447 レーザー=0.447 使用=0.447 可能=0.447 知る=0.447]
# index=767, label=4744 [できる=0.500 ポインター=0.500 レーザー=0.500 利用=0.500]
# index=768, label=4678 [する=0.447 システム=0.447 会議=0.447 使用=0.447 電話=0.447]
# index=769, label=4678 [する=0.354 システム=0.354 会議=0.707 使う=0.354 電話=0.354]
# index=770, label=4678 [いい=0.316 する=0.632 どう=0.316 システム=0.316 会議=0.316 利用=0.316 電話=0.316]
# index=771, label=4678 [システム=0.408 会議=0.408 使い方=0.408 教える=0.408 欲しい=0.408 電話=0.408]
# index=772, label=4678 [システム=0.447 会議=0.447 使い方=0.447 知る=0.447 電話=0.447]
# index=773, label=4678 [する=0.632 どう=0.316 システム=0.316 会議=0.316 利用=0.316 良い=0.316 電話=0.316]
# index=774, label=4678 [システム=0.500 会議=0.500 使える=0.500 電話=0.500]
# index=775, label=4678 [できる=0.447 システム=0.447 会議=0.447 利用=0.447 電話=0.447]
# index=776, label=4678 [つかえる=0.500 システム=0.500 会議=0.500 電話=0.500]
# index=777, label=4678 [システム=0.500 会議=0.500 借りる=0.500 電話=0.500]
# index=778, label=4678 [システム=0.500 会議=0.500 借りる=0.500 電話=0.500]
# index=779, label=4678 [れる=0.447 システム=0.447 会議=0.447 借りる=0.447 電話=0.447]
# index=780, label=4678 [プロジェクター=0.707 使える=0.707]
# index=781, label=4678 [できる=0.577 プロジェクター=0.577 利用=0.577]
# index=782, label=4678 [プロジェクター=0.707 使える=0.707]
# index=783, label=4678 [する=0.500 せる=0.500 プロジェクター=0.500 故障=0.500]
# index=784, label=4678 [する=0.577 プロジェクター=0.577 破壊=0.577]
# index=785, label=4678 [プロジェクター=0.577 与える=0.577 損傷=0.577]
# index=786, label=4678 [プロジェクター=0.707 壊れる=0.707]
# index=787, label=4678 [できる=0.577 プロジェクター=0.577 使う=0.577]
# index=788, label=4678 [できる=0.577 プロジェクター=0.577 使用=0.577]
# index=789, label=4678 [プロジェクター=1.000]
# index=790, label=4678 [プロジェクター=0.707 見つかる=0.707]
# index=791, label=4678 [なくなる=0.707 プロジェクター=0.707]
# index=792, label=4678 [する=0.577 プロジェクター=0.577 使用=0.577]
# index=793, label=4678 [する=0.577 プロジェクター=0.577 利用=0.577]
# index=794, label=4678 [プロジェクター=0.577 使用=0.577 希望=0.577]
# index=795, label=4678 [する=0.577 プロジェクター=0.577 利用=0.577]
# index=796, label=4678 [する=0.577 プロジェクター=0.577 使用=0.577]
# index=797, label=4678 [プロジェクター=0.707 用いる=0.707]
# index=798, label=4678 [プロジェクター=0.707 使える=0.707]
# index=799, label=4678 [プロジェクター=0.707 使える=0.707]
# index=800, label=4678 [できる=0.577 プロジェクター=0.577 使用=0.577]
# index=801, label=4678 [する=0.500 プロジェクター=0.500 利用=0.500 方法=0.500]
# index=802, label=4678 [プロジェクター=0.577 使い方=0.577 知る=0.577]
# index=803, label=4678 [する=0.500 プロジェクター=0.500 利用=0.500 手順=0.500]
# index=804, label=4678 [できる=0.577 プロジェクター=0.577 予約=0.577]--->error detected
# index=805, label=4678 [プロジェクター=0.707 使える=0.707]
# index=806, label=4678 [する=0.447 できる=0.447 プロジェクター=0.447 予約=0.447 利用=0.447]
# index=807, label=4678 [れる=0.577 プロジェクター=0.577 借りる=0.577]
# index=808, label=4678 [プロジェクター=0.707 使える=0.707]
# index=809, label=4678 [プロジェクター=0.577 使用=0.577 希望=0.577]
# index=810, label=4745 [ipad=0.577 する=0.577 使用=0.577]
# index=811, label=4745 [ipad=0.577 いい=0.577 使う=0.577]
# index=812, label=4745 [ipad=0.500 する=0.500 使用=0.500 希望=0.500]
# index=813, label=4745 [ipad=0.577 する=0.577 使用=0.577]
# index=814, label=4745 [ipad=0.707 使える=0.707]
# index=815, label=4745 [ipad=0.577 使う=0.577 大丈夫=0.577]
# index=816, label=4745 [ipad=0.577 できる=0.577 使用=0.577]
# index=817, label=4745 [ipad=0.577 利用=0.577 希望=0.577]
# index=818, label=4745 [ipad=0.707 使える=0.707]
# index=819, label=4678 [ipad=0.707 借りる=0.707]
# index=820, label=4678 [ipad=0.707 使える=0.707]
# index=821, label=4678 [ipad=0.577 いい=0.577 使う=0.577]
# index=822, label=4750 [コート=0.577 ハンガー=0.577 使える=0.577]
# index=823, label=4750 [する=0.500 コート=0.500 ハンガー=0.500 利用=0.500]
# index=824, label=4750 [いい=0.500 コート=0.500 ハンガー=0.500 使う=0.500]
# index=825, label=4750 [コート=0.577 ハンガー=0.577 使える=0.577]
# index=826, label=4750 [できる=0.500 コート=0.500 ハンガー=0.500 使用=0.500]
# index=827, label=4750 [コート=0.577 ハンガー=0.577 使える=0.577]
# index=828, label=4750 [コート=0.577 使える=0.577 掛け=0.577]
# index=829, label=4750 [できる=0.500 コート=0.500 使用=0.500 掛け=0.500]
# index=830, label=4750 [コート=0.500 使える=0.500 掛け=0.500 知る=0.500]
# index=831, label=4751 [なる=0.577 ダメ=0.577 携帯=0.577]
# index=832, label=4751 [する=0.577 携帯=0.577 故障=0.577]
# index=833, label=4751 [なる=0.577 悪い=0.577 携帯=0.577]
# index=834, label=4751 [壊れる=0.707 携帯=0.707]
# index=835, label=4751 [壊れる=0.707 携帯=0.707]
# index=836, label=4751 [する=0.577 携帯=0.577 破損=0.577]
# index=837, label=4751 [する=0.577 携帯=0.577 故障=0.577]
# index=838, label=4751 [スマホ=0.707 動く=0.707]
# index=839, label=4751 [スマ=0.500 壊れる=0.500 対処=0.500 携帯=0.500]
# index=840, label=4752 [する=0.577 動作=0.577 携帯=0.577]
# index=841, label=4752 [動く=0.577 壊れる=0.577 携帯=0.577]
# ...
# index=3822, label=4713 [られる=0.577 イントラ=0.577 見る=0.577]
# index=3823, label=4718 [する=0.577 変更=0.577 座席=0.577]
# index=3824, label=4719 [する=0.577 変更=0.577 座席=0.577]
# index=3825, label=4720 [する=0.500 予定=0.500 変更=0.500 座席=0.500]
# index=3826, label=4721 [スローガン=1.000]
# index=3827, label=4724 [カード=0.577 キー=0.577 忘れる=0.577]
# index=3828, label=4727 [カード=0.577 キー=0.577 無い=0.577]
# index=3829, label=4728 [カード=0.500 キー=0.500 入れ物=0.500 壊れる=0.500]
# index=3830, label=4728 [カード=0.500 キー=0.500 入れ物=0.500 欲しい=0.500]
# index=3831, label=4728 [カード=0.577 ケース=0.577 壊れる=0.577]
# index=3832, label=4728 [カード=0.577 ケース=0.577 取り替える=0.577]
# index=3833, label=4729 [する=0.500 予約=0.500 会議=0.500 室=0.500]--->error detected
# index=3834, label=4730 [する=0.500 ルーム=0.500 ワーク=0.500 予約=0.500]
# index=3835, label=4731 [する=0.500 予約=0.500 室=0.500 顧問=0.500]
# index=3836, label=4732 [暑い=0.707 部屋=0.707]
# index=3837, label=4732 [寒い=0.707 部屋=0.707]
# index=3838, label=4678 [会議=0.577 使う=0.577 室=0.577]
# index=3839, label=4678 [会議=0.577 借りる=0.577 室=0.577]
# index=3840, label=4678 [壊れる=0.500 機=0.500 給=0.500 茶=0.500]
# index=3841, label=4678 [出る=0.447 機=0.447 水=0.447 給=0.447 茶=0.447]
# index=3842, label=4678 [お湯=0.447 出る=0.447 機=0.447 給=0.447 茶=0.447]
# index=3843, label=4678 [機=0.447 無い=0.447 粉=0.447 給=0.447 茶=0.447]
# index=3844, label=4733 [コーヒー=0.707 無い=0.707]
# index=3845, label=4678 [コーヒー=0.577 フィルター=0.577 無い=0.577]
# index=3846, label=4678 [コーヒー=0.577 無い=0.577 豆=0.577]
# index=3847, label=4678 [ない=0.577 コーヒー=0.577 ミルク=0.577]
# index=3848, label=4678 [コーヒー=0.577 スプーン=0.577 無い=0.577]
# index=3849, label=4678 [コップ=0.577 無い=0.577 紙=0.577]
# index=3850, label=4678 [グラス=0.707 無い=0.707]
# index=3851, label=4678 [湯呑み=0.707 無い=0.707]
# index=3852, label=4678 [受け=0.577 無い=0.577 茶=0.577]
# index=3853, label=4678 [コード=0.577 借りる=0.577 延長=0.577]
# index=3854, label=4678 [コード=0.577 使う=0.577 延長=0.577]
# index=3855, label=4678 [テプラ=0.707 使う=0.707]
# index=3856, label=4678 [テプラ=0.707 借りる=0.707]
# index=3857, label=4678 [ic=0.577 レコーダー=0.577 使う=0.577]
# index=3858, label=4678 [ic=0.577 レコーダー=0.577 借りる=0.577]
# index=3859, label=4734 [ビデオカメラ=0.707 使う=0.707]
# index=3860, label=4678 [ビデオカメラ=0.707 借りる=0.707]
# index=3861, label=4735 [sd=0.577 カード=0.577 無い=0.577]
# index=3862, label=4738 [デジカメ=0.707 使う=0.707]
# index=3863, label=4739 [デジカメ=0.707 借りる=0.707]
# index=3864, label=4740 [三脚=0.707 使う=0.707]
# index=3865, label=4741 [三脚=0.707 借りる=0.707]
# index=3866, label=4742 [aed=0.707 借りる=0.707]
# index=3867, label=4743 [ポインター=0.577 レーザー=0.577 使う=0.577]
# index=3868, label=4744 [ポインター=0.577 レーザー=0.577 借りる=0.577]
# index=3869, label=4678 [システム=0.500 会議=0.500 使う=0.500 電話=0.500]
# index=3870, label=4678 [システム=0.500 会議=0.500 借りる=0.500 電話=0.500]
# index=3871, label=4678 [プロジェクター=0.707 壊れる=0.707]
# index=3872, label=4678 [プロジェクター=0.707 壊す=0.707]
# index=3873, label=4678 [プロジェクター=0.707 無い=0.707]
# index=3874, label=4678 [プロジェクター=0.707 使う=0.707]
# index=3875, label=4678 [する=0.577 プロジェクター=0.577 予約=0.577]
# index=3876, label=4678 [プロジェクター=0.707 借りる=0.707]
# index=3877, label=4745 [ipad=0.707 使う=0.707]
# index=3878, label=4678 [ipad=0.707 借りる=0.707]
# index=3879, label=4750 [コート=0.577 ハンガー=0.577 使う=0.577]
# index=3880, label=4750 [コート=0.577 使う=0.577 掛け=0.577]
# index=3881, label=4751 [壊れる=0.707 携帯=0.707]
# index=3882, label=4752 [動く=0.707 携帯=0.707]
# index=3883, label=4753 [換える=0.707 携帯=0.707]
# index=3884, label=4754 [する=0.408 交換=0.408 携帯=0.408 早い=0.408 減る=0.408 電池=0.408]
# index=3885, label=4755 [iphone=0.577 メッセージ=0.577 壊れる=0.577]
# index=3886, label=4756 [iphone=0.577 メッセージ=0.577 送れる=0.577]
# index=3887, label=4757 [iphone=0.577 メッセージ=0.577 届く=0.577]
# index=3888, label=4758 [iphone=0.577 メッセージ=0.577 重い=0.577]
# index=3889, label=4759 [iphone=0.577 メッセージ=0.577 動く=0.577]
# index=3890, label=4758 [iphone=0.500 メッセージ=0.500 動き=0.500 遅い=0.500]
# index=3891, label=4760 [iphone=0.408 する=0.408 交換=0.408 早い=0.408 減る=0.408 電池=0.408]
# index=3892, label=4678 [カバー=0.447 スマ=0.447 ホ=0.447 携帯=0.447 欲しい=0.447]
# index=3893, label=4678 [する=0.378 ほしい=0.378 カバー=0.378 スマ=0.378 ホ=0.378 交換=0.378 携帯=0.378]
# index=3894, label=4678 [スマ=0.447 フィルム=0.447 ホ=0.447 携帯=0.447 欲しい=0.447]
# index=3895, label=4678 [する=0.378 ほしい=0.378 スマ=0.378 フィルム=0.378 ホ=0.378 交換=0.378 携帯=0.378]
# index=3896, label=4678 [お守り=0.577 ステッカー=0.577 欲しい=0.577]
# index=3897, label=4761 [イヤ=0.577 ホン=0.577 壊れる=0.577]
# index=3898, label=4678 [イヤ=0.500 ホン=0.500 新しい=0.500 欲しい=0.500]
# index=3899, label=4678 [する=0.447 ほしい=0.447 イヤ=0.447 ホン=0.447 交換=0.447]
# index=3900, label=4762 [コード=0.577 充電=0.577 切れる=0.577]
# index=3901, label=4766 [コード=0.577 充電=0.577 壊れる=0.577]
# index=3902, label=4767 [コード=0.500 充電=0.500 新しい=0.500 欲しい=0.500]
# index=3903, label=4678 [する=0.447 ほしい=0.447 コード=0.447 交換=0.447 充電=0.447]
# index=3904, label=4678 [する=0.577 変更=0.577 機種=0.577]
# index=3905, label=4678 [iphone=0.707 する=0.707]
# index=3906, label=4678 [する=0.707 ガラケー=0.707]
# index=3907, label=4678 [する=0.500 帳=0.500 更新=0.500 電話=0.500]
# index=3908, label=4678 [する=0.447 スマホ=0.447 帳=0.447 更新=0.447 電話=0.447]--->error detected
# index=3909, label=4678 [する=0.447 スマホ=0.447 先=0.447 更新=0.447 連絡=0.447]--->error detected
# index=3910, label=4678 [する=0.447 帳=0.447 携帯=0.447 更新=0.447 電話=0.447]
# index=3911, label=4678 [する=0.447 先=0.447 携帯=0.447 更新=0.447 連絡=0.447]--->error detected
# index=3912, label=4772 [メールアドレス=0.707 無い=0.707]
# index=3913, label=4772 [メールアドレス=0.707 作る=0.707]
# index=3914, label=4772 [メールアドレス=0.707 欲しい=0.707]
# index=3915, label=4772 [もらう=0.707 メールアドレス=0.707]
# index=3916, label=4678 [取れる=0.577 決裁=0.577 知る=0.577]
# index=3917, label=4776 [どこ=0.447 今=0.447 回る=0.447 決裁=0.447 知る=0.447]
# index=3918, label=4781 [決裁=0.577 見る=0.577 過去=0.577]
# index=3919, label=4782 [捺印=0.577 知る=0.577 終わる=0.577]
# index=3920, label=4678 [どこ=0.447 今=0.447 回る=0.447 捺印=0.447 知る=0.447]
# index=3921, label=4678 [ex=0.577 カード=0.577 借りる=0.577]
# index=3922, label=4678 [する=0.707 出張=0.707]
# index=3923, label=4678 [コピー=0.577 欲しい=0.577 用紙=0.577]
# index=3924, label=4678 [コピー=0.577 無い=0.577 用紙=0.577]
# index=3925, label=4678 [封筒=0.707 欲しい=0.707]
# index=3926, label=4678 [封筒=0.707 買う=0.707]
# index=3927, label=4678 [封筒=0.707 無い=0.707]
# index=3928, label=4678 [会社=0.577 概要=0.577 欲しい=0.577]
# index=3929, label=4678 [会社=0.577 概要=0.577 無い=0.577]
# index=3930, label=4678 [会社=0.577 案内=0.577 欲しい=0.577]
# index=3931, label=4678 [会社=0.577 案内=0.577 無い=0.577]
# index=3932, label=4678 [欲しい=0.707 紙袋=0.707]
# index=3933, label=4678 [無い=0.707 紙袋=0.707]
# index=3934, label=4678 [ラミネートフィルム=0.707 使う=0.707]
# index=3935, label=4678 [ラミネートフィルム=0.707 借りる=0.707]
# index=3936, label=4678 [ひも=0.707 欲しい=0.707]
# index=3937, label=4678 [ひも=0.707 無くなる=0.707]
# index=3938, label=4678 [コップ=0.577 欲しい=0.577 紙=0.577]
# index=3939, label=4678 [ゴミ=0.707 捨てる=0.707]
# index=3940, label=4678 [いっぱい=0.577 なる=0.577 ゴミ=0.577]
# index=3941, label=4678 [捨てる=0.707 段ボール=0.707]
# index=3942, label=4678 [捨てる=0.707 電池=0.707]
# index=3943, label=4678 [割れ物=0.707 捨てる=0.707]
# index=3944, label=4678 [来社=0.500 欲しい=0.500 票=0.500 記録=0.500]
# index=3945, label=4678 [来社=0.500 無い=0.500 票=0.500 記録=0.500]
# index=3946, label=4678 [受付=0.447 来社=0.447 票=0.447 置く=0.447 記録=0.447]
# index=3947, label=4678 [どこ=0.408 わかる=0.408 来社=0.408 票=0.408 置く=0.408 記録=0.408]--->error detected
# index=3948, label=4678 [届く=0.707 落とし物=0.707]
# index=3949, label=4678 [落とし物=0.707 見つける=0.707]
# index=3950, label=4678 [ポスター=0.707 貼る=0.707]
# index=3951, label=4678 [掃除=0.577 欲しい=0.577 道具=0.577]
# index=3952, label=4678 [借りる=0.577 掃除=0.577 道具=0.577]
# index=3953, label=4678 [欲しい=0.707 雑巾=0.707]
# index=3954, label=4678 [借りる=0.707 雑巾=0.707]
# index=3955, label=4678 [買う=0.707 雑巾=0.707]
# index=3956, label=4678 [ふきん=0.707 無くなる=0.707]
# index=3957, label=4678 [ふきん=0.707 欲しい=0.707]
# index=3958, label=4678 [ふきん=0.707 買う=0.707]
# index=3959, label=4678 [洗剤=0.707 無くなる=0.707]
# index=3960, label=4678 [欲しい=0.707 洗剤=0.707]
# index=3961, label=4678 [洗剤=0.707 買う=0.707]
# index=3962, label=4678 [スポンジ=0.707 無くなる=0.707]
# index=3963, label=4678 [スポンジ=0.707 欲しい=0.707]
# index=3964, label=4678 [スポンジ=0.707 買う=0.707]
# index=3965, label=4678 [する=0.577 スポンジ=0.577 交換=0.577]
# index=3966, label=4678 [枯れる=0.577 植物=0.577 観葉=0.577]
# index=3967, label=4678 [捨てる=0.577 植物=0.577 観葉=0.577]
# index=3968, label=4678 [する=0.447 せる=0.447 植物=0.447 移動=0.447 観葉=0.447]
# index=3969, label=4783 [ほしい=0.577 券=0.577 定期=0.577]
# index=3970, label=4678 [ヘルメット=0.707 欲しい=0.707]
# index=3971, label=4678 [ヘルメット=0.707 無い=0.707]
# index=3972, label=4678 [欲しい=0.707 軍手=0.707]
# index=3973, label=4678 [無い=0.707 軍手=0.707]
# index=3974, label=4678 [ハンガー=0.577 マグネット=0.577 欲しい=0.577]
# index=3975, label=4678 [ハンガー=0.577 マグネット=0.577 無い=0.577]
# index=3976, label=4678 [伝票=0.500 宅配=0.500 欲しい=0.500 見る=0.500]
# index=3977, label=4678 [何=0.500 便=0.500 時=0.500 社内=0.500]
# index=3978, label=4678 [何=0.500 便=0.500 宅配=0.500 時=0.500]
# index=3979, label=4678 [ヤマト=0.500 何=0.500 便=0.500 時=0.500]
# index=3980, label=4678 [佐川急便=0.577 何=0.577 時=0.577]
# index=3981, label=4678 [ゆう=0.500 パック=0.500 何=0.500 時=0.500]
# index=3982, label=4678 [グループ=0.447 パソナ=0.447 便=0.447 社内=0.447 送れる=0.447]--->error detected
# index=3983, label=4678 [ソリューションズ=0.500 便=0.500 社内=0.500 送れる=0.500]
# index=3984, label=4678 [ヘルスケア=0.500 便=0.500 社内=0.500 送れる=0.500]
# index=3985, label=4678 [ペイロール=0.500 便=0.500 社内=0.500 送れる=0.500]
# index=3986, label=4678 [便=0.408 封筒=0.408 欲しい=0.408 無い=0.408 無くなる=0.408 社内=0.408]
# index=3987, label=4678 [出す=0.707 郵便=0.707]
# index=3988, label=4678 [ハスラー=0.577 使い方=0.577 分かる=0.577]
# index=3989, label=4678 [ハスラー=0.707 動く=0.707]
# index=3990, label=4678 [ハスラー=0.577 押す=0.577 間違える=0.577]
# index=3991, label=4678 [シール=0.707 無い=0.707]
# index=3992, label=4678 [インク=0.577 ハスラー=0.577 切れる=0.577]
# index=3993, label=4678 [なる=0.500 ハスラー=0.500 不足=0.500 残高=0.500]--->error detected
# index=3994, label=4678 [なる=0.500 ハスラー=0.500 不足=0.500 料金=0.500]--->error detected
# index=3995, label=4786 [する=0.354 利用=0.354 発送=0.354 確認=0.354 者=0.707]
# index=3996, label=4678 [壊れる=0.707 椅子=0.707]
# index=3997, label=4678 [する=0.500 ほしい=0.500 交換=0.500 椅子=0.500]
# index=3998, label=4678 [壊れる=0.707 机=0.707]
# index=3999, label=4678 [する=0.500 ほしい=0.500 交換=0.500 机=0.500]
# index=4000, label=4678 [椅子=0.707 欲しい=0.707]
# index=4001, label=4678 [机=0.707 欲しい=0.707]
# index=4002, label=4678 [ない=0.577 固定=0.577 電話機=0.577]--->error detected
# index=4003, label=4678 [固定=0.577 欲しい=0.577 電話機=0.577]
# index=4004, label=4678 [作る=0.707 合鍵=0.707]
# index=4005, label=4678 [机=0.577 無い=0.577 鍵=0.577]
# index=4006, label=4678 [キャビネット=0.577 無い=0.577 鍵=0.577]
# index=4007, label=4678 [トナー=0.577 プリンター=0.577 欲しい=0.577]
# index=4008, label=4678 [トナー=0.577 プリンター=0.577 無くなる=0.577]
# index=4009, label=4678 [する=0.500 トナー=0.500 プリンター=0.500 交換=0.500]
# index=4010, label=4678 [ずれる=0.577 時刻=0.577 時計=0.577]
# index=4011, label=4678 [時計=0.577 止まる=0.577 針=0.577]
# index=4012, label=4678 [ずれる=0.500 ほしい=0.500 チャイム=0.500 直す=0.500]
# index=4013, label=4678 [パンチ=0.500 借りる=0.500 穴=0.500 開ける=0.500]
# index=4014, label=4678 [ホチキス=0.577 厚い=0.577 止める=0.577]--->error detected
# index=4015, label=4678 [クリア=0.577 ファイル=0.577 無い=0.577]
# index=4016, label=4678 [クリア=0.577 ファイル=0.577 欲しい=0.577]
# index=4017, label=4678 [いる=0.500 なる=0.500 クリア=0.500 ファイル=0.500]
# index=4018, label=4734 [借りる=0.707 台車=0.707]
# index=4019, label=4792 [使う=0.707 台車=0.707]
# index=4020, label=4793 [借りる=0.707 脚立=0.707]
# index=4021, label=4794 [使う=0.707 脚立=0.707]
# index=4022, label=4678 [ドライバー=0.707 借りる=0.707]
# index=4023, label=4678 [切れる=0.707 電気=0.707]
# index=4024, label=4678 [切れる=0.577 灯=0.577 蛍光=0.577]
# index=4025, label=4678 [こぼす=0.707 ジュース=0.707]
# index=4026, label=4678 [こぼす=0.707 コーヒー=0.707]
# index=4027, label=4678 [お茶=0.707 こぼす=0.707]
# index=4028, label=4678 [床=0.707 汚す=0.707]
# index=4029, label=4678 [ブラインド=0.707 壊れる=0.707]
# index=4030, label=4678 [ブラインド=0.707 動く=0.707]
# index=4031, label=4678 [テプラ=0.577 テープ=0.577 無くなる=0.577]--->error detected
# index=4032, label=4678 [テプラ=0.577 テープ=0.577 欲しい=0.577]
# index=4033, label=4678 [文具=0.707 欲しい=0.707]
# index=4034, label=4678 [テープ=0.577 欲しい=0.577 製本=0.577]
# index=4035, label=4678 [テープ=0.577 使う=0.577 製本=0.577]
# index=4036, label=4678 [欲しい=0.707 電池=0.707]
# index=4037, label=4678 [無くなる=0.707 電池=0.707]
# index=4038, label=4678 [付箋=0.707 欲しい=0.707]
# index=4039, label=4678 [付箋=0.707 無くなる=0.707]
# index=4040, label=4678 [ほしい=0.707 ホワイトボードマーカー=0.707]
# index=4041, label=4678 [ホワイトボードマーカー=0.707 無くなる=0.707]
# index=4042, label=4678 [ガム=0.577 テープ=0.577 欲しい=0.577]
# index=4043, label=4678 [ガム=0.577 テープ=0.577 無くなる=0.577]
# index=4044, label=4678 [セロテープ=0.707 欲しい=0.707]
# index=4045, label=4678 [セロテープ=0.707 無くなる=0.707]
# index=4046, label=4678 [欲しい=0.707 消しゴム=0.707]
# index=4047, label=4678 [消しゴム=0.707 無くなる=0.707]
# index=4048, label=4678 [シャー=0.500 ペン=0.500 欲しい=0.500 芯=0.500]
# index=4049, label=4678 [シャー=0.500 ペン=0.500 無くなる=0.500 芯=0.500]
# index=4050, label=4678 [ホチキス=0.577 欲しい=0.577 針=0.577]
# index=4051, label=4678 [ホチキス=0.577 無くなる=0.577 針=0.577]
# index=4052, label=4678 [クリップ=0.707 欲しい=0.707]
# index=4053, label=4678 [クリップ=0.707 無い=0.707]
# index=4054, label=4678 [欲しい=0.707 輪ゴム=0.707]
# index=4055, label=4678 [無い=0.707 輪ゴム=0.707]
# index=4056, label=4678 [のり=0.707 欲しい=0.707]
# index=4057, label=4678 [のり=0.707 無い=0.707]
# index=4058, label=4678 [デート=0.577 印=0.577 壊れる=0.577]
# index=4059, label=4678 [名刺=0.707 無くなる=0.707]
# index=4060, label=4678 [作る=0.707 名刺=0.707]
# index=4061, label=4678 [する=0.500 内容=0.500 名刺=0.500 変更=0.500]
# index=4062, label=4678 [内容=0.577 名刺=0.577 変える=0.577]
# index=4063, label=4678 [氷=0.707 無い=0.707]
# index=4064, label=4678 [できる=0.707 氷=0.707]
# index=4065, label=4678 [いっぱい=0.577 入る=0.577 冷蔵庫=0.577]
# index=4066, label=4678 [する=0.500 ほしい=0.500 冷蔵庫=0.500 整理=0.500]
# index=4067, label=4678 [入る=0.707 変=0.707]
# index=4068, label=4678 [ニッポン=0.408 レンタカー=0.816 使う=0.408]
# index=4069, label=4678 [する=0.378 ニッポン=0.378 レンタカー=0.756 申請=0.378]
# index=4070, label=4678 [レンタカー=0.707 使う=0.707]
# index=4071, label=4678 [する=0.577 レンタカー=0.577 申請=0.577]--->error detected
# index=4072, label=4678 [カー=0.577 シェア=0.577 使う=0.577]
# index=4073, label=4678 [レンタカー=0.577 使う=0.577 初めて=0.577]
# index=4074, label=4678 [受ける=0.577 安全=0.577 講習=0.577]--->error detected
# index=4075, label=4678 [受ける=0.577 安全=0.577 講習=0.577]--->error detected
# index=4076, label=4678 [レンタカー=0.447 使う=0.447 受ける=0.447 安全=0.447 講習=0.447]--->error detected
# index=4077, label=4678 [etc=0.577 カード=0.577 借りる=0.577]
# index=4078, label=4795 [pc=0.577 ノート=0.577 借りる=0.577]
# index=4079, label=4798 [pc=0.500 利用=0.500 外=0.500 時間=0.500]
# index=4080, label=4800 [pc=0.577 つく=0.577 電源=0.577]
# index=4081, label=4802 [pc=0.577 する=0.577 故障=0.577]
# index=4082, label=4804 [iphone=0.707 テザリング=0.707]
# index=4083, label=4807 [する=0.500 れる=0.500 アカウント=0.500 ロック=0.500]
# index=4084, label=4817 [ク=0.577 ネットワ=0.577 繋がる=0.577]
# index=4085, label=4821 [word=1.000]
# index=4086, label=4821 [excel=1.000]
# index=4087, label=4821 [powerpoint=1.000]
# index=4088, label=4824 [する=0.500 ほしい=0.500 データ=0.500 復旧=0.500]
# index=4089, label=4824 [する=0.500 ほしい=0.500 ファイル=0.500 復旧=0.500]
# index=4090, label=4827 [できる=0.447 サーバ=0.447 データ=0.447 ファイル=0.447 保存=0.447]
# index=4091, label=4830 [サーバ=0.447 ファイル=0.447 会議=0.447 室=0.447 見る=0.447]
# index=4092, label=4830 [会議=0.500 室=0.500 環境=0.500 社内=0.500]
# index=4093, label=4831 [する=0.447 ネット=0.447 会議=0.447 室=0.447 接続=0.447]
# index=4094, label=4798 [usb=0.577 メモリ=0.577 借りる=0.577]
# index=4095, label=4798 [wifi=0.577 ルータ=0.577 借りる=0.577]
# index=4096, label=4808 [lan=0.577 ケーブル=0.577 借りる=0.577]
# index=4097, label=4808 [コード=0.500 借りる=0.500 延長=0.500 電源=0.500]
# index=4098, label=4808 [dvd=0.577 する=0.577 再生=0.577]
# index=4099, label=4808 [する=0.577 再生=0.577 動画=0.577]
# index=4100, label=4808 [する=0.577 動画=0.577 編集=0.577]
# index=4101, label=4833 [dat=0.500 winmail=0.500 する=0.500 解凍=0.500]
# index=4102, label=4834 [pdf=0.707 見れる=0.707]
# index=4103, label=4808 [できる=0.577 ファイル=0.577 解凍=0.577]
# index=4104, label=4808 [できる=0.577 ファイル=0.577 圧縮=0.577]
# index=4105, label=4808 [する=0.447 パスワード=0.447 ファイル=0.447 付き=0.447 圧縮=0.447]
# index=4106, label=4835 [する=0.447 メール=0.447 応答=0.447 自動=0.447 設定=0.447]
# index=4107, label=4835 [する=0.500 メール=0.500 検索=0.500 過去=0.500]
# index=4108, label=4797 [する=0.577 メーリングリスト=0.577 作成=0.577]
# index=4109, label=4797 [する=0.577 メーリングリスト=0.577 変更=0.577]
# index=4110, label=4797 [ほしい=0.577 メーリングリスト=0.577 外す=0.577]
# index=4111, label=4836 [くる=0.577 メール=0.577 怪しい=0.577]
# index=4112, label=4836 [くる=0.707 スパムメール=0.707]
# index=4113, label=4837 [ソフト=0.707 使う=0.707]
#
# error rate=0.1
