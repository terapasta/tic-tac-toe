# %% [markdown]
# # One-class SVM における誤検出率（nu=0.01に変更）
#
# scikit-learn の <b>One-class SVM</b> の、誤検出率（アノマリーでないデータがアノマリーと検出されてしまう率）を求める方法の検討になります。
#
#
# ## (0) 確認結果
#
# 結果から申し上げると、誤検出率は、パラメータの nu 値（0.01＝外れ判定される件数を全体の 1% と想定）を上回る結果（0.041）となりました。
#
# One-class SVMが元来（１件もアノマリーデータが混入していない訓練データを使用して学習したにもかかわらず）訓練データ中に常に「一定数のアノマリーが存在している」前提のモデルなので、一定の誤検出率が上がってしまうのは、不可避と考えております。

# %% [markdown]
# ## (1) テストデータ／環境準備
#
# マイオペで使用しているテストデータ（learning/tests/engine/fixtures/ 配下のCSVファイル）をベースに動作確認を行います。
#
# 動作確認にあたっては、MySQLdb に接続できないため、ローカル環境テスト用の Bot クラスを使用しています。

# %%
'''
    テスト環境を準備するためのモジュールを使用します。
'''
import sys
import os
learning_dir = os.path.abspath("../../") #<--- donusagi-bot/learning
os.chdir(learning_dir)

if learning_dir not in sys.path:
    sys.path.append(learning_dir)

from prototype.modules import TestTool

# %%
'''
    データファイルは、既存の訓練データを別場所にコピーしてから使用します
    テストデータは、csv_file_name で指定した複数件のファイルを使用します。
'''
csv_file_names = [
    'test_benefitone_conversation.csv',
    'test_daikin_conversation.csv',
    'test_ptna_conversation.csv',
    'test_septeni_conversation.csv'
]
copied_csv_file_paths = TestTool.copy_testdata_csv(learning_dir, csv_file_names)
copied_csv_file_paths
# Out:
# CSV file for test=[/Users/makmorit/GitHub/donusagi-bot/learning/prototype/resources/test_benefitone_conversation.csv]
# CSV file for test=[/Users/makmorit/GitHub/donusagi-bot/learning/prototype/resources/test_daikin_conversation.csv]
# CSV file for test=[/Users/makmorit/GitHub/donusagi-bot/learning/prototype/resources/test_ptna_conversation.csv]
# CSV file for test=[/Users/makmorit/GitHub/donusagi-bot/learning/prototype/resources/test_septeni_conversation.csv]
# ['/Users/makmorit/GitHub/donusagi-bot/learning/prototype/resources/test_benefitone_conversation.csv',
#  '/Users/makmorit/GitHub/donusagi-bot/learning/prototype/resources/test_daikin_conversation.csv',
#  '/Users/makmorit/GitHub/donusagi-bot/learning/prototype/resources/test_ptna_conversation.csv',
#  '/Users/makmorit/GitHub/donusagi-bot/learning/prototype/resources/test_septeni_conversation.csv']

# %% [markdown]
# ## (2) TF-IDFベクターの準備
#
# Bot クラス内に組み込まれている __build_training_set_from_csv 関数をバラして実行しています。

# %%
'''
    初期設定
    データファイル、エンコードを指定
    内容は、learn.py を参考にしました。    
'''
from learning.core.learn.learning_parameter import LearningParameter
attr = {
    'include_failed_data': False,
    'include_tag_vector': False,
    'classify_threshold': None,
    # 'algorithm': LearningParameter.ALGORITHM_NAIVE_BAYES
    'algorithm': LearningParameter.ALGORITHM_LOGISTIC_REGRESSION,
    # 'params_for_algorithm': { 'C': 200 }
    'params_for_algorithm': {}
}
learning_parameter = LearningParameter(attr)

bot_id = 7777
csv_file_encoding = 'utf-8'

# %% [markdown]
# ### (2-1) 訓練データのTF-IDFベクター

# %%
'''
    訓練データの生成（内部で TF-IDF 処理を実行）
    
    text_array.py における TF-IDF 処理では、
    以下の通り「する」をストップワード化指定しております
    
    class TextArray:
        :
        def __build_vectorizer(self):
            :
            vectorizer = TfidfVectorizer(use_idf=False, token_pattern=u'(?u)\\b\\w+\\b', stop_words=['する'])
'''
#from learning.core.training_set.training_message_from_csv import TrainingMessageFromCsv
from prototype.modules.training_message_from_csv import TrainingMessageFromCsv
training_set = TrainingMessageFromCsv(bot_id, copied_csv_file_paths, learning_parameter, encoding=csv_file_encoding)
build_training_set_from_csv = training_set.build()

X = build_training_set_from_csv.x
y = build_training_set_from_csv.y
# Out:
# 2017/03/23 PM 09:40:51 TrainingMessageFromCsv#__build_learning_training_messages count of learning data: 28272
# 2017/03/23 PM 09:40:51 TextArray#__init__ start
# 2017/03/23 PM 09:41:05 TextArray#to_vec start
# 2017/03/23 PM 09:41:05 TextArray#to_vec end

# %%
n_sample = X.shape[0]
n_feature = X.shape[1]
print("sample=%d, feature=%d" % (n_sample, n_feature))
# Out:
# sample=28272, feature=2748

# %% [markdown]
# ### (2-2) 外れデータのTF-IDFベクター
#
# <b><a href="12.ipynb">こちらで再検証した時と同じ質問文</a></b>をつかっております。

# %%
'''
    マイオペのプロダクション・コードと同じように、
    訓練データ作成時と同じベクトライザーを使用します。
'''
#from learning.core.training_set.text_array import TextArray
from prototype.modules.text_array import TextArray

test_X = [
    '要素技術は自然languageの機械learningですか？', # まったくfeatureが抽出されない質問文

    '人生相談をしたいのですが？', # featureが１件抽出されるな質問文「する」を含む
    '難解なプログラミング技術を調達？', # featureが１件抽出される質問文「する」を含まない

    '何か習い事をしますか？', # featureが２件抽出される質問文「する」を含む
    '何か習い事がいいですか？', # featureが２件抽出される質問文「する」を含まない
    
    '何か習い事をしたほうがいいですか？', # featureが３件抽出される質問文「する」を含む
    '何か習い事を行うほうがいいですか？', # featureが３件抽出される質問文「する」を含まない
    
    '会社を辞めたいのですが誰に相談するのがいいですか？', # featureが４件抽出される質問文「する」を含む
    '会社を辞めたいのですが誰に相談を行うのがいいですか？', # featureが４件抽出される質問文「する」を含まない

    '有給休暇を取って海外に行き旅行する意向があります。', # featureが５件抽出される質問文「する」を含む
    '有給休暇を取って海外に行きたいと思っています。', # featureが５件抽出される質問文「する」を含まない
]
vectorizer = training_set.body_array.vectorizer
text_array = TextArray(test_X, vectorizer=vectorizer)

'''
    外れデータのTF-IDFベクターを取得
'''
X_error = text_array.to_vec()
# Out:
# 2017/03/23 PM 09:41:05 TextArray#__init__ start
# 2017/03/23 PM 09:41:05 TextArray#to_vec start
# 2017/03/23 PM 09:41:05 TextArray#to_vec end

# %%
vocabulary = text_array._vectorizer.vocabulary_
dumped_features = TestTool.get_dumped_features(X_error, vocabulary)
for d in dumped_features:
    print(d)
# Out:
# index=0[]
# index=1[]
# index=2[調達=1.000]
# index=3[何=1.000]
# index=4[いい=0.707 何=0.707]
# index=5[いい=0.707 何=0.707]
# index=6[いい=0.577 何=0.577 行う=0.577]
# index=7[いい=0.577 会社=0.577 誰=0.577]
# index=8[いい=0.500 会社=0.500 行う=0.500 誰=0.500]
# index=9[休暇=0.500 取る=0.500 海外=0.500 行く=0.500]
# index=10[休暇=0.447 取る=0.447 思う=0.447 海外=0.447 行く=0.447]

# %% [markdown]
# ## (3) One-class SVMで学習
#
# 線形カーネルを使用しています。
#
# また、パラメータの nu を 0.01 へ変更しています。

# %%
'''
    One-class SVM with linear kernel, anomary is half
        fn(i,j) = i'*j
'''
from sklearn import svm
clf_linear = svm.OneClassSVM(
    kernel='linear', # linearカーネルを使用
    nu=0.01          # 外れ判定される件数の見積もりを全体の 1% と想定
    ) 
clf_linear.fit(X)
# Out:
# OneClassSVM(cache_size=200, coef0=0.0, degree=3, gamma='auto',
#       kernel='linear', max_iter=-1, nu=0.01, random_state=None,
#       shrinking=True, tol=0.001, verbose=False)

# %% [markdown]
# ## (4) 誤検出率の算定

# %% [markdown]
# ### (4-1) 訓練データを使って予測実行
#
# アノマリーでないデータ＝訓練データを使って予測した時、アノマリーと検出されてしまうデータがあるかどうか確認します。

# %%
'''
    訓練データを使用して、外れ判定を実行してみます
'''
pred_by_linear_for_train = clf_linear.predict(X)
pred_by_linear_for_train
# Out:
# array([ 1.,  1.,  1., ...,  1.,  1.,  1.])

# %% [markdown]
# ### (4-2) 誤検出率を算出
#
# 誤検出率＝アノマリー検出件数 ÷ 訓練データ件数 になります。
#
# パラメータの nu 値（0.01）を上回る結果となりました。

# %%
n_anomaly = len([c for c in pred_by_linear_for_train if c == -1])

print('誤検出率=%0.3f [サンプル件数=%d, アノマリー件数=%d]' % (n_anomaly / n_sample, n_sample, n_anomaly))
# Out:
# 誤検出率=0.041 [サンプル件数=28272, アノマリー件数=1155]

# %% [markdown]
# ### (4-3) 参考：アノマリーと検出された訓練データだけを抽出

# %%
'''
    (4-1) において、アノマリーと検出されたデータを抽出
'''
from scipy.sparse import lil_matrix, csr_matrix

X_misdetected_temp = lil_matrix((n_anomaly, n_feature))
idx = 0
for i, v in enumerate(pred_by_linear_for_train):
    if v == -1:
        X_misdetected_temp[idx] = X.getrow(i)
        idx += 1

# %% [markdown]
# ### (4-4) 参考：アノマリーと検出された訓練データの特徴を確認
#
# 長いですが、ご参考までに全量表示します。
#
# 例えば「ゴミを捨てたいのですが？」は回答不能になってしまうという事になります。

# %%
dumped_features = TestTool.get_dumped_features(X_misdetected_temp, vocabulary)
for d in dumped_features:
    print(d)
# Out:
# index=0[suica=0.707 登録=0.707]
# index=1[パスモ=0.707 登録=0.707]
# index=2[icoca=0.707 登録=0.707]
# index=3[ゴミ=0.707 捨てる=0.707]
# index=4[割れ物=0.707 捨てる=0.707]
# index=5[ドライバー=0.707 借りる=0.707]
# index=6[ほしい=0.707 ホワイトボードマーカー=0.707]
# index=7[消しゴム=0.707 無くなる=0.707]
# index=8[デート=0.577 印=0.577 壊れる=0.577]
# index=9[ク=0.577 ネットワ=0.577 繋がる=0.577]
# index=10[lan=0.577 ケーブル=0.577 借りる=0.577]
# index=11[dat=0.577 winmail=0.577 解凍=0.577]
# index=12[プリンターー=0.707 換える=0.707]
# index=13[プリンターー=0.707 換える=0.707]
# index=14[印鑑=0.707 捺印=0.707]
# index=15[印鑑=0.707 捺印=0.707]
# index=16[印鑑=0.707 捺印=0.707]
# index=17[印紙=0.500 収入=0.500 欲しい=0.500 説明=0.500]
# index=18[契約=0.577 書=0.577 見せる=0.577]
# index=19[やり方=0.577 小口=0.577 申請=0.577]
# index=20[プリンター=0.707 他=0.707]
# index=21[コピー=0.707 白黒=0.707]
# index=22[イントラ=0.707 見る=0.707]
# index=23[予定=0.577 変える=0.577 座席=0.577]
# index=24[予定=0.577 変える=0.577 座席=0.577]
# index=25[カードキーケース=0.707 下さる=0.707]
# index=26[リザーブ=0.577 ルーム=0.577 ワーク=0.577]
# index=27[室=0.577 押さえる=0.577 顧問=0.577]
# index=28[涼しい=0.707 部屋=0.707]
# index=29[下げる=0.500 暑い=0.500 温度=0.500 部屋=0.500]
# index=30[冷える=0.707 部屋=0.707]
# index=31[とっても=0.577 寒い=0.577 部屋=0.577]
# index=32[コーヒー=0.707 フィルター=0.707]
# index=33[コーヒー=0.707 フィルター=0.707]
# index=34[コーヒー=0.707 豆=0.707]
# index=35[コーヒー=0.707 スプーン=0.707]
# index=36[グラス=1.000]
# index=37[グラス=1.000]
# index=38[湯呑み=0.707 足りる=0.707]
# index=39[ない=0.707 茶菓子=0.707]
# index=40[お茶=0.707 受け=0.707]
# index=41[コード=0.577 延長=0.577 貸与=0.577]
# index=42[ic=0.577 レコーダー=0.577 貸す=0.577]
# index=43[ビデオカメラ=0.577 可能=0.577 貸し出し=0.577]
# index=44[デジカメ=0.707 使用=0.707]
# index=45[ポインター=0.577 レーザー=0.577 使用=0.577]
# index=46[プロジェクター=0.707 破壊=0.707]
# index=47[プロジェクター=0.707 用いる=0.707]
# index=48[なる=0.577 ダメ=0.577 携帯=0.577]
# index=49[動作=0.707 携帯=0.707]
# index=50[アイホン=0.500 メッセージ=0.500 動き=0.500 悪い=0.500]
# index=51[イヤ=0.500 ホン=0.500 壊れる=0.500 聴こえる=0.500]
# index=52[イヤ=0.577 ホン=0.577 取り替える=0.577]
# index=53[イヤ=0.577 ホン=0.577 取り替える=0.577]
# index=54[コード=0.577 充電=0.577 切断=0.577]
# index=55[メールアドレス=0.707 与える=0.707]
# index=56[メルアド=0.707 入手=0.707]
# index=57[取れる=0.577 教える=0.577 決裁=0.577]
# index=58[取れる=0.577 教える=0.577 決裁=0.577]
# index=59[どこ=0.500 今=0.500 回る=0.500 決裁=0.500]
# index=60[履歴=0.577 決裁=0.577 確認=0.577]
# index=61[把握=0.500 決裁=0.500 状況=0.500 過去=0.500]
# index=62[捺印=0.707 終わる=0.707]
# index=63[今=0.577 捺印=0.577 誰=0.577]
# index=64[コピー=0.707 用紙=0.707]
# index=65[封筒=1.000]
# index=66[封筒=1.000]
# index=67[みあたる=0.707 紙袋=0.707]
# index=68[紐=0.707 見つかる=0.707]
# index=69[紐=0.707 見当たる=0.707]
# index=70[ゴミ=0.707 捨てる=0.707]
# index=71[ごみ=0.707 段ボール=0.707]
# index=72[処分=0.707 割れ物=0.707]
# index=73[来社=0.577 票=0.577 記録=0.577]
# index=74[来社=0.577 票=0.577 記録=0.577]
# index=75[受付=0.500 来社=0.500 票=0.500 記録=0.500]
# index=76[受付=0.500 来社=0.500 票=0.500 記録=0.500]
# index=77[受付=0.500 来社=0.500 票=0.500 記録=0.500]
# index=78[拾う=0.707 落とし物=0.707]
# index=79[ポスター=0.707 飾る=0.707]
# index=80[ポスター=0.707 貼れる=0.707]
# index=81[ポスター=0.707 貼れる=0.707]
# index=82[くださる=0.577 掃除=0.577 道具=0.577]
# index=83[レンタル=0.577 掃除=0.577 用具=0.577]
# index=84[購入=0.707 雑巾=0.707]
# index=85[新調=0.707 雑巾=0.707]
# index=86[購入=0.707 雑巾=0.707]
# index=87[買える=0.707 雑巾=0.707]
# index=88[買える=0.707 雑巾=0.707]
# index=89[ふきん=1.000]
# index=90[もらえる=0.707 布巾=0.707]
# index=91[洗剤=1.000]
# index=92[洗剤=1.000]
# index=93[ストック=0.577 スポンジ=0.577 切らす=0.577]
# index=94[そう=0.500 枯れる=0.500 植物=0.500 観葉=0.500]
# index=95[廃棄=0.577 植物=0.577 観葉=0.577]
# index=96[もらう=0.577 券=0.577 定期=0.577]
# index=97[何時=0.500 出す=0.500 宅急便=0.500 間に合う=0.500]
# index=98[いる=0.707 佐川急便=0.707]
# index=99[いる=0.707 佐川急便=0.707]
# index=100[ゆう=0.447 パック=0.447 何=0.447 時=0.447 締め切り=0.447]
# index=101[ソリューションズ=0.500 便=0.500 社内=0.500 送付=0.500]
# index=102[ペイロール=0.500 便=0.500 届ける=0.500 社内=0.500]
# index=103[出せる=0.707 郵便=0.707]
# index=104[出せる=0.707 郵便=0.707]
# index=105[投函=0.707 郵便=0.707]
# index=106[ハスラー=0.577 不動=0.577 状態=0.577]
# index=107[ハスラー=0.577 不具合=0.577 起こす=0.577]
# index=108[シール=1.000]
# index=109[シール=0.707 見える=0.707]
# index=110[インク=0.577 ハスラー=0.577 補充=0.577]
# index=111[交換=0.707 机=0.707]
# index=112[交換=0.707 机=0.707]
# index=113[固定=0.577 置く=0.577 電話=0.577]
# index=114[固定=0.577 引く=0.577 電話=0.577]
# index=115[作れる=0.707 合鍵=0.707]
# index=116[作れる=0.707 合鍵=0.707]
# index=117[作製=0.707 合鍵=0.707]
# index=118[ズレる=0.707 時計=0.707]
# index=119[ずれる=0.500 少し=0.500 時刻=0.500 時計=0.500]
# index=120[ずれる=0.577 チャイム=0.577 直す=0.577]
# index=121[パンチ=0.500 持つ=0.500 穴=0.500 開ける=0.500]
# index=122[レンタル=0.707 台車=0.707]
# index=123[使える=0.707 脚立=0.707]
# index=124[こぼれる=0.707 ジュース=0.707]
# index=125[こぼれる=0.707 ジュース=0.707]
# index=126[こぼれる=0.707 ジュース=0.707]
# index=127[こぼれる=0.707 ジュース=0.707]
# index=128[こぼれる=0.707 ジュース=0.707]
# index=129[お茶=0.707 かっぱ=0.707]
# index=130[お茶=0.707 こぼれる=0.707]
# index=131[お茶=0.707 こぼれる=0.707]
# index=132[テプラ=0.500 テープ=0.500 用意=0.500 願う=0.500]
# index=133[付箋=0.707 切れる=0.707]
# index=134[なくなる=0.577 付箋=0.577 在庫=0.577]
# index=135[付箋=0.707 無い=0.707]
# index=136[ホワイトボードマーカー=0.707 買う=0.707]
# index=137[ホワイトボードマーカー=0.707 準備=0.707]
# index=138[ホワイトボードマーカー=0.707 見当たる=0.707]
# index=139[消しゴム=0.707 無くなる=0.707]
# index=140[消しゴム=0.707 無くなる=0.707]
# index=141[シャー=0.500 ペン=0.500 替え=0.500 芯=0.500]
# index=142[シャー=0.577 ペン=0.577 芯=0.577]
# index=143[シャー=0.577 ペン=0.577 芯=0.577]
# index=144[ホチキス=0.707 針=0.707]
# index=145[クリップ=1.000]
# index=146[クリップ=1.000]
# index=147[デート=0.577 印=0.577 壊れる=0.577]
# index=148[デート=0.577 印=0.577 壊れる=0.577]
# index=149[作成=0.707 名刺=0.707]
# index=150[修正=0.500 内容=0.500 名刺=0.500 記載=0.500]
# index=151[修正=0.577 内容=0.577 名刺=0.577]
# index=152[いう=0.500 はいる=0.500 冷蔵庫=0.500 沢山=0.500]
# index=153[冷蔵庫=0.707 綺麗=0.707]
# index=154[冷蔵庫=0.707 綺麗=0.707]
# index=155[まざる=1.000]
# index=156[ニッポン=0.500 レンタカー=0.500 借りる=0.500 車=0.500]
# index=157[ニッポン=0.500 レンタカー=0.500 借りる=0.500 車=0.500]
# index=158[レンタカー=0.707 希望=0.707]
# index=159[カー=0.500 シェア=0.500 利用=0.500 制度=0.500]
# index=160[安全=0.577 聞く=0.577 講習=0.577]
# index=161[ノーパソ=0.707 貸す=0.707]
# index=162[スイッチ=0.577 パソコン=0.577 押せる=0.577]
# index=163[ネットワーク=0.577 不可=0.577 接続=0.577]
# index=164[ク=0.577 ネットワ=0.577 繋がる=0.577]
# index=165[ク=0.577 ネットワ=0.577 繋がる=0.577]
# index=166[ワード=1.000]
# index=167[word=0.707 関係=0.707]
# index=168[エクセル=1.000]
# index=169[ソフト=0.707 計算=0.707]
# index=170[パワー=0.707 ポイント=0.707]
# index=171[パワー=0.707 ポイント=0.707]
# index=172[データ=0.707 復旧=0.707]
# index=173[lan=0.577 ケーブル=0.577 借りる=0.577]
# index=174[dvd=0.707 観る=0.707]
# index=175[動画=0.707 視聴=0.707]
# index=176[メーリングリスト=0.707 作り方=0.707]
# index=177[メーリングリスト=0.707 外す=0.707]
# index=178[メーリングリスト=0.707 外す=0.707]
# index=179[メーリングリスト=0.707 外す=0.707]
# index=180[メール=0.577 受け取る=0.577 怪しい=0.577]
# index=181[スパムメール=0.707 受信=0.707]
# index=182[印鑑=0.707 捺印=0.707]
# index=183[印鑑=0.707 捺印=0.707]
# index=184[印鑑=0.707 捺印=0.707]
# index=185[印紙=0.500 収入=0.500 欲しい=0.500 説明=0.500]
# index=186[契約=0.577 書=0.577 見せる=0.577]
# index=187[やり方=0.577 小口=0.577 申請=0.577]
# index=188[プリンター=0.707 他=0.707]
# index=189[コピー=0.707 白黒=0.707]
# index=190[イントラ=0.707 見る=0.707]
# index=191[予定=0.577 変える=0.577 座席=0.577]
# index=192[予定=0.577 変える=0.577 座席=0.577]
# index=193[カードキーケース=0.707 下さる=0.707]
# index=194[リザーブ=0.577 ルーム=0.577 ワーク=0.577]
# index=195[室=0.577 押さえる=0.577 顧問=0.577]
# index=196[涼しい=0.707 部屋=0.707]
# index=197[下げる=0.500 暑い=0.500 温度=0.500 部屋=0.500]
# index=198[冷える=0.707 部屋=0.707]
# index=199[とっても=0.577 寒い=0.577 部屋=0.577]
# index=200[コーヒー=0.707 フィルター=0.707]
# index=201[コーヒー=0.707 フィルター=0.707]
# index=202[コーヒー=0.707 豆=0.707]
# index=203[コーヒー=0.707 スプーン=0.707]
# index=204[グラス=1.000]
# index=205[グラス=1.000]
# index=206[湯呑み=0.707 足りる=0.707]
# index=207[ない=0.707 茶菓子=0.707]
# index=208[お茶=0.707 受け=0.707]
# index=209[コード=0.577 延長=0.577 貸与=0.577]
# index=210[ic=0.577 レコーダー=0.577 貸す=0.577]
# index=211[ビデオカメラ=0.577 可能=0.577 貸し出し=0.577]
# index=212[デジカメ=0.707 使用=0.707]
# index=213[ポインター=0.577 レーザー=0.577 使用=0.577]
# index=214[プロジェクター=0.707 破壊=0.707]
# index=215[プロジェクター=0.707 用いる=0.707]
# index=216[なる=0.577 ダメ=0.577 携帯=0.577]
# index=217[動作=0.707 携帯=0.707]
# index=218[アイホン=0.500 メッセージ=0.500 動き=0.500 悪い=0.500]
# index=219[イヤ=0.500 ホン=0.500 壊れる=0.500 聴こえる=0.500]
# index=220[イヤ=0.577 ホン=0.577 取り替える=0.577]
# index=221[イヤ=0.577 ホン=0.577 取り替える=0.577]
# index=222[コード=0.577 充電=0.577 切断=0.577]
# index=223[メールアドレス=0.707 与える=0.707]
# index=224[メルアド=0.707 入手=0.707]
# index=225[取れる=0.577 教える=0.577 決裁=0.577]
# index=226[取れる=0.577 教える=0.577 決裁=0.577]
# index=227[どこ=0.500 今=0.500 回る=0.500 決裁=0.500]
# index=228[履歴=0.577 決裁=0.577 確認=0.577]
# index=229[把握=0.500 決裁=0.500 状況=0.500 過去=0.500]
# index=230[捺印=0.707 終わる=0.707]
# index=231[今=0.577 捺印=0.577 誰=0.577]
# index=232[コピー=0.707 用紙=0.707]
# index=233[封筒=1.000]
# index=234[封筒=1.000]
# index=235[みあたる=0.707 紙袋=0.707]
# index=236[紐=0.707 見つかる=0.707]
# index=237[紐=0.707 見当たる=0.707]
# index=238[ゴミ=0.707 捨てる=0.707]
# index=239[ごみ=0.707 段ボール=0.707]
# index=240[処分=0.707 割れ物=0.707]
# index=241[来社=0.577 票=0.577 記録=0.577]
# index=242[来社=0.577 票=0.577 記録=0.577]
# index=243[受付=0.500 来社=0.500 票=0.500 記録=0.500]
# index=244[受付=0.500 来社=0.500 票=0.500 記録=0.500]
# index=245[受付=0.500 来社=0.500 票=0.500 記録=0.500]
# index=246[拾う=0.707 落とし物=0.707]
# index=247[ポスター=0.707 飾る=0.707]
# index=248[ポスター=0.707 貼れる=0.707]
# index=249[ポスター=0.707 貼れる=0.707]
# index=250[くださる=0.577 掃除=0.577 道具=0.577]
# index=251[レンタル=0.577 掃除=0.577 用具=0.577]
# index=252[購入=0.707 雑巾=0.707]
# index=253[新調=0.707 雑巾=0.707]
# index=254[購入=0.707 雑巾=0.707]
# index=255[買える=0.707 雑巾=0.707]
# index=256[買える=0.707 雑巾=0.707]
# index=257[ふきん=1.000]
# index=258[もらえる=0.707 布巾=0.707]
# index=259[洗剤=1.000]
# index=260[洗剤=1.000]
# index=261[ストック=0.577 スポンジ=0.577 切らす=0.577]
# index=262[そう=0.500 枯れる=0.500 植物=0.500 観葉=0.500]
# index=263[廃棄=0.577 植物=0.577 観葉=0.577]
# index=264[もらう=0.577 券=0.577 定期=0.577]
# index=265[何時=0.500 出す=0.500 宅急便=0.500 間に合う=0.500]
# index=266[いる=0.707 佐川急便=0.707]
# index=267[いる=0.707 佐川急便=0.707]
# index=268[ゆう=0.447 パック=0.447 何=0.447 時=0.447 締め切り=0.447]
# index=269[ソリューションズ=0.500 便=0.500 社内=0.500 送付=0.500]
# index=270[ペイロール=0.500 便=0.500 届ける=0.500 社内=0.500]
# index=271[出せる=0.707 郵便=0.707]
# index=272[出せる=0.707 郵便=0.707]
# index=273[投函=0.707 郵便=0.707]
# index=274[ハスラー=0.577 不動=0.577 状態=0.577]
# index=275[ハスラー=0.577 不具合=0.577 起こす=0.577]
# index=276[シール=1.000]
# index=277[シール=0.707 見える=0.707]
# index=278[インク=0.577 ハスラー=0.577 補充=0.577]
# index=279[交換=0.707 机=0.707]
# index=280[交換=0.707 机=0.707]
# index=281[固定=0.577 置く=0.577 電話=0.577]
# index=282[固定=0.577 引く=0.577 電話=0.577]
# index=283[作れる=0.707 合鍵=0.707]
# index=284[作れる=0.707 合鍵=0.707]
# index=285[作製=0.707 合鍵=0.707]
# index=286[ズレる=0.707 時計=0.707]
# index=287[ずれる=0.500 少し=0.500 時刻=0.500 時計=0.500]
# index=288[ずれる=0.577 チャイム=0.577 直す=0.577]
# index=289[パンチ=0.500 持つ=0.500 穴=0.500 開ける=0.500]
# index=290[レンタル=0.707 台車=0.707]
# index=291[使える=0.707 脚立=0.707]
# index=292[こぼれる=0.707 ジュース=0.707]
# index=293[こぼれる=0.707 ジュース=0.707]
# index=294[こぼれる=0.707 ジュース=0.707]
# index=295[こぼれる=0.707 ジュース=0.707]
# index=296[こぼれる=0.707 ジュース=0.707]
# index=297[お茶=0.707 かっぱ=0.707]
# index=298[お茶=0.707 こぼれる=0.707]
# index=299[お茶=0.707 こぼれる=0.707]
# index=300[テプラ=0.500 テープ=0.500 用意=0.500 願う=0.500]
# index=301[付箋=0.707 切れる=0.707]
# index=302[なくなる=0.577 付箋=0.577 在庫=0.577]
# index=303[付箋=0.707 無い=0.707]
# index=304[ホワイトボードマーカー=0.707 買う=0.707]
# index=305[ホワイトボードマーカー=0.707 準備=0.707]
# index=306[ホワイトボードマーカー=0.707 見当たる=0.707]
# index=307[消しゴム=0.707 無くなる=0.707]
# index=308[消しゴム=0.707 無くなる=0.707]
# index=309[シャー=0.500 ペン=0.500 替え=0.500 芯=0.500]
# index=310[シャー=0.577 ペン=0.577 芯=0.577]
# index=311[シャー=0.577 ペン=0.577 芯=0.577]
# index=312[ホチキス=0.707 針=0.707]
# index=313[クリップ=1.000]
# index=314[クリップ=1.000]
# index=315[デート=0.577 印=0.577 壊れる=0.577]
# index=316[デート=0.577 印=0.577 壊れる=0.577]
# index=317[作成=0.707 名刺=0.707]
# index=318[修正=0.500 内容=0.500 名刺=0.500 記載=0.500]
# index=319[修正=0.577 内容=0.577 名刺=0.577]
# index=320[いう=0.500 はいる=0.500 冷蔵庫=0.500 沢山=0.500]
# index=321[冷蔵庫=0.707 綺麗=0.707]
# index=322[冷蔵庫=0.707 綺麗=0.707]
# index=323[まざる=1.000]
# index=324[ニッポン=0.500 レンタカー=0.500 借りる=0.500 車=0.500]
# index=325[ニッポン=0.500 レンタカー=0.500 借りる=0.500 車=0.500]
# index=326[レンタカー=0.707 希望=0.707]
# index=327[カー=0.500 シェア=0.500 利用=0.500 制度=0.500]
# index=328[安全=0.577 聞く=0.577 講習=0.577]
# index=329[ノーパソ=0.707 貸す=0.707]
# index=330[スイッチ=0.577 パソコン=0.577 押せる=0.577]
# index=331[ネットワーク=0.577 不可=0.577 接続=0.577]
# index=332[ク=0.577 ネットワ=0.577 繋がる=0.577]
# index=333[ク=0.577 ネットワ=0.577 繋がる=0.577]
# index=334[ワード=1.000]
# index=335[word=0.707 関係=0.707]
# index=336[エクセル=1.000]
# index=337[ソフト=0.707 計算=0.707]
# index=338[パワー=0.707 ポイント=0.707]
# index=339[パワー=0.707 ポイント=0.707]
# index=340[データ=0.707 復旧=0.707]
# index=341[lan=0.577 ケーブル=0.577 借りる=0.577]
# index=342[dvd=0.707 観る=0.707]
# index=343[動画=0.707 視聴=0.707]
# index=344[メーリングリスト=0.707 作り方=0.707]
# index=345[メーリングリスト=0.707 外す=0.707]
# index=346[メーリングリスト=0.707 外す=0.707]
# index=347[メーリングリスト=0.707 外す=0.707]
# index=348[メール=0.577 受け取る=0.577 怪しい=0.577]
# index=349[スパムメール=0.707 受信=0.707]
# index=350[suica=0.707 登録=0.707]
# index=351[パスモ=0.707 登録=0.707]
# index=352[icoca=0.707 登録=0.707]
# index=353[ゴミ=0.707 捨てる=0.707]
# index=354[割れ物=0.707 捨てる=0.707]
# index=355[ドライバー=0.707 借りる=0.707]
# index=356[ほしい=0.707 ホワイトボードマーカー=0.707]
# index=357[消しゴム=0.707 無くなる=0.707]
# index=358[デート=0.577 印=0.577 壊れる=0.577]
# index=359[ク=0.577 ネットワ=0.577 繋がる=0.577]
# index=360[lan=0.577 ケーブル=0.577 借りる=0.577]
# index=361[dat=0.577 winmail=0.577 解凍=0.577]
# index=362[pro=0.500 ピーマン=0.500 版=0.500 英語=0.500]
# index=363[インストール=0.500 インターネットエクスプローラー=0.500 ディスク=0.500 種類=0.500]
# index=364[どこ=0.577 インストーラー=0.577 インターネットエクスプローラー=0.577]
# index=365[sp=0.354 インターネットエクスプローラ=0.354 ウィンドウズ=0.354 設定=0.707 １=0.354]
# index=366[365=0.447 office=0.447 securepremium=0.447 アカウント=0.447 移設=0.447]
# index=367[パスワ=0.500 ログイン=0.500 入力=0.500 無くなる=0.500]
# index=368[os=0.577 標準=0.577 社内=0.577]
# index=369[adobe=0.447 なる=0.447 インスト=0.447 エラ=0.447 ル=0.447]
# index=370[wifi=0.500 だめ=0.500 スマ=0.500 トデバイス=0.500]
# index=371[パソコン=0.577 購買=0.577 集中=0.577]
# index=372[email=0.378 thunderbird=0.378 インデント=0.378 付ける=0.378 可能=0.378 同様=0.378 返信=0.378]
# index=373[servicepack=0.577 必須=0.577 適用=0.577]
# index=374[ipad=0.447 いい=0.447 くい=0.447 どう=0.447 失=0.447]
# index=375[email=0.500 どうして=0.500 来る=0.500 迷惑=0.500]
# index=376[email=0.378 thunderbird=0.378 インデント=0.378 付ける=0.378 可能=0.378 同様=0.378 返信=0.378]
# index=377[servicepack=0.577 必須=0.577 適用=0.577]
# index=378[ipad=0.447 いい=0.447 くい=0.447 どう=0.447 失=0.447]
# index=379[email=0.500 どうして=0.500 来る=0.500 迷惑=0.500]
# index=380[アウト=0.408 サンダーバード=0.408 テンプレメール=0.408 ルック=0.408 似る=0.408 機能=0.408]
# index=381[アウト=0.408 サンダーバード=0.408 テンプレメール=0.408 ルック=0.408 似る=0.408 機能=0.408]
# index=382[outlook=0.378 できる=0.378 サーバ=0.378 ローカルフォルダ=0.378 一括=0.378 内=0.378 検索=0.378]
# index=383[vcard=0.500 アウト=0.500 サイン=0.500 ルック=0.500]
# index=384[れる=0.302 アウト=0.302 ルック=0.302 入力=0.302 反映=0.302 姓名=0.302 検索=0.603 結果=0.302]
# index=385[2010=0.447 outlook=0.447 ひる=0.447 不能=0.447 検索=0.447]
# index=386[2010=0.354 outlook=0.354 なでる=0.354 ひる=0.354 ら=0.354 不可能=0.354 宛先=0.354 検索=0.354]
# index=387[タイトル=0.408 化け=0.408 宛先=0.408 文字=0.408 現象=0.408 解消=0.408]
# index=388[なる=0.378 サンダーバード=0.378 メアド=0.378 送れる=0.756]
# index=389[アウト=0.354 グループ=0.354 メンバー=0.354 ルック=0.354 作成=0.354 先=0.354 共有=0.354 連絡=0.354]
# index=390[2010=0.378 ouｔlook=0.378 トレイ=0.378 件名=0.378 内=0.378 受信=0.378 誤操作=0.378]
# index=391[owa=0.447 イントラネット=0.447 トップページ=0.447 ホームページ=0.447 行ける=0.447]
# index=392[2010=0.500 outlook=0.500 同期=0.500 失敗=0.500]
# index=393[11=0.408 cd=0.408 ie=0.408 保管=0.408 媒体=0.408 自身=0.408]
# index=394[ie=0.354 れる=0.354 インストーラ=0.354 配信=0.354 １=0.707]
# index=395[ie=0.354 れる=0.354 インストーラ=0.354 配信=0.354 １=0.707]
# index=396[ie=0.354 れる=0.354 インストーラ=0.354 配信=0.354 １=0.707]
# index=397[ie=0.354 れる=0.354 インストーラ=0.354 配信=0.354 １=0.707]
# index=398[ie=0.354 れる=0.354 インストーラ=0.354 配信=0.354 １=0.707]
# index=399[ie=0.354 れる=0.354 インストーラ=0.354 配信=0.354 １=0.707]
# index=400[ie=0.354 れる=0.354 インストーラ=0.354 配信=0.354 １=0.707]
# index=401[ie=0.354 れる=0.354 インストーラ=0.354 配信=0.354 １=0.707]
# index=402[ie=0.354 れる=0.354 インストーラ=0.354 配信=0.354 １=0.707]
# index=403[ie=0.354 れる=0.354 インストーラ=0.354 配信=0.354 １=0.707]
# index=404[ie=0.354 れる=0.354 インストーラ=0.354 配信=0.354 １=0.707]
# index=405[ie=0.354 れる=0.354 インストーラ=0.354 配信=0.354 １=0.707]
# index=406[れる=0.447 アダプト=0.447 エンタープライズ=0.447 モード=0.447 確認=0.447]
# index=407[reportvviewer=0.500 対処=0.500 方法=0.500 開く=0.500]
# index=408[daina=0.333 document=0.333 library=0.333 technical=0.333 web=0.333 なる=0.333 対処=0.333 方法=0.333 画面=0.333]
# index=409[mcafee=0.354 よい=0.354 ウイルス=0.354 スキャン=0.354 対象=0.354 設定=0.354 適応=0.354 除外=0.354]
# index=410[2008=0.354 32=0.354 bit=0.354 mｃafee=0.354 ウィンドウズ=0.354 サーバー=0.354 対応=0.354 知る=0.354]
# index=411[it=0.333 だせる=0.333 ハードエェア=0.333 フォーマット=0.333 管理=0.333 資産=0.667]
# index=412[it=0.333 だせる=0.333 ハードエェア=0.333 フォーマット=0.333 管理=0.333 資産=0.667]
# index=413[it=0.333 だせる=0.333 ハードエェア=0.333 フォーマット=0.333 管理=0.333 資産=0.667]
# index=414[it=0.333 だせる=0.333 ハードエェア=0.333 フォーマット=0.333 管理=0.333 資産=0.667]
# index=415[ip=0.632 it=0.316 つけ加える=0.316 アドレス=0.316 台帳=0.316 管理=0.316 資産=0.316]
# index=416[ip=0.632 it=0.316 アドレス=0.316 台帳=0.316 多い=0.316 管理=0.316 資産=0.316]
# index=417[agent=0.243 client=0.243 communication=0.243 create=0.243 depot=0.243 interprocess=0.243 the=0.485 to=0.243 unable=0.243 vpn=0.243 was=0.243 どう=0.243 よい=0.243 出る=0.243]
# index=418[ツールリカバリファイル=0.408 バックアップ=0.408 化=0.408 必ず=0.408 必要=0.408 暗号=0.408]
# index=419[ツールリカバリファイル=0.408 バックアップ=0.408 化=0.408 必ず=0.408 必要=0.408 暗号=0.408]
# index=420[pointsec=0.577 リカバリーファイル=0.577 名称=0.577]
# index=421[pointsec=0.577 リカバリーファイル=0.577 名称=0.577]
# index=422[ツールリカバリファイル=0.500 化=0.500 名前=0.500 暗号=0.500]
# index=423[いい=0.500 ツールリカバリファイル=0.500 化=0.500 暗号=0.500]
# index=424[ツールリカバリファイル=0.500 化=0.500 名前=0.500 暗号=0.500]
# index=425[linux=0.577 pointsec=0.577 対応=0.577]
# index=426[れる=0.408 ジョブ=0.408 プリント=0.408 機=0.408 複合=0.408 飛ばす=0.408]
# index=427[6=0.408 ipv=0.408 ネットワーク=0.408 時=0.408 有無=0.408 設定=0.408]
# index=428[6=0.354 ipv=0.354 ネットワーク=0.354 不要=0.354 設定=0.707]
# index=429[administrator=0.500 ユーザ=0.500 末端=0.500 機器=0.500]
# index=430[administrator=0.500 ユーザー=0.500 存在=0.500 端末=0.500]
# index=431[administrator=0.500 いる=0.500 なぜ=0.500 ユーザ=0.500]
# index=432[はいる=0.500 サービス=0.500 パック=0.500 適用=0.500]
# index=433[servicepack=0.577 必須=0.577 適用=0.577]
# index=434[servicepack=0.500 せる=0.500 欠く=0.500 適用=0.500]
# index=435[servicepack=0.577 必須=0.577 適用=0.577]
# index=436[mcafee=0.500 バージョンアップ=0.500 注意=0.500 点=0.500]
# index=437[バージョン=0.577 マカフィー=0.577 新しい=0.577]
# index=438[mcafee=0.500 アイコ=0.500 異なる=0.500 通常=0.500]
# index=439[おかしい=0.500 アイコン=0.500 マカフィー=0.500 見た目=0.500]
# index=440[vpn=0.577 キー=0.577 取り直す=0.577]
# index=441[vpn=0.500 キー=0.500 再度=0.500 発行=0.500]
# index=442[2000=0.316 2010=0.316 microsoftoffice=0.632 できる=0.316 形式=0.316 文書=0.316 閲覧=0.316]
# index=443[office=0.316 全般=0.316 十=0.316 数=0.316 時間=0.316 的=0.316 秒=0.316 製品=0.316 要す=0.316 起動=0.316]
# index=444[adobe=0.447 インストーラ=0.447 サイト=0.447 ダウンロード=0.447 上=0.447]
# index=445[eden=0.577 伝票=0.577 印刷=0.577]
# index=446[adobereade=0.577 アップテータ=0.577 設定=0.577]
# index=447[livelink=0.577 インストール=0.577 手動=0.577]
# index=448[livelink=0.500 つける=0.500 バージョンアップ=0.500 気=0.500]
# index=449[livelink=0.408 こちら=0.408 やる=0.408 インストール=0.408 側=0.408 後=0.408]
# index=450[pro=0.500 ピーマン=0.500 版=0.500 英語=0.500]
# index=451[pro=0.500 ピーマン=0.500 版=0.500 英語=0.500]
# index=452[pro=0.500 ピーマン=0.500 版=0.500 英語=0.500]
# index=453[pro=0.500 ピーマン=0.500 版=0.500 英語=0.500]
# index=454[pro=0.500 ピーマン=0.500 英字=0.500 表記=0.500]
# index=455[pro=0.500 イングリッシュ=0.500 バージョン=0.500 ピーマン=0.500]
# index=456[pro=0.447 ピーマン=0.447 向け=0.447 英語=0.447 話者=0.447]
# index=457[ピーマン=0.447 プロ=0.447 入手=0.447 式=0.447 最新=0.447]
# index=458[ファルダ=0.316 メッセージ=0.316 メール=0.316 受信=0.316 増える=0.316 数=0.316 未読=0.316 本当に=0.316 私=0.316 迷惑=0.316]
# index=459[spam=0.707 フォルダ=0.354 メール=0.354 内=0.354 大事=0.354]
# index=460[spam=0.707 フォルダ=0.354 メール=0.354 内=0.354 大事=0.354]
# index=461[れる=0.408 スパムメール=0.816 判別=0.408]
# index=462[spam=0.408 フォルダ=0.408 削除=0.408 知る=0.408 策=0.408 解決=0.408]
# index=463[spam=0.408 どう=0.408 よい=0.408 フォルダ=0.408 消却=0.408 誤る=0.408]
# index=464[メール=0.408 削除=0.408 日間=0.408 自動=0.408 １=0.408 ４=0.408]
# index=465[dki=0.408 e=0.408 メール=0.408 暗い=0.408 通知=0.408 預かる=0.408]
# index=466[dki=0.500 e=0.500 メール=0.500 暗い=0.500]
# index=467[dki=0.408 e=0.408 メール=0.408 取り入れる=0.408 暗号=0.408 自社=0.408]
# index=468[ios=1.000]
# index=469[ios=1.000]
# index=470[dk=0.447 e=0.447 ha=0.447 メール=0.447 暗号=0.447]
# index=471[7=0.229 windows=0.229 れる=0.229 アップ=0.229 エディション=0.459 グレード=0.229 セッティング=0.229 プロフェッショナル=0.459 ホーム=0.459 移行=0.229]
# index=472[わかる=0.577 ウィンドウズユーザアカウント=0.577 パスワード=0.577]
# index=473[activedirectory=0.500 faq=0.500 おかしい=0.500 状態=0.500]
# index=474[3=0.408 g=0.408 スマート=0.408 デバイス=0.408 必要=0.408 理由=0.408]
# index=475[スマート=0.500 デバイス=0.500 ナンバーポータビリティ=0.500 適切=0.500]
# index=476[スマート=0.500 デバイス=0.500 ナンバーポータビリティ=0.500 適当=0.500]
# index=477[vpn=1.000]
# index=478[いい=0.408 いれる=0.408 アイパッド=0.408 ウィルス=0.408 ソフト=0.408 対策=0.408]
# index=479[ipad=0.500 国=0.500 持ち込める=0.500 日本=0.500]
# index=480[ipad=0.447 いい=0.447 くい=0.447 どう=0.447 失=0.447]
# index=481[ばける=0.408 アイパッド=0.408 イントラホームページ=0.408 ページ=0.408 文字=0.408 見る=0.408]
# index=482[ipone=0.408 内線=0.408 着信=0.408 聞こえる=0.408 表示=0.408 音=0.408]
# index=483[アイパッド=0.447 ダイキンイントラメール=0.447 接続=0.447 見れる=0.447 ｖｐｎ=0.447]
# index=484[anyconnect=0.447 byod=0.447 citrix=0.447 アンインストール=0.447 問題=0.447]
# index=485[byod=0.500 帯=0.500 時間=0.500 稼働=0.500]
# index=486[byod=0.577 年中=0.577 無休=0.577]
# index=487[byod=0.378 とれる=0.378 バックアップ=0.378 ログオフ=0.378 保存=0.378 前=0.378 場合=0.378]
# index=488[securebrowser=0.577 ファイル=0.577 添付=0.577]
# index=489[なくす=0.500 場合=0.500 端末=0.500 補償=0.500]
# index=490[セキュアブラウザ=0.447 メール=0.447 モバイル=0.447 点=0.447 相違=0.447]
# index=491[1120=0.447 a=0.447 エラーメッセージ=0.447 セキュアブラウザ=0.447 発生=0.447]
# index=492[コピペ=0.577 メモアプリ=0.289 上=0.289 作成=0.289 使える=0.289 別途=0.289 文章=0.289 機能=0.289 ｂｙｏｄ=0.289]
# index=493[10=0.577 ウインドウズ=0.577 起動=0.577]
# index=494[ad=0.577 ログイン=0.577 参加=0.577]
# index=495[ca=0.316 dil=0.316 lan=0.316 作業=0.316 実施=0.316 書=0.316 無線=0.316 現れる=0.316 設定=0.316 通り=0.316]
# index=496[使う=0.707 ｆｍｃ=0.707]
# index=497[コース=0.707 教育=0.707]
# index=498[チェック=0.577 全社=0.577 規程=0.577]
# index=499[全社=0.577 拝見=0.577 規定=0.577]
# index=500[おなか=0.707 ぺこぺこ=0.707]
# index=501[空腹=1.000]
# index=502[空腹=1.000]
# index=503[はる=0.707 ぺこ=0.707]
# index=504[できる=0.447 アウト=0.447 サインイン=0.447 ルック=0.447 突然=0.447]
# index=505[どこ=0.577 インストーラー=0.577 インターネットエクスプローラー=0.577]
# index=506[どこ=0.577 インストーラー=0.577 インターネットエクスプローラー=0.577]
# index=507[どこ=0.577 インストーラー=0.577 インターネットエクスプローラー=0.577]
# index=508[どこ=0.577 インストーラー=0.577 インターネットエクスプローラー=0.577]
# index=509[どこ=0.577 インストーラー=0.577 インターネットエクスプローラー=0.577]
# index=510[どこ=0.577 インストーラー=0.577 インターネットエクスプローラー=0.577]
# index=511[sp=0.354 インターネットエクスプローラ=0.354 ウィンドウズ=0.354 設定=0.707 １=0.354]
# index=512[hd=0.354 まずい=0.354 ポイントセック=0.354 分割=0.354 容量=0.354 導入=0.354 後=0.354 消す=0.354]
# index=513[アドレス=0.447 サンダーバード=0.447 個人=0.447 帳=0.447 移す=0.447]
# index=514[ピ=0.577 マン=0.577 動く=0.577]
# index=515[ピーマン=0.500 送る=0.500 ｃｄ=0.500 ｐｒｏ=0.500]
# index=516[ピーマン=0.500 送る=0.500 ｃｄ=0.500 ｐｒｏ=0.500]
# index=517[ピーマン=0.500 送る=0.500 ｃｄ=0.500 ｐｒｏ=0.500]
# index=518[wifi=0.500 だめ=0.500 スマ=0.500 トデバイス=0.500]
# index=519[wifi=0.500 だめ=0.500 スマ=0.500 トデバイス=0.500]
# index=520[mnp=0.707 スマホ=0.707]
# index=521[アウト=0.408 サンダーバード=0.408 テンプレメール=0.408 ルック=0.408 似る=0.408 機能=0.408]
# index=522[アウト=0.408 サンダーバード=0.408 テンプレメール=0.408 ルック=0.408 似る=0.408 機能=0.408]
# index=523[outlook=0.378 できる=0.378 サーバ=0.378 ローカルフォルダ=0.378 一括=0.378 内=0.378 検索=0.378]
# index=524[vcard=0.500 アウト=0.500 サイン=0.500 ルック=0.500]
# index=525[れる=0.302 アウト=0.302 ルック=0.302 入力=0.302 反映=0.302 姓名=0.302 検索=0.603 結果=0.302]
# index=526[2010=0.447 outlook=0.447 ひる=0.447 不能=0.447 検索=0.447]
# index=527[2010=0.354 outlook=0.354 なでる=0.354 ひる=0.354 ら=0.354 不可能=0.354 宛先=0.354 検索=0.354]
# index=528[タイトル=0.408 化け=0.408 宛先=0.408 文字=0.408 現象=0.408 解消=0.408]
# index=529[なる=0.378 サンダーバード=0.378 メアド=0.378 送れる=0.756]
# index=530[アウト=0.354 グループ=0.354 メンバー=0.354 ルック=0.354 作成=0.354 先=0.354 共有=0.354 連絡=0.354]
# index=531[2010=0.378 ouｔlook=0.378 トレイ=0.378 件名=0.378 内=0.378 受信=0.378 誤操作=0.378]
# index=532[owa=0.447 イントラネット=0.447 トップページ=0.447 ホームページ=0.447 行ける=0.447]
# index=533[2010=0.500 outlook=0.500 同期=0.500 失敗=0.500]
# index=534[11=0.408 cd=0.408 ie=0.408 保管=0.408 媒体=0.408 自身=0.408]
# index=535[ie=0.354 れる=0.354 インストーラ=0.354 配信=0.354 １=0.707]
# index=536[ie=0.354 れる=0.354 インストーラ=0.354 配信=0.354 １=0.707]
# index=537[ie=0.354 れる=0.354 インストーラ=0.354 配信=0.354 １=0.707]
# index=538[ie=0.354 れる=0.354 インストーラ=0.354 配信=0.354 １=0.707]
# index=539[ie=0.354 れる=0.354 インストーラ=0.354 配信=0.354 １=0.707]
# index=540[ie=0.354 れる=0.354 インストーラ=0.354 配信=0.354 １=0.707]
# index=541[ie=0.354 れる=0.354 インストーラ=0.354 配信=0.354 １=0.707]
# index=542[ie=0.354 れる=0.354 インストーラ=0.354 配信=0.354 １=0.707]
# index=543[ie=0.354 れる=0.354 インストーラ=0.354 配信=0.354 １=0.707]
# index=544[ie=0.354 れる=0.354 インストーラ=0.354 配信=0.354 １=0.707]
# index=545[ie=0.354 れる=0.354 インストーラ=0.354 配信=0.354 １=0.707]
# index=546[ie=0.354 れる=0.354 インストーラ=0.354 配信=0.354 １=0.707]
# index=547[れる=0.447 アダプト=0.447 エンタープライズ=0.447 モード=0.447 確認=0.447]
# index=548[reportvviewer=0.500 対処=0.500 方法=0.500 開く=0.500]
# index=549[daina=0.333 document=0.333 library=0.333 technical=0.333 web=0.333 なる=0.333 対処=0.333 方法=0.333 画面=0.333]
# index=550[mcafee=0.354 よい=0.354 ウイルス=0.354 スキャン=0.354 対象=0.354 設定=0.354 適応=0.354 除外=0.354]
# index=551[2008=0.354 32=0.354 bit=0.354 mｃafee=0.354 ウィンドウズ=0.354 サーバー=0.354 対応=0.354 知る=0.354]
# index=552[it=0.333 だせる=0.333 ハードエェア=0.333 フォーマット=0.333 管理=0.333 資産=0.667]
# index=553[it=0.333 だせる=0.333 ハードエェア=0.333 フォーマット=0.333 管理=0.333 資産=0.667]
# index=554[it=0.333 だせる=0.333 ハードエェア=0.333 フォーマット=0.333 管理=0.333 資産=0.667]
# index=555[it=0.333 だせる=0.333 ハードエェア=0.333 フォーマット=0.333 管理=0.333 資産=0.667]
# index=556[ip=0.632 it=0.316 つけ加える=0.316 アドレス=0.316 台帳=0.316 管理=0.316 資産=0.316]
# index=557[ip=0.632 it=0.316 アドレス=0.316 台帳=0.316 多い=0.316 管理=0.316 資産=0.316]
# index=558[agent=0.243 client=0.243 communication=0.243 create=0.243 depot=0.243 interprocess=0.243 the=0.485 to=0.243 unable=0.243 vpn=0.243 was=0.243 どう=0.243 よい=0.243 出る=0.243]
# index=559[ツールリカバリファイル=0.408 バックアップ=0.408 化=0.408 必ず=0.408 必要=0.408 暗号=0.408]
# index=560[ツールリカバリファイル=0.408 バックアップ=0.408 化=0.408 必ず=0.408 必要=0.408 暗号=0.408]
# index=561[pointsec=0.577 リカバリーファイル=0.577 名称=0.577]
# index=562[pointsec=0.577 リカバリーファイル=0.577 名称=0.577]
# index=563[ツールリカバリファイル=0.500 化=0.500 名前=0.500 暗号=0.500]
# index=564[いい=0.500 ツールリカバリファイル=0.500 化=0.500 暗号=0.500]
# index=565[ツールリカバリファイル=0.500 化=0.500 名前=0.500 暗号=0.500]
# index=566[linux=0.577 pointsec=0.577 対応=0.577]
# index=567[れる=0.408 ジョブ=0.408 プリント=0.408 機=0.408 複合=0.408 飛ばす=0.408]
# index=568[6=0.408 ipv=0.408 ネットワーク=0.408 時=0.408 有無=0.408 設定=0.408]
# index=569[6=0.354 ipv=0.354 ネットワーク=0.354 不要=0.354 設定=0.707]
# index=570[administrator=0.500 ユーザ=0.500 末端=0.500 機器=0.500]
# index=571[administrator=0.500 ユーザー=0.500 存在=0.500 端末=0.500]
# index=572[administrator=0.500 いる=0.500 なぜ=0.500 ユーザ=0.500]
# index=573[はいる=0.500 サービス=0.500 パック=0.500 適用=0.500]
# index=574[servicepack=0.577 必須=0.577 適用=0.577]
# index=575[servicepack=0.500 せる=0.500 欠く=0.500 適用=0.500]
# index=576[servicepack=0.577 必須=0.577 適用=0.577]
# index=577[mcafee=0.500 バージョンアップ=0.500 注意=0.500 点=0.500]
# index=578[バージョン=0.577 マカフィー=0.577 新しい=0.577]
# index=579[mcafee=0.500 アイコ=0.500 異なる=0.500 通常=0.500]
# index=580[おかしい=0.500 アイコン=0.500 マカフィー=0.500 見た目=0.500]
# index=581[vpn=0.577 キー=0.577 取り直す=0.577]
# index=582[vpn=0.500 キー=0.500 再度=0.500 発行=0.500]
# index=583[2000=0.316 2010=0.316 microsoftoffice=0.632 できる=0.316 形式=0.316 文書=0.316 閲覧=0.316]
# index=584[office=0.316 全般=0.316 十=0.316 数=0.316 時間=0.316 的=0.316 秒=0.316 製品=0.316 要す=0.316 起動=0.316]
# index=585[adobe=0.447 インストーラ=0.447 サイト=0.447 ダウンロード=0.447 上=0.447]
# index=586[eden=0.577 伝票=0.577 印刷=0.577]
# index=587[adobereade=0.577 アップテータ=0.577 設定=0.577]
# index=588[livelink=0.577 インストール=0.577 手動=0.577]
# index=589[livelink=0.500 つける=0.500 バージョンアップ=0.500 気=0.500]
# index=590[livelink=0.408 こちら=0.408 やる=0.408 インストール=0.408 側=0.408 後=0.408]
# index=591[pro=0.500 ピーマン=0.500 版=0.500 英語=0.500]
# index=592[pro=0.500 ピーマン=0.500 版=0.500 英語=0.500]
# index=593[pro=0.500 ピーマン=0.500 版=0.500 英語=0.500]
# index=594[pro=0.500 ピーマン=0.500 版=0.500 英語=0.500]
# index=595[pro=0.500 ピーマン=0.500 英字=0.500 表記=0.500]
# index=596[pro=0.500 イングリッシュ=0.500 バージョン=0.500 ピーマン=0.500]
# index=597[pro=0.447 ピーマン=0.447 向け=0.447 英語=0.447 話者=0.447]
# index=598[ピーマン=0.447 プロ=0.447 入手=0.447 式=0.447 最新=0.447]
# index=599[ファルダ=0.316 メッセージ=0.316 メール=0.316 受信=0.316 増える=0.316 数=0.316 未読=0.316 本当に=0.316 私=0.316 迷惑=0.316]
# index=600[spam=0.707 フォルダ=0.354 メール=0.354 内=0.354 大事=0.354]
# index=601[spam=0.707 フォルダ=0.354 メール=0.354 内=0.354 大事=0.354]
# index=602[れる=0.408 スパムメール=0.816 判別=0.408]
# index=603[spam=0.408 フォルダ=0.408 削除=0.408 知る=0.408 策=0.408 解決=0.408]
# index=604[spam=0.408 どう=0.408 よい=0.408 フォルダ=0.408 消却=0.408 誤る=0.408]
# index=605[メール=0.408 削除=0.408 日間=0.408 自動=0.408 １=0.408 ４=0.408]
# index=606[dki=0.408 e=0.408 メール=0.408 暗い=0.408 通知=0.408 預かる=0.408]
# index=607[dki=0.500 e=0.500 メール=0.500 暗い=0.500]
# index=608[dki=0.408 e=0.408 メール=0.408 取り入れる=0.408 暗号=0.408 自社=0.408]
# index=609[ios=1.000]
# index=610[ios=1.000]
# index=611[dk=0.447 e=0.447 ha=0.447 メール=0.447 暗号=0.447]
# index=612[7=0.229 windows=0.229 れる=0.229 アップ=0.229 エディション=0.459 グレード=0.229 セッティング=0.229 プロフェッショナル=0.459 ホーム=0.459 移行=0.229]
# index=613[わかる=0.577 ウィンドウズユーザアカウント=0.577 パスワード=0.577]
# index=614[activedirectory=0.500 faq=0.500 おかしい=0.500 状態=0.500]
# index=615[3=0.408 g=0.408 スマート=0.408 デバイス=0.408 必要=0.408 理由=0.408]
# index=616[スマート=0.500 デバイス=0.500 ナンバーポータビリティ=0.500 適切=0.500]
# index=617[スマート=0.500 デバイス=0.500 ナンバーポータビリティ=0.500 適当=0.500]
# index=618[vpn=1.000]
# index=619[いい=0.408 いれる=0.408 アイパッド=0.408 ウィルス=0.408 ソフト=0.408 対策=0.408]
# index=620[ipad=0.500 国=0.500 持ち込める=0.500 日本=0.500]
# index=621[ipad=0.447 いい=0.447 くい=0.447 どう=0.447 失=0.447]
# index=622[ばける=0.408 アイパッド=0.408 イントラホームページ=0.408 ページ=0.408 文字=0.408 見る=0.408]
# index=623[ipone=0.408 内線=0.408 着信=0.408 聞こえる=0.408 表示=0.408 音=0.408]
# index=624[アイパッド=0.447 ダイキンイントラメール=0.447 接続=0.447 見れる=0.447 ｖｐｎ=0.447]
# index=625[anyconnect=0.447 byod=0.447 citrix=0.447 アンインストール=0.447 問題=0.447]
# index=626[byod=0.500 帯=0.500 時間=0.500 稼働=0.500]
# index=627[byod=0.577 年中=0.577 無休=0.577]
# index=628[byod=0.378 とれる=0.378 バックアップ=0.378 ログオフ=0.378 保存=0.378 前=0.378 場合=0.378]
# index=629[securebrowser=0.577 ファイル=0.577 添付=0.577]
# index=630[なくす=0.500 場合=0.500 端末=0.500 補償=0.500]
# index=631[セキュアブラウザ=0.447 メール=0.447 モバイル=0.447 点=0.447 相違=0.447]
# index=632[1120=0.447 a=0.447 エラーメッセージ=0.447 セキュアブラウザ=0.447 発生=0.447]
# index=633[コピペ=0.577 メモアプリ=0.289 上=0.289 作成=0.289 使える=0.289 別途=0.289 文章=0.289 機能=0.289 ｂｙｏｄ=0.289]
# index=634[10=0.577 ウインドウズ=0.577 起動=0.577]
# index=635[ad=0.577 ログイン=0.577 参加=0.577]
# index=636[ca=0.316 dil=0.316 lan=0.316 作業=0.316 実施=0.316 書=0.316 無線=0.316 現れる=0.316 設定=0.316 通り=0.316]
# index=637[使う=0.707 ｆｍｃ=0.707]
# index=638[コース=0.707 教育=0.707]
# index=639[チェック=0.577 全社=0.577 規程=0.577]
# index=640[全社=0.577 拝見=0.577 規定=0.577]
# index=641[おなか=0.707 ぺこぺこ=0.707]
# index=642[空腹=1.000]
# index=643[空腹=1.000]
# index=644[はる=0.707 ぺこ=0.707]
# index=645[できる=0.447 アウト=0.447 サインイン=0.447 ルック=0.447 突然=0.447]
# index=646[どこ=0.577 インストーラー=0.577 インターネットエクスプローラー=0.577]
# index=647[どこ=0.577 インストーラー=0.577 インターネットエクスプローラー=0.577]
# index=648[どこ=0.577 インストーラー=0.577 インターネットエクスプローラー=0.577]
# index=649[どこ=0.577 インストーラー=0.577 インターネットエクスプローラー=0.577]
# index=650[どこ=0.577 インストーラー=0.577 インターネットエクスプローラー=0.577]
# index=651[どこ=0.577 インストーラー=0.577 インターネットエクスプローラー=0.577]
# index=652[sp=0.354 インターネットエクスプローラ=0.354 ウィンドウズ=0.354 設定=0.707 １=0.354]
# index=653[hd=0.354 まずい=0.354 ポイントセック=0.354 分割=0.354 容量=0.354 導入=0.354 後=0.354 消す=0.354]
# index=654[アドレス=0.447 サンダーバード=0.447 個人=0.447 帳=0.447 移す=0.447]
# index=655[ピ=0.577 マン=0.577 動く=0.577]
# index=656[ピーマン=0.500 送る=0.500 ｃｄ=0.500 ｐｒｏ=0.500]
# index=657[ピーマン=0.500 送る=0.500 ｃｄ=0.500 ｐｒｏ=0.500]
# index=658[ピーマン=0.500 送る=0.500 ｃｄ=0.500 ｐｒｏ=0.500]
# index=659[wifi=0.500 だめ=0.500 スマ=0.500 トデバイス=0.500]
# index=660[wifi=0.500 だめ=0.500 スマ=0.500 トデバイス=0.500]
# index=661[mnp=0.707 スマホ=0.707]
# index=662[pro=0.500 ピーマン=0.500 版=0.500 英語=0.500]
# index=663[インストール=0.500 インターネットエクスプローラー=0.500 ディスク=0.500 種類=0.500]
# index=664[どこ=0.577 インストーラー=0.577 インターネットエクスプローラー=0.577]
# index=665[sp=0.354 インターネットエクスプローラ=0.354 ウィンドウズ=0.354 設定=0.707 １=0.354]
# index=666[365=0.447 office=0.447 securepremium=0.447 アカウント=0.447 移設=0.447]
# index=667[パスワ=0.500 ログイン=0.500 入力=0.500 無くなる=0.500]
# index=668[os=0.577 標準=0.577 社内=0.577]
# index=669[adobe=0.447 なる=0.447 インスト=0.447 エラ=0.447 ル=0.447]
# index=670[wifi=0.500 だめ=0.500 スマ=0.500 トデバイス=0.500]
# index=671[パソコン=0.577 購買=0.577 集中=0.577]
# index=672[月謝=1.000]
# index=673[どれ=0.707 紹介=0.707]
# index=674[だいじょうぶ=0.577 ピアノ=0.577 持つ=0.577]
# index=675[スカイプレッスン=0.707 教室=0.707]
# index=676[無言=1.000]
# index=677[先生=0.707 男=0.707]
# index=678[いい=0.707 もう=0.707]
# index=679[先生=0.707 女=0.707]
# index=680[できる=0.707 見学=0.707]
# index=681[あり=0.408 かかれる=0.408 ややこしい=0.408 声=0.408 生徒=0.408 見れる=0.408]
# index=682[費用=1.000]
# index=683[同時に=0.707 申込む=0.707]
# index=684[同時に=0.707 申込む=0.707]
# index=685[スッテ=0.577 プ=0.577 参加=0.577]
# index=686[所在地=0.577 書く=0.577 氏名=0.577]
# index=687[18=0.500 未満=0.500 歳=0.500 申し込める=0.500]
# index=688[17=0.577 年齢=0.577 申し込める=0.577]
# index=689[費用=1.000]
# index=690[同時に=0.707 申込む=0.707]
# index=691[同時に=0.707 申込む=0.707]
# index=692[スッテ=0.577 プ=0.577 参加=0.577]
# index=693[所在地=0.577 書く=0.577 氏名=0.577]
# index=694[18=0.500 未満=0.500 歳=0.500 申し込める=0.500]
# index=695[17=0.577 年齢=0.577 申し込める=0.577]
# index=696[ピティナ=0.707 意味=0.707]
# index=697[なん=0.707 ピティナ=0.707]
# index=698[ピティナ=0.707 意味=0.707]
# index=699[ピティナ=0.707 意味=0.707]
# index=700[ピティナ=0.707 仕組み=0.707]
# index=701[基準=0.707 申し込み=0.707]
# index=702[登録=0.707 試験=0.707]
# index=703[]
# index=704[費用=1.000]
# index=705[金額=1.000]
# index=706[金額=1.000]
# index=707[費用=1.000]
# index=708[費用=1.000]
# index=709[支払=0.577 月々=0.577 額=0.577]
# index=710[月謝=1.000]
# index=711[月謝=1.000]
# index=712[支払=0.577 月々=0.577 額=0.577]
# index=713[一緒=0.707 申し込む=0.707]
# index=714[同時=0.707 申請=0.707]
# index=715[一緒=0.707 申込む=0.707]
# index=716[一緒=0.707 申し込める=0.707]
# index=717[同時に=0.707 申込む=0.707]
# index=718[いっぺんに=0.707 申し込む=0.707]
# index=719[一緒=0.707 申し込む=0.707]
# index=720[ptna=0.707 意味=0.707]
# index=721[今日=1.000]
# index=722[やあ=1.000]
# index=723[お疲れさま=1.000]
# index=724[おはよう=0.707 さん=0.707]
# index=725[おはよう=0.707 さん=0.707]
# index=726[入会=0.707 利点=0.707]
# index=727[入会=0.707 利点=0.707]
# index=728[期間=0.707 特典=0.707]
# index=729[申し込み=1.000]
# index=730[はじめる=0.707 ピティナ=0.707]
# index=731[はじめる=0.707 ピティナ=0.707]
# index=732[取り消す=1.000]
# index=733[取り消す=1.000]
# index=734[停止=1.000]
# index=735[どれ=0.707 紹介=0.707]
# index=736[どれ=0.707 紹介=0.707]
# index=737[どれ=0.707 紹介=0.707]
# index=738[プライバシー=0.707 関連=0.707]
# index=739[分かる=0.577 受講=0.577 料=0.577]
# index=740[授業=0.707 料=0.707]
# index=741[代=0.707 稽古=0.707]
# index=742[かかる=0.500 会費=0.500 年=0.500 用=0.500]
# index=743[1=0.408 安い=0.408 年会=0.408 時期=0.408 番=0.408 費=0.408]
# index=744[入る=0.707 条件=0.707]
# index=745[なる=0.577 会員=0.577 資格=0.577]
# index=746[おはよう=0.707 さん=0.707]
# index=747[おはよう=0.707 さん=0.707]
# index=748[やあ=1.000]
# index=749[夜=0.577 失礼=0.577 遅い=0.577]
# index=750[おば=1.000]
# index=751[入会=0.707 特権=0.707]
# index=752[入会=0.707 利点=0.707]
# index=753[よろしい=0.707 ピアノ=0.707]
# index=754[受ける=0.577 指導=0.577 短期間=0.577]
# index=755[伴奏=0.707 頼める=0.707]
# index=756[伴奏=0.707 依頼=0.707]
# index=757[レッスン=0.408 保育=0.408 受験=0.408 士=0.408 対策=0.408 目的=0.408]
# index=758[スカイプレッスン=0.707 教室=0.707]
# index=759[スカイプレッスン=0.707 教室=0.707]
# index=760[スカイプレッスン=0.707 教室=0.707]
# index=761[キーボード=0.500 卓上=0.500 持ち物=0.500 良い=0.500]
# index=762[どうか=0.408 まだ=0.408 悩む=0.408 申し込む=0.408 知る=0.408 近所=0.408]
# index=763[ござる=0.333 以降=0.333 休日=0.333 夕方=0.333 早朝=0.333 時間=0.333 良い=0.333 都合=0.333 電話=0.333]
# index=764[無言=1.000]
# index=765[発する=0.707 言葉=0.707]
# index=766[いくつ=0.577 ピアノ=0.577 開始=0.577]
# index=767[持参=0.577 楽器=0.577 自宅=0.577]
# index=768[所有=0.707 楽器=0.707]
# index=769[大丈夫=0.500 後=0.500 指導=0.500 開始=0.500]
# index=770[レッスン=0.577 後で=0.577 良い=0.577]
# index=771[外国=0.707 講師=0.707]
# index=772[ティーチャー=0.707 海外=0.707]
# index=773[一=0.577 曲=0.577 習得=0.577]
# index=774[音大=1.000]
# index=775[音大=1.000]
# index=776[演奏=0.707 者=0.707]
# index=777[バック=0.707 演奏=0.707]
# index=778[伴奏=0.707 依頼=0.707]
# index=779[内=0.447 指定=0.447 指導=0.447 期間=0.447 頼む=0.447]
# index=780[取り消す=1.000]
# index=781[解約=1.000]
# index=782[取り消し=0.707 行う=0.707]
# index=783[早急=0.707 見つける=0.707]
# index=784[早々=0.707 見つける=0.707]
# index=785[急ぐ=0.707 見つける=0.707]
# index=786[同時に=0.707 申込む=0.707]
# index=787[同時に=0.707 申込む=0.707]
# index=788[同時に=0.707 申込む=0.707]
# index=789[月謝=0.707 知らせる=0.707]
# index=790[ステップ=0.707 体験=0.707]
# index=791[どう=0.707 調子=0.707]
# index=792[久しぶり=1.000]
# index=793[まだ=0.378 ピアノ=0.378 子供=0.378 早い=0.378 歳=0.378 習わせる=0.378 ２=0.378]
# index=794[いくつ=0.707 ピアノ=0.707]
# index=795[住所=0.500 心配=0.500 書く=0.500 氏名=0.500]
# index=796[料る=0.707 紹介=0.707]
# index=797[初心者=0.577 大丈夫=0.577 大人=0.577]
# index=798[初心者=0.577 大人=0.577 良い=0.577]
# index=799[全く=0.577 初めて=0.577 大人=0.577]
# index=800[とる=0.577 ヤマハ=0.577 級=0.577]
# index=801[もつ=0.577 グレード=0.577 ヤマハ=0.577]
# index=802[とる=0.577 ヤマハ=0.577 級=0.577]
# index=803[トライ=0.707 ポピュラー=0.707]
# index=804[おぼえる=0.707 ポピュラー=0.707]
# index=805[ポップス=0.707 興味=0.707]
# index=806[ポップス=0.707 学習=0.707]
# index=807[ポップス=0.707 習える=0.707]
# index=808[うまい=0.577 ポピュラー=0.577 弾く=0.577]
# index=809[ジャズ=0.707 学習=0.707]
# index=810[ジャズ=0.707 弾ける=0.707]
# index=811[pops=0.707 学ぶ=0.707]
# index=812[pops=0.707 学ぶ=0.707]
# index=813[ジャズ=0.707 習える=0.707]
# index=814[ptna=0.707 意味=0.707]
# index=815[コンクール=0.707 出場=0.707]
# index=816[コンクール=0.707 出場=0.707]
# index=817[思う=0.577 芸大=0.577 行く=0.577]
# index=818[競争=1.000]
# index=819[きめる=0.577 どちら=0.577 戦い=0.577]
# index=820[掲載=0.707 教室=0.707]
# index=821[掲載=0.707 教室=0.707]
# index=822[ろ=0.707 ー=0.707]
# index=823[はーい=1.000]
# index=824[やあ=1.000]
# index=825[いっぱい=0.577 感謝=0.577 気持ち=0.577]
# index=826[もう=0.707 平気=0.707]
# index=827[いう=0.707 もう=0.707]
# index=828[いう=0.707 もう=0.707]
# index=829[ピアノ=0.707 練習=0.707]
# index=830[なん=0.707 ステーション=0.707]
# index=831[なん=0.707 ステーション=0.707]
# index=832[なん=0.707 ステーション=0.707]
# index=833[ステーション=0.707 意味=0.707]
# index=834[ステーション=0.707 詳細=0.707]
# index=835[来る=0.707 自宅=0.707]
# index=836[かえれる=0.707 写真=0.707]
# index=837[アップデート=0.577 出来る=0.577 最近=0.577]
# index=838[18=0.500 未満=0.500 歳=0.500 申込む=0.500]
# index=839[できる=0.707 見学=0.707]
# index=840[あり=0.447 かかれる=0.447 声=0.447 生徒=0.447 見れる=0.447]
# index=841[あり=0.408 かかれる=0.408 ややこしい=0.408 声=0.408 生徒=0.408 見れる=0.408]
# index=842[かわれる=0.577 他=0.577 教室=0.577]
# index=843[ピティナ=0.707 意味=0.707]
# index=844[なん=0.707 ピティナ=0.707]
# index=845[ピティナ=0.707 意味=0.707]
# index=846[ピティナ=0.707 意味=0.707]
# index=847[ピティナ=0.707 仕組み=0.707]
# index=848[基準=0.707 申し込み=0.707]
# index=849[登録=0.707 試験=0.707]
# index=850[]
# index=851[費用=1.000]
# index=852[金額=1.000]
# index=853[金額=1.000]
# index=854[費用=1.000]
# index=855[費用=1.000]
# index=856[支払=0.577 月々=0.577 額=0.577]
# index=857[月謝=1.000]
# index=858[月謝=1.000]
# index=859[支払=0.577 月々=0.577 額=0.577]
# index=860[一緒=0.707 申し込む=0.707]
# index=861[同時=0.707 申請=0.707]
# index=862[一緒=0.707 申込む=0.707]
# index=863[一緒=0.707 申し込める=0.707]
# index=864[同時に=0.707 申込む=0.707]
# index=865[いっぺんに=0.707 申し込む=0.707]
# index=866[一緒=0.707 申し込む=0.707]
# index=867[ptna=0.707 意味=0.707]
# index=868[今日=1.000]
# index=869[やあ=1.000]
# index=870[お疲れさま=1.000]
# index=871[おはよう=0.707 さん=0.707]
# index=872[おはよう=0.707 さん=0.707]
# index=873[入会=0.707 利点=0.707]
# index=874[入会=0.707 利点=0.707]
# index=875[期間=0.707 特典=0.707]
# index=876[申し込み=1.000]
# index=877[はじめる=0.707 ピティナ=0.707]
# index=878[はじめる=0.707 ピティナ=0.707]
# index=879[取り消す=1.000]
# index=880[取り消す=1.000]
# index=881[停止=1.000]
# index=882[どれ=0.707 紹介=0.707]
# index=883[どれ=0.707 紹介=0.707]
# index=884[どれ=0.707 紹介=0.707]
# index=885[プライバシー=0.707 関連=0.707]
# index=886[分かる=0.577 受講=0.577 料=0.577]
# index=887[授業=0.707 料=0.707]
# index=888[代=0.707 稽古=0.707]
# index=889[かかる=0.500 会費=0.500 年=0.500 用=0.500]
# index=890[1=0.408 安い=0.408 年会=0.408 時期=0.408 番=0.408 費=0.408]
# index=891[入る=0.707 条件=0.707]
# index=892[なる=0.577 会員=0.577 資格=0.577]
# index=893[おはよう=0.707 さん=0.707]
# index=894[おはよう=0.707 さん=0.707]
# index=895[やあ=1.000]
# index=896[夜=0.577 失礼=0.577 遅い=0.577]
# index=897[おば=1.000]
# index=898[入会=0.707 特権=0.707]
# index=899[入会=0.707 利点=0.707]
# index=900[よろしい=0.707 ピアノ=0.707]
# index=901[受ける=0.577 指導=0.577 短期間=0.577]
# index=902[伴奏=0.707 頼める=0.707]
# index=903[伴奏=0.707 依頼=0.707]
# index=904[レッスン=0.408 保育=0.408 受験=0.408 士=0.408 対策=0.408 目的=0.408]
# index=905[スカイプレッスン=0.707 教室=0.707]
# index=906[スカイプレッスン=0.707 教室=0.707]
# index=907[スカイプレッスン=0.707 教室=0.707]
# index=908[キーボード=0.500 卓上=0.500 持ち物=0.500 良い=0.500]
# index=909[どうか=0.408 まだ=0.408 悩む=0.408 申し込む=0.408 知る=0.408 近所=0.408]
# index=910[ござる=0.333 以降=0.333 休日=0.333 夕方=0.333 早朝=0.333 時間=0.333 良い=0.333 都合=0.333 電話=0.333]
# index=911[無言=1.000]
# index=912[発する=0.707 言葉=0.707]
# index=913[いくつ=0.577 ピアノ=0.577 開始=0.577]
# index=914[持参=0.577 楽器=0.577 自宅=0.577]
# index=915[所有=0.707 楽器=0.707]
# index=916[大丈夫=0.500 後=0.500 指導=0.500 開始=0.500]
# index=917[レッスン=0.577 後で=0.577 良い=0.577]
# index=918[外国=0.707 講師=0.707]
# index=919[ティーチャー=0.707 海外=0.707]
# index=920[一=0.577 曲=0.577 習得=0.577]
# index=921[音大=1.000]
# index=922[音大=1.000]
# index=923[演奏=0.707 者=0.707]
# index=924[バック=0.707 演奏=0.707]
# index=925[伴奏=0.707 依頼=0.707]
# index=926[内=0.447 指定=0.447 指導=0.447 期間=0.447 頼む=0.447]
# index=927[取り消す=1.000]
# index=928[解約=1.000]
# index=929[取り消し=0.707 行う=0.707]
# index=930[早急=0.707 見つける=0.707]
# index=931[早々=0.707 見つける=0.707]
# index=932[急ぐ=0.707 見つける=0.707]
# index=933[同時に=0.707 申込む=0.707]
# index=934[同時に=0.707 申込む=0.707]
# index=935[同時に=0.707 申込む=0.707]
# index=936[月謝=0.707 知らせる=0.707]
# index=937[ステップ=0.707 体験=0.707]
# index=938[どう=0.707 調子=0.707]
# index=939[久しぶり=1.000]
# index=940[まだ=0.378 ピアノ=0.378 子供=0.378 早い=0.378 歳=0.378 習わせる=0.378 ２=0.378]
# index=941[いくつ=0.707 ピアノ=0.707]
# index=942[住所=0.500 心配=0.500 書く=0.500 氏名=0.500]
# index=943[料る=0.707 紹介=0.707]
# index=944[初心者=0.577 大丈夫=0.577 大人=0.577]
# index=945[初心者=0.577 大人=0.577 良い=0.577]
# index=946[全く=0.577 初めて=0.577 大人=0.577]
# index=947[とる=0.577 ヤマハ=0.577 級=0.577]
# index=948[もつ=0.577 グレード=0.577 ヤマハ=0.577]
# index=949[とる=0.577 ヤマハ=0.577 級=0.577]
# index=950[トライ=0.707 ポピュラー=0.707]
# index=951[おぼえる=0.707 ポピュラー=0.707]
# index=952[ポップス=0.707 興味=0.707]
# index=953[ポップス=0.707 学習=0.707]
# index=954[ポップス=0.707 習える=0.707]
# index=955[うまい=0.577 ポピュラー=0.577 弾く=0.577]
# index=956[ジャズ=0.707 学習=0.707]
# index=957[ジャズ=0.707 弾ける=0.707]
# index=958[pops=0.707 学ぶ=0.707]
# index=959[pops=0.707 学ぶ=0.707]
# index=960[ジャズ=0.707 習える=0.707]
# index=961[ptna=0.707 意味=0.707]
# index=962[コンクール=0.707 出場=0.707]
# index=963[コンクール=0.707 出場=0.707]
# index=964[思う=0.577 芸大=0.577 行く=0.577]
# index=965[競争=1.000]
# index=966[きめる=0.577 どちら=0.577 戦い=0.577]
# index=967[掲載=0.707 教室=0.707]
# index=968[掲載=0.707 教室=0.707]
# index=969[ろ=0.707 ー=0.707]
# index=970[はーい=1.000]
# index=971[やあ=1.000]
# index=972[いっぱい=0.577 感謝=0.577 気持ち=0.577]
# index=973[もう=0.707 平気=0.707]
# index=974[いう=0.707 もう=0.707]
# index=975[いう=0.707 もう=0.707]
# index=976[ピアノ=0.707 練習=0.707]
# index=977[なん=0.707 ステーション=0.707]
# index=978[なん=0.707 ステーション=0.707]
# index=979[なん=0.707 ステーション=0.707]
# index=980[ステーション=0.707 意味=0.707]
# index=981[ステーション=0.707 詳細=0.707]
# index=982[来る=0.707 自宅=0.707]
# index=983[かえれる=0.707 写真=0.707]
# index=984[アップデート=0.577 出来る=0.577 最近=0.577]
# index=985[18=0.500 未満=0.500 歳=0.500 申込む=0.500]
# index=986[できる=0.707 見学=0.707]
# index=987[あり=0.447 かかれる=0.447 声=0.447 生徒=0.447 見れる=0.447]
# index=988[あり=0.408 かかれる=0.408 ややこしい=0.408 声=0.408 生徒=0.408 見れる=0.408]
# index=989[かわれる=0.577 他=0.577 教室=0.577]
# index=990[月謝=1.000]
# index=991[どれ=0.707 紹介=0.707]
# index=992[だいじょうぶ=0.577 ピアノ=0.577 持つ=0.577]
# index=993[スカイプレッスン=0.707 教室=0.707]
# index=994[無言=1.000]
# index=995[先生=0.707 男=0.707]
# index=996[いい=0.707 もう=0.707]
# index=997[先生=0.707 男=0.707]
# index=998[先生=0.707 女=0.707]
# index=999[先生=0.707 男=0.707]
# index=1000[先生=0.707 女=0.707]
# index=1001[先生=0.707 男=0.707]
# index=1002[先生=0.707 男=0.707]
# index=1003[できる=0.707 見学=0.707]
# index=1004[あり=0.408 かかれる=0.408 ややこしい=0.408 声=0.408 生徒=0.408 見れる=0.408]
# index=1005[れる=0.354 クリーン=0.354 シャット=0.354 ダウン=0.354 ブルース=0.354 強制=0.354 発生=0.354 的=0.354]
# index=1006[ip=0.500 アドレス=0.500 拠点=0.500 知る=0.500]
# index=1007[c=0.500 ドライブ=0.500 容量=0.500 枯渇=0.500]
# index=1008[ハードディスク=0.577 不足=0.577 容量=0.577]
# index=1009[メールアドレス=0.707 複数=0.707]
# index=1010[マウス=0.707 故障=0.707]
# index=1011[officepdf=0.707 化=0.707]
# index=1012[gmail=0.707 手順=0.707]
# index=1013[akindo=0.707 繋がる=0.707]
# index=1014[crm=0.707 手順=0.707]
# index=1015[アクセス=0.577 ガルーン=0.577 社外=0.577]
# index=1016[co=0.447 holdings=0.447 id=0.447 jp=0.447 septeni=0.447]
# index=1017[10=0.577 windows=0.577 セッティング=0.577]
# index=1018[chrome=0.500 flash=0.500 られる=0.500 見る=0.500]
# index=1019[usb=0.707 使う=0.707]
# index=1020[7=0.354 シス=0.354 事前=0.354 場合=0.354 情=0.354 操作=0.354 準備=0.354 遠隔=0.354]
# index=1021[0=0.354 せる=0.354 パッチ=0.707 レベル=0.354 適用=0.354]
# index=1022[kunai=0.577 サイボウズ=0.577 利用=0.577]
# index=1023[ie=0.577 ランタイムエラー=0.577 起こる=0.577]
# index=1024[つく=0.577 ノート=0.577 電源=0.577]
# index=1025[dns=0.707 利用=0.707]
# index=1026[入替る=0.707 行う=0.707]
# index=1027[サイボウズ=0.577 戻す=0.577 日本語=0.577]
# index=1028[チャット=0.707 他社=0.707]
# index=1029[google=0.577 競合=0.577 解消=0.577]
# index=1030[google=0.577 困る=0.577 競合=0.577]
# index=1031[データ=0.577 共有=0.577 社外=0.577]
# index=1032[2003=0.500 2007=0.500 オフィス=0.500 見れる=0.500]
# index=1033[アカウント=0.577 ロック=0.577 解除=0.577]
# index=1034[アクセス=0.707 勤怠=0.707]
# index=1035[ネット=0.577 挿す=0.577 有線=0.577]
# index=1036[ssl=0.707 取得=0.707]
# index=1037[ssl=0.707 取得=0.707]
# index=1038[サブ=0.577 ドメイン=0.577 作る=0.577]
# index=1039[アドビ=0.707 使う=0.707]
# index=1040[pc=0.577 聞こえる=0.577 音=0.577]
# index=1041[インターネット=0.500 ウインドウ=0.500 警告=0.500 閲覧=0.500]
# index=1042[8=0.500 ie=0.500 グレート=0.500 ダウン=0.500]
# index=1043[モニタ=0.707 不調=0.707]
# index=1044[エラー=0.500 報告=0.500 完了=0.500 販管=0.500]
# index=1045[エラー=0.500 報告=0.500 実費=0.500 販管=0.500]
# index=1046[乖離=0.378 値=0.378 申請=0.378 許容=0.378 販管=0.378 超える=0.378 額=0.378]
# index=1047[chrome=0.577 初期=0.577 設定=0.577]
# index=1048[エラー=0.577 編集=0.577 販管=0.577]
# index=1049[ファイル=0.577 削除=0.577 復活=0.577]
# index=1050[mac=0.577 マウント=0.577 販管=0.577]
# index=1051[できる=0.707 圧縮=0.707]
# index=1052[ログオン=0.707 出来る=0.707]
# index=1053[gmail=0.707 方法=0.707]
# index=1054[2=0.577 sftowastela=0.577 使い方=0.577]
# index=1055[ログオンパスワード=0.577 忘れる=0.577 販管=0.577]
# index=1056[パスワード=0.500 忘れる=0.500 管理=0.500 販売=0.500]
# index=1057[メーリス=0.577 届く=0.577 誤り=0.577]
# index=1058[pw=0.707 変える=0.707]
# index=1059[gemail=0.500 名=0.500 変更=0.500 差出人=0.500]
# index=1060[firefox=0.500 pw=0.500 記憶=0.500 認証=0.500]
# index=1061[explorer=0.500 internet=0.500 ランタイムエラー=0.500 起こる=0.500]
# index=1062[27=0.378 dm=0.378 クロス=0.378 ゲート=0.378 プリンター=0.378 利用=0.378 階=0.378]
# index=1063[27=0.408 cg=0.408 dm=0.408 プリンタ=0.408 利用=0.408 階=0.408]
# index=1064[アカウント=0.577 ブラウザ=0.577 ログオン=0.577]
# index=1065[2003=0.500 2007=0.500 office=0.500 見れる=0.500]
# index=1066[office=0.577 互換=0.577 性=0.577]
# index=1067[ml=0.707 url=0.707]
# index=1068[vsr=0.577 ドライバ=0.577 プリンター=0.577]
# index=1069[2=0.500 pw=0.500 sfts=0.500 リセット=0.500]
# index=1070[explorer=0.500 internet=0.500 グレード=0.500 ダウン=0.500]
# index=1071[sap=0.500 エラー=0.500 報告=0.500 完了=0.500]
# index=1072[sap=0.500 エラー=0.500 報告=0.500 実費=0.500]
# index=1073[sap=0.378 乖離=0.378 値=0.378 申請=0.378 許容=0.378 超える=0.378 額=0.378]
# index=1074[sap=0.577 エラー=0.577 編集=0.577]
# index=1075[pw=0.577 知る=0.577 自分=0.577]
# index=1076[mac=0.577 sap=0.577 マウント=0.577]
# index=1077[pc=0.577 フロー=0.577 追加=0.577]
# index=1078[セプテーニ=0.577 ドライバ=0.577 プリンター=0.577]
# index=1079[ドライバ=0.577 プリンター=0.577 ホールディングス=0.577]
# index=1080[ログオン=0.707 出来る=0.707]
# index=1081[gmail=0.707 方法=0.707]
# index=1082[2=0.577 sftowastela=0.577 使い方=0.577]
# index=1083[ログオンパスワード=0.577 忘れる=0.577 販管=0.577]
# index=1084[パスワード=0.500 忘れる=0.500 管理=0.500 販売=0.500]
# index=1085[メーリス=0.577 届く=0.577 誤り=0.577]
# index=1086[pw=0.707 変える=0.707]
# index=1087[gemail=0.500 名=0.500 変更=0.500 差出人=0.500]
# index=1088[firefox=0.500 pw=0.500 記憶=0.500 認証=0.500]
# index=1089[explorer=0.500 internet=0.500 ランタイムエラー=0.500 起こる=0.500]
# index=1090[27=0.378 dm=0.378 クロス=0.378 ゲート=0.378 プリンター=0.378 利用=0.378 階=0.378]
# index=1091[27=0.408 cg=0.408 dm=0.408 プリンタ=0.408 利用=0.408 階=0.408]
# index=1092[アカウント=0.577 ブラウザ=0.577 ログオン=0.577]
# index=1093[2003=0.500 2007=0.500 office=0.500 見れる=0.500]
# index=1094[office=0.577 互換=0.577 性=0.577]
# index=1095[ml=0.707 url=0.707]
# index=1096[vsr=0.577 ドライバ=0.577 プリンター=0.577]
# index=1097[2=0.500 pw=0.500 sfts=0.500 リセット=0.500]
# index=1098[explorer=0.500 internet=0.500 グレード=0.500 ダウン=0.500]
# index=1099[sap=0.500 エラー=0.500 報告=0.500 完了=0.500]
# index=1100[sap=0.500 エラー=0.500 報告=0.500 実費=0.500]
# index=1101[sap=0.378 乖離=0.378 値=0.378 申請=0.378 許容=0.378 超える=0.378 額=0.378]
# index=1102[sap=0.577 エラー=0.577 編集=0.577]
# index=1103[pw=0.577 知る=0.577 自分=0.577]
# index=1104[mac=0.577 sap=0.577 マウント=0.577]
# index=1105[pc=0.577 フロー=0.577 追加=0.577]
# index=1106[セプテーニ=0.577 ドライバ=0.577 プリンター=0.577]
# index=1107[ドライバ=0.577 プリンター=0.577 ホールディングス=0.577]
# index=1108[れる=0.354 クリーン=0.354 シャット=0.354 ダウン=0.354 ブルース=0.354 強制=0.354 発生=0.354 的=0.354]
# index=1109[ip=0.500 アドレス=0.500 拠点=0.500 知る=0.500]
# index=1110[c=0.500 ドライブ=0.500 容量=0.500 枯渇=0.500]
# index=1111[ハードディスク=0.577 不足=0.577 容量=0.577]
# index=1112[メールアドレス=0.707 複数=0.707]
# index=1113[マウス=0.707 故障=0.707]
# index=1114[officepdf=0.707 化=0.707]
# index=1115[gmail=0.707 手順=0.707]
# index=1116[akindo=0.707 繋がる=0.707]
# index=1117[crm=0.707 手順=0.707]
# index=1118[アクセス=0.577 ガルーン=0.577 社外=0.577]
# index=1119[co=0.447 holdings=0.447 id=0.447 jp=0.447 septeni=0.447]
# index=1120[10=0.577 windows=0.577 セッティング=0.577]
# index=1121[chrome=0.500 flash=0.500 られる=0.500 見る=0.500]
# index=1122[usb=0.707 使う=0.707]
# index=1123[7=0.354 シス=0.354 事前=0.354 場合=0.354 情=0.354 操作=0.354 準備=0.354 遠隔=0.354]
# index=1124[0=0.354 せる=0.354 パッチ=0.707 レベル=0.354 適用=0.354]
# index=1125[kunai=0.577 サイボウズ=0.577 利用=0.577]
# index=1126[ie=0.577 ランタイムエラー=0.577 起こる=0.577]
# index=1127[つく=0.577 ノート=0.577 電源=0.577]
# index=1128[dns=0.707 利用=0.707]
# index=1129[入替る=0.707 行う=0.707]
# index=1130[サイボウズ=0.577 戻す=0.577 日本語=0.577]
# index=1131[チャット=0.707 他社=0.707]
# index=1132[google=0.577 競合=0.577 解消=0.577]
# index=1133[google=0.577 困る=0.577 競合=0.577]
# index=1134[データ=0.577 共有=0.577 社外=0.577]
# index=1135[2003=0.500 2007=0.500 オフィス=0.500 見れる=0.500]
# index=1136[アカウント=0.577 ロック=0.577 解除=0.577]
# index=1137[アクセス=0.707 勤怠=0.707]
# index=1138[ネット=0.577 挿す=0.577 有線=0.577]
# index=1139[ssl=0.707 取得=0.707]
# index=1140[ssl=0.707 取得=0.707]
# index=1141[サブ=0.577 ドメイン=0.577 作る=0.577]
# index=1142[アドビ=0.707 使う=0.707]
# index=1143[pc=0.577 聞こえる=0.577 音=0.577]
# index=1144[インターネット=0.500 ウインドウ=0.500 警告=0.500 閲覧=0.500]
# index=1145[8=0.500 ie=0.500 グレート=0.500 ダウン=0.500]
# index=1146[モニタ=0.707 不調=0.707]
# index=1147[エラー=0.500 報告=0.500 完了=0.500 販管=0.500]
# index=1148[エラー=0.500 報告=0.500 実費=0.500 販管=0.500]
# index=1149[乖離=0.378 値=0.378 申請=0.378 許容=0.378 販管=0.378 超える=0.378 額=0.378]
# index=1150[chrome=0.577 初期=0.577 設定=0.577]
# index=1151[エラー=0.577 編集=0.577 販管=0.577]
# index=1152[ファイル=0.577 削除=0.577 復活=0.577]
# index=1153[mac=0.577 マウント=0.577 販管=0.577]
# index=1154[できる=0.707 圧縮=0.707]

# %% [markdown]
# ## (5) 参考：外れデータを使って予測
#
# 頻出ワードが含まれる質問文に対しては、アノマリーと検出されない傾向があります。
#
# ただし、明らかにminorityまたは異常とみなされる質問文に対しては、アノマリーと検出するようです。

# %%
'''
    外れデータを使用して、外れ判定を実行してみます
'''
pred_by_linear_for_error = clf_linear.predict(X_error)
vocabulary = text_array._vectorizer.vocabulary_

dumped_features = TestTool.get_dumped_features(X_error, vocabulary)
for k, d in enumerate(dumped_features):
    if pred_by_linear_for_error[k] == -1:
        print(d, '--->detected as anomaly')
    else:
        print(d)
# Out:
# index=0[] --->detected as anomaly
# index=1[] --->detected as anomaly
# index=2[調達=1.000] --->detected as anomaly
# index=3[何=1.000] --->detected as anomaly
# index=4[いい=0.707 何=0.707]
# index=5[いい=0.707 何=0.707]
# index=6[いい=0.577 何=0.577 行う=0.577]
# index=7[いい=0.577 会社=0.577 誰=0.577] --->detected as anomaly
# index=8[いい=0.500 会社=0.500 行う=0.500 誰=0.500]
# index=9[休暇=0.500 取る=0.500 海外=0.500 行く=0.500] --->detected as anomaly
# index=10[休暇=0.447 取る=0.447 思う=0.447 海外=0.447 行く=0.447] --->detected as anomaly

# %% [markdown]
# ### (5-2) 参考：頻出ワード（100位まで）

# %%
ext_feature_count = [0.0 for i in range(n_feature)]
tot_feature_count = 0.0
for i in range(n_sample):
    
    arr = X[i].toarray()[0]
    for j in range(n_feature):
        if arr[j] == 0.0:
            continue
        ext_feature_count[j] += 1.0
        tot_feature_count += 1.0
        
ext_feature_list = []
for k, v in enumerate(ext_feature_count):
    item = TestTool.get_item_from_vocabulary(vocabulary, k)
    elem = (item, v, v / tot_feature_count)
    ext_feature_list.append(elem)

sorted_list = sorted(ext_feature_list, key=lambda x: x[1], reverse=True)

# %%
for i in range(100):
    print("[%s] count=%d, rate=%0.4f" % sorted_list[i])
# Out:
# [メール] count=4900, rate=0.0263
# [できる] count=3516, rate=0.0189
# [れる] count=3379, rate=0.0181
# [2010] count=2694, rate=0.0145
# [outlook] count=2477, rate=0.0133
# [教える] count=2394, rate=0.0129
# [暗号] count=2252, rate=0.0121
# [設定] count=2100, rate=0.0113
# [表示] count=1973, rate=0.0106
# [方法] count=1856, rate=0.0100
# [e] count=1769, rate=0.0095
# [インストール] count=1766, rate=0.0095
# [管理] count=1720, rate=0.0092
# [利用] count=1624, rate=0.0087
# [どう] count=1508, rate=0.0081
# [ツール] count=1506, rate=0.0081
# [化] count=1414, rate=0.0076
# [システム] count=1408, rate=0.0076
# [dki] count=1404, rate=0.0075
# [it] count=1328, rate=0.0071
# [知る] count=1319, rate=0.0071
# [資産] count=1302, rate=0.0070
# [パスワード] count=1262, rate=0.0068
# [なる] count=1236, rate=0.0066
# [使用] count=1234, rate=0.0066
# [pointsec] count=1226, rate=0.0066
# [いい] count=1221, rate=0.0066
# [端末] count=1050, rate=0.0056
# [可能] count=1006, rate=0.0054
# [ファイル] count=1002, rate=0.0054
# [欲しい] count=994, rate=0.0053
# [出来る] count=968, rate=0.0052
# [アウト] count=932, rate=0.0050
# [先生] count=914, rate=0.0049
# [11] count=894, rate=0.0048
# [アドレス] count=878, rate=0.0047
# [ルック] count=864, rate=0.0046
# [情報] count=856, rate=0.0046
# [確認] count=822, rate=0.0044
# [場合] count=786, rate=0.0042
# [送信] count=774, rate=0.0042
# [画面] count=764, rate=0.0041
# [認証] count=764, rate=0.0041
# [手順] count=734, rate=0.0039
# [vpn] count=720, rate=0.0039
# [接続] count=702, rate=0.0038
# [対処] count=686, rate=0.0037
# [ie] count=684, rate=0.0037
# [必要] count=678, rate=0.0036
# [後] count=672, rate=0.0036
# [ipad] count=664, rate=0.0036
# [出る] count=653, rate=0.0035
# [何] count=652, rate=0.0035
# [使う] count=628, rate=0.0034
# [メッセージ] count=620, rate=0.0033
# [自動] count=614, rate=0.0033
# [pc] count=606, rate=0.0033
# [起動] count=600, rate=0.0032
# [エラー] count=594, rate=0.0032
# [windows] count=592, rate=0.0032
# [時] count=584, rate=0.0031
# [byod] count=580, rate=0.0031
# [レッスン] count=578, rate=0.0031
# [対応] count=576, rate=0.0031
# [登録] count=568, rate=0.0030
# [データ] count=562, rate=0.0030
# [変更] count=556, rate=0.0030
# [全社] count=542, rate=0.0029
# [mcafee] count=534, rate=0.0029
# [パソコン] count=514, rate=0.0028
# [削除] count=514, rate=0.0028
# [アカウント] count=513, rate=0.0028
# [帳] count=502, rate=0.0027
# [ピアノ] count=490, rate=0.0026
# [でる] count=484, rate=0.0026
# [使える] count=478, rate=0.0026
# [email] count=473, rate=0.0025
# [添付] count=470, rate=0.0025
# [受信] count=464, rate=0.0025
# [報] count=462, rate=0.0025
# [良い] count=460, rate=0.0025
# [先] count=458, rate=0.0025
# [ログイン] count=456, rate=0.0024
# [検索] count=456, rate=0.0024
# [中] count=444, rate=0.0024
# [通知] count=444, rate=0.0024
# [文書] count=430, rate=0.0023
# [activedirectory] count=428, rate=0.0023
# [入会] count=426, rate=0.0023
# [無線] count=422, rate=0.0023
# [thunderbird] count=412, rate=0.0022
# [移行] count=412, rate=0.0022
# [者] count=412, rate=0.0022
# [入力] count=410, rate=0.0022
# [収集] count=410, rate=0.0022
# [ピーマン] count=406, rate=0.0022
# [書] count=406, rate=0.0022
# [office] count=404, rate=0.0022
# [ほしい] count=402, rate=0.0022
# [かかる] count=400, rate=0.0021
