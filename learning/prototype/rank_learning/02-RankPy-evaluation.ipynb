# %% [markdown]
# # RankPy についての調査
#
# ランク学習の実装事例である「RankPy」について調査しました。
#
# こちらを参考にいたしました。
#
# https://bitbucket.org/tunystom/rankpy
#
#
# ただし、結論から申し上げると、Python 3.x 系の環境ですと正しくセットアップができない様子です。
#
# 残念ながら、今回は試用を中止いたしました。
#
# （ご参考までに、環境準備から実行までのログは、下記の通り残しておきます）

# %% [markdown]
# ## (1) 概要

# %% [markdown]
# 概要を見る限りでは、<a href="01-SVMRank-outline.ipynb"><b>SVMRank</b></a> 同様のランキング予想のようです。
#
# コアな部分は、Cython という処理系により実装されております。
#
# ただし、ベースは Python で実装されており、内部で scikit-learn を呼び出しています。

# %% [markdown]
# ## (2) 環境準備

# %% [markdown]
# ### (2-1) GitHub からファイルを取得

# %% [markdown]
# ```
# MacBookPro-makmorit-jp:~ makmorit$ cd GitHub
# MacBookPro-makmorit-jp:GitHub makmorit$ ls
# NixieTube		RMWiFiController	donusagi-bot		library_for_eagle	mecab
# MacBookPro-makmorit-jp:GitHub makmorit$ git clone https://bitbucket.org/tunystom/rankpy.git
# Cloning into 'rankpy'...
# remote: Counting objects: 616, done.
# remote: Compressing objects: 100% (613/613), done.
# remote: Total 616 (delta 426), reused 0 (delta 0)
# Receiving objects: 100% (616/616), 1.13 MiB | 579.00 KiB/s, done.
# Resolving deltas: 100% (426/426), done.
# MacBookPro-makmorit-jp:GitHub makmorit$ cd rankpy
# MacBookPro-makmorit-jp:rankpy makmorit$ ls -al
# total 144
# drwxr-xr-x  11 makmorit  staff    374 May  3 10:10 .
# drwxr-xr-x  10 makmorit  staff    340 May  3 10:09 ..
# drwxr-xr-x  12 makmorit  staff    408 May  3 10:10 .git
# -rw-r--r--   1 makmorit  staff    675 May  3 10:10 .gitignore
# -rw-r--r--   1 makmorit  staff  35147 May  3 10:10 COPYING
# -rw-r--r--   1 makmorit  staff   7651 May  3 10:10 COPYING.LESSER
# -rw-r--r--   1 makmorit  staff  13118 May  3 10:10 README.rst
# drwxr-xr-x  11 makmorit  staff    374 May  3 10:10 rankpy
# -rw-r--r--   1 makmorit  staff     61 May  3 10:10 requirements.txt
# drwxr-xr-x   7 makmorit  staff    238 May  3 10:10 scripts
# -rw-r--r--   1 makmorit  staff   3515 May  3 10:10 setup.py
# MacBookPro-makmorit-jp:rankpy makmorit$
# ```

# %% [markdown]
# ### (2-2) Cython の導入

# %% [markdown]
# ```
# MacBookPro-makmorit-jp:rankpy makmorit$ pip3 install -r requirements.txt
# Collecting Cython>=0.22 (from -r requirements.txt (line 1))
#   Downloading Cython-0.25.2-cp35-cp35m-macosx_10_6_intel.macosx_10_9_intel.macosx_10_9_x86_64.macosx_10_10_intel.macosx_10_10_x86_64.whl (4.1MB)
#     100% |████████████████████████████████| 4.1MB 361kB/s
# Requirement already satisfied: numpy>=1.9.2 in /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages (from -r requirements.txt (line 2))
# Requirement already satisfied: scipy>=0.15.1 in /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages (from -r requirements.txt (line 3))
# Requirement already satisfied: scikit-learn>=0.16.1 in /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages (from -r requirements.txt (line 4))
# Installing collected packages: Cython
# Successfully installed Cython-0.25.2
# ```

# %% [markdown]
# ### (2-3) セットアップ実行
#
# いくつか警告が出ましたが、正しく Cython のファイル（.pyx, .pxd）が生成されたところを見る限りでは、成功したと思われます。
#
# 長いですが、為念で全量掲載いたします。

# %% [markdown]
# ```
# MacBookPro-makmorit-jp:rankpy makmorit$ python3 setup.py install
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/setuptools/dist.py:285: UserWarning: Normalizing '0.0.1-alpha' to '0.0.1a0'
#   normalized_version,
# running install
# running bdist_egg
# running egg_info
# creating RankPy.egg-info
# writing RankPy.egg-info/PKG-INFO
# writing dependency_links to RankPy.egg-info/dependency_links.txt
# writing top-level names to RankPy.egg-info/top_level.txt
# writing manifest file 'RankPy.egg-info/SOURCES.txt'
# reading manifest file 'RankPy.egg-info/SOURCES.txt'
# writing manifest file 'RankPy.egg-info/SOURCES.txt'
# installing library code to build/bdist.macosx-10.6-intel/egg
# running install_lib
# running build_py
# creating build
# creating build/lib.macosx-10.6-intel-3.5
# creating build/lib.macosx-10.6-intel-3.5/rankpy
# copying rankpy/__init__.py -> build/lib.macosx-10.6-intel-3.5/rankpy
# copying rankpy/gridsearch.py -> build/lib.macosx-10.6-intel-3.5/rankpy
# copying rankpy/queries.py -> build/lib.macosx-10.6-intel-3.5/rankpy
# copying rankpy/utils.py -> build/lib.macosx-10.6-intel-3.5/rankpy
# creating build/lib.macosx-10.6-intel-3.5/rankpy/analysis
# copying rankpy/analysis/__init__.py -> build/lib.macosx-10.6-intel-3.5/rankpy/analysis
# copying rankpy/analysis/lambdamart.py -> build/lib.macosx-10.6-intel-3.5/rankpy/analysis
# creating build/lib.macosx-10.6-intel-3.5/rankpy/externals
# copying rankpy/externals/__init__.py -> build/lib.macosx-10.6-intel-3.5/rankpy/externals
# creating build/lib.macosx-10.6-intel-3.5/rankpy/metrics
# copying rankpy/metrics/__init__.py -> build/lib.macosx-10.6-intel-3.5/rankpy/metrics
# copying rankpy/metrics/metrics.py -> build/lib.macosx-10.6-intel-3.5/rankpy/metrics
# creating build/lib.macosx-10.6-intel-3.5/rankpy/models
# copying rankpy/models/__init__.py -> build/lib.macosx-10.6-intel-3.5/rankpy/models
# copying rankpy/models/lambdamart.py -> build/lib.macosx-10.6-intel-3.5/rankpy/models
# copying rankpy/models/lambdarandomforest.py -> build/lib.macosx-10.6-intel-3.5/rankpy/models
# creating build/lib.macosx-10.6-intel-3.5/rankpy/tree
# copying rankpy/tree/__init__.py -> build/lib.macosx-10.6-intel-3.5/rankpy/tree
# copying rankpy/tree/tree.py -> build/lib.macosx-10.6-intel-3.5/rankpy/tree
# creating build/lib.macosx-10.6-intel-3.5/rankpy/externals/joblib
# copying rankpy/externals/joblib/__init__.py -> build/lib.macosx-10.6-intel-3.5/rankpy/externals/joblib
# copying rankpy/externals/joblib/_compat.py -> build/lib.macosx-10.6-intel-3.5/rankpy/externals/joblib
# copying rankpy/externals/joblib/_memory_helpers.py -> build/lib.macosx-10.6-intel-3.5/rankpy/externals/joblib
# copying rankpy/externals/joblib/_multiprocessing_helpers.py -> build/lib.macosx-10.6-intel-3.5/rankpy/externals/joblib
# copying rankpy/externals/joblib/disk.py -> build/lib.macosx-10.6-intel-3.5/rankpy/externals/joblib
# copying rankpy/externals/joblib/format_stack.py -> build/lib.macosx-10.6-intel-3.5/rankpy/externals/joblib
# copying rankpy/externals/joblib/func_inspect.py -> build/lib.macosx-10.6-intel-3.5/rankpy/externals/joblib
# copying rankpy/externals/joblib/hashing.py -> build/lib.macosx-10.6-intel-3.5/rankpy/externals/joblib
# copying rankpy/externals/joblib/logger.py -> build/lib.macosx-10.6-intel-3.5/rankpy/externals/joblib
# copying rankpy/externals/joblib/memory.py -> build/lib.macosx-10.6-intel-3.5/rankpy/externals/joblib
# copying rankpy/externals/joblib/my_exceptions.py -> build/lib.macosx-10.6-intel-3.5/rankpy/externals/joblib
# copying rankpy/externals/joblib/numpy_pickle.py -> build/lib.macosx-10.6-intel-3.5/rankpy/externals/joblib
# copying rankpy/externals/joblib/parallel.py -> build/lib.macosx-10.6-intel-3.5/rankpy/externals/joblib
# copying rankpy/externals/joblib/pool.py -> build/lib.macosx-10.6-intel-3.5/rankpy/externals/joblib
# copying rankpy/externals/joblib/testing.py -> build/lib.macosx-10.6-intel-3.5/rankpy/externals/joblib
# creating build/lib.macosx-10.6-intel-3.5/rankpy/models/users
# copying rankpy/models/users/__init__.py -> build/lib.macosx-10.6-intel-3.5/rankpy/models/users
# running build_ext
# building 'rankpy.metrics._metrics' extension
# creating build/temp.macosx-10.6-intel-3.5
# creating build/temp.macosx-10.6-intel-3.5/rankpy
# creating build/temp.macosx-10.6-intel-3.5/rankpy/metrics
# /usr/bin/clang -fno-strict-aliasing -Wsign-compare -fno-common -dynamic -DNDEBUG -g -fwrapv -O3 -Wall -Wstrict-prototypes -arch i386 -arch x86_64 -g -I/Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/numpy/core/include -I/Library/Frameworks/Python.framework/Versions/3.5/include/python3.5m -c ./rankpy/metrics/_metrics.c -o build/temp.macosx-10.6-intel-3.5/./rankpy/metrics/_metrics.o
# In file included from ./rankpy/metrics/_metrics.c:250:
# In file included from /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/numpy/core/include/numpy/arrayobject.h:4:
# In file included from /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/numpy/core/include/numpy/ndarrayobject.h:18:
# In file included from /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/numpy/core/include/numpy/ndarraytypes.h:1788:
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/numpy/core/include/numpy/npy_1_7_deprecated_api.h:15:2: warning:
#       "Using deprecated NumPy API, disable it by " "#defining NPY_NO_DEPRECATED_API NPY_1_7_API_VERSION" [-W#warnings]
# #warning "Using deprecated NumPy API, disable it by " \
#  ^
# ./rankpy/metrics/_metrics.c:49449:32: warning: unused function '__Pyx_PyUnicode_FromString' [-Wunused-function]
# static CYTHON_INLINE PyObject* __Pyx_PyUnicode_FromString(const char* c_str) {
#                                ^
# ./rankpy/metrics/_metrics.c:47198:32: warning: unused function '__Pyx_GetItemInt_List_Fast' [-Wunused-function]
# static CYTHON_INLINE PyObject *__Pyx_GetItemInt_List_Fast(PyObject *o, Py_ssize_t i,
#                                ^
# ./rankpy/metrics/_metrics.c:47212:32: warning: unused function '__Pyx_GetItemInt_Tuple_Fast' [-Wunused-function]
# static CYTHON_INLINE PyObject *__Pyx_GetItemInt_Tuple_Fast(PyObject *o, Py_ssize_t i,
#                                ^
# ./rankpy/metrics/_metrics.c:47310:26: warning: unused function '__Pyx_PyBytes_Equals' [-Wunused-function]
# static CYTHON_INLINE int __Pyx_PyBytes_Equals(PyObject* s1, PyObject* s2, int equals) {
#                          ^
# ./rankpy/metrics/_metrics.c:48811:48: warning: unused function '__pyx_t_float_complex_from_parts' [-Wunused-function]
#     static CYTHON_INLINE __pyx_t_float_complex __pyx_t_float_complex_from_parts(float x, float y) {
#                                                ^
# ./rankpy/metrics/_metrics.c:48821:30: warning: unused function '__Pyx_c_eqf' [-Wunused-function]
#     static CYTHON_INLINE int __Pyx_c_eqf(__pyx_t_float_complex a, __pyx_t_float_complex b) {
#                              ^
# ./rankpy/metrics/_metrics.c:48824:48: warning: unused function '__Pyx_c_sumf' [-Wunused-function]
#     static CYTHON_INLINE __pyx_t_float_complex __Pyx_c_sumf(__pyx_t_float_complex a, __pyx_t_float_complex b) {
#                                                ^
# ./rankpy/metrics/_metrics.c:48830:48: warning: unused function '__Pyx_c_difff' [-Wunused-function]
#     static CYTHON_INLINE __pyx_t_float_complex __Pyx_c_difff(__pyx_t_float_complex a, __pyx_t_float_complex b) {
#                                                ^
# ./rankpy/metrics/_metrics.c:48842:48: warning: unused function '__Pyx_c_quotf' [-Wunused-function]
#     static CYTHON_INLINE __pyx_t_float_complex __Pyx_c_quotf(__pyx_t_float_complex a, __pyx_t_float_complex b) {
#                                                ^
# ./rankpy/metrics/_metrics.c:48849:48: warning: unused function '__Pyx_c_negf' [-Wunused-function]
#     static CYTHON_INLINE __pyx_t_float_complex __Pyx_c_negf(__pyx_t_float_complex a) {
#                                                ^
# ./rankpy/metrics/_metrics.c:48855:30: warning: unused function '__Pyx_c_is_zerof' [-Wunused-function]
#     static CYTHON_INLINE int __Pyx_c_is_zerof(__pyx_t_float_complex a) {
#                              ^
# ./rankpy/metrics/_metrics.c:48858:48: warning: unused function '__Pyx_c_conjf' [-Wunused-function]
#     static CYTHON_INLINE __pyx_t_float_complex __Pyx_c_conjf(__pyx_t_float_complex a) {
#                                                ^
# ./rankpy/metrics/_metrics.c:48872:52: warning: unused function '__Pyx_c_powf' [-Wunused-function]
#         static CYTHON_INLINE __pyx_t_float_complex __Pyx_c_powf(__pyx_t_float_complex a, __pyx_t_float_complex b) {
#                                                    ^
# ./rankpy/metrics/_metrics.c:48931:49: warning: unused function '__pyx_t_double_complex_from_parts' [-Wunused-function]
#     static CYTHON_INLINE __pyx_t_double_complex __pyx_t_double_complex_from_parts(double x, double y) {
#                                                 ^
# ./rankpy/metrics/_metrics.c:48941:30: warning: unused function '__Pyx_c_eq' [-Wunused-function]
#     static CYTHON_INLINE int __Pyx_c_eq(__pyx_t_double_complex a, __pyx_t_double_complex b) {
#                              ^
# ./rankpy/metrics/_metrics.c:48944:49: warning: unused function '__Pyx_c_sum' [-Wunused-function]
#     static CYTHON_INLINE __pyx_t_double_complex __Pyx_c_sum(__pyx_t_double_complex a, __pyx_t_double_complex b) {
#                                                 ^
# ./rankpy/metrics/_metrics.c:48950:49: warning: unused function '__Pyx_c_diff' [-Wunused-function]
#     static CYTHON_INLINE __pyx_t_double_complex __Pyx_c_diff(__pyx_t_double_complex a, __pyx_t_double_complex b) {
#                                                 ^
# ./rankpy/metrics/_metrics.c:48962:49: warning: unused function '__Pyx_c_quot' [-Wunused-function]
#     static CYTHON_INLINE __pyx_t_double_complex __Pyx_c_quot(__pyx_t_double_complex a, __pyx_t_double_complex b) {
#                                                 ^
# ./rankpy/metrics/_metrics.c:48969:49: warning: unused function '__Pyx_c_neg' [-Wunused-function]
#     static CYTHON_INLINE __pyx_t_double_complex __Pyx_c_neg(__pyx_t_double_complex a) {
#                                                 ^
# ./rankpy/metrics/_metrics.c:48975:30: warning: unused function '__Pyx_c_is_zero' [-Wunused-function]
#     static CYTHON_INLINE int __Pyx_c_is_zero(__pyx_t_double_complex a) {
#                              ^
# ./rankpy/metrics/_metrics.c:48978:49: warning: unused function '__Pyx_c_conj' [-Wunused-function]
#     static CYTHON_INLINE __pyx_t_double_complex __Pyx_c_conj(__pyx_t_double_complex a) {
#                                                 ^
# ./rankpy/metrics/_metrics.c:48992:53: warning: unused function '__Pyx_c_pow' [-Wunused-function]
#         static CYTHON_INLINE __pyx_t_double_complex __Pyx_c_pow(__pyx_t_double_complex a, __pyx_t_double_complex b) {
#                                                     ^
# ./rankpy/metrics/_metrics.c:49175:27: warning: function '__Pyx_PyInt_As_char' is not needed and will not be emitted [-Wunneeded-internal-declaration]
# static CYTHON_INLINE char __Pyx_PyInt_As_char(PyObject *x) {
#                           ^
# ./rankpy/metrics/_metrics.c:31715:32: warning: unused function '__pyx_f_5numpy_PyArray_MultiIterNew1' [-Wunused-function]
# static CYTHON_INLINE PyObject *__pyx_f_5numpy_PyArray_MultiIterNew1(PyObject *__pyx_v_a) {
#                                ^
# ./rankpy/metrics/_metrics.c:31765:32: warning: unused function '__pyx_f_5numpy_PyArray_MultiIterNew2' [-Wunused-function]
# static CYTHON_INLINE PyObject *__pyx_f_5numpy_PyArray_MultiIterNew2(PyObject *__pyx_v_a, PyObject *__pyx_v_b) {
#                                ^
# ./rankpy/metrics/_metrics.c:31815:32: warning: unused function '__pyx_f_5numpy_PyArray_MultiIterNew3' [-Wunused-function]
# static CYTHON_INLINE PyObject *__pyx_f_5numpy_PyArray_MultiIterNew3(PyObject *__pyx_v_a, PyObject *__pyx_v_b, PyObject *__pyx_v_c) {
#                                ^
# ./rankpy/metrics/_metrics.c:31865:32: warning: unused function '__pyx_f_5numpy_PyArray_MultiIterNew4' [-Wunused-function]
# static CYTHON_INLINE PyObject *__pyx_f_5numpy_PyArray_MultiIterNew4(PyObject *__pyx_v_a, PyObject *__pyx_v_b, PyObject *__pyx_v_c, PyObject *_...
#                                ^
# ./rankpy/metrics/_metrics.c:31915:32: warning: unused function '__pyx_f_5numpy_PyArray_MultiIterNew5' [-Wunused-function]
# static CYTHON_INLINE PyObject *__pyx_f_5numpy_PyArray_MultiIterNew5(PyObject *__pyx_v_a, PyObject *__pyx_v_b, PyObject *__pyx_v_c, PyObject *_...
#                                ^
# ./rankpy/metrics/_metrics.c:32682:27: warning: unused function '__pyx_f_5numpy_set_array_base' [-Wunused-function]
# static CYTHON_INLINE void __pyx_f_5numpy_set_array_base(PyArrayObject *__pyx_v_arr, PyObject *__pyx_v_base) {
#                           ^
# ./rankpy/metrics/_metrics.c:32770:32: warning: unused function '__pyx_f_5numpy_get_array_base' [-Wunused-function]
# static CYTHON_INLINE PyObject *__pyx_f_5numpy_get_array_base(PyArrayObject *__pyx_v_arr) {
#                                ^
# 31 warnings generated.
# In file included from ./rankpy/metrics/_metrics.c:250:
# In file included from /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/numpy/core/include/numpy/arrayobject.h:4:
# In file included from /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/numpy/core/include/numpy/ndarrayobject.h:18:
# In file included from /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/numpy/core/include/numpy/ndarraytypes.h:1788:
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/numpy/core/include/numpy/npy_1_7_deprecated_api.h:15:2: warning:
#       "Using deprecated NumPy API, disable it by " "#defining NPY_NO_DEPRECATED_API NPY_1_7_API_VERSION" [-W#warnings]
# #warning "Using deprecated NumPy API, disable it by " \
#  ^
# ./rankpy/metrics/_metrics.c:49449:32: warning: unused function '__Pyx_PyUnicode_FromString' [-Wunused-function]
# static CYTHON_INLINE PyObject* __Pyx_PyUnicode_FromString(const char* c_str) {
#                                ^
# ./rankpy/metrics/_metrics.c:47003:1: warning: unused function '__pyx_add_acquisition_count_locked' [-Wunused-function]
# __pyx_add_acquisition_count_locked(__pyx_atomic_int *acquisition_count,
# ^
# ./rankpy/metrics/_metrics.c:47013:1: warning: unused function '__pyx_sub_acquisition_count_locked' [-Wunused-function]
# __pyx_sub_acquisition_count_locked(__pyx_atomic_int *acquisition_count,
# ^
# ./rankpy/metrics/_metrics.c:47198:32: warning: unused function '__Pyx_GetItemInt_List_Fast' [-Wunused-function]
# static CYTHON_INLINE PyObject *__Pyx_GetItemInt_List_Fast(PyObject *o, Py_ssize_t i,
#                                ^
# ./rankpy/metrics/_metrics.c:47212:32: warning: unused function '__Pyx_GetItemInt_Tuple_Fast' [-Wunused-function]
# static CYTHON_INLINE PyObject *__Pyx_GetItemInt_Tuple_Fast(PyObject *o, Py_ssize_t i,
#                                ^
# ./rankpy/metrics/_metrics.c:47310:26: warning: unused function '__Pyx_PyBytes_Equals' [-Wunused-function]
# static CYTHON_INLINE int __Pyx_PyBytes_Equals(PyObject* s1, PyObject* s2, int equals) {
#                          ^
# ./rankpy/metrics/_metrics.c:48811:48: warning: unused function '__pyx_t_float_complex_from_parts' [-Wunused-function]
#     static CYTHON_INLINE __pyx_t_float_complex __pyx_t_float_complex_from_parts(float x, float y) {
#                                                ^
# ./rankpy/metrics/_metrics.c:48821:30: warning: unused function '__Pyx_c_eqf' [-Wunused-function]
#     static CYTHON_INLINE int __Pyx_c_eqf(__pyx_t_float_complex a, __pyx_t_float_complex b) {
#                              ^
# ./rankpy/metrics/_metrics.c:48824:48: warning: unused function '__Pyx_c_sumf' [-Wunused-function]
#     static CYTHON_INLINE __pyx_t_float_complex __Pyx_c_sumf(__pyx_t_float_complex a, __pyx_t_float_complex b) {
#                                                ^
# ./rankpy/metrics/_metrics.c:48830:48: warning: unused function '__Pyx_c_difff' [-Wunused-function]
#     static CYTHON_INLINE __pyx_t_float_complex __Pyx_c_difff(__pyx_t_float_complex a, __pyx_t_float_complex b) {
#                                                ^
# ./rankpy/metrics/_metrics.c:48842:48: warning: unused function '__Pyx_c_quotf' [-Wunused-function]
#     static CYTHON_INLINE __pyx_t_float_complex __Pyx_c_quotf(__pyx_t_float_complex a, __pyx_t_float_complex b) {
#                                                ^
# ./rankpy/metrics/_metrics.c:48849:48: warning: unused function '__Pyx_c_negf' [-Wunused-function]
#     static CYTHON_INLINE __pyx_t_float_complex __Pyx_c_negf(__pyx_t_float_complex a) {
#                                                ^
# ./rankpy/metrics/_metrics.c:48855:30: warning: unused function '__Pyx_c_is_zerof' [-Wunused-function]
#     static CYTHON_INLINE int __Pyx_c_is_zerof(__pyx_t_float_complex a) {
#                              ^
# ./rankpy/metrics/_metrics.c:48858:48: warning: unused function '__Pyx_c_conjf' [-Wunused-function]
#     static CYTHON_INLINE __pyx_t_float_complex __Pyx_c_conjf(__pyx_t_float_complex a) {
#                                                ^
# ./rankpy/metrics/_metrics.c:48872:52: warning: unused function '__Pyx_c_powf' [-Wunused-function]
#         static CYTHON_INLINE __pyx_t_float_complex __Pyx_c_powf(__pyx_t_float_complex a, __pyx_t_float_complex b) {
#                                                    ^
# ./rankpy/metrics/_metrics.c:48931:49: warning: unused function '__pyx_t_double_complex_from_parts' [-Wunused-function]
#     static CYTHON_INLINE __pyx_t_double_complex __pyx_t_double_complex_from_parts(double x, double y) {
#                                                 ^
# ./rankpy/metrics/_metrics.c:48941:30: warning: unused function '__Pyx_c_eq' [-Wunused-function]
#     static CYTHON_INLINE int __Pyx_c_eq(__pyx_t_double_complex a, __pyx_t_double_complex b) {
#                              ^
# ./rankpy/metrics/_metrics.c:48944:49: warning: unused function '__Pyx_c_sum' [-Wunused-function]
#     static CYTHON_INLINE __pyx_t_double_complex __Pyx_c_sum(__pyx_t_double_complex a, __pyx_t_double_complex b) {
#                                                 ^
# ./rankpy/metrics/_metrics.c:48950:49: warning: unused function '__Pyx_c_diff' [-Wunused-function]
#     static CYTHON_INLINE __pyx_t_double_complex __Pyx_c_diff(__pyx_t_double_complex a, __pyx_t_double_complex b) {
#                                                 ^
# ./rankpy/metrics/_metrics.c:48962:49: warning: unused function '__Pyx_c_quot' [-Wunused-function]
#     static CYTHON_INLINE __pyx_t_double_complex __Pyx_c_quot(__pyx_t_double_complex a, __pyx_t_double_complex b) {
#                                                 ^
# ./rankpy/metrics/_metrics.c:48969:49: warning: unused function '__Pyx_c_neg' [-Wunused-function]
#     static CYTHON_INLINE __pyx_t_double_complex __Pyx_c_neg(__pyx_t_double_complex a) {
#                                                 ^
# ./rankpy/metrics/_metrics.c:48975:30: warning: unused function '__Pyx_c_is_zero' [-Wunused-function]
#     static CYTHON_INLINE int __Pyx_c_is_zero(__pyx_t_double_complex a) {
#                              ^
# ./rankpy/metrics/_metrics.c:48978:49: warning: unused function '__Pyx_c_conj' [-Wunused-function]
#     static CYTHON_INLINE __pyx_t_double_complex __Pyx_c_conj(__pyx_t_double_complex a) {
#                                                 ^
# ./rankpy/metrics/_metrics.c:48992:53: warning: unused function '__Pyx_c_pow' [-Wunused-function]
#         static CYTHON_INLINE __pyx_t_double_complex __Pyx_c_pow(__pyx_t_double_complex a, __pyx_t_double_complex b) {
#                                                     ^
# ./rankpy/metrics/_metrics.c:49175:27: warning: function '__Pyx_PyInt_As_char' is not needed and will not be emitted [-Wunneeded-internal-declaration]
# static CYTHON_INLINE char __Pyx_PyInt_As_char(PyObject *x) {
#                           ^
# ./rankpy/metrics/_metrics.c:31715:32: warning: unused function '__pyx_f_5numpy_PyArray_MultiIterNew1' [-Wunused-function]
# static CYTHON_INLINE PyObject *__pyx_f_5numpy_PyArray_MultiIterNew1(PyObject *__pyx_v_a) {
#                                ^
# ./rankpy/metrics/_metrics.c:31765:32: warning: unused function '__pyx_f_5numpy_PyArray_MultiIterNew2' [-Wunused-function]
# static CYTHON_INLINE PyObject *__pyx_f_5numpy_PyArray_MultiIterNew2(PyObject *__pyx_v_a, PyObject *__pyx_v_b) {
#                                ^
# ./rankpy/metrics/_metrics.c:31815:32: warning: unused function '__pyx_f_5numpy_PyArray_MultiIterNew3' [-Wunused-function]
# static CYTHON_INLINE PyObject *__pyx_f_5numpy_PyArray_MultiIterNew3(PyObject *__pyx_v_a, PyObject *__pyx_v_b, PyObject *__pyx_v_c) {
#                                ^
# ./rankpy/metrics/_metrics.c:31865:32: warning: unused function '__pyx_f_5numpy_PyArray_MultiIterNew4' [-Wunused-function]
# static CYTHON_INLINE PyObject *__pyx_f_5numpy_PyArray_MultiIterNew4(PyObject *__pyx_v_a, PyObject *__pyx_v_b, PyObject *__pyx_v_c, PyObject *_...
#                                ^
# ./rankpy/metrics/_metrics.c:31915:32: warning: unused function '__pyx_f_5numpy_PyArray_MultiIterNew5' [-Wunused-function]
# static CYTHON_INLINE PyObject *__pyx_f_5numpy_PyArray_MultiIterNew5(PyObject *__pyx_v_a, PyObject *__pyx_v_b, PyObject *__pyx_v_c, PyObject *_...
#                                ^
# ./rankpy/metrics/_metrics.c:32682:27: warning: unused function '__pyx_f_5numpy_set_array_base' [-Wunused-function]
# static CYTHON_INLINE void __pyx_f_5numpy_set_array_base(PyArrayObject *__pyx_v_arr, PyObject *__pyx_v_base) {
#                           ^
# ./rankpy/metrics/_metrics.c:32770:32: warning: unused function '__pyx_f_5numpy_get_array_base' [-Wunused-function]
# static CYTHON_INLINE PyObject *__pyx_f_5numpy_get_array_base(PyArrayObject *__pyx_v_arr) {
#                                ^
# 33 warnings generated.
# /usr/bin/clang -bundle -undefined dynamic_lookup -arch i386 -arch x86_64 -g build/temp.macosx-10.6-intel-3.5/./rankpy/metrics/_metrics.o -lm -o build/lib.macosx-10.6-intel-3.5/rankpy/metrics/_metrics.cpython-35m-darwin.so
# building 'rankpy.metrics._utils' extension
# /usr/bin/clang -fno-strict-aliasing -Wsign-compare -fno-common -dynamic -DNDEBUG -g -fwrapv -O3 -Wall -Wstrict-prototypes -arch i386 -arch x86_64 -g -I/Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/numpy/core/include -I/Library/Frameworks/Python.framework/Versions/3.5/include/python3.5m -c ./rankpy/metrics/_utils.c -o build/temp.macosx-10.6-intel-3.5/./rankpy/metrics/_utils.o
# In file included from ./rankpy/metrics/_utils.c:250:
# In file included from /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/numpy/core/include/numpy/arrayobject.h:4:
# In file included from /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/numpy/core/include/numpy/ndarrayobject.h:18:
# In file included from /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/numpy/core/include/numpy/ndarraytypes.h:1788:
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/numpy/core/include/numpy/npy_1_7_deprecated_api.h:15:2: warning:
#       "Using deprecated NumPy API, disable it by " "#defining NPY_NO_DEPRECATED_API NPY_1_7_API_VERSION" [-W#warnings]
# #warning "Using deprecated NumPy API, disable it by " \
#  ^
# ./rankpy/metrics/_utils.c:24756:32: warning: unused function '__Pyx_PyUnicode_FromString' [-Wunused-function]
# static CYTHON_INLINE PyObject* __Pyx_PyUnicode_FromString(const char* c_str) {
#                                ^
# ./rankpy/metrics/_utils.c:24896:33: warning: unused function '__Pyx_PyInt_FromSize_t' [-Wunused-function]
# static CYTHON_INLINE PyObject * __Pyx_PyInt_FromSize_t(size_t ival) {
#                                 ^
# ./rankpy/metrics/_utils.c:22776:26: warning: unused function '__Pyx_PyBytes_Equals' [-Wunused-function]
# static CYTHON_INLINE int __Pyx_PyBytes_Equals(PyObject* s1, PyObject* s2, int equals) {
#                          ^
# ./rankpy/metrics/_utils.c:23048:32: warning: unused function '__Pyx_GetItemInt_List_Fast' [-Wunused-function]
# static CYTHON_INLINE PyObject *__Pyx_GetItemInt_List_Fast(PyObject *o, Py_ssize_t i,
#                                ^
# ./rankpy/metrics/_utils.c:23062:32: warning: unused function '__Pyx_GetItemInt_Tuple_Fast' [-Wunused-function]
# static CYTHON_INLINE PyObject *__Pyx_GetItemInt_Tuple_Fast(PyObject *o, Py_ssize_t i,
#                                ^
# ./rankpy/metrics/_utils.c:23945:48: warning: unused function '__pyx_t_float_complex_from_parts' [-Wunused-function]
#     static CYTHON_INLINE __pyx_t_float_complex __pyx_t_float_complex_from_parts(float x, float y) {
#                                                ^
# ./rankpy/metrics/_utils.c:23955:30: warning: unused function '__Pyx_c_eqf' [-Wunused-function]
#     static CYTHON_INLINE int __Pyx_c_eqf(__pyx_t_float_complex a, __pyx_t_float_complex b) {
#                              ^
# ./rankpy/metrics/_utils.c:23958:48: warning: unused function '__Pyx_c_sumf' [-Wunused-function]
#     static CYTHON_INLINE __pyx_t_float_complex __Pyx_c_sumf(__pyx_t_float_complex a, __pyx_t_float_complex b) {
#                                                ^
# ./rankpy/metrics/_utils.c:23964:48: warning: unused function '__Pyx_c_difff' [-Wunused-function]
#     static CYTHON_INLINE __pyx_t_float_complex __Pyx_c_difff(__pyx_t_float_complex a, __pyx_t_float_complex b) {
#                                                ^
# ./rankpy/metrics/_utils.c:23976:48: warning: unused function '__Pyx_c_quotf' [-Wunused-function]
#     static CYTHON_INLINE __pyx_t_float_complex __Pyx_c_quotf(__pyx_t_float_complex a, __pyx_t_float_complex b) {
#                                                ^
# ./rankpy/metrics/_utils.c:23983:48: warning: unused function '__Pyx_c_negf' [-Wunused-function]
#     static CYTHON_INLINE __pyx_t_float_complex __Pyx_c_negf(__pyx_t_float_complex a) {
#                                                ^
# ./rankpy/metrics/_utils.c:23989:30: warning: unused function '__Pyx_c_is_zerof' [-Wunused-function]
#     static CYTHON_INLINE int __Pyx_c_is_zerof(__pyx_t_float_complex a) {
#                              ^
# ./rankpy/metrics/_utils.c:23992:48: warning: unused function '__Pyx_c_conjf' [-Wunused-function]
#     static CYTHON_INLINE __pyx_t_float_complex __Pyx_c_conjf(__pyx_t_float_complex a) {
#                                                ^
# ./rankpy/metrics/_utils.c:24006:52: warning: unused function '__Pyx_c_powf' [-Wunused-function]
#         static CYTHON_INLINE __pyx_t_float_complex __Pyx_c_powf(__pyx_t_float_complex a, __pyx_t_float_complex b) {
#                                                    ^
# ./rankpy/metrics/_utils.c:24065:49: warning: unused function '__pyx_t_double_complex_from_parts' [-Wunused-function]
#     static CYTHON_INLINE __pyx_t_double_complex __pyx_t_double_complex_from_parts(double x, double y) {
#                                                 ^
# ./rankpy/metrics/_utils.c:24075:30: warning: unused function '__Pyx_c_eq' [-Wunused-function]
#     static CYTHON_INLINE int __Pyx_c_eq(__pyx_t_double_complex a, __pyx_t_double_complex b) {
#                              ^
# ./rankpy/metrics/_utils.c:24078:49: warning: unused function '__Pyx_c_sum' [-Wunused-function]
#     static CYTHON_INLINE __pyx_t_double_complex __Pyx_c_sum(__pyx_t_double_complex a, __pyx_t_double_complex b) {
#                                                 ^
# ./rankpy/metrics/_utils.c:24084:49: warning: unused function '__Pyx_c_diff' [-Wunused-function]
#     static CYTHON_INLINE __pyx_t_double_complex __Pyx_c_diff(__pyx_t_double_complex a, __pyx_t_double_complex b) {
#                                                 ^
# ./rankpy/metrics/_utils.c:24096:49: warning: unused function '__Pyx_c_quot' [-Wunused-function]
#     static CYTHON_INLINE __pyx_t_double_complex __Pyx_c_quot(__pyx_t_double_complex a, __pyx_t_double_complex b) {
#                                                 ^
# ./rankpy/metrics/_utils.c:24103:49: warning: unused function '__Pyx_c_neg' [-Wunused-function]
#     static CYTHON_INLINE __pyx_t_double_complex __Pyx_c_neg(__pyx_t_double_complex a) {
#                                                 ^
# ./rankpy/metrics/_utils.c:24109:30: warning: unused function '__Pyx_c_is_zero' [-Wunused-function]
#     static CYTHON_INLINE int __Pyx_c_is_zero(__pyx_t_double_complex a) {
#                              ^
# ./rankpy/metrics/_utils.c:24112:49: warning: unused function '__Pyx_c_conj' [-Wunused-function]
#     static CYTHON_INLINE __pyx_t_double_complex __Pyx_c_conj(__pyx_t_double_complex a) {
#                                                 ^
# ./rankpy/metrics/_utils.c:24126:53: warning: unused function '__Pyx_c_pow' [-Wunused-function]
#         static CYTHON_INLINE __pyx_t_double_complex __Pyx_c_pow(__pyx_t_double_complex a, __pyx_t_double_complex b) {
#                                                     ^
# ./rankpy/metrics/_utils.c:24404:27: warning: function '__Pyx_PyInt_As_char' is not needed and will not be emitted [-Wunneeded-internal-declaration]
# static CYTHON_INLINE char __Pyx_PyInt_As_char(PyObject *x) {
#                           ^
# ./rankpy/metrics/_utils.c:24499:27: warning: function '__Pyx_PyInt_As_long' is not needed and will not be emitted [-Wunneeded-internal-declaration]
# static CYTHON_INLINE long __Pyx_PyInt_As_long(PyObject *x) {
#                           ^
# ./rankpy/metrics/_utils.c:7354:26: warning: unused function '__pyx_f_6rankpy_7metrics_6_utils_rand_int_c' [-Wunused-function]
# static CYTHON_INLINE int __pyx_f_6rankpy_7metrics_6_utils_rand_int_c(int __pyx_v_low, int __pyx_v_high, unsigned int *__pyx_v_seed) {
#                          ^
# ./rankpy/metrics/_utils.c:8305:32: warning: unused function '__pyx_f_5numpy_PyArray_MultiIterNew1' [-Wunused-function]
# static CYTHON_INLINE PyObject *__pyx_f_5numpy_PyArray_MultiIterNew1(PyObject *__pyx_v_a) {
#                                ^
# ./rankpy/metrics/_utils.c:8355:32: warning: unused function '__pyx_f_5numpy_PyArray_MultiIterNew2' [-Wunused-function]
# static CYTHON_INLINE PyObject *__pyx_f_5numpy_PyArray_MultiIterNew2(PyObject *__pyx_v_a, PyObject *__pyx_v_b) {
#                                ^
# ./rankpy/metrics/_utils.c:8405:32: warning: unused function '__pyx_f_5numpy_PyArray_MultiIterNew3' [-Wunused-function]
# static CYTHON_INLINE PyObject *__pyx_f_5numpy_PyArray_MultiIterNew3(PyObject *__pyx_v_a, PyObject *__pyx_v_b, PyObject *__pyx_v_c) {
#                                ^
# ./rankpy/metrics/_utils.c:8455:32: warning: unused function '__pyx_f_5numpy_PyArray_MultiIterNew4' [-Wunused-function]
# static CYTHON_INLINE PyObject *__pyx_f_5numpy_PyArray_MultiIterNew4(PyObject *__pyx_v_a, PyObject *__pyx_v_b, PyObject *__pyx_v_c, PyObject *_...
#                                ^
# ./rankpy/metrics/_utils.c:8505:32: warning: unused function '__pyx_f_5numpy_PyArray_MultiIterNew5' [-Wunused-function]
# static CYTHON_INLINE PyObject *__pyx_f_5numpy_PyArray_MultiIterNew5(PyObject *__pyx_v_a, PyObject *__pyx_v_b, PyObject *__pyx_v_c, PyObject *_...
#                                ^
# ./rankpy/metrics/_utils.c:9272:27: warning: unused function '__pyx_f_5numpy_set_array_base' [-Wunused-function]
# static CYTHON_INLINE void __pyx_f_5numpy_set_array_base(PyArrayObject *__pyx_v_arr, PyObject *__pyx_v_base) {
#                           ^
# ./rankpy/metrics/_utils.c:9360:32: warning: unused function '__pyx_f_5numpy_get_array_base' [-Wunused-function]
# static CYTHON_INLINE PyObject *__pyx_f_5numpy_get_array_base(PyArrayObject *__pyx_v_arr) {
#                                ^
# 34 warnings generated.
# In file included from ./rankpy/metrics/_utils.c:250:
# In file included from /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/numpy/core/include/numpy/arrayobject.h:4:
# In file included from /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/numpy/core/include/numpy/ndarrayobject.h:18:
# In file included from /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/numpy/core/include/numpy/ndarraytypes.h:1788:
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/numpy/core/include/numpy/npy_1_7_deprecated_api.h:15:2: warning:
#       "Using deprecated NumPy API, disable it by " "#defining NPY_NO_DEPRECATED_API NPY_1_7_API_VERSION" [-W#warnings]
# #warning "Using deprecated NumPy API, disable it by " \
#  ^
# ./rankpy/metrics/_utils.c:24756:32: warning: unused function '__Pyx_PyUnicode_FromString' [-Wunused-function]
# static CYTHON_INLINE PyObject* __Pyx_PyUnicode_FromString(const char* c_str) {
#                                ^
# ./rankpy/metrics/_utils.c:24896:33: warning: unused function '__Pyx_PyInt_FromSize_t' [-Wunused-function]
# static CYTHON_INLINE PyObject * __Pyx_PyInt_FromSize_t(size_t ival) {
#                                 ^
# ./rankpy/metrics/_utils.c:22498:1: warning: unused function '__pyx_add_acquisition_count_locked' [-Wunused-function]
# __pyx_add_acquisition_count_locked(__pyx_atomic_int *acquisition_count,
# ^
# ./rankpy/metrics/_utils.c:22508:1: warning: unused function '__pyx_sub_acquisition_count_locked' [-Wunused-function]
# __pyx_sub_acquisition_count_locked(__pyx_atomic_int *acquisition_count,
# ^
# ./rankpy/metrics/_utils.c:22776:26: warning: unused function '__Pyx_PyBytes_Equals' [-Wunused-function]
# static CYTHON_INLINE int __Pyx_PyBytes_Equals(PyObject* s1, PyObject* s2, int equals) {
#                          ^
# ./rankpy/metrics/_utils.c:23048:32: warning: unused function '__Pyx_GetItemInt_List_Fast' [-Wunused-function]
# static CYTHON_INLINE PyObject *__Pyx_GetItemInt_List_Fast(PyObject *o, Py_ssize_t i,
#                                ^
# ./rankpy/metrics/_utils.c:23062:32: warning: unused function '__Pyx_GetItemInt_Tuple_Fast' [-Wunused-function]
# static CYTHON_INLINE PyObject *__Pyx_GetItemInt_Tuple_Fast(PyObject *o, Py_ssize_t i,
#                                ^
# ./rankpy/metrics/_utils.c:23945:48: warning: unused function '__pyx_t_float_complex_from_parts' [-Wunused-function]
#     static CYTHON_INLINE __pyx_t_float_complex __pyx_t_float_complex_from_parts(float x, float y) {
#                                                ^
# ./rankpy/metrics/_utils.c:23955:30: warning: unused function '__Pyx_c_eqf' [-Wunused-function]
#     static CYTHON_INLINE int __Pyx_c_eqf(__pyx_t_float_complex a, __pyx_t_float_complex b) {
#                              ^
# ./rankpy/metrics/_utils.c:23958:48: warning: unused function '__Pyx_c_sumf' [-Wunused-function]
#     static CYTHON_INLINE __pyx_t_float_complex __Pyx_c_sumf(__pyx_t_float_complex a, __pyx_t_float_complex b) {
#                                                ^
# ./rankpy/metrics/_utils.c:23964:48: warning: unused function '__Pyx_c_difff' [-Wunused-function]
#     static CYTHON_INLINE __pyx_t_float_complex __Pyx_c_difff(__pyx_t_float_complex a, __pyx_t_float_complex b) {
#                                                ^
# ./rankpy/metrics/_utils.c:23976:48: warning: unused function '__Pyx_c_quotf' [-Wunused-function]
#     static CYTHON_INLINE __pyx_t_float_complex __Pyx_c_quotf(__pyx_t_float_complex a, __pyx_t_float_complex b) {
#                                                ^
# ./rankpy/metrics/_utils.c:23983:48: warning: unused function '__Pyx_c_negf' [-Wunused-function]
#     static CYTHON_INLINE __pyx_t_float_complex __Pyx_c_negf(__pyx_t_float_complex a) {
#                                                ^
# ./rankpy/metrics/_utils.c:23989:30: warning: unused function '__Pyx_c_is_zerof' [-Wunused-function]
#     static CYTHON_INLINE int __Pyx_c_is_zerof(__pyx_t_float_complex a) {
#                              ^
# ./rankpy/metrics/_utils.c:23992:48: warning: unused function '__Pyx_c_conjf' [-Wunused-function]
#     static CYTHON_INLINE __pyx_t_float_complex __Pyx_c_conjf(__pyx_t_float_complex a) {
#                                                ^
# ./rankpy/metrics/_utils.c:24006:52: warning: unused function '__Pyx_c_powf' [-Wunused-function]
#         static CYTHON_INLINE __pyx_t_float_complex __Pyx_c_powf(__pyx_t_float_complex a, __pyx_t_float_complex b) {
#                                                    ^
# ./rankpy/metrics/_utils.c:24065:49: warning: unused function '__pyx_t_double_complex_from_parts' [-Wunused-function]
#     static CYTHON_INLINE __pyx_t_double_complex __pyx_t_double_complex_from_parts(double x, double y) {
#                                                 ^
# ./rankpy/metrics/_utils.c:24075:30: warning: unused function '__Pyx_c_eq' [-Wunused-function]
#     static CYTHON_INLINE int __Pyx_c_eq(__pyx_t_double_complex a, __pyx_t_double_complex b) {
#                              ^
# ./rankpy/metrics/_utils.c:24078:49: warning: unused function '__Pyx_c_sum' [-Wunused-function]
#     static CYTHON_INLINE __pyx_t_double_complex __Pyx_c_sum(__pyx_t_double_complex a, __pyx_t_double_complex b) {
#                                                 ^
# ./rankpy/metrics/_utils.c:24084:49: warning: unused function '__Pyx_c_diff' [-Wunused-function]
#     static CYTHON_INLINE __pyx_t_double_complex __Pyx_c_diff(__pyx_t_double_complex a, __pyx_t_double_complex b) {
#                                                 ^
# ./rankpy/metrics/_utils.c:24096:49: warning: unused function '__Pyx_c_quot' [-Wunused-function]
#     static CYTHON_INLINE __pyx_t_double_complex __Pyx_c_quot(__pyx_t_double_complex a, __pyx_t_double_complex b) {
#                                                 ^
# ./rankpy/metrics/_utils.c:24103:49: warning: unused function '__Pyx_c_neg' [-Wunused-function]
#     static CYTHON_INLINE __pyx_t_double_complex __Pyx_c_neg(__pyx_t_double_complex a) {
#                                                 ^
# ./rankpy/metrics/_utils.c:24109:30: warning: unused function '__Pyx_c_is_zero' [-Wunused-function]
#     static CYTHON_INLINE int __Pyx_c_is_zero(__pyx_t_double_complex a) {
#                              ^
# ./rankpy/metrics/_utils.c:24112:49: warning: unused function '__Pyx_c_conj' [-Wunused-function]
#     static CYTHON_INLINE __pyx_t_double_complex __Pyx_c_conj(__pyx_t_double_complex a) {
#                                                 ^
# ./rankpy/metrics/_utils.c:24126:53: warning: unused function '__Pyx_c_pow' [-Wunused-function]
#         static CYTHON_INLINE __pyx_t_double_complex __Pyx_c_pow(__pyx_t_double_complex a, __pyx_t_double_complex b) {
#                                                     ^
# ./rankpy/metrics/_utils.c:24404:27: warning: function '__Pyx_PyInt_As_char' is not needed and will not be emitted [-Wunneeded-internal-declaration]
# static CYTHON_INLINE char __Pyx_PyInt_As_char(PyObject *x) {
#                           ^
# ./rankpy/metrics/_utils.c:24499:27: warning: function '__Pyx_PyInt_As_long' is not needed and will not be emitted [-Wunneeded-internal-declaration]
# static CYTHON_INLINE long __Pyx_PyInt_As_long(PyObject *x) {
#                           ^
# ./rankpy/metrics/_utils.c:7354:26: warning: unused function '__pyx_f_6rankpy_7metrics_6_utils_rand_int_c' [-Wunused-function]
# static CYTHON_INLINE int __pyx_f_6rankpy_7metrics_6_utils_rand_int_c(int __pyx_v_low, int __pyx_v_high, unsigned int *__pyx_v_seed) {
#                          ^
# ./rankpy/metrics/_utils.c:8305:32: warning: unused function '__pyx_f_5numpy_PyArray_MultiIterNew1' [-Wunused-function]
# static CYTHON_INLINE PyObject *__pyx_f_5numpy_PyArray_MultiIterNew1(PyObject *__pyx_v_a) {
#                                ^
# ./rankpy/metrics/_utils.c:8355:32: warning: unused function '__pyx_f_5numpy_PyArray_MultiIterNew2' [-Wunused-function]
# static CYTHON_INLINE PyObject *__pyx_f_5numpy_PyArray_MultiIterNew2(PyObject *__pyx_v_a, PyObject *__pyx_v_b) {
#                                ^
# ./rankpy/metrics/_utils.c:8405:32: warning: unused function '__pyx_f_5numpy_PyArray_MultiIterNew3' [-Wunused-function]
# static CYTHON_INLINE PyObject *__pyx_f_5numpy_PyArray_MultiIterNew3(PyObject *__pyx_v_a, PyObject *__pyx_v_b, PyObject *__pyx_v_c) {
#                                ^
# ./rankpy/metrics/_utils.c:8455:32: warning: unused function '__pyx_f_5numpy_PyArray_MultiIterNew4' [-Wunused-function]
# static CYTHON_INLINE PyObject *__pyx_f_5numpy_PyArray_MultiIterNew4(PyObject *__pyx_v_a, PyObject *__pyx_v_b, PyObject *__pyx_v_c, PyObject *_...
#                                ^
# ./rankpy/metrics/_utils.c:8505:32: warning: unused function '__pyx_f_5numpy_PyArray_MultiIterNew5' [-Wunused-function]
# static CYTHON_INLINE PyObject *__pyx_f_5numpy_PyArray_MultiIterNew5(PyObject *__pyx_v_a, PyObject *__pyx_v_b, PyObject *__pyx_v_c, PyObject *_...
#                                ^
# ./rankpy/metrics/_utils.c:9272:27: warning: unused function '__pyx_f_5numpy_set_array_base' [-Wunused-function]
# static CYTHON_INLINE void __pyx_f_5numpy_set_array_base(PyArrayObject *__pyx_v_arr, PyObject *__pyx_v_base) {
#                           ^
# ./rankpy/metrics/_utils.c:9360:32: warning: unused function '__pyx_f_5numpy_get_array_base' [-Wunused-function]
# static CYTHON_INLINE PyObject *__pyx_f_5numpy_get_array_base(PyArrayObject *__pyx_v_arr) {
#                                ^
# 36 warnings generated.
# /usr/bin/clang -bundle -undefined dynamic_lookup -arch i386 -arch x86_64 -g build/temp.macosx-10.6-intel-3.5/./rankpy/metrics/_utils.o -lm -o build/lib.macosx-10.6-intel-3.5/rankpy/metrics/_utils.cpython-35m-darwin.so
# building 'rankpy.models.lambdamart_inner' extension
# creating build/temp.macosx-10.6-intel-3.5/rankpy/models
# /usr/bin/clang -fno-strict-aliasing -Wsign-compare -fno-common -dynamic -DNDEBUG -g -fwrapv -O3 -Wall -Wstrict-prototypes -arch i386 -arch x86_64 -g -I/Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/numpy/core/include -I/Library/Frameworks/Python.framework/Versions/3.5/include/python3.5m -c ./rankpy/models/lambdamart_inner.c -o build/temp.macosx-10.6-intel-3.5/./rankpy/models/lambdamart_inner.o
# In file included from ./rankpy/models/lambdamart_inner.c:251:
# In file included from /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/numpy/core/include/numpy/arrayobject.h:4:
# In file included from /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/numpy/core/include/numpy/ndarrayobject.h:18:
# In file included from /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/numpy/core/include/numpy/ndarraytypes.h:1788:
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/numpy/core/include/numpy/npy_1_7_deprecated_api.h:15:2: warning:
#       "Using deprecated NumPy API, disable it by " "#defining NPY_NO_DEPRECATED_API NPY_1_7_API_VERSION" [-W#warnings]
# #warning "Using deprecated NumPy API, disable it by " \
#  ^
# In file included from ./rankpy/models/lambdamart_inner.c:251:
# In file included from /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/numpy/core/include/numpy/arrayobject.h:4:
# In file included from /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/numpy/core/include/numpy/ndarrayobject.h:27:
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/numpy/core/include/numpy/__multiarray_api.h:1448:1: warning: unused
#       function '_import_array' [-Wunused-function]
# _import_array(void)
# ^
# ./rankpy/models/lambdamart_inner.c:22354:32: warning: unused function '__Pyx_PyUnicode_FromString' [-Wunused-function]
# static CYTHON_INLINE PyObject* __Pyx_PyUnicode_FromString(const char* c_str) {
#                                ^
# ./rankpy/models/lambdamart_inner.c:22494:33: warning: unused function '__Pyx_PyInt_FromSize_t' [-Wunused-function]
# static CYTHON_INLINE PyObject * __Pyx_PyInt_FromSize_t(size_t ival) {
#                                 ^
# ./rankpy/models/lambdamart_inner.c:19872:26: warning: unused function '__Pyx_GetBufferAndValidate' [-Wunused-function]
# static CYTHON_INLINE int __Pyx_GetBufferAndValidate(
#                          ^
# ./rankpy/models/lambdamart_inner.c:19906:27: warning: unused function '__Pyx_SafeReleaseBuffer' [-Wunused-function]
# static CYTHON_INLINE void __Pyx_SafeReleaseBuffer(Py_buffer* info) {
#                           ^
# ./rankpy/models/lambdamart_inner.c:20308:26: warning: unused function '__Pyx_PyBytes_Equals' [-Wunused-function]
# static CYTHON_INLINE int __Pyx_PyBytes_Equals(PyObject* s1, PyObject* s2, int equals) {
#                          ^
# ./rankpy/models/lambdamart_inner.c:20580:32: warning: unused function '__Pyx_GetItemInt_List_Fast' [-Wunused-function]
# static CYTHON_INLINE PyObject *__Pyx_GetItemInt_List_Fast(PyObject *o, Py_ssize_t i,
#                                ^
# ./rankpy/models/lambdamart_inner.c:20594:32: warning: unused function '__Pyx_GetItemInt_Tuple_Fast' [-Wunused-function]
# static CYTHON_INLINE PyObject *__Pyx_GetItemInt_Tuple_Fast(PyObject *o, Py_ssize_t i,
#                                ^
# ./rankpy/models/lambdamart_inner.c:21437:32: warning: unused function '__Pyx_PyInt_From_npy_int32' [-Wunused-function]
# static CYTHON_INLINE PyObject* __Pyx_PyInt_From_npy_int32(npy_int32 value) {
#                                ^
# ./rankpy/models/lambdamart_inner.c:21526:48: warning: unused function '__pyx_t_float_complex_from_parts' [-Wunused-function]
#     static CYTHON_INLINE __pyx_t_float_complex __pyx_t_float_complex_from_parts(float x, float y) {
#                                                ^
# ./rankpy/models/lambdamart_inner.c:21536:30: warning: unused function '__Pyx_c_eqf' [-Wunused-function]
#     static CYTHON_INLINE int __Pyx_c_eqf(__pyx_t_float_complex a, __pyx_t_float_complex b) {
#                              ^
# ./rankpy/models/lambdamart_inner.c:21539:48: warning: unused function '__Pyx_c_sumf' [-Wunused-function]
#     static CYTHON_INLINE __pyx_t_float_complex __Pyx_c_sumf(__pyx_t_float_complex a, __pyx_t_float_complex b) {
#                                                ^
# ./rankpy/models/lambdamart_inner.c:21545:48: warning: unused function '__Pyx_c_difff' [-Wunused-function]
#     static CYTHON_INLINE __pyx_t_float_complex __Pyx_c_difff(__pyx_t_float_complex a, __pyx_t_float_complex b) {
#                                                ^
# ./rankpy/models/lambdamart_inner.c:21557:48: warning: unused function '__Pyx_c_quotf' [-Wunused-function]
#     static CYTHON_INLINE __pyx_t_float_complex __Pyx_c_quotf(__pyx_t_float_complex a, __pyx_t_float_complex b) {
#                                                ^
# ./rankpy/models/lambdamart_inner.c:21564:48: warning: unused function '__Pyx_c_negf' [-Wunused-function]
#     static CYTHON_INLINE __pyx_t_float_complex __Pyx_c_negf(__pyx_t_float_complex a) {
#                                                ^
# ./rankpy/models/lambdamart_inner.c:21570:30: warning: unused function '__Pyx_c_is_zerof' [-Wunused-function]
#     static CYTHON_INLINE int __Pyx_c_is_zerof(__pyx_t_float_complex a) {
#                              ^
# ./rankpy/models/lambdamart_inner.c:21573:48: warning: unused function '__Pyx_c_conjf' [-Wunused-function]
#     static CYTHON_INLINE __pyx_t_float_complex __Pyx_c_conjf(__pyx_t_float_complex a) {
#                                                ^
# ./rankpy/models/lambdamart_inner.c:21587:52: warning: unused function '__Pyx_c_powf' [-Wunused-function]
#         static CYTHON_INLINE __pyx_t_float_complex __Pyx_c_powf(__pyx_t_float_complex a, __pyx_t_float_complex b) {
#                                                    ^
# ./rankpy/models/lambdamart_inner.c:21646:49: warning: unused function '__pyx_t_double_complex_from_parts' [-Wunused-function]
#     static CYTHON_INLINE __pyx_t_double_complex __pyx_t_double_complex_from_parts(double x, double y) {
#                                                 ^
# ./rankpy/models/lambdamart_inner.c:21656:30: warning: unused function '__Pyx_c_eq' [-Wunused-function]
#     static CYTHON_INLINE int __Pyx_c_eq(__pyx_t_double_complex a, __pyx_t_double_complex b) {
#                              ^
# ./rankpy/models/lambdamart_inner.c:21659:49: warning: unused function '__Pyx_c_sum' [-Wunused-function]
#     static CYTHON_INLINE __pyx_t_double_complex __Pyx_c_sum(__pyx_t_double_complex a, __pyx_t_double_complex b) {
#                                                 ^
# ./rankpy/models/lambdamart_inner.c:21665:49: warning: unused function '__Pyx_c_diff' [-Wunused-function]
#     static CYTHON_INLINE __pyx_t_double_complex __Pyx_c_diff(__pyx_t_double_complex a, __pyx_t_double_complex b) {
#                                                 ^
# ./rankpy/models/lambdamart_inner.c:21677:49: warning: unused function '__Pyx_c_quot' [-Wunused-function]
#     static CYTHON_INLINE __pyx_t_double_complex __Pyx_c_quot(__pyx_t_double_complex a, __pyx_t_double_complex b) {
#                                                 ^
# ./rankpy/models/lambdamart_inner.c:21684:49: warning: unused function '__Pyx_c_neg' [-Wunused-function]
#     static CYTHON_INLINE __pyx_t_double_complex __Pyx_c_neg(__pyx_t_double_complex a) {
#                                                 ^
# ./rankpy/models/lambdamart_inner.c:21690:30: warning: unused function '__Pyx_c_is_zero' [-Wunused-function]
#     static CYTHON_INLINE int __Pyx_c_is_zero(__pyx_t_double_complex a) {
#                              ^
# ./rankpy/models/lambdamart_inner.c:21693:49: warning: unused function '__Pyx_c_conj' [-Wunused-function]
#     static CYTHON_INLINE __pyx_t_double_complex __Pyx_c_conj(__pyx_t_double_complex a) {
#                                                 ^
# ./rankpy/models/lambdamart_inner.c:21707:53: warning: unused function '__Pyx_c_pow' [-Wunused-function]
#         static CYTHON_INLINE __pyx_t_double_complex __Pyx_c_pow(__pyx_t_double_complex a, __pyx_t_double_complex b) {
#                                                     ^
# ./rankpy/models/lambdamart_inner.c:21985:27: warning: function '__Pyx_PyInt_As_char' is not needed and will not be emitted
#       [-Wunneeded-internal-declaration]
# static CYTHON_INLINE char __Pyx_PyInt_As_char(PyObject *x) {
#                           ^
# ./rankpy/models/lambdamart_inner.c:22080:27: warning: function '__Pyx_PyInt_As_long' is not needed and will not be emitted
#       [-Wunneeded-internal-declaration]
# static CYTHON_INLINE long __Pyx_PyInt_As_long(PyObject *x) {
#                           ^
# ./rankpy/models/lambdamart_inner.c:5985:32: warning: unused function '__pyx_f_5numpy_PyArray_MultiIterNew1' [-Wunused-function]
# static CYTHON_INLINE PyObject *__pyx_f_5numpy_PyArray_MultiIterNew1(PyObject *__pyx_v_a) {
#                                ^
# ./rankpy/models/lambdamart_inner.c:6035:32: warning: unused function '__pyx_f_5numpy_PyArray_MultiIterNew2' [-Wunused-function]
# static CYTHON_INLINE PyObject *__pyx_f_5numpy_PyArray_MultiIterNew2(PyObject *__pyx_v_a, PyObject *__pyx_v_b) {
#                                ^
# ./rankpy/models/lambdamart_inner.c:6085:32: warning: unused function '__pyx_f_5numpy_PyArray_MultiIterNew3' [-Wunused-function]
# static CYTHON_INLINE PyObject *__pyx_f_5numpy_PyArray_MultiIterNew3(PyObject *__pyx_v_a, PyObject *__pyx_v_b, PyObject *__pyx_v_c) {
#                                ^
# ./rankpy/models/lambdamart_inner.c:6135:32: warning: unused function '__pyx_f_5numpy_PyArray_MultiIterNew4' [-Wunused-function]
# static CYTHON_INLINE PyObject *__pyx_f_5numpy_PyArray_MultiIterNew4(PyObject *__pyx_v_a, PyObject *__pyx_v_b, PyObject *__pyx_v_c, PyObject *_...
#                                ^
# ./rankpy/models/lambdamart_inner.c:6185:32: warning: unused function '__pyx_f_5numpy_PyArray_MultiIterNew5' [-Wunused-function]
# static CYTHON_INLINE PyObject *__pyx_f_5numpy_PyArray_MultiIterNew5(PyObject *__pyx_v_a, PyObject *__pyx_v_b, PyObject *__pyx_v_c, PyObject *_...
#                                ^
# ./rankpy/models/lambdamart_inner.c:6952:27: warning: unused function '__pyx_f_5numpy_set_array_base' [-Wunused-function]
# static CYTHON_INLINE void __pyx_f_5numpy_set_array_base(PyArrayObject *__pyx_v_arr, PyObject *__pyx_v_base) {
#                           ^
# ./rankpy/models/lambdamart_inner.c:7040:32: warning: unused function '__pyx_f_5numpy_get_array_base' [-Wunused-function]
# static CYTHON_INLINE PyObject *__pyx_f_5numpy_get_array_base(PyArrayObject *__pyx_v_arr) {
#                                ^
# 37 warnings generated.
# In file included from ./rankpy/models/lambdamart_inner.c:251:
# In file included from /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/numpy/core/include/numpy/arrayobject.h:4:
# In file included from /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/numpy/core/include/numpy/ndarrayobject.h:18:
# In file included from /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/numpy/core/include/numpy/ndarraytypes.h:1788:
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/numpy/core/include/numpy/npy_1_7_deprecated_api.h:15:2: warning:
#       "Using deprecated NumPy API, disable it by " "#defining NPY_NO_DEPRECATED_API NPY_1_7_API_VERSION" [-W#warnings]
# #warning "Using deprecated NumPy API, disable it by " \
#  ^
# In file included from ./rankpy/models/lambdamart_inner.c:251:
# In file included from /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/numpy/core/include/numpy/arrayobject.h:4:
# In file included from /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/numpy/core/include/numpy/ndarrayobject.h:27:
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/numpy/core/include/numpy/__multiarray_api.h:1448:1: warning: unused
#       function '_import_array' [-Wunused-function]
# _import_array(void)
# ^
# ./rankpy/models/lambdamart_inner.c:22354:32: warning: unused function '__Pyx_PyUnicode_FromString' [-Wunused-function]
# static CYTHON_INLINE PyObject* __Pyx_PyUnicode_FromString(const char* c_str) {
#                                ^
# ./rankpy/models/lambdamart_inner.c:22494:33: warning: unused function '__Pyx_PyInt_FromSize_t' [-Wunused-function]
# static CYTHON_INLINE PyObject * __Pyx_PyInt_FromSize_t(size_t ival) {
#                                 ^
# ./rankpy/models/lambdamart_inner.c:19872:26: warning: unused function '__Pyx_GetBufferAndValidate' [-Wunused-function]
# static CYTHON_INLINE int __Pyx_GetBufferAndValidate(
#                          ^
# ./rankpy/models/lambdamart_inner.c:19906:27: warning: unused function '__Pyx_SafeReleaseBuffer' [-Wunused-function]
# static CYTHON_INLINE void __Pyx_SafeReleaseBuffer(Py_buffer* info) {
#                           ^
# ./rankpy/models/lambdamart_inner.c:19979:1: warning: unused function '__pyx_add_acquisition_count_locked' [-Wunused-function]
# __pyx_add_acquisition_count_locked(__pyx_atomic_int *acquisition_count,
# ^
# ./rankpy/models/lambdamart_inner.c:19989:1: warning: unused function '__pyx_sub_acquisition_count_locked' [-Wunused-function]
# __pyx_sub_acquisition_count_locked(__pyx_atomic_int *acquisition_count,
# ^
# ./rankpy/models/lambdamart_inner.c:20308:26: warning: unused function '__Pyx_PyBytes_Equals' [-Wunused-function]
# static CYTHON_INLINE int __Pyx_PyBytes_Equals(PyObject* s1, PyObject* s2, int equals) {
#                          ^
# ./rankpy/models/lambdamart_inner.c:20580:32: warning: unused function '__Pyx_GetItemInt_List_Fast' [-Wunused-function]
# static CYTHON_INLINE PyObject *__Pyx_GetItemInt_List_Fast(PyObject *o, Py_ssize_t i,
#                                ^
# ./rankpy/models/lambdamart_inner.c:20594:32: warning: unused function '__Pyx_GetItemInt_Tuple_Fast' [-Wunused-function]
# static CYTHON_INLINE PyObject *__Pyx_GetItemInt_Tuple_Fast(PyObject *o, Py_ssize_t i,
#                                ^
# ./rankpy/models/lambdamart_inner.c:21437:32: warning: unused function '__Pyx_PyInt_From_npy_int32' [-Wunused-function]
# static CYTHON_INLINE PyObject* __Pyx_PyInt_From_npy_int32(npy_int32 value) {
#                                ^
# ./rankpy/models/lambdamart_inner.c:21526:48: warning: unused function '__pyx_t_float_complex_from_parts' [-Wunused-function]
#     static CYTHON_INLINE __pyx_t_float_complex __pyx_t_float_complex_from_parts(float x, float y) {
#                                                ^
# ./rankpy/models/lambdamart_inner.c:21536:30: warning: unused function '__Pyx_c_eqf' [-Wunused-function]
#     static CYTHON_INLINE int __Pyx_c_eqf(__pyx_t_float_complex a, __pyx_t_float_complex b) {
#                              ^
# ./rankpy/models/lambdamart_inner.c:21539:48: warning: unused function '__Pyx_c_sumf' [-Wunused-function]
#     static CYTHON_INLINE __pyx_t_float_complex __Pyx_c_sumf(__pyx_t_float_complex a, __pyx_t_float_complex b) {
#                                                ^
# ./rankpy/models/lambdamart_inner.c:21545:48: warning: unused function '__Pyx_c_difff' [-Wunused-function]
#     static CYTHON_INLINE __pyx_t_float_complex __Pyx_c_difff(__pyx_t_float_complex a, __pyx_t_float_complex b) {
#                                                ^
# ./rankpy/models/lambdamart_inner.c:21557:48: warning: unused function '__Pyx_c_quotf' [-Wunused-function]
#     static CYTHON_INLINE __pyx_t_float_complex __Pyx_c_quotf(__pyx_t_float_complex a, __pyx_t_float_complex b) {
#                                                ^
# ./rankpy/models/lambdamart_inner.c:21564:48: warning: unused function '__Pyx_c_negf' [-Wunused-function]
#     static CYTHON_INLINE __pyx_t_float_complex __Pyx_c_negf(__pyx_t_float_complex a) {
#                                                ^
# ./rankpy/models/lambdamart_inner.c:21570:30: warning: unused function '__Pyx_c_is_zerof' [-Wunused-function]
#     static CYTHON_INLINE int __Pyx_c_is_zerof(__pyx_t_float_complex a) {
#                              ^
# ./rankpy/models/lambdamart_inner.c:21573:48: warning: unused function '__Pyx_c_conjf' [-Wunused-function]
#     static CYTHON_INLINE __pyx_t_float_complex __Pyx_c_conjf(__pyx_t_float_complex a) {
#                                                ^
# ./rankpy/models/lambdamart_inner.c:21587:52: warning: unused function '__Pyx_c_powf' [-Wunused-function]
#         static CYTHON_INLINE __pyx_t_float_complex __Pyx_c_powf(__pyx_t_float_complex a, __pyx_t_float_complex b) {
#                                                    ^
# ./rankpy/models/lambdamart_inner.c:21646:49: warning: unused function '__pyx_t_double_complex_from_parts' [-Wunused-function]
#     static CYTHON_INLINE __pyx_t_double_complex __pyx_t_double_complex_from_parts(double x, double y) {
#                                                 ^
# ./rankpy/models/lambdamart_inner.c:21656:30: warning: unused function '__Pyx_c_eq' [-Wunused-function]
#     static CYTHON_INLINE int __Pyx_c_eq(__pyx_t_double_complex a, __pyx_t_double_complex b) {
#                              ^
# ./rankpy/models/lambdamart_inner.c:21659:49: warning: unused function '__Pyx_c_sum' [-Wunused-function]
#     static CYTHON_INLINE __pyx_t_double_complex __Pyx_c_sum(__pyx_t_double_complex a, __pyx_t_double_complex b) {
#                                                 ^
# ./rankpy/models/lambdamart_inner.c:21665:49: warning: unused function '__Pyx_c_diff' [-Wunused-function]
#     static CYTHON_INLINE __pyx_t_double_complex __Pyx_c_diff(__pyx_t_double_complex a, __pyx_t_double_complex b) {
#                                                 ^
# ./rankpy/models/lambdamart_inner.c:21677:49: warning: unused function '__Pyx_c_quot' [-Wunused-function]
#     static CYTHON_INLINE __pyx_t_double_complex __Pyx_c_quot(__pyx_t_double_complex a, __pyx_t_double_complex b) {
#                                                 ^
# ./rankpy/models/lambdamart_inner.c:21684:49: warning: unused function '__Pyx_c_neg' [-Wunused-function]
#     static CYTHON_INLINE __pyx_t_double_complex __Pyx_c_neg(__pyx_t_double_complex a) {
#                                                 ^
# ./rankpy/models/lambdamart_inner.c:21690:30: warning: unused function '__Pyx_c_is_zero' [-Wunused-function]
#     static CYTHON_INLINE int __Pyx_c_is_zero(__pyx_t_double_complex a) {
#                              ^
# ./rankpy/models/lambdamart_inner.c:21693:49: warning: unused function '__Pyx_c_conj' [-Wunused-function]
#     static CYTHON_INLINE __pyx_t_double_complex __Pyx_c_conj(__pyx_t_double_complex a) {
#                                                 ^
# ./rankpy/models/lambdamart_inner.c:21707:53: warning: unused function '__Pyx_c_pow' [-Wunused-function]
#         static CYTHON_INLINE __pyx_t_double_complex __Pyx_c_pow(__pyx_t_double_complex a, __pyx_t_double_complex b) {
#                                                     ^
# ./rankpy/models/lambdamart_inner.c:21985:27: warning: function '__Pyx_PyInt_As_char' is not needed and will not be emitted
#       [-Wunneeded-internal-declaration]
# static CYTHON_INLINE char __Pyx_PyInt_As_char(PyObject *x) {
#                           ^
# ./rankpy/models/lambdamart_inner.c:22080:27: warning: function '__Pyx_PyInt_As_long' is not needed and will not be emitted
#       [-Wunneeded-internal-declaration]
# static CYTHON_INLINE long __Pyx_PyInt_As_long(PyObject *x) {
#                           ^
# ./rankpy/models/lambdamart_inner.c:5985:32: warning: unused function '__pyx_f_5numpy_PyArray_MultiIterNew1' [-Wunused-function]
# static CYTHON_INLINE PyObject *__pyx_f_5numpy_PyArray_MultiIterNew1(PyObject *__pyx_v_a) {
#                                ^
# ./rankpy/models/lambdamart_inner.c:6035:32: warning: unused function '__pyx_f_5numpy_PyArray_MultiIterNew2' [-Wunused-function]
# static CYTHON_INLINE PyObject *__pyx_f_5numpy_PyArray_MultiIterNew2(PyObject *__pyx_v_a, PyObject *__pyx_v_b) {
#                                ^
# ./rankpy/models/lambdamart_inner.c:6085:32: warning: unused function '__pyx_f_5numpy_PyArray_MultiIterNew3' [-Wunused-function]
# static CYTHON_INLINE PyObject *__pyx_f_5numpy_PyArray_MultiIterNew3(PyObject *__pyx_v_a, PyObject *__pyx_v_b, PyObject *__pyx_v_c) {
#                                ^
# ./rankpy/models/lambdamart_inner.c:6135:32: warning: unused function '__pyx_f_5numpy_PyArray_MultiIterNew4' [-Wunused-function]
# static CYTHON_INLINE PyObject *__pyx_f_5numpy_PyArray_MultiIterNew4(PyObject *__pyx_v_a, PyObject *__pyx_v_b, PyObject *__pyx_v_c, PyObject *_...
#                                ^
# ./rankpy/models/lambdamart_inner.c:6185:32: warning: unused function '__pyx_f_5numpy_PyArray_MultiIterNew5' [-Wunused-function]
# static CYTHON_INLINE PyObject *__pyx_f_5numpy_PyArray_MultiIterNew5(PyObject *__pyx_v_a, PyObject *__pyx_v_b, PyObject *__pyx_v_c, PyObject *_...
#                                ^
# ./rankpy/models/lambdamart_inner.c:6952:27: warning: unused function '__pyx_f_5numpy_set_array_base' [-Wunused-function]
# static CYTHON_INLINE void __pyx_f_5numpy_set_array_base(PyArrayObject *__pyx_v_arr, PyObject *__pyx_v_base) {
#                           ^
# ./rankpy/models/lambdamart_inner.c:7040:32: warning: unused function '__pyx_f_5numpy_get_array_base' [-Wunused-function]
# static CYTHON_INLINE PyObject *__pyx_f_5numpy_get_array_base(PyArrayObject *__pyx_v_arr) {
#                                ^
# 39 warnings generated.
# /usr/bin/clang -bundle -undefined dynamic_lookup -arch i386 -arch x86_64 -g build/temp.macosx-10.6-intel-3.5/./rankpy/models/lambdamart_inner.o -lm -o build/lib.macosx-10.6-intel-3.5/rankpy/models/lambdamart_inner.cpython-35m-darwin.so
# building 'rankpy.models.users.users_inner' extension
# creating build/temp.macosx-10.6-intel-3.5/rankpy/models/users
# /usr/bin/clang -fno-strict-aliasing -Wsign-compare -fno-common -dynamic -DNDEBUG -g -fwrapv -O3 -Wall -Wstrict-prototypes -arch i386 -arch x86_64 -g -I/Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/numpy/core/include -I/Library/Frameworks/Python.framework/Versions/3.5/include/python3.5m -c ./rankpy/models/users/users_inner.c -o build/temp.macosx-10.6-intel-3.5/./rankpy/models/users/users_inner.o
# In file included from ./rankpy/models/users/users_inner.c:257:
# In file included from /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/numpy/core/include/numpy/arrayobject.h:4:
# In file included from /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/numpy/core/include/numpy/ndarrayobject.h:18:
# In file included from /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/numpy/core/include/numpy/ndarraytypes.h:1788:
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/numpy/core/include/numpy/npy_1_7_deprecated_api.h:15:2: warning:
#       "Using deprecated NumPy API, disable it by " "#defining NPY_NO_DEPRECATED_API NPY_1_7_API_VERSION" [-W#warnings]
# #warning "Using deprecated NumPy API, disable it by " \
#  ^
# ./rankpy/models/users/users_inner.c:20338:28: warning: unused function '__Pyx_PyObject_AsString' [-Wunused-function]
# static CYTHON_INLINE char* __Pyx_PyObject_AsString(PyObject* o) {
#                            ^
# ./rankpy/models/users/users_inner.c:20335:32: warning: unused function '__Pyx_PyUnicode_FromString' [-Wunused-function]
# static CYTHON_INLINE PyObject* __Pyx_PyUnicode_FromString(const char* c_str) {
#                                ^
# ./rankpy/models/users/users_inner.c:20450:33: warning: unused function '__Pyx_PyIndex_AsSsize_t' [-Wunused-function]
# static CYTHON_INLINE Py_ssize_t __Pyx_PyIndex_AsSsize_t(PyObject* b) {
#                                 ^
# ./rankpy/models/users/users_inner.c:20475:33: warning: unused function '__Pyx_PyInt_FromSize_t' [-Wunused-function]
# static CYTHON_INLINE PyObject * __Pyx_PyInt_FromSize_t(size_t ival) {
#                                 ^
# ./rankpy/models/users/users_inner.c:19707:32: warning: function '__Pyx_PyInt_As_npy_int32' is not needed and will not be emitted
#       [-Wunneeded-internal-declaration]
# static CYTHON_INLINE npy_int32 __Pyx_PyInt_As_npy_int32(PyObject *x) {
#                                ^
# ./rankpy/models/users/users_inner.c:19812:32: warning: unused function '__Pyx_PyInt_From_long' [-Wunused-function]
# static CYTHON_INLINE PyObject* __Pyx_PyInt_From_long(long value) {
#                                ^
# ./rankpy/models/users/users_inner.c:19875:48: warning: unused function '__pyx_t_float_complex_from_parts' [-Wunused-function]
#     static CYTHON_INLINE __pyx_t_float_complex __pyx_t_float_complex_from_parts(float x, float y) {
#                                                ^
# ./rankpy/models/users/users_inner.c:19885:30: warning: unused function '__Pyx_c_eqf' [-Wunused-function]
#     static CYTHON_INLINE int __Pyx_c_eqf(__pyx_t_float_complex a, __pyx_t_float_complex b) {
#                              ^
# ./rankpy/models/users/users_inner.c:19888:48: warning: unused function '__Pyx_c_sumf' [-Wunused-function]
#     static CYTHON_INLINE __pyx_t_float_complex __Pyx_c_sumf(__pyx_t_float_complex a, __pyx_t_float_complex b) {
#                                                ^
# ./rankpy/models/users/users_inner.c:19894:48: warning: unused function '__Pyx_c_difff' [-Wunused-function]
#     static CYTHON_INLINE __pyx_t_float_complex __Pyx_c_difff(__pyx_t_float_complex a, __pyx_t_float_complex b) {
#                                                ^
# ./rankpy/models/users/users_inner.c:19906:48: warning: unused function '__Pyx_c_quotf' [-Wunused-function]
#     static CYTHON_INLINE __pyx_t_float_complex __Pyx_c_quotf(__pyx_t_float_complex a, __pyx_t_float_complex b) {
#                                                ^
# ./rankpy/models/users/users_inner.c:19913:48: warning: unused function '__Pyx_c_negf' [-Wunused-function]
#     static CYTHON_INLINE __pyx_t_float_complex __Pyx_c_negf(__pyx_t_float_complex a) {
#                                                ^
# ./rankpy/models/users/users_inner.c:19919:30: warning: unused function '__Pyx_c_is_zerof' [-Wunused-function]
#     static CYTHON_INLINE int __Pyx_c_is_zerof(__pyx_t_float_complex a) {
#                              ^
# ./rankpy/models/users/users_inner.c:19922:48: warning: unused function '__Pyx_c_conjf' [-Wunused-function]
#     static CYTHON_INLINE __pyx_t_float_complex __Pyx_c_conjf(__pyx_t_float_complex a) {
#                                                ^
# ./rankpy/models/users/users_inner.c:19936:52: warning: unused function '__Pyx_c_powf' [-Wunused-function]
#         static CYTHON_INLINE __pyx_t_float_complex __Pyx_c_powf(__pyx_t_float_complex a, __pyx_t_float_complex b) {
#                                                    ^
# ./rankpy/models/users/users_inner.c:19995:49: warning: unused function '__pyx_t_double_complex_from_parts' [-Wunused-function]
#     static CYTHON_INLINE __pyx_t_double_complex __pyx_t_double_complex_from_parts(double x, double y) {
#                                                 ^
# ./rankpy/models/users/users_inner.c:20005:30: warning: unused function '__Pyx_c_eq' [-Wunused-function]
#     static CYTHON_INLINE int __Pyx_c_eq(__pyx_t_double_complex a, __pyx_t_double_complex b) {
#                              ^
# ./rankpy/models/users/users_inner.c:20008:49: warning: unused function '__Pyx_c_sum' [-Wunused-function]
#     static CYTHON_INLINE __pyx_t_double_complex __Pyx_c_sum(__pyx_t_double_complex a, __pyx_t_double_complex b) {
#                                                 ^
# ./rankpy/models/users/users_inner.c:20014:49: warning: unused function '__Pyx_c_diff' [-Wunused-function]
#     static CYTHON_INLINE __pyx_t_double_complex __Pyx_c_diff(__pyx_t_double_complex a, __pyx_t_double_complex b) {
#                                                 ^
# ./rankpy/models/users/users_inner.c:20026:49: warning: unused function '__Pyx_c_quot' [-Wunused-function]
#     static CYTHON_INLINE __pyx_t_double_complex __Pyx_c_quot(__pyx_t_double_complex a, __pyx_t_double_complex b) {
#                                                 ^
# ./rankpy/models/users/users_inner.c:20033:49: warning: unused function '__Pyx_c_neg' [-Wunused-function]
#     static CYTHON_INLINE __pyx_t_double_complex __Pyx_c_neg(__pyx_t_double_complex a) {
#                                                 ^
# ./rankpy/models/users/users_inner.c:20039:30: warning: unused function '__Pyx_c_is_zero' [-Wunused-function]
#     static CYTHON_INLINE int __Pyx_c_is_zero(__pyx_t_double_complex a) {
#                              ^
# ./rankpy/models/users/users_inner.c:20042:49: warning: unused function '__Pyx_c_conj' [-Wunused-function]
#     static CYTHON_INLINE __pyx_t_double_complex __Pyx_c_conj(__pyx_t_double_complex a) {
#                                                 ^
# ./rankpy/models/users/users_inner.c:20056:53: warning: unused function '__Pyx_c_pow' [-Wunused-function]
#         static CYTHON_INLINE __pyx_t_double_complex __Pyx_c_pow(__pyx_t_double_complex a, __pyx_t_double_complex b) {
#                                                     ^
# ./rankpy/models/users/users_inner.c:20104:27: warning: function '__Pyx_PyInt_As_long' is not needed and will not be emitted
#       [-Wunneeded-internal-declaration]
# static CYTHON_INLINE long __Pyx_PyInt_As_long(PyObject *x) {
#                           ^
# ./rankpy/models/users/users_inner.c:14948:32: warning: unused function '__pyx_f_5numpy_PyArray_MultiIterNew1' [-Wunused-function]
# static CYTHON_INLINE PyObject *__pyx_f_5numpy_PyArray_MultiIterNew1(PyObject *__pyx_v_a) {
#                                ^
# ./rankpy/models/users/users_inner.c:14998:32: warning: unused function '__pyx_f_5numpy_PyArray_MultiIterNew2' [-Wunused-function]
# static CYTHON_INLINE PyObject *__pyx_f_5numpy_PyArray_MultiIterNew2(PyObject *__pyx_v_a, PyObject *__pyx_v_b) {
#                                ^
# ./rankpy/models/users/users_inner.c:15048:32: warning: unused function '__pyx_f_5numpy_PyArray_MultiIterNew3' [-Wunused-function]
# static CYTHON_INLINE PyObject *__pyx_f_5numpy_PyArray_MultiIterNew3(PyObject *__pyx_v_a, PyObject *__pyx_v_b, PyObject *__pyx_v_c) {
#                                ^
# ./rankpy/models/users/users_inner.c:15098:32: warning: unused function '__pyx_f_5numpy_PyArray_MultiIterNew4' [-Wunused-function]
# static CYTHON_INLINE PyObject *__pyx_f_5numpy_PyArray_MultiIterNew4(PyObject *__pyx_v_a, PyObject *__pyx_v_b, PyObject *__pyx_v_c, PyObject *_...
#                                ^
# ./rankpy/models/users/users_inner.c:15148:32: warning: unused function '__pyx_f_5numpy_PyArray_MultiIterNew5' [-Wunused-function]
# static CYTHON_INLINE PyObject *__pyx_f_5numpy_PyArray_MultiIterNew5(PyObject *__pyx_v_a, PyObject *__pyx_v_b, PyObject *__pyx_v_c, PyObject *_...
#                                ^
# ./rankpy/models/users/users_inner.c:15916:27: warning: unused function '__pyx_f_5numpy_set_array_base' [-Wunused-function]
# static CYTHON_INLINE void __pyx_f_5numpy_set_array_base(PyArrayObject *__pyx_v_arr, PyObject *__pyx_v_base) {
#                           ^
# ./rankpy/models/users/users_inner.c:16004:32: warning: unused function '__pyx_f_5numpy_get_array_base' [-Wunused-function]
# static CYTHON_INLINE PyObject *__pyx_f_5numpy_get_array_base(PyArrayObject *__pyx_v_arr) {
#                                ^
# 33 warnings generated.
# In file included from ./rankpy/models/users/users_inner.c:257:
# In file included from /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/numpy/core/include/numpy/arrayobject.h:4:
# In file included from /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/numpy/core/include/numpy/ndarrayobject.h:18:
# In file included from /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/numpy/core/include/numpy/ndarraytypes.h:1788:
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/numpy/core/include/numpy/npy_1_7_deprecated_api.h:15:2: warning:
#       "Using deprecated NumPy API, disable it by " "#defining NPY_NO_DEPRECATED_API NPY_1_7_API_VERSION" [-W#warnings]
# #warning "Using deprecated NumPy API, disable it by " \
#  ^
# ./rankpy/models/users/users_inner.c:20338:28: warning: unused function '__Pyx_PyObject_AsString' [-Wunused-function]
# static CYTHON_INLINE char* __Pyx_PyObject_AsString(PyObject* o) {
#                            ^
# ./rankpy/models/users/users_inner.c:20335:32: warning: unused function '__Pyx_PyUnicode_FromString' [-Wunused-function]
# static CYTHON_INLINE PyObject* __Pyx_PyUnicode_FromString(const char* c_str) {
#                                ^
# ./rankpy/models/users/users_inner.c:20450:33: warning: unused function '__Pyx_PyIndex_AsSsize_t' [-Wunused-function]
# static CYTHON_INLINE Py_ssize_t __Pyx_PyIndex_AsSsize_t(PyObject* b) {
#                                 ^
# ./rankpy/models/users/users_inner.c:20475:33: warning: unused function '__Pyx_PyInt_FromSize_t' [-Wunused-function]
# static CYTHON_INLINE PyObject * __Pyx_PyInt_FromSize_t(size_t ival) {
#                                 ^
# ./rankpy/models/users/users_inner.c:19707:32: warning: function '__Pyx_PyInt_As_npy_int32' is not needed and will not be emitted
#       [-Wunneeded-internal-declaration]
# static CYTHON_INLINE npy_int32 __Pyx_PyInt_As_npy_int32(PyObject *x) {
#                                ^
# ./rankpy/models/users/users_inner.c:19812:32: warning: unused function '__Pyx_PyInt_From_long' [-Wunused-function]
# static CYTHON_INLINE PyObject* __Pyx_PyInt_From_long(long value) {
#                                ^
# ./rankpy/models/users/users_inner.c:19875:48: warning: unused function '__pyx_t_float_complex_from_parts' [-Wunused-function]
#     static CYTHON_INLINE __pyx_t_float_complex __pyx_t_float_complex_from_parts(float x, float y) {
#                                                ^
# ./rankpy/models/users/users_inner.c:19885:30: warning: unused function '__Pyx_c_eqf' [-Wunused-function]
#     static CYTHON_INLINE int __Pyx_c_eqf(__pyx_t_float_complex a, __pyx_t_float_complex b) {
#                              ^
# ./rankpy/models/users/users_inner.c:19888:48: warning: unused function '__Pyx_c_sumf' [-Wunused-function]
#     static CYTHON_INLINE __pyx_t_float_complex __Pyx_c_sumf(__pyx_t_float_complex a, __pyx_t_float_complex b) {
#                                                ^
# ./rankpy/models/users/users_inner.c:19894:48: warning: unused function '__Pyx_c_difff' [-Wunused-function]
#     static CYTHON_INLINE __pyx_t_float_complex __Pyx_c_difff(__pyx_t_float_complex a, __pyx_t_float_complex b) {
#                                                ^
# ./rankpy/models/users/users_inner.c:19906:48: warning: unused function '__Pyx_c_quotf' [-Wunused-function]
#     static CYTHON_INLINE __pyx_t_float_complex __Pyx_c_quotf(__pyx_t_float_complex a, __pyx_t_float_complex b) {
#                                                ^
# ./rankpy/models/users/users_inner.c:19913:48: warning: unused function '__Pyx_c_negf' [-Wunused-function]
#     static CYTHON_INLINE __pyx_t_float_complex __Pyx_c_negf(__pyx_t_float_complex a) {
#                                                ^
# ./rankpy/models/users/users_inner.c:19919:30: warning: unused function '__Pyx_c_is_zerof' [-Wunused-function]
#     static CYTHON_INLINE int __Pyx_c_is_zerof(__pyx_t_float_complex a) {
#                              ^
# ./rankpy/models/users/users_inner.c:19922:48: warning: unused function '__Pyx_c_conjf' [-Wunused-function]
#     static CYTHON_INLINE __pyx_t_float_complex __Pyx_c_conjf(__pyx_t_float_complex a) {
#                                                ^
# ./rankpy/models/users/users_inner.c:19936:52: warning: unused function '__Pyx_c_powf' [-Wunused-function]
#         static CYTHON_INLINE __pyx_t_float_complex __Pyx_c_powf(__pyx_t_float_complex a, __pyx_t_float_complex b) {
#                                                    ^
# ./rankpy/models/users/users_inner.c:19995:49: warning: unused function '__pyx_t_double_complex_from_parts' [-Wunused-function]
#     static CYTHON_INLINE __pyx_t_double_complex __pyx_t_double_complex_from_parts(double x, double y) {
#                                                 ^
# ./rankpy/models/users/users_inner.c:20005:30: warning: unused function '__Pyx_c_eq' [-Wunused-function]
#     static CYTHON_INLINE int __Pyx_c_eq(__pyx_t_double_complex a, __pyx_t_double_complex b) {
#                              ^
# ./rankpy/models/users/users_inner.c:20008:49: warning: unused function '__Pyx_c_sum' [-Wunused-function]
#     static CYTHON_INLINE __pyx_t_double_complex __Pyx_c_sum(__pyx_t_double_complex a, __pyx_t_double_complex b) {
#                                                 ^
# ./rankpy/models/users/users_inner.c:20014:49: warning: unused function '__Pyx_c_diff' [-Wunused-function]
#     static CYTHON_INLINE __pyx_t_double_complex __Pyx_c_diff(__pyx_t_double_complex a, __pyx_t_double_complex b) {
#                                                 ^
# ./rankpy/models/users/users_inner.c:20026:49: warning: unused function '__Pyx_c_quot' [-Wunused-function]
#     static CYTHON_INLINE __pyx_t_double_complex __Pyx_c_quot(__pyx_t_double_complex a, __pyx_t_double_complex b) {
#                                                 ^
# ./rankpy/models/users/users_inner.c:20033:49: warning: unused function '__Pyx_c_neg' [-Wunused-function]
#     static CYTHON_INLINE __pyx_t_double_complex __Pyx_c_neg(__pyx_t_double_complex a) {
#                                                 ^
# ./rankpy/models/users/users_inner.c:20039:30: warning: unused function '__Pyx_c_is_zero' [-Wunused-function]
#     static CYTHON_INLINE int __Pyx_c_is_zero(__pyx_t_double_complex a) {
#                              ^
# ./rankpy/models/users/users_inner.c:20042:49: warning: unused function '__Pyx_c_conj' [-Wunused-function]
#     static CYTHON_INLINE __pyx_t_double_complex __Pyx_c_conj(__pyx_t_double_complex a) {
#                                                 ^
# ./rankpy/models/users/users_inner.c:20056:53: warning: unused function '__Pyx_c_pow' [-Wunused-function]
#         static CYTHON_INLINE __pyx_t_double_complex __Pyx_c_pow(__pyx_t_double_complex a, __pyx_t_double_complex b) {
#                                                     ^
# ./rankpy/models/users/users_inner.c:20104:27: warning: function '__Pyx_PyInt_As_long' is not needed and will not be emitted
#       [-Wunneeded-internal-declaration]
# static CYTHON_INLINE long __Pyx_PyInt_As_long(PyObject *x) {
#                           ^
# ./rankpy/models/users/users_inner.c:14948:32: warning: unused function '__pyx_f_5numpy_PyArray_MultiIterNew1' [-Wunused-function]
# static CYTHON_INLINE PyObject *__pyx_f_5numpy_PyArray_MultiIterNew1(PyObject *__pyx_v_a) {
#                                ^
# ./rankpy/models/users/users_inner.c:14998:32: warning: unused function '__pyx_f_5numpy_PyArray_MultiIterNew2' [-Wunused-function]
# static CYTHON_INLINE PyObject *__pyx_f_5numpy_PyArray_MultiIterNew2(PyObject *__pyx_v_a, PyObject *__pyx_v_b) {
#                                ^
# ./rankpy/models/users/users_inner.c:15048:32: warning: unused function '__pyx_f_5numpy_PyArray_MultiIterNew3' [-Wunused-function]
# static CYTHON_INLINE PyObject *__pyx_f_5numpy_PyArray_MultiIterNew3(PyObject *__pyx_v_a, PyObject *__pyx_v_b, PyObject *__pyx_v_c) {
#                                ^
# ./rankpy/models/users/users_inner.c:15098:32: warning: unused function '__pyx_f_5numpy_PyArray_MultiIterNew4' [-Wunused-function]
# static CYTHON_INLINE PyObject *__pyx_f_5numpy_PyArray_MultiIterNew4(PyObject *__pyx_v_a, PyObject *__pyx_v_b, PyObject *__pyx_v_c, PyObject *_...
#                                ^
# ./rankpy/models/users/users_inner.c:15148:32: warning: unused function '__pyx_f_5numpy_PyArray_MultiIterNew5' [-Wunused-function]
# static CYTHON_INLINE PyObject *__pyx_f_5numpy_PyArray_MultiIterNew5(PyObject *__pyx_v_a, PyObject *__pyx_v_b, PyObject *__pyx_v_c, PyObject *_...
#                                ^
# ./rankpy/models/users/users_inner.c:15916:27: warning: unused function '__pyx_f_5numpy_set_array_base' [-Wunused-function]
# static CYTHON_INLINE void __pyx_f_5numpy_set_array_base(PyArrayObject *__pyx_v_arr, PyObject *__pyx_v_base) {
#                           ^
# ./rankpy/models/users/users_inner.c:16004:32: warning: unused function '__pyx_f_5numpy_get_array_base' [-Wunused-function]
# static CYTHON_INLINE PyObject *__pyx_f_5numpy_get_array_base(PyArrayObject *__pyx_v_arr) {
#                                ^
# 33 warnings generated.
# /usr/bin/clang -bundle -undefined dynamic_lookup -arch i386 -arch x86_64 -g build/temp.macosx-10.6-intel-3.5/./rankpy/models/users/users_inner.o -lm -o build/lib.macosx-10.6-intel-3.5/rankpy/models/users/users_inner.cpython-35m-darwin.so
# building 'rankpy.tree._tree' extension
# creating build/temp.macosx-10.6-intel-3.5/rankpy/tree
# /usr/bin/clang -fno-strict-aliasing -Wsign-compare -fno-common -dynamic -DNDEBUG -g -fwrapv -O3 -Wall -Wstrict-prototypes -arch i386 -arch x86_64 -g -I/Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/numpy/core/include -I/Library/Frameworks/Python.framework/Versions/3.5/include/python3.5m -c ./rankpy/tree/_tree.c -o build/temp.macosx-10.6-intel-3.5/./rankpy/tree/_tree.o -O3
# In file included from ./rankpy/tree/_tree.c:239:
# In file included from /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/numpy/core/include/numpy/arrayobject.h:4:
# In file included from /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/numpy/core/include/numpy/ndarrayobject.h:18:
# In file included from /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/numpy/core/include/numpy/ndarraytypes.h:1788:
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/numpy/core/include/numpy/npy_1_7_deprecated_api.h:15:2: warning:
#       "Using deprecated NumPy API, disable it by " "#defining NPY_NO_DEPRECATED_API NPY_1_7_API_VERSION" [-W#warnings]
# #warning "Using deprecated NumPy API, disable it by " \
#  ^
# ./rankpy/tree/_tree.c:4850:36: warning: incompatible pointer types passing 'PyObject *' (aka 'struct _object *') to parameter of type 'PyTypeObject *'
#       (aka 'struct _typeobject *') [-Wincompatible-pointer-types]
#   __pyx_t_3 = PyArray_NewFromDescr(((PyObject *)((PyObject*)__pyx_ptype_5numpy_ndarray)), ((PyArray_Descr *)__pyx_t_2), 1, (&__pyx_v_shape), (...
#                                    ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ./rankpy/tree/_tree.c:29206:32: warning: unused function '__Pyx_PyUnicode_FromString' [-Wunused-function]
# static CYTHON_INLINE PyObject* __Pyx_PyUnicode_FromString(const char* c_str) {
#                                ^
# ./rankpy/tree/_tree.c:29346:33: warning: unused function '__Pyx_PyInt_FromSize_t' [-Wunused-function]
# static CYTHON_INLINE PyObject * __Pyx_PyInt_FromSize_t(size_t ival) {
#                                 ^
# ./rankpy/tree/_tree.c:26308:32: warning: unused function '__Pyx_GetItemInt_List_Fast' [-Wunused-function]
# static CYTHON_INLINE PyObject *__Pyx_GetItemInt_List_Fast(PyObject *o, Py_ssize_t i,
#                                ^
# ./rankpy/tree/_tree.c:26322:32: warning: unused function '__Pyx_GetItemInt_Tuple_Fast' [-Wunused-function]
# static CYTHON_INLINE PyObject *__Pyx_GetItemInt_Tuple_Fast(PyObject *o, Py_ssize_t i,
#                                ^
# ./rankpy/tree/_tree.c:27261:26: warning: unused function '__Pyx_PyBytes_Equals' [-Wunused-function]
# static CYTHON_INLINE int __Pyx_PyBytes_Equals(PyObject* s1, PyObject* s2, int equals) {
#                          ^
# ./rankpy/tree/_tree.c:28526:48: warning: unused function '__pyx_t_float_complex_from_parts' [-Wunused-function]
#     static CYTHON_INLINE __pyx_t_float_complex __pyx_t_float_complex_from_parts(float x, float y) {
#                                                ^
# ./rankpy/tree/_tree.c:28536:30: warning: unused function '__Pyx_c_eqf' [-Wunused-function]
#     static CYTHON_INLINE int __Pyx_c_eqf(__pyx_t_float_complex a, __pyx_t_float_complex b) {
#                              ^
# ./rankpy/tree/_tree.c:28539:48: warning: unused function '__Pyx_c_sumf' [-Wunused-function]
#     static CYTHON_INLINE __pyx_t_float_complex __Pyx_c_sumf(__pyx_t_float_complex a, __pyx_t_float_complex b) {
#                                                ^
# ./rankpy/tree/_tree.c:28545:48: warning: unused function '__Pyx_c_difff' [-Wunused-function]
#     static CYTHON_INLINE __pyx_t_float_complex __Pyx_c_difff(__pyx_t_float_complex a, __pyx_t_float_complex b) {
#                                                ^
# ./rankpy/tree/_tree.c:28557:48: warning: unused function '__Pyx_c_quotf' [-Wunused-function]
#     static CYTHON_INLINE __pyx_t_float_complex __Pyx_c_quotf(__pyx_t_float_complex a, __pyx_t_float_complex b) {
#                                                ^
# ./rankpy/tree/_tree.c:28564:48: warning: unused function '__Pyx_c_negf' [-Wunused-function]
#     static CYTHON_INLINE __pyx_t_float_complex __Pyx_c_negf(__pyx_t_float_complex a) {
#                                                ^
# ./rankpy/tree/_tree.c:28570:30: warning: unused function '__Pyx_c_is_zerof' [-Wunused-function]
#     static CYTHON_INLINE int __Pyx_c_is_zerof(__pyx_t_float_complex a) {
#                              ^
# ./rankpy/tree/_tree.c:28573:48: warning: unused function '__Pyx_c_conjf' [-Wunused-function]
#     static CYTHON_INLINE __pyx_t_float_complex __Pyx_c_conjf(__pyx_t_float_complex a) {
#                                                ^
# ./rankpy/tree/_tree.c:28587:52: warning: unused function '__Pyx_c_powf' [-Wunused-function]
#         static CYTHON_INLINE __pyx_t_float_complex __Pyx_c_powf(__pyx_t_float_complex a, __pyx_t_float_complex b) {
#                                                    ^
# ./rankpy/tree/_tree.c:28646:49: warning: unused function '__pyx_t_double_complex_from_parts' [-Wunused-function]
#     static CYTHON_INLINE __pyx_t_double_complex __pyx_t_double_complex_from_parts(double x, double y) {
#                                                 ^
# ./rankpy/tree/_tree.c:28656:30: warning: unused function '__Pyx_c_eq' [-Wunused-function]
#     static CYTHON_INLINE int __Pyx_c_eq(__pyx_t_double_complex a, __pyx_t_double_complex b) {
#                              ^
# ./rankpy/tree/_tree.c:28659:49: warning: unused function '__Pyx_c_sum' [-Wunused-function]
#     static CYTHON_INLINE __pyx_t_double_complex __Pyx_c_sum(__pyx_t_double_complex a, __pyx_t_double_complex b) {
#                                                 ^
# ./rankpy/tree/_tree.c:28665:49: warning: unused function '__Pyx_c_diff' [-Wunused-function]
#     static CYTHON_INLINE __pyx_t_double_complex __Pyx_c_diff(__pyx_t_double_complex a, __pyx_t_double_complex b) {
#                                                 ^
# ./rankpy/tree/_tree.c:28677:49: warning: unused function '__Pyx_c_quot' [-Wunused-function]
#     static CYTHON_INLINE __pyx_t_double_complex __Pyx_c_quot(__pyx_t_double_complex a, __pyx_t_double_complex b) {
#                                                 ^
# ./rankpy/tree/_tree.c:28684:49: warning: unused function '__Pyx_c_neg' [-Wunused-function]
#     static CYTHON_INLINE __pyx_t_double_complex __Pyx_c_neg(__pyx_t_double_complex a) {
#                                                 ^
# ./rankpy/tree/_tree.c:28690:30: warning: unused function '__Pyx_c_is_zero' [-Wunused-function]
#     static CYTHON_INLINE int __Pyx_c_is_zero(__pyx_t_double_complex a) {
#                              ^
# ./rankpy/tree/_tree.c:28693:49: warning: unused function '__Pyx_c_conj' [-Wunused-function]
#     static CYTHON_INLINE __pyx_t_double_complex __Pyx_c_conj(__pyx_t_double_complex a) {
#                                                 ^
# ./rankpy/tree/_tree.c:28707:53: warning: unused function '__Pyx_c_pow' [-Wunused-function]
#         static CYTHON_INLINE __pyx_t_double_complex __Pyx_c_pow(__pyx_t_double_complex a, __pyx_t_double_complex b) {
#                                                     ^
# ./rankpy/tree/_tree.c:28890:27: warning: function '__Pyx_PyInt_As_char' is not needed and will not be emitted [-Wunneeded-internal-declaration]
# static CYTHON_INLINE char __Pyx_PyInt_As_char(PyObject *x) {
#                           ^
# ./rankpy/tree/_tree.c:28985:27: warning: function '__Pyx_PyInt_As_long' is not needed and will not be emitted [-Wunneeded-internal-declaration]
# static CYTHON_INLINE long __Pyx_PyInt_As_long(PyObject *x) {
#                           ^
# ./rankpy/tree/_tree.c:6921:27: warning: unused function '__pyx_f_6rankpy_4tree_5_tree_Splitter_update_node_value' [-Wunused-function]
# static CYTHON_INLINE void __pyx_f_6rankpy_4tree_5_tree_Splitter_update_node_value(__pyx_t_6rankpy_4tree_5_tree_SplitterPtr __pyx_v_self, struc...
#                           ^
# ./rankpy/tree/_tree.c:11944:32: warning: unused function '__pyx_f_5numpy_PyArray_MultiIterNew1' [-Wunused-function]
# static CYTHON_INLINE PyObject *__pyx_f_5numpy_PyArray_MultiIterNew1(PyObject *__pyx_v_a) {
#                                ^
# ./rankpy/tree/_tree.c:11994:32: warning: unused function '__pyx_f_5numpy_PyArray_MultiIterNew2' [-Wunused-function]
# static CYTHON_INLINE PyObject *__pyx_f_5numpy_PyArray_MultiIterNew2(PyObject *__pyx_v_a, PyObject *__pyx_v_b) {
#                                ^
# ./rankpy/tree/_tree.c:12044:32: warning: unused function '__pyx_f_5numpy_PyArray_MultiIterNew3' [-Wunused-function]
# static CYTHON_INLINE PyObject *__pyx_f_5numpy_PyArray_MultiIterNew3(PyObject *__pyx_v_a, PyObject *__pyx_v_b, PyObject *__pyx_v_c) {
#                                ^
# ./rankpy/tree/_tree.c:12094:32: warning: unused function '__pyx_f_5numpy_PyArray_MultiIterNew4' [-Wunused-function]
# static CYTHON_INLINE PyObject *__pyx_f_5numpy_PyArray_MultiIterNew4(PyObject *__pyx_v_a, PyObject *__pyx_v_b, PyObject *__pyx_v_c, PyObject *_...
#                                ^
# ./rankpy/tree/_tree.c:12144:32: warning: unused function '__pyx_f_5numpy_PyArray_MultiIterNew5' [-Wunused-function]
# static CYTHON_INLINE PyObject *__pyx_f_5numpy_PyArray_MultiIterNew5(PyObject *__pyx_v_a, PyObject *__pyx_v_b, PyObject *__pyx_v_c, PyObject *_...
#                                ^
# ./rankpy/tree/_tree.c:12907:27: warning: unused function '__pyx_f_5numpy_set_array_base' [-Wunused-function]
# static CYTHON_INLINE void __pyx_f_5numpy_set_array_base(PyArrayObject *__pyx_v_arr, PyObject *__pyx_v_base) {
#                           ^
# ./rankpy/tree/_tree.c:12995:32: warning: unused function '__pyx_f_5numpy_get_array_base' [-Wunused-function]
# static CYTHON_INLINE PyObject *__pyx_f_5numpy_get_array_base(PyArrayObject *__pyx_v_arr) {
#                                ^
# 35 warnings generated.
# In file included from ./rankpy/tree/_tree.c:239:
# In file included from /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/numpy/core/include/numpy/arrayobject.h:4:
# In file included from /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/numpy/core/include/numpy/ndarrayobject.h:18:
# In file included from /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/numpy/core/include/numpy/ndarraytypes.h:1788:
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/numpy/core/include/numpy/npy_1_7_deprecated_api.h:15:2: warning:
#       "Using deprecated NumPy API, disable it by " "#defining NPY_NO_DEPRECATED_API NPY_1_7_API_VERSION" [-W#warnings]
# #warning "Using deprecated NumPy API, disable it by " \
#  ^
# ./rankpy/tree/_tree.c:4850:36: warning: incompatible pointer types passing 'PyObject *' (aka 'struct _object *') to parameter of type 'PyTypeObject *'
#       (aka 'struct _typeobject *') [-Wincompatible-pointer-types]
#   __pyx_t_3 = PyArray_NewFromDescr(((PyObject *)((PyObject*)__pyx_ptype_5numpy_ndarray)), ((PyArray_Descr *)__pyx_t_2), 1, (&__pyx_v_shape), (...
#                                    ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ./rankpy/tree/_tree.c:29206:32: warning: unused function '__Pyx_PyUnicode_FromString' [-Wunused-function]
# static CYTHON_INLINE PyObject* __Pyx_PyUnicode_FromString(const char* c_str) {
#                                ^
# ./rankpy/tree/_tree.c:29346:33: warning: unused function '__Pyx_PyInt_FromSize_t' [-Wunused-function]
# static CYTHON_INLINE PyObject * __Pyx_PyInt_FromSize_t(size_t ival) {
#                                 ^
# ./rankpy/tree/_tree.c:26308:32: warning: unused function '__Pyx_GetItemInt_List_Fast' [-Wunused-function]
# static CYTHON_INLINE PyObject *__Pyx_GetItemInt_List_Fast(PyObject *o, Py_ssize_t i,
#                                ^
# ./rankpy/tree/_tree.c:26322:32: warning: unused function '__Pyx_GetItemInt_Tuple_Fast' [-Wunused-function]
# static CYTHON_INLINE PyObject *__Pyx_GetItemInt_Tuple_Fast(PyObject *o, Py_ssize_t i,
#                                ^
# ./rankpy/tree/_tree.c:27011:1: warning: unused function '__pyx_add_acquisition_count_locked' [-Wunused-function]
# __pyx_add_acquisition_count_locked(__pyx_atomic_int *acquisition_count,
# ^
# ./rankpy/tree/_tree.c:27021:1: warning: unused function '__pyx_sub_acquisition_count_locked' [-Wunused-function]
# __pyx_sub_acquisition_count_locked(__pyx_atomic_int *acquisition_count,
# ^
# ./rankpy/tree/_tree.c:27261:26: warning: unused function '__Pyx_PyBytes_Equals' [-Wunused-function]
# static CYTHON_INLINE int __Pyx_PyBytes_Equals(PyObject* s1, PyObject* s2, int equals) {
#                          ^
# ./rankpy/tree/_tree.c:28526:48: warning: unused function '__pyx_t_float_complex_from_parts' [-Wunused-function]
#     static CYTHON_INLINE __pyx_t_float_complex __pyx_t_float_complex_from_parts(float x, float y) {
#                                                ^
# ./rankpy/tree/_tree.c:28536:30: warning: unused function '__Pyx_c_eqf' [-Wunused-function]
#     static CYTHON_INLINE int __Pyx_c_eqf(__pyx_t_float_complex a, __pyx_t_float_complex b) {
#                              ^
# ./rankpy/tree/_tree.c:28539:48: warning: unused function '__Pyx_c_sumf' [-Wunused-function]
#     static CYTHON_INLINE __pyx_t_float_complex __Pyx_c_sumf(__pyx_t_float_complex a, __pyx_t_float_complex b) {
#                                                ^
# ./rankpy/tree/_tree.c:28545:48: warning: unused function '__Pyx_c_difff' [-Wunused-function]
#     static CYTHON_INLINE __pyx_t_float_complex __Pyx_c_difff(__pyx_t_float_complex a, __pyx_t_float_complex b) {
#                                                ^
# ./rankpy/tree/_tree.c:28557:48: warning: unused function '__Pyx_c_quotf' [-Wunused-function]
#     static CYTHON_INLINE __pyx_t_float_complex __Pyx_c_quotf(__pyx_t_float_complex a, __pyx_t_float_complex b) {
#                                                ^
# ./rankpy/tree/_tree.c:28564:48: warning: unused function '__Pyx_c_negf' [-Wunused-function]
#     static CYTHON_INLINE __pyx_t_float_complex __Pyx_c_negf(__pyx_t_float_complex a) {
#                                                ^
# ./rankpy/tree/_tree.c:28570:30: warning: unused function '__Pyx_c_is_zerof' [-Wunused-function]
#     static CYTHON_INLINE int __Pyx_c_is_zerof(__pyx_t_float_complex a) {
#                              ^
# ./rankpy/tree/_tree.c:28573:48: warning: unused function '__Pyx_c_conjf' [-Wunused-function]
#     static CYTHON_INLINE __pyx_t_float_complex __Pyx_c_conjf(__pyx_t_float_complex a) {
#                                                ^
# ./rankpy/tree/_tree.c:28587:52: warning: unused function '__Pyx_c_powf' [-Wunused-function]
#         static CYTHON_INLINE __pyx_t_float_complex __Pyx_c_powf(__pyx_t_float_complex a, __pyx_t_float_complex b) {
#                                                    ^
# ./rankpy/tree/_tree.c:28646:49: warning: unused function '__pyx_t_double_complex_from_parts' [-Wunused-function]
#     static CYTHON_INLINE __pyx_t_double_complex __pyx_t_double_complex_from_parts(double x, double y) {
#                                                 ^
# ./rankpy/tree/_tree.c:28656:30: warning: unused function '__Pyx_c_eq' [-Wunused-function]
#     static CYTHON_INLINE int __Pyx_c_eq(__pyx_t_double_complex a, __pyx_t_double_complex b) {
#                              ^
# ./rankpy/tree/_tree.c:28659:49: warning: unused function '__Pyx_c_sum' [-Wunused-function]
#     static CYTHON_INLINE __pyx_t_double_complex __Pyx_c_sum(__pyx_t_double_complex a, __pyx_t_double_complex b) {
#                                                 ^
# ./rankpy/tree/_tree.c:28665:49: warning: unused function '__Pyx_c_diff' [-Wunused-function]
#     static CYTHON_INLINE __pyx_t_double_complex __Pyx_c_diff(__pyx_t_double_complex a, __pyx_t_double_complex b) {
#                                                 ^
# ./rankpy/tree/_tree.c:28677:49: warning: unused function '__Pyx_c_quot' [-Wunused-function]
#     static CYTHON_INLINE __pyx_t_double_complex __Pyx_c_quot(__pyx_t_double_complex a, __pyx_t_double_complex b) {
#                                                 ^
# ./rankpy/tree/_tree.c:28684:49: warning: unused function '__Pyx_c_neg' [-Wunused-function]
#     static CYTHON_INLINE __pyx_t_double_complex __Pyx_c_neg(__pyx_t_double_complex a) {
#                                                 ^
# ./rankpy/tree/_tree.c:28690:30: warning: unused function '__Pyx_c_is_zero' [-Wunused-function]
#     static CYTHON_INLINE int __Pyx_c_is_zero(__pyx_t_double_complex a) {
#                              ^
# ./rankpy/tree/_tree.c:28693:49: warning: unused function '__Pyx_c_conj' [-Wunused-function]
#     static CYTHON_INLINE __pyx_t_double_complex __Pyx_c_conj(__pyx_t_double_complex a) {
#                                                 ^
# ./rankpy/tree/_tree.c:28707:53: warning: unused function '__Pyx_c_pow' [-Wunused-function]
#         static CYTHON_INLINE __pyx_t_double_complex __Pyx_c_pow(__pyx_t_double_complex a, __pyx_t_double_complex b) {
#                                                     ^
# ./rankpy/tree/_tree.c:28890:27: warning: function '__Pyx_PyInt_As_char' is not needed and will not be emitted [-Wunneeded-internal-declaration]
# static CYTHON_INLINE char __Pyx_PyInt_As_char(PyObject *x) {
#                           ^
# ./rankpy/tree/_tree.c:28985:27: warning: function '__Pyx_PyInt_As_long' is not needed and will not be emitted [-Wunneeded-internal-declaration]
# static CYTHON_INLINE long __Pyx_PyInt_As_long(PyObject *x) {
#                           ^
# ./rankpy/tree/_tree.c:6921:27: warning: unused function '__pyx_f_6rankpy_4tree_5_tree_Splitter_update_node_value' [-Wunused-function]
# static CYTHON_INLINE void __pyx_f_6rankpy_4tree_5_tree_Splitter_update_node_value(__pyx_t_6rankpy_4tree_5_tree_SplitterPtr __pyx_v_self, struc...
#                           ^
# ./rankpy/tree/_tree.c:11944:32: warning: unused function '__pyx_f_5numpy_PyArray_MultiIterNew1' [-Wunused-function]
# static CYTHON_INLINE PyObject *__pyx_f_5numpy_PyArray_MultiIterNew1(PyObject *__pyx_v_a) {
#                                ^
# ./rankpy/tree/_tree.c:11994:32: warning: unused function '__pyx_f_5numpy_PyArray_MultiIterNew2' [-Wunused-function]
# static CYTHON_INLINE PyObject *__pyx_f_5numpy_PyArray_MultiIterNew2(PyObject *__pyx_v_a, PyObject *__pyx_v_b) {
#                                ^
# ./rankpy/tree/_tree.c:12044:32: warning: unused function '__pyx_f_5numpy_PyArray_MultiIterNew3' [-Wunused-function]
# static CYTHON_INLINE PyObject *__pyx_f_5numpy_PyArray_MultiIterNew3(PyObject *__pyx_v_a, PyObject *__pyx_v_b, PyObject *__pyx_v_c) {
#                                ^
# ./rankpy/tree/_tree.c:12094:32: warning: unused function '__pyx_f_5numpy_PyArray_MultiIterNew4' [-Wunused-function]
# static CYTHON_INLINE PyObject *__pyx_f_5numpy_PyArray_MultiIterNew4(PyObject *__pyx_v_a, PyObject *__pyx_v_b, PyObject *__pyx_v_c, PyObject *_...
#                                ^
# ./rankpy/tree/_tree.c:12144:32: warning: unused function '__pyx_f_5numpy_PyArray_MultiIterNew5' [-Wunused-function]
# static CYTHON_INLINE PyObject *__pyx_f_5numpy_PyArray_MultiIterNew5(PyObject *__pyx_v_a, PyObject *__pyx_v_b, PyObject *__pyx_v_c, PyObject *_...
#                                ^
# ./rankpy/tree/_tree.c:12907:27: warning: unused function '__pyx_f_5numpy_set_array_base' [-Wunused-function]
# static CYTHON_INLINE void __pyx_f_5numpy_set_array_base(PyArrayObject *__pyx_v_arr, PyObject *__pyx_v_base) {
#                           ^
# ./rankpy/tree/_tree.c:12995:32: warning: unused function '__pyx_f_5numpy_get_array_base' [-Wunused-function]
# static CYTHON_INLINE PyObject *__pyx_f_5numpy_get_array_base(PyArrayObject *__pyx_v_arr) {
#                                ^
# 37 warnings generated.
# /usr/bin/clang -bundle -undefined dynamic_lookup -arch i386 -arch x86_64 -g build/temp.macosx-10.6-intel-3.5/./rankpy/tree/_tree.o -lm -o build/lib.macosx-10.6-intel-3.5/rankpy/tree/_tree.cpython-35m-darwin.so
# creating build/bdist.macosx-10.6-intel
# creating build/bdist.macosx-10.6-intel/egg
# creating build/bdist.macosx-10.6-intel/egg/rankpy
# copying build/lib.macosx-10.6-intel-3.5/rankpy/__init__.py -> build/bdist.macosx-10.6-intel/egg/rankpy
# creating build/bdist.macosx-10.6-intel/egg/rankpy/analysis
# copying build/lib.macosx-10.6-intel-3.5/rankpy/analysis/__init__.py -> build/bdist.macosx-10.6-intel/egg/rankpy/analysis
# copying build/lib.macosx-10.6-intel-3.5/rankpy/analysis/lambdamart.py -> build/bdist.macosx-10.6-intel/egg/rankpy/analysis
# creating build/bdist.macosx-10.6-intel/egg/rankpy/externals
# copying build/lib.macosx-10.6-intel-3.5/rankpy/externals/__init__.py -> build/bdist.macosx-10.6-intel/egg/rankpy/externals
# creating build/bdist.macosx-10.6-intel/egg/rankpy/externals/joblib
# copying build/lib.macosx-10.6-intel-3.5/rankpy/externals/joblib/__init__.py -> build/bdist.macosx-10.6-intel/egg/rankpy/externals/joblib
# copying build/lib.macosx-10.6-intel-3.5/rankpy/externals/joblib/_compat.py -> build/bdist.macosx-10.6-intel/egg/rankpy/externals/joblib
# copying build/lib.macosx-10.6-intel-3.5/rankpy/externals/joblib/_memory_helpers.py -> build/bdist.macosx-10.6-intel/egg/rankpy/externals/joblib
# copying build/lib.macosx-10.6-intel-3.5/rankpy/externals/joblib/_multiprocessing_helpers.py -> build/bdist.macosx-10.6-intel/egg/rankpy/externals/joblib
# copying build/lib.macosx-10.6-intel-3.5/rankpy/externals/joblib/disk.py -> build/bdist.macosx-10.6-intel/egg/rankpy/externals/joblib
# copying build/lib.macosx-10.6-intel-3.5/rankpy/externals/joblib/format_stack.py -> build/bdist.macosx-10.6-intel/egg/rankpy/externals/joblib
# copying build/lib.macosx-10.6-intel-3.5/rankpy/externals/joblib/func_inspect.py -> build/bdist.macosx-10.6-intel/egg/rankpy/externals/joblib
# copying build/lib.macosx-10.6-intel-3.5/rankpy/externals/joblib/hashing.py -> build/bdist.macosx-10.6-intel/egg/rankpy/externals/joblib
# copying build/lib.macosx-10.6-intel-3.5/rankpy/externals/joblib/logger.py -> build/bdist.macosx-10.6-intel/egg/rankpy/externals/joblib
# copying build/lib.macosx-10.6-intel-3.5/rankpy/externals/joblib/memory.py -> build/bdist.macosx-10.6-intel/egg/rankpy/externals/joblib
# copying build/lib.macosx-10.6-intel-3.5/rankpy/externals/joblib/my_exceptions.py -> build/bdist.macosx-10.6-intel/egg/rankpy/externals/joblib
# copying build/lib.macosx-10.6-intel-3.5/rankpy/externals/joblib/numpy_pickle.py -> build/bdist.macosx-10.6-intel/egg/rankpy/externals/joblib
# copying build/lib.macosx-10.6-intel-3.5/rankpy/externals/joblib/parallel.py -> build/bdist.macosx-10.6-intel/egg/rankpy/externals/joblib
# copying build/lib.macosx-10.6-intel-3.5/rankpy/externals/joblib/pool.py -> build/bdist.macosx-10.6-intel/egg/rankpy/externals/joblib
# copying build/lib.macosx-10.6-intel-3.5/rankpy/externals/joblib/testing.py -> build/bdist.macosx-10.6-intel/egg/rankpy/externals/joblib
# copying build/lib.macosx-10.6-intel-3.5/rankpy/gridsearch.py -> build/bdist.macosx-10.6-intel/egg/rankpy
# creating build/bdist.macosx-10.6-intel/egg/rankpy/metrics
# copying build/lib.macosx-10.6-intel-3.5/rankpy/metrics/__init__.py -> build/bdist.macosx-10.6-intel/egg/rankpy/metrics
# copying build/lib.macosx-10.6-intel-3.5/rankpy/metrics/_metrics.cpython-35m-darwin.so -> build/bdist.macosx-10.6-intel/egg/rankpy/metrics
# copying build/lib.macosx-10.6-intel-3.5/rankpy/metrics/_utils.cpython-35m-darwin.so -> build/bdist.macosx-10.6-intel/egg/rankpy/metrics
# copying build/lib.macosx-10.6-intel-3.5/rankpy/metrics/metrics.py -> build/bdist.macosx-10.6-intel/egg/rankpy/metrics
# creating build/bdist.macosx-10.6-intel/egg/rankpy/models
# copying build/lib.macosx-10.6-intel-3.5/rankpy/models/__init__.py -> build/bdist.macosx-10.6-intel/egg/rankpy/models
# copying build/lib.macosx-10.6-intel-3.5/rankpy/models/lambdamart.py -> build/bdist.macosx-10.6-intel/egg/rankpy/models
# copying build/lib.macosx-10.6-intel-3.5/rankpy/models/lambdamart_inner.cpython-35m-darwin.so -> build/bdist.macosx-10.6-intel/egg/rankpy/models
# copying build/lib.macosx-10.6-intel-3.5/rankpy/models/lambdarandomforest.py -> build/bdist.macosx-10.6-intel/egg/rankpy/models
# creating build/bdist.macosx-10.6-intel/egg/rankpy/models/users
# copying build/lib.macosx-10.6-intel-3.5/rankpy/models/users/__init__.py -> build/bdist.macosx-10.6-intel/egg/rankpy/models/users
# copying build/lib.macosx-10.6-intel-3.5/rankpy/models/users/users_inner.cpython-35m-darwin.so -> build/bdist.macosx-10.6-intel/egg/rankpy/models/users
# copying build/lib.macosx-10.6-intel-3.5/rankpy/queries.py -> build/bdist.macosx-10.6-intel/egg/rankpy
# creating build/bdist.macosx-10.6-intel/egg/rankpy/tree
# copying build/lib.macosx-10.6-intel-3.5/rankpy/tree/__init__.py -> build/bdist.macosx-10.6-intel/egg/rankpy/tree
# copying build/lib.macosx-10.6-intel-3.5/rankpy/tree/_tree.cpython-35m-darwin.so -> build/bdist.macosx-10.6-intel/egg/rankpy/tree
# copying build/lib.macosx-10.6-intel-3.5/rankpy/tree/tree.py -> build/bdist.macosx-10.6-intel/egg/rankpy/tree
# copying build/lib.macosx-10.6-intel-3.5/rankpy/utils.py -> build/bdist.macosx-10.6-intel/egg/rankpy
# byte-compiling build/bdist.macosx-10.6-intel/egg/rankpy/__init__.py to __init__.cpython-35.pyc
# byte-compiling build/bdist.macosx-10.6-intel/egg/rankpy/analysis/__init__.py to __init__.cpython-35.pyc
# byte-compiling build/bdist.macosx-10.6-intel/egg/rankpy/analysis/lambdamart.py to lambdamart.cpython-35.pyc
# byte-compiling build/bdist.macosx-10.6-intel/egg/rankpy/externals/__init__.py to __init__.cpython-35.pyc
# byte-compiling build/bdist.macosx-10.6-intel/egg/rankpy/externals/joblib/__init__.py to __init__.cpython-35.pyc
# byte-compiling build/bdist.macosx-10.6-intel/egg/rankpy/externals/joblib/_compat.py to _compat.cpython-35.pyc
# byte-compiling build/bdist.macosx-10.6-intel/egg/rankpy/externals/joblib/_memory_helpers.py to _memory_helpers.cpython-35.pyc
# byte-compiling build/bdist.macosx-10.6-intel/egg/rankpy/externals/joblib/_multiprocessing_helpers.py to _multiprocessing_helpers.cpython-35.pyc
# byte-compiling build/bdist.macosx-10.6-intel/egg/rankpy/externals/joblib/disk.py to disk.cpython-35.pyc
# byte-compiling build/bdist.macosx-10.6-intel/egg/rankpy/externals/joblib/format_stack.py to format_stack.cpython-35.pyc
# byte-compiling build/bdist.macosx-10.6-intel/egg/rankpy/externals/joblib/func_inspect.py to func_inspect.cpython-35.pyc
# byte-compiling build/bdist.macosx-10.6-intel/egg/rankpy/externals/joblib/hashing.py to hashing.cpython-35.pyc
# byte-compiling build/bdist.macosx-10.6-intel/egg/rankpy/externals/joblib/logger.py to logger.cpython-35.pyc
# byte-compiling build/bdist.macosx-10.6-intel/egg/rankpy/externals/joblib/memory.py to memory.cpython-35.pyc
# byte-compiling build/bdist.macosx-10.6-intel/egg/rankpy/externals/joblib/my_exceptions.py to my_exceptions.cpython-35.pyc
# byte-compiling build/bdist.macosx-10.6-intel/egg/rankpy/externals/joblib/numpy_pickle.py to numpy_pickle.cpython-35.pyc
# byte-compiling build/bdist.macosx-10.6-intel/egg/rankpy/externals/joblib/parallel.py to parallel.cpython-35.pyc
# byte-compiling build/bdist.macosx-10.6-intel/egg/rankpy/externals/joblib/pool.py to pool.cpython-35.pyc
# byte-compiling build/bdist.macosx-10.6-intel/egg/rankpy/externals/joblib/testing.py to testing.cpython-35.pyc
# byte-compiling build/bdist.macosx-10.6-intel/egg/rankpy/gridsearch.py to gridsearch.cpython-35.pyc
# byte-compiling build/bdist.macosx-10.6-intel/egg/rankpy/metrics/__init__.py to __init__.cpython-35.pyc
# byte-compiling build/bdist.macosx-10.6-intel/egg/rankpy/metrics/metrics.py to metrics.cpython-35.pyc
# byte-compiling build/bdist.macosx-10.6-intel/egg/rankpy/models/__init__.py to __init__.cpython-35.pyc
# byte-compiling build/bdist.macosx-10.6-intel/egg/rankpy/models/lambdamart.py to lambdamart.cpython-35.pyc
# byte-compiling build/bdist.macosx-10.6-intel/egg/rankpy/models/lambdarandomforest.py to lambdarandomforest.cpython-35.pyc
# byte-compiling build/bdist.macosx-10.6-intel/egg/rankpy/models/users/__init__.py to __init__.cpython-35.pyc
# byte-compiling build/bdist.macosx-10.6-intel/egg/rankpy/queries.py to queries.cpython-35.pyc
#   File "build/bdist.macosx-10.6-intel/egg/rankpy/queries.py", line 478
#     print 'Ill-formated line: %d' % lineno
#                                 ^
# SyntaxError: Missing parentheses in call to 'print'
#
# byte-compiling build/bdist.macosx-10.6-intel/egg/rankpy/tree/__init__.py to __init__.cpython-35.pyc
# byte-compiling build/bdist.macosx-10.6-intel/egg/rankpy/tree/tree.py to tree.cpython-35.pyc
# byte-compiling build/bdist.macosx-10.6-intel/egg/rankpy/utils.py to utils.cpython-35.pyc
# creating stub loader for rankpy/metrics/_metrics.cpython-35m-darwin.so
# creating stub loader for rankpy/metrics/_utils.cpython-35m-darwin.so
# creating stub loader for rankpy/models/lambdamart_inner.cpython-35m-darwin.so
# creating stub loader for rankpy/models/users/users_inner.cpython-35m-darwin.so
# creating stub loader for rankpy/tree/_tree.cpython-35m-darwin.so
# byte-compiling build/bdist.macosx-10.6-intel/egg/rankpy/metrics/_metrics.py to _metrics.cpython-35.pyc
# byte-compiling build/bdist.macosx-10.6-intel/egg/rankpy/metrics/_utils.py to _utils.cpython-35.pyc
# byte-compiling build/bdist.macosx-10.6-intel/egg/rankpy/models/lambdamart_inner.py to lambdamart_inner.cpython-35.pyc
# byte-compiling build/bdist.macosx-10.6-intel/egg/rankpy/models/users/users_inner.py to users_inner.cpython-35.pyc
# byte-compiling build/bdist.macosx-10.6-intel/egg/rankpy/tree/_tree.py to _tree.cpython-35.pyc
# creating build/bdist.macosx-10.6-intel/egg/EGG-INFO
# copying RankPy.egg-info/PKG-INFO -> build/bdist.macosx-10.6-intel/egg/EGG-INFO
# copying RankPy.egg-info/SOURCES.txt -> build/bdist.macosx-10.6-intel/egg/EGG-INFO
# copying RankPy.egg-info/dependency_links.txt -> build/bdist.macosx-10.6-intel/egg/EGG-INFO
# copying RankPy.egg-info/top_level.txt -> build/bdist.macosx-10.6-intel/egg/EGG-INFO
# writing build/bdist.macosx-10.6-intel/egg/EGG-INFO/native_libs.txt
# zip_safe flag not set; analyzing archive contents...
# rankpy.externals.joblib.__pycache__.format_stack.cpython-35: module references __file__
# rankpy.externals.joblib.__pycache__.format_stack.cpython-35: module MAY be using inspect.getinnerframes
# rankpy.externals.joblib.__pycache__.format_stack.cpython-35: module MAY be using inspect.getouterframes
# rankpy.externals.joblib.__pycache__.func_inspect.cpython-35: module MAY be using inspect.getsourcefile
# rankpy.metrics.__pycache__._metrics.cpython-35: module references __file__
# rankpy.metrics.__pycache__._utils.cpython-35: module references __file__
# rankpy.models.__pycache__.lambdamart_inner.cpython-35: module references __file__
# rankpy.models.users.__pycache__.users_inner.cpython-35: module references __file__
# rankpy.tree.__pycache__._tree.cpython-35: module references __file__
# creating dist
# creating 'dist/RankPy-0.0.1a0-py3.5-macosx-10.6-intel.egg' and adding 'build/bdist.macosx-10.6-intel/egg' to it
# removing 'build/bdist.macosx-10.6-intel/egg' (and everything under it)
# Processing RankPy-0.0.1a0-py3.5-macosx-10.6-intel.egg
# creating /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/RankPy-0.0.1a0-py3.5-macosx-10.6-intel.egg
# Extracting RankPy-0.0.1a0-py3.5-macosx-10.6-intel.egg to /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages
#   File "/Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/RankPy-0.0.1a0-py3.5-macosx-10.6-intel.egg/rankpy/queries.py", line 478
#     print 'Ill-formated line: %d' % lineno
#                                 ^
# SyntaxError: Missing parentheses in call to 'print'
#
# Adding RankPy 0.0.1a0 to easy-install.pth file
#
# Installed /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/RankPy-0.0.1a0-py3.5-macosx-10.6-intel.egg
# Processing dependencies for RankPy==0.0.1a0
# Finished processing dependencies for RankPy==0.0.1a0
# MacBookPro-makmorit-jp:rankpy makmorit$
#
# ```

# %% [markdown]
# ### (2-4) テストデータの準備
#
# <a href="01-SVMRank-outline.ipynb"><b>SVMRank</b></a> の調査で使用したファイルがそのまま使用できるようです。
#
# 任意のフォルダーに配置します。

# %% [markdown]
# ```
# MacBookPro-makmorit-jp:rankpy makmorit$ cd data/MQ2007/Fold1/
# MacBookPro-makmorit-jp:Fold1 makmorit$ pwd
# /Users/makmorit/GitHub/rankpy/data/MQ2007/Fold1
# MacBookPro-makmorit-jp:Fold1 makmorit$ ls -al
# total 24
# drwxr-xr-x  5 makmorit  staff  170 May  3 10:45 .
# drwxr-xr-x  4 makmorit  staff  136 May  3 10:43 ..
# -rwxr-----@ 1 makmorit  staff  124 Jul  3  2002 test.txt
# -rwxr-----@ 1 makmorit  staff  405 Jul  3  2002 train.txt
# -rwxr-----@ 1 makmorit  staff  124 Apr 30 14:41 vali.txt
# MacBookPro-makmorit-jp:Fold1 makmorit$ cat train.txt
# # query 1
# 3 qid:1 1:1 2:1 3:0 4:0.2 5:0
# 2 qid:1 1:0 2:0 3:1 4:0.1 5:1
# 1 qid:1 1:0 2:1 3:0 4:0.4 5:0
# 1 qid:1 1:0 2:0 3:1 4:0.3 5:0
# # query 2
# 1 qid:2 1:0 2:0 3:1 4:0.2 5:0
# 2 qid:2 1:1 2:0 3:1 4:0.4 5:0
# 1 qid:2 1:0 2:0 3:1 4:0.1 5:0
# 1 qid:2 1:0 2:0 3:1 4:0.2 5:0
# # query 3
# 2 qid:3 1:0 2:0 3:1 4:0.1 5:1
# 3 qid:3 1:1 2:1 3:0 4:0.3 5:0
# 4 qid:3 1:1 2:0 3:0 4:0.4 5:1
# 1 qid:3 1:0 2:1 3:1 4:0.5 5:0
# MacBookPro-makmorit-jp:Fold1 makmorit$ cat test.txt
# 4 qid:4 1:1 2:0 3:0 4:0.2 5:1
# 3 qid:4 1:1 2:1 3:0 4:0.3 5:0
# 2 qid:4 1:0 2:0 3:0 4:0.2 5:1
# 1 qid:4 1:0 2:0 3:1 4:0.2 5:0
# MacBookPro-makmorit-jp:Fold1 makmorit$
# ```

# %% [markdown]
# ## (3) サンプルスクリプト実行

# %% [markdown]
# ### (3-1) サンプルスクリプトの準備
#
# 下記のようなスクリプト「run_lambdamart.py」を、こちら (https://bitbucket.org/tunystom/rankpy/src) を参考に作成します。

# %%
# -*- coding: utf-8 -*-

import numpy as np

import logging

from rankpy.queries import Queries
from rankpy.queries import find_constant_features

from rankpy.models import LambdaMART


# Turn on logging.
logging.basicConfig(format='%(asctime)s : %(message)s', level=logging.INFO)

# Load the query datasets.
training_queries = Queries.load_from_text('data/MQ2007/Fold1/train.txt')
validation_queries = Queries.load_from_text('data/MQ2007/Fold1/vali.txt')
test_queries = Queries.load_from_text('data/MQ2007/Fold1/test.txt')

logging.info('================================================================================')

# Save them to binary format ...
training_queries.save('data/MQ2007/Fold1/training')
validation_queries.save('data/MQ2007/Fold1/validation')
test_queries.save('data/MQ2007/Fold1/test')

# ... because loading them will be then faster.
training_queries = Queries.load('data/MQ2007/Fold1/training')
validation_queries = Queries.load('data/MQ2007/Fold1/validation')
test_queries = Queries.load('data/MQ2007/Fold1/test')

logging.info('================================================================================')

# Print basic info about query datasets.
logging.info('Train queries: %s' % training_queries)
logging.info('Valid queries: %s' % validation_queries)
logging.info('Test queries: %s' %test_queries)

logging.info('================================================================================')

# Set this to True in order to remove queries containing all documents
# of the same relevance score -- these are useless for LambdaMART.
remove_useless_queries = False

# Find constant query-document features.
cfs = find_constant_features([training_queries, validation_queries, test_queries])

# Get rid of constant features and (possibly) remove useless queries.
training_queries.adjust(remove_features=cfs, purge=remove_useless_queries)
validation_queries.adjust(remove_features=cfs, purge=remove_useless_queries)
test_queries.adjust(remove_features=cfs)

# Print basic info about query datasets.
logging.info('Train queries: %s' % training_queries)
logging.info('Valid queries: %s' % validation_queries)
logging.info('Test queries: %s' % test_queries)

logging.info('================================================================================')

model = LambdaMART(metric='nDCG@10', max_leaf_nodes=7, shrinkage=0.1,
                   estopping=50, n_jobs=-1, min_samples_leaf=50,
                   random_state=42)

model.fit(training_queries, validation_queries=validation_queries)

logging.info('================================================================================')

logging.info('%s on the test queries: %.8f'
             % (model.metric, model.evaluate(test_queries, n_jobs=-1)))

model.save('LambdaMART_L7_S0.1_E50_' + model.metric)

# %% [markdown]
# ### (3-2) 実行
#
# 残念ながら Cython モジュールの import で失敗してしまいます。
#
# 一通り原因を当たりましたが対処出来ず、試用を中止いたしました。

# %% [markdown]
# ```
# MacBookPro-makmorit-jp:rankpy makmorit$ pwd
# /Users/makmorit/GitHub/rankpy
# MacBookPro-makmorit-jp:rankpy makmorit$ python3 run_lambdamart.py
# Traceback (most recent call last):
#   File "run_lambdamart.py", line 7, in <module>
#     from rankpy.queries import Queries
#   File "/Users/makmorit/GitHub/rankpy/rankpy/__init__.py", line 17, in <module>
#     from rankpy import models, queries, utils
#   File "/Users/makmorit/GitHub/rankpy/rankpy/models/__init__.py", line 23, in <module>
#     from . import users
#   File "/Users/makmorit/GitHub/rankpy/rankpy/models/users/__init__.py", line 22, in <module>
#     from .users_inner import CascadeUserModel
# ImportError: No module named 'rankpy.models.users.users_inner'
# MacBookPro-makmorit-jp:rankpy makmorit$
# MacBookPro-makmorit-jp:rankpy makmorit$ ls -al /Users/makmorit/GitHub/rankpy/rankpy/models/users/
# total 2096
# drwxr-xr-x   8 makmorit  staff      272 May  3 11:13 .
# drwxr-xr-x  11 makmorit  staff      374 May  3 11:07 ..
# -rw-r--r--@  1 makmorit  staff     6148 May  3 11:14 .DS_Store
# -rw-r--r--   1 makmorit  staff     1116 May  3 10:10 __init__.py
# drwxr-xr-x   4 makmorit  staff      136 May  3 11:13 __pycache__
# -rw-r--r--   1 makmorit  staff  1015455 May  3 10:10 users_inner.c
# -rwxr-xr-x   1 makmorit  staff     7896 May  3 10:10 users_inner.pxd
# -rwxr-xr-x   1 makmorit  staff    36673 May  3 10:10 users_inner.pyx <----モジュールは配置されているがimport出来ず
# MacBookPro-makmorit-jp:rankpy makmorit$
#
# ```
